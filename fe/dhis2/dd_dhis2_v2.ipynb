# %% [markdown]
# # DHIS2 Data Download Web API - Central Server V2

# %%
import os
import time
import requests
import pandas as pd

# %%
WD = '/Users/edinhamzic/Symphony/wb_bangladesh/'
os.chdir(WD)
os.getcwd()
# Out:
# '/Users/edinhamzic/Symphony/wb_bangladesh'

# %% [markdown]
# ## Organisation Units
# ### Organisation Unit Levels

# %%
organisationUnitsLevels = 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/26/organisationUnitLevels.json?paging=false'
with requests.Session() as s:
    organisationUnitsLevels_json = s.get(organisationUnitsLevels,auth=('wbbigdata_view', 'DGHS@1234#')).json()
pd.DataFrame.from_dict(organisationUnitsLevels_json['organisationUnitLevels'])
# Out:
#                                  displayName           id
# 0        Community Clinic and Union Level HF  P3xaO9CNrVY
# 1                                    Country  kv8G6cp7G8n
# 2  District and National/Divisional level HF  TY67fOo5ywC
# 3                                   Division  hrLzNYoLILu
# 4                                    Level 7  sVti5YayDAf
# 5                 Union and Upazila level HF  IWh6WrGXOyN
# 6              Upazila and District level HF  WDBz0AfvG8C

# %% [markdown]
# ### Organisation Unit Groups

# %%
organisationUnitGroups = 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/26/organisationUnitGroups.json?paging=false'
with requests.Session() as s:
    organisationUnitGroups_json = s.get(organisationUnitGroups,auth=('wbbigdata_view', 'DGHS@1234#')).json()
organisationUnitGroups_json = pd.DataFrame.from_dict(organisationUnitGroups_json['organisationUnitGroups'])

# %%
geos = {'District and National_Divisional level HF':'3',
        'Union and Upazila level HF': '5',
        'Upazila and District level HF': '4',
        'Upazila':'XpE4AlQZRkV',
        'Upazila Health Complex':'TwFxBSq8iAg',
        'District': 'PyK69cVqr5l',
        'District Hospital_General Hospital':'yiUFzYnD1f9',
        'District NGO & Private Total': 'Uey6NprfqrE',
        'UNICEF-MNHI district': 'PX8DLtPxleW'}
geo_types = {'District and National_Divisional level HF':'LEVEL',
        'Union and Upazila level HF': 'LEVEL',
        'Upazila and District level HF': 'LEVEL',
        'Upazila':'GROUP',
        'Upazila Health Complex':'GROUP',
        'District': 'GROUP',
        'District Hospital_General Hospital':'GROUP',
        'District NGO & Private Total': 'GROUP',
        'UNICEF-MNHI district': 'GROUP'}
print(geos)
print(geo_types)
# Out:
# {'District and National_Divisional level HF': '3', 'Union and Upazila level HF': '5', 'Upazila and District level HF': '4', 'Upazila': 'XpE4AlQZRkV', 'Upazila Health Complex': 'TwFxBSq8iAg', 'District': 'PyK69cVqr5l', 'District Hospital_General Hospital': 'yiUFzYnD1f9', 'District NGO & Private Total': 'Uey6NprfqrE', 'UNICEF-MNHI district': 'PX8DLtPxleW'}
# {'District and National_Divisional level HF': 'LEVEL', 'Union and Upazila level HF': 'LEVEL', 'Upazila and District level HF': 'LEVEL', 'Upazila': 'GROUP', 'Upazila Health Complex': 'GROUP', 'District': 'GROUP', 'District Hospital_General Hospital': 'GROUP', 'District NGO & Private Total': 'GROUP', 'UNICEF-MNHI district': 'GROUP'}

# %%
dhis2_api = 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/resources'
with requests.Session() as s:
    dhis2_api_json = s.get(dhis2_api,auth=('wbbigdata_view', 'DGHS@1234#')).json()
dhis2_api_json
# Out:
# {'resources': [{'displayName': 'Validation Rule Groups',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/validationRuleGroups',
#    'plural': 'validationRuleGroups',
#    'singular': 'validationRuleGroup'},
#   {'displayName': 'Data Element Group Sets',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/dataElementGroupSets',
#    'plural': 'dataElementGroupSets',
#    'singular': 'dataElementGroupSet'},
#   {'displayName': 'Dashboard Items',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/dashboardItems',
#    'plural': 'dashboardItems',
#    'singular': 'dashboardItem'},
#   {'displayName': 'Categories',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/categories',
#    'plural': 'categories',
#    'singular': 'category'},
#   {'displayName': 'Color Sets',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/colorSets',
#    'plural': 'colorSets',
#    'singular': 'colorSet'},
#   {'displayName': 'Program Indicators',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/programIndicators',
#    'plural': 'programIndicators',
#    'singular': 'programIndicator'},
#   {'displayName': 'O Auth2 Clients',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/oAuth2Clients',
#    'plural': 'oAuth2Clients',
#    'singular': 'oAuth2Client'},
#   {'displayName': 'Push Analysis',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/pushAnalysis',
#    'plural': 'pushAnalysis',
#    'singular': 'pushAnalysis'},
#   {'displayName': 'Event Charts',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/eventCharts',
#    'plural': 'eventCharts',
#    'singular': 'eventChart'},
#   {'displayName': 'Program Stages',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/programStages',
#    'plural': 'programStages',
#    'singular': 'programStage'},
#   {'displayName': 'Data Element Operands',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/dataElementOperands',
#    'plural': 'dataElementOperands',
#    'singular': 'dataElementOperand'},
#   {'displayName': 'Program Notification Templates',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/programNotificationTemplates',
#    'plural': 'programNotificationTemplates',
#    'singular': 'programNotificationTemplate'},
#   {'displayName': 'Program Indicator Groups',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/programIndicatorGroups',
#    'plural': 'programIndicatorGroups',
#    'singular': 'programIndicatorGroup'},
#   {'displayName': 'Message Conversations',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/messageConversations',
#    'plural': 'messageConversations',
#    'singular': 'messageConversation'},
#   {'displayName': 'Attributes',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/attributes',
#    'plural': 'attributes',
#    'singular': 'attribute'},
#   {'displayName': 'Data Approval Levels',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/dataApprovalLevels',
#    'plural': 'dataApprovalLevels',
#    'singular': 'dataApprovalLevel'},
#   {'displayName': 'Organisation Units',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/organisationUnits',
#    'plural': 'organisationUnits',
#    'singular': 'organisationUnit'},
#   {'displayName': 'Maps',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/maps',
#    'plural': 'maps',
#    'singular': 'map'},
#   {'displayName': 'Option Sets',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/optionSets',
#    'plural': 'optionSets',
#    'singular': 'optionSet'},
#   {'displayName': 'Category Combos',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/categoryCombos',
#    'plural': 'categoryCombos',
#    'singular': 'categoryCombo'},
#   {'displayName': 'Data Sets',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/dataSets',
#    'plural': 'dataSets',
#    'singular': 'dataSet'},
#   {'displayName': 'Validation Notification Templates',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/validationNotificationTemplates',
#    'plural': 'validationNotificationTemplates',
#    'singular': 'validationNotificationTemplate'},
#   {'displayName': 'Program Data Elements',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/programDataElements',
#    'plural': 'programDataElements',
#    'singular': 'programDataElement'},
#   {'displayName': 'Program Tracked Entity Attribute Groups',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/programTrackedEntityAttributeGroups',
#    'plural': 'programTrackedEntityAttributeGroups',
#    'singular': 'programTrackedEntityAttributeGroup'},
#   {'displayName': 'Program Sections',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/programSections',
#    'plural': 'programSections',
#    'singular': 'programSection'},
#   {'displayName': 'Indicator Group Sets',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/indicatorGroupSets',
#    'plural': 'indicatorGroupSets',
#    'singular': 'indicatorGroupSet'},
#   {'displayName': 'Validation Rules',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/validationRules',
#    'plural': 'validationRules',
#    'singular': 'validationRule'},
#   {'displayName': 'External File Resources',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/externalFileResources',
#    'plural': 'externalFileResources',
#    'singular': 'externalFileResource'},
#   {'displayName': 'File Resources',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/fileResources',
#    'plural': 'fileResources',
#    'singular': 'fileResource'},
#   {'displayName': 'Indicator Types',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/indicatorTypes',
#    'plural': 'indicatorTypes',
#    'singular': 'indicatorType'},
#   {'displayName': 'Program Rules',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/programRules',
#    'plural': 'programRules',
#    'singular': 'programRule'},
#   {'displayName': 'Map Views',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/mapViews',
#    'plural': 'mapViews',
#    'singular': 'mapView'},
#   {'displayName': 'Relationship Types',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/relationshipTypes',
#    'plural': 'relationshipTypes',
#    'singular': 'relationshipType'},
#   {'displayName': 'Legend Sets',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/legendSets',
#    'plural': 'legendSets',
#    'singular': 'legendSet'},
#   {'displayName': 'Category Option Group Sets',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/categoryOptionGroupSets',
#    'plural': 'categoryOptionGroupSets',
#    'singular': 'categoryOptionGroupSet'},
#   {'displayName': 'Analytics Table Hooks',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/analyticsTableHooks',
#    'plural': 'analyticsTableHooks',
#    'singular': 'analyticsTableHook'},
#   {'displayName': 'External Map Layers',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/externalMapLayers',
#    'plural': 'externalMapLayers',
#    'singular': 'externalMapLayer'},
#   {'displayName': 'Documents',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/documents',
#    'plural': 'documents',
#    'singular': 'document'},
#   {'displayName': 'Category Option Groups',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/categoryOptionGroups',
#    'plural': 'categoryOptionGroups',
#    'singular': 'categoryOptionGroup'},
#   {'displayName': 'Users',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/users',
#    'plural': 'users',
#    'singular': 'user'},
#   {'displayName': 'Organisation Unit Groups',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/organisationUnitGroups',
#    'plural': 'organisationUnitGroups',
#    'singular': 'organisationUnitGroup'},
#   {'displayName': 'Min Max Data Elements',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/minMaxDataElements',
#    'plural': 'minMaxDataElements',
#    'singular': 'minMaxDataElement'},
#   {'displayName': 'Constants',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/constants',
#    'plural': 'constants',
#    'singular': 'constant'},
#   {'displayName': 'Sql Views',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/sqlViews',
#    'plural': 'sqlViews',
#    'singular': 'sqlView'},
#   {'displayName': 'Option Group Sets',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/optionGroupSets',
#    'plural': 'optionGroupSets',
#    'singular': 'optionGroupSet'},
#   {'displayName': 'Tracked Entity Instances',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/trackedEntityInstances',
#    'plural': 'trackedEntityInstances',
#    'singular': 'trackedEntityInstance'},
#   {'displayName': 'Option Groups',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/optionGroups',
#    'plural': 'optionGroups',
#    'singular': 'optionGroup'},
#   {'displayName': 'Charts',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/charts',
#    'plural': 'charts',
#    'singular': 'chart'},
#   {'displayName': 'Data Set Notification Templates',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/dataSetNotificationTemplates',
#    'plural': 'dataSetNotificationTemplates',
#    'singular': 'dataSetNotificationTemplate'},
#   {'displayName': 'User Groups',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/userGroups',
#    'plural': 'userGroups',
#    'singular': 'userGroup'},
#   {'displayName': 'Indicator Groups',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/indicatorGroups',
#    'plural': 'indicatorGroups',
#    'singular': 'indicatorGroup'},
#   {'displayName': 'Data Approval Workflows',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/dataApprovalWorkflows',
#    'plural': 'dataApprovalWorkflows',
#    'singular': 'dataApprovalWorkflow'},
#   {'displayName': 'Validation Results',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/validationResults',
#    'plural': 'validationResults',
#    'singular': 'validationResult'},
#   {'displayName': 'Metadata Versions',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/metadata/version',
#    'plural': 'metadataVersions',
#    'singular': 'metadataVersion'},
#   {'displayName': 'Report Tables',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/reportTables',
#    'plural': 'reportTables',
#    'singular': 'reportTable'},
#   {'displayName': 'Tracked Entity Types',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/trackedEntityTypes',
#    'plural': 'trackedEntityTypes',
#    'singular': 'trackedEntityType'},
#   {'displayName': 'Data Entry Forms',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/dataEntryForms',
#    'plural': 'dataEntryForms',
#    'singular': 'dataEntryForm'},
#   {'displayName': 'Predictors',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/predictors',
#    'plural': 'predictors',
#    'singular': 'predictor'},
#   {'displayName': 'Data Element Groups',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/dataElementGroups',
#    'plural': 'dataElementGroups',
#    'singular': 'dataElementGroup'},
#   {'displayName': 'Reports',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/reports',
#    'plural': 'reports',
#    'singular': 'report'},
#   {'displayName': 'Program Stage Sections',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/programStageSections',
#    'plural': 'programStageSections',
#    'singular': 'programStageSection'},
#   {'displayName': 'Sections',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/sections',
#    'plural': 'sections',
#    'singular': 'section'},
#   {'displayName': 'Options',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/options',
#    'plural': 'options',
#    'singular': 'option'},
#   {'displayName': 'Job Configurations',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/jobConfigurations',
#    'plural': 'jobConfigurations',
#    'singular': 'jobConfiguration'},
#   {'displayName': 'Tracked Entity Attributes',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/trackedEntityAttributes',
#    'plural': 'trackedEntityAttributes',
#    'singular': 'trackedEntityAttribute'},
#   {'displayName': 'Data Elements',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/dataElements',
#    'plural': 'dataElements',
#    'singular': 'dataElement'},
#   {'displayName': 'User Roles',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/userRoles',
#    'plural': 'userRoles',
#    'singular': 'userRole'},
#   {'displayName': 'Program Rule Variables',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/programRuleVariables',
#    'plural': 'programRuleVariables',
#    'singular': 'programRuleVariable'},
#   {'displayName': 'Category Options',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/categoryOptions',
#    'plural': 'categoryOptions',
#    'singular': 'categoryOption'},
#   {'displayName': 'Program Rule Actions',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/programRuleActions',
#    'plural': 'programRuleActions',
#    'singular': 'programRuleAction'},
#   {'displayName': 'Organisation Unit Group Sets',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/organisationUnitGroupSets',
#    'plural': 'organisationUnitGroupSets',
#    'singular': 'organisationUnitGroupSet'},
#   {'displayName': 'Interpretations',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/interpretations',
#    'plural': 'interpretations',
#    'singular': 'interpretation'},
#   {'displayName': 'Event Reports',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/eventReports',
#    'plural': 'eventReports',
#    'singular': 'eventReport'},
#   {'displayName': 'Indicators',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/indicators',
#    'plural': 'indicators',
#    'singular': 'indicator'},
#   {'displayName': 'Sms Commands',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/smsCommands',
#    'plural': 'smsCommands',
#    'singular': 'smsCommand'},
#   {'displayName': 'Organisation Unit Levels',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/organisationUnitLevels',
#    'plural': 'organisationUnitLevels',
#    'singular': 'organisationUnitLevel'},
#   {'displayName': 'Programs',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/programs',
#    'plural': 'programs',
#    'singular': 'program'},
#   {'displayName': 'Dashboards',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/dashboards',
#    'plural': 'dashboards',
#    'singular': 'dashboard'},
#   {'displayName': 'Category Option Combos',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/categoryOptionCombos',
#    'plural': 'categoryOptionCombos',
#    'singular': 'categoryOptionCombo'}]}

# %% [markdown]
# ## Predefined Data Elements

# %%
dataElementGroups = 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/26/dataElementGroups'
with requests.Session() as s:
    dataElementGroups_json = s.get(dataElementGroups,auth=('wbbigdata_view', 'DGHS@1234#')).json()

# %%
pd.DataFrame(dataElementGroups_json['dataElementGroups']).iloc[0:10]
# Out:
#                             displayName           id
# 0  01. EPI Report (Routine vaccination)  o8p6P5eLyDZ
# 1                 02. EPI Upazila Stock  YVD3pxIrl9M
# 2                03. EPI District Stock  lsKz7YoTeAA
# 3          04. EPI District Requisition  W7RaJnzf3Id
# 4               05. EPI District Supply  sD0LRbRVX7I
# 5                06. EPI Upazila Supply  ZFVpdQk8RQh
# 6                             07. EmONC  FZJWJUJ1nyM
# 7                              08. IMCI  bm68OgySJMb
# 8                09. Adolescent Health   eep3tXrAYAh
# 9                               10. KMC  niipJz6kBoU

# %%
data_elements = {'01. EPI Report (Routine vaccination)':'o8p6P5eLyDZ',
                 '02. EPI Upazila Stock': 'YVD3pxIrl9M',
                 '03. EPI District Stock': 'lsKz7YoTeAA',
                 '04. EPI District Requisition': 'W7RaJnzf3Id',
                 '05. EPI District Supply': 'sD0LRbRVX7I',
                 '06. EPI Upazila Supply': 'ZFVpdQk8RQh',
                 '09. Adolescent Health': 'eep3tXrAYAh',
                 '10. KMC': 'niipJz6kBoU',
                 '11. EMEN (MBFFI)': 'i7msFlsuJRz'
                }
data_elements
# Out:
# {'01. EPI Report (Routine vaccination)': 'o8p6P5eLyDZ',
#  '02. EPI Upazila Stock': 'YVD3pxIrl9M',
#  '03. EPI District Stock': 'lsKz7YoTeAA',
#  '04. EPI District Requisition': 'W7RaJnzf3Id',
#  '05. EPI District Supply': 'sD0LRbRVX7I',
#  '06. EPI Upazila Supply': 'ZFVpdQk8RQh',
#  '09. Adolescent Health': 'eep3tXrAYAh',
#  '10. KMC': 'niipJz6kBoU',
#  '11. EMEN (MBFFI)': 'i7msFlsuJRz'}

# %%
data_element_names = {'o8p6P5eLyDZ': '01. EPI Report (Routine vaccination)',
                      'YVD3pxIrl9M': '02. EPI Upazila Stock',
                      'lsKz7YoTeAA': '03. EPI District Stock',
                      'W7RaJnzf3Id': '04. EPI District Requisition',
                      'sD0LRbRVX7I': '05. EPI District Supply',
                      'ZFVpdQk8RQh': '06. EPI Upazila Supply',
                      'eep3tXrAYAh': '09. Adolescent Health',
                      'niipJz6kBoU': '10. KMC',
                      'i7msFlsuJRz': '11. EMEN (MBFFI)'
                     }
data_element_names
# Out:
# {'W7RaJnzf3Id': '04. EPI District Requisition',
#  'YVD3pxIrl9M': '02. EPI Upazila Stock',
#  'ZFVpdQk8RQh': '06. EPI Upazila Supply',
#  'eep3tXrAYAh': '09. Adolescent Health',
#  'i7msFlsuJRz': '11. EMEN (MBFFI)',
#  'lsKz7YoTeAA': '03. EPI District Stock',
#  'niipJz6kBoU': '10. KMC',
#  'o8p6P5eLyDZ': '01. EPI Report (Routine vaccination)',
#  'sD0LRbRVX7I': '05. EPI District Supply'}

# %% [markdown]
# ## Time Periods

# %%
years = {'2009':2009, '2010':2010, '2011':2011, '2012':2012,
         '2013':2013, '2014':2014, '2015':2015, '2016':2016,
         '2017':2017, '2018':2018,

        }
years
# Out:
# {'2009': 2009,
#  '2010': 2010,
#  '2011': 2011,
#  '2012': 2012,
#  '2013': 2013,
#  '2014': 2014,
#  '2015': 2015,
#  '2016': 2016,
#  '2017': 2017,
#  '2018': 2018}

# %% [markdown]
# ## Building the API queries

# %% [markdown]
# ## Functions

# %%
def extract_dataElementVariables(data_elements, pause_length):
    data_elements_dict = {}
    for element_name, element_id in data_elements.items():
        url_main = 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/26/dataElementGroups/'
        url = url_main + element_id
        print(url)
        with requests.Session() as s:
            tmp = s.get(url, auth=('wbbigdata_view', 'DGHS@1234#')).json()['dataElements']
        tmp = pd.DataFrame.from_dict(tmp)
        tmp_out = [variable_id for variable_id in tmp.iloc[:,0]]
        length_tmp = len(tmp_out)
        tmp = (';').join(tmp_out) 
        data_elements_dict[element_id] = tmp
        del(tmp, tmp_out)
        print(length_tmp)
        print(data_elements_dict[element_id])
        time.sleep(pause_length)
    return data_elements_dict

def create_api_queries(variables, dataElements_names, period, geos, geo_types):
    api_queries = {}
    for element_item, element_value in variables.items():
        for year_item, year_value in period.items():
            for geo_item, geo_value in geos.items():
                dhis_main = 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?'
                dataElementGroups_variables= f'dimension=dx:{element_value}'
                geo_variables = f'&dimension=ou:OU_{geo_types[geo_item]}-{geo_value};'
                time_variables = f'dNLjKwsVjod&filter=pe:{year_item};LAST_12_MONTHS&displayProperty=NAME&outputIdScheme='
                url = dhis_main + dataElementGroups_variables + geo_variables + time_variables
                file_name = dataElements_names[element_item] + '_' + year_item + '_' + geo_item
                file_name = file_name.replace(" ", "").replace(".", "")
                api_queries[file_name] = url
    return api_queries

def data_download(api_queries, pause_length, dest_dir):
    for file_name, api_query in api_queries.items():
        print(f"Starting the process for {file_name} files: with geo codes and names respectively")
        print(f"Constructing file path for {file_name} file")
        file_with_codes = os.path.join(dest_dir, file_name + '_CODE' + '.csv') 
        file_with_names = os.path.join(dest_dir, file_name + '_NAME' + '.csv') 
        if file_name + '_CODE' + '.csv' in os.listdir(dest_dir):
            print(f"{file_name} file already downloaded")
        else:
            with requests.Session() as s:
                print(f"Getting API query for {file_with_codes} file")
                data_codes = s.get(api_query + 'CODE', auth=('wbbigdata_view', 'DGHS@1234#'),stream=True)
                with open(file_with_codes, 'wb') as f:
                    print(file_with_codes)
                    print(f"Writing in chunks {file_with_codes} file")
                    for chunk in data_codes.iter_content(chunk_size=1024):
                        if chunk:
                            f.write(chunk)
                print(f"Pausing the process for {pause_length} seconds")
                time.sleep(pause_length)
        if file_name + '_NAME' + '.csv' in os.listdir(dest_dir):
            print(f"{file_name} file already downloaded")
        else:
            with requests.Session() as s:
                print(f"Restarting the process for {file_with_names} file")
                data_names = s.get(api_query + 'NAME', auth=('wbbigdata_view', 'DGHS@1234#'),stream=True)
                with open(file_with_names, 'wb') as f:
                    print(f"Writing in chunks {file_with_names} file")
                    for chunk in data_names.iter_content(chunk_size=1024):
                        if chunk:
                            f.write(chunk)
            print(f"Pausing the process for {pause_length} seconds")
            time.sleep(pause_length)

# %%
data_element_variables_list = extract_dataElementVariables(data_elements=data_elements, pause_length=30)
# Out:
# https://centraldhis.mohfw.gov.bd/dhismohfw/api/26/dataElementGroups/o8p6P5eLyDZ
# 47
# wLP0rrjuZhi;sheiuFeL5re;hAfIn6KK9la;cqtZ9bBPXyp;OS8FHo7DST0;jl2jEVv3D55;VaBLE2Oz1jf;N9NTA88xoba;nbQTnNFs1I8;wZXwYXgTykD;C93vSemlmPr;A6sJKceysXy;CVWtvuChnN4;YkajaYobus9;TzbgFs3CSyp;Na5rrDNtwOW;zGQIRoCQIcK;DtpRyAA9wzE;qMZseedjTs2;E6AiAnkch0X;muSBpGa5y5l;IbUOS7h4vas;NuyUsmhoaVC;foSKZmdiKvO;HDzRDBWv2O5;MdUHc12UQlq;MWNswykuV4i;Ypclb3YAk8s;Skwid1Sa4Qm;AgfjXpHFl7j;HCGy8hSQrrn;Pyz7rlAmMZ4;xdzFff7DZuQ;ngTaipbJCrH;izqdLEayxtk;Y5nylfVJpHj;AFIo5tpZjyr;e3ZZIBX8HvL;iXgQr1TzpZ3;eYJ3MgWzghH;aO26dRReDw1;WMO4fDbBBsN;nNTNsd237Zf;GoIHz80UERt;RYtOwMY20z9;y18L7Mx36gU;m8CuUsmmV5o
# https://centraldhis.mohfw.gov.bd/dhismohfw/api/26/dataElementGroups/YVD3pxIrl9M
# 110
# kpkNrzQTYkG;esdiLuANYzJ;gCFmCwtKtG9;wyYeZ43DyVh;Pmkei3034T3;gkVkv3ffz5v;Lk7r5xTYGJ5;TW5OuZHpb6D;mSRPxSz7mpC;XNiO6llG6XA;tfs4ubhi7aS;wl7rSTXZnYH;Ya0KM6n2lnV;lGxUawh9Rgq;nYixxLPGLKg;Z1LFCojJ3oU;CSmnrn14bzc;Gf6lEllg2nM;F7SY1nlzxsh;SeHc7pKhNZ3;bsS9xrHNN7k;zpxBh06iewG;jeJ3ZSbbg2z;YmH96Ob0NBP;ENYJhlIJkdD;OM8Cr8d7NOm;lXY1Qn1Xmym;CMuwZf2vDD3;aiQep6Y8DiC;bZlOe4y8Mh5;tVMfryQtVPM;D6DrcyNPJRe;cLca60N5Sz5;FHj891Dd9IO;nAHhMwgUTIC;xej1sxYYCYM;eb3ByhaTJPc;XcI4Wjp5L7i;CdbqCEN6J1I;iWNq47wSHeH;KrtijNiVXQd;LfeSJhYeM50;kTqSo5SnlBi;F6DqE5xpTOZ;Xi0rEcM2dnU;j9BXR3fcgBU;avwgDjGy5QN;gANxnvWKSYw;HwX8sJbFytZ;hveFMwiLEd6;GsVpkzuOvvr;iHhFjeFaUE2;oHx6fAhrdRw;JTzAgZJknnZ;F6Sj0Nemixl;qC35JBYiNvW;hTPF3SgOJWH;faixFpbou4s;ohB37t76b2c;S7WmD2KXggR;KUD3k3ABNzE;tJmmzGcJpAJ;lzDaUMzu2sB;mxdYJga4Oj9;sk1epOoCbSF;gxlRbfWMpVx;YRp9K1grg0T;bWQSZuLmC4h;sthqDXmS4Nm;eNTRf5caxYa;mkS9tKtFJwg;L2LsEE6nsv0;He5rkYQTRXc;f6Klhc8cltP;WsDcPVFfFdD;jSXbWOsbeVM;Gl0BEtUdHIo;HH3mbuLQ3Fy;snj7yyk7H6r;CCYijZzjjn0;CzNDOBhTozp;iJaOVK1TYbc;W9TGbZMjS1N;ViTJ0SouxHk;GLsAX7CoejC;ejwMhgWnnjp;zi1A9mHfQnC;PsvlF5jSgI3;uCak0uhIKX5;HgCvJyeV8s1;bUhksJVFOU1;XdBa916vNo2;zpF9PXuVzFb;oFuUltZt2kL;hDbw2Z8FinI;lnJZ8U8fAps;L3D8zpb45fV;iPOIupRRbet;vg24BsDISHx;qRf4BEqDWEO;GMuJ1q2PFFJ;SxNM9MR02Fq;ildWGF3ceBO;aK1cbe954yX;VExs9bwa6Mb;uv5CVs53ise;CcyZexM0LpH;seXaR7uNRXJ;QUvmRKu2SHI;xhXpgEsWEv9
# https://centraldhis.mohfw.gov.bd/dhismohfw/api/26/dataElementGroups
U0snvp;g70CSZhH7ec;OJAiCHgnDy2;sSaXwOXAqKS;C6XPQlHjT9K;DeGy5sFskzI;PQh0RHCSh9B;mwwdkWaQqR3;T7NYaNJhm78;WTKfuGFbwGE;rYwjOBXsRLZ;AD0MAkqsyd7;nhHbyc1U8Ao;eUofaPpbkoE;fFyheAB6oEs;qaMoHUVnx0O;v3dzwfFSDax;qkIUftZfvgo;wHkAwjlOE8G;S7kAtkuuRTo;gnYQi7md6ZP;wtZzbPS0ZpB;NwpZ2t6mDUJ;eZEhI9BuIfL;YYnhZK1INXh;aVCwLrb6c1p;TFMhdPWFd5k;QahPBFm8A8A;EbQ7aPlO9Pi;XlFKbfzmmp3;bByilAkcQAB;Fxr7xAQKgxN;IdG4fXKoTAa;xGW7HlYRwX9;heKhPchG71P;kui5fVw8OHR;kRxQDoxg4rd;ESw7avyxKh6;xTPx6p2kDx5;kXJplDhwFuG;nvxvBnWHhei;OWlaSUBeeRW;tA2gl7Cyu2E'}

# %%
len(data_element_variables_list)
# Out:
# 9

# %% [markdown]
# ### Periods

# %%
years
# Out:
# {'2009': 2009,
#  '2010': 2010,
#  '2011': 2011,
#  '2012': 2012,
#  '2013': 2013,
#  '2014': 2014,
#  '2015': 2015,
#  '2016': 2016,
#  '2017': 2017,
#  '2018': 2018}

# %% [markdown]
# ### Geos

# %%
geos
# Out:
# {'District': 'PyK69cVqr5l',
#  'District Hospital_General Hospital': 'yiUFzYnD1f9',
#  'District NGO & Private Total': 'Uey6NprfqrE',
#  'District and National_Divisional level HF': '3',
#  'UNICEF-MNHI district': 'PX8DLtPxleW',
#  'Union and Upazila level HF': '5',
#  'Upazila': 'XpE4AlQZRkV',
#  'Upazila Health Complex': 'TwFxBSq8iAg',
#  'Upazila and District level HF': '4'}

# %% [markdown]
# ### Geo Types

# %%
geo_types
# Out:
# {'District': 'GROUP',
#  'District Hospital_General Hospital': 'GROUP',
#  'District NGO & Private Total': 'GROUP',
#  'District and National_Divisional level HF': 'LEVEL',
#  'UNICEF-MNHI district': 'GROUP',
#  'Union and Upazila level HF': 'LEVEL',
#  'Upazila': 'GROUP',
#  'Upazila Health Complex': 'GROUP',
#  'Upazila and District level HF': 'LEVEL'}

# %% [markdown]
# ### Downloading data

# %%
data_element_names
# Out:
# {'W7RaJnzf3Id': '04. EPI District Requisition',
#  'YVD3pxIrl9M': '02. EPI Upazila Stock',
#  'ZFVpdQk8RQh': '06. EPI Upazila Supply',
#  'eep3tXrAYAh': '09. Adolescent Health',
#  'i7msFlsuJRz': '11. EMEN (MBFFI)',
#  'lsKz7YoTeAA': '03. EPI District Stock',
#  'niipJz6kBoU': '10. KMC',
#  'o8p6P5eLyDZ': '01. EPI Report (Routine vaccination)',
#  'sD0LRbRVX7I': '05. EPI District Supply'}

# %%
dghis_queries = create_api_queries(variables=data_element_variables_list,
                                   dataElements_names=data_element_names, 
                                   period=years, 
                                   geos=geos, 
                                   geo_types=geo_types)

# %%
dghis_queries
# Out:
# {'01EPIReport(Routinevaccination)_2009_District': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:wLP0rrjuZhi;sheiuFeL5re;hAfIn6KK9la;cqtZ9bBPXyp;OS8FHo7DST0;jl2jEVv3D55;VaBLE2Oz1jf;N9NTA88xoba;nbQTnNFs1I8;wZXwYXgTykD;C93vSemlmPr;A6sJKceysXy;CVWtvuChnN4;YkajaYobus9;TzbgFs3CSyp;Na5rrDNtwOW;zGQIRoCQIcK;DtpRyAA9wzE;qMZseedjTs2;E6AiAnkch0X;muSBpGa5y5l;IbUOS7h4vas;NuyUsmhoaVC;foSKZmdiKvO;HDzRDBWv2O5;MdUHc12UQlq;MWNswykuV4i;Ypclb3YAk8s;Skwid1Sa4Qm;AgfjXpHFl7j;HCGy8hSQrrn;Pyz7rlAmMZ4;xdzFff7DZuQ;ngTaipbJCrH;izqdLEayxtk;Y5nylfVJpHj;AFIo5tpZjyr;e3ZZIBX8HvL;iXgQr1TzpZ3;eYJ3MgWzghH;aO26dRReDw1;WMO4fDbBBsN;nNTNsd237Zf;GoIHz80UERt;RYtOwMY20z9;y18L7Mx36gU;m8CuUsmmV5o&dimension=ou:OU_GROUP-PyK69cVqr5l;dNLjKwsVjod&filter=pe:2009;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  '01EPIReport(Routinevaccination)_
GTFCE7wy;DluAR5bBgRS;mCxbDcAGOgu;HmhcJzqjjAy;HRsGzjZ50Sy;rsWfwiRoI1y;zpWJXw2iwMr;GW6NR7b0Jn5;kwH34qQEGNe;DsKLoeFOo5s;cIgnSCyTsD4;fETzFyk0L4v;xiBm1dF4cMz;lVwvLd0GAP3;R14scGNyutk;yjuOWGwYmqc;VZA2xZvl0X5;eC5kD3Zy19T;reiXmfEmly3;NZlZ49U6SjN;ef0DNqKwhSC;ew7rcDGbAJG;TcLYWe9quMK;dqWONERQ49X;zfH93frNrj6;olXUCkZ7oUM;Z7Auvk7R12c;MFiuOXgcblM;que9GdwI0zB;sJ74iV0Q4AA;mXMEeRyNVvu;k3nn0MjnBYN;fHemCItaWHF;ScXHMiqi29p;sGd394ZSpOo&dimension=ou:OU_LEVEL-4;dNLjKwsVjod&filter=pe:2018;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme='}

# %%
len(dghis_queries)
# Out:
# 810

# %%
data_download(api_queries=dghis_queries, pause_length=30, dest_dir='data/dhis2/data_3')
# Out:
# Starting the process for 01EPIReport(Routinevaccination)_2009_DistrictandNational_DivisionallevelHF files: with geo codes and names respectively
# Constructing file path for 01EPIReport(Routinevaccination)_2009_DistrictandNational_DivisionallevelHF file
# 01EPIReport(Routinevaccination)_2009_DistrictandNational_DivisionallevelHF file already downloaded
# 01EPIReport(Routinevaccination)_2009_DistrictandNational_DivisionallevelHF file already downloaded
# Starting the process for 01EPIReport(Routinevaccination)_2009_UnionandUpazilalevelHF files: with geo codes and names respectively
# Constructing file path for 01EPIReport(Routinevaccination)_2009_UnionandUpazilalevelHF file
# 01EPIReport(Routinevaccination)_2009_UnionandUpazilalevelHF file already downloaded
# Restarting the process for data/dhis2/data_3/01EPIReport(Routinevaccination)_2009_UnionandUpazilalevelHF_NAME.csv file
# Writing in chunks data/dhis2/data_3/01EPIReport(Routinevaccination)_2009_UnionandUpazilalevelHF_NAME.csv file
# Pausing the process for 30 seconds
# Starting the process for 01EPIReport(Routinevaccination)_2009_UpazilaandDistrictlevelHF files: with geo codes and names respectively
# Constructing file path for 01EPIReport(Routinevaccination)_2009_UpazilaandDistrictlevelHF file
# Getting API query for data/dhis2/data_3/01EPIReport(Routinevaccination)_2009_UpazilaandDistrictlevelHF_CODE.csv file
# data/dhis2/data_3/01EPIReport(Routinevaccination)_2009_UpazilaandDistrictlevelHF_CODE.csv
# Writing in chunks data/dhis2/data_3/01EPIReport(Routinevaccination)_2009_UpazilaandDistrictlevelHF_CODE.csv file
# Pausing the process for 30 seconds
# Restarting the process for data/dhis2/data_3/01EPIReport(Routinevaccination)_2009_UpazilaandDistrictlevelHF_NAME.csv file
# Writing in chunks data/dhis2/data_3/01EPIReport(Routinevaccination)_2009_UpazilaandDistrictlevelHF_NAME.csv file
# Pausing the process for 30 seconds
# Starting the process for 01EPIReport(Routinevaccination)_2009_Upazila files: with geo codes and names respectively
# Constructing file path for 01EPIReport(Routinevaccination)_2009_Upazila file
# Getting API query for data/dhis2/data_3/01EPIReport(Routinevaccination)_2009_Upazila_CODE.csv file
# data/dhis2/data_3/01EPIReport(Routinevaccination)_2009_Upazila_CODE.csv
# Writing in chunks data/dhis2/data_3/01EPIReport(Routinevaccination)_2009_Upazila_CODE.csv file
# Pausing the process for 30 seconds
# Restarting the process for data/dhis2/data_3/01EPIReport(Routinevaccination)_2009_Upazila_NAME.csv file
# Writing in chunks data/dhis2/data_3/01EPIReport(Routinevaccination)_2009_Upazila_NAME.csv file
# Pausing the process for 30 seconds
# Starting the process for 01EPIReport(Routinevaccination)_2009_UpazilaHealthComplex files: with geo codes and names respectively
# Constructing file path for 01EPIReport(Routinevaccination)_2009_UpazilaHealthComplex file
# Getting API query for data/dhis2/data_3/01EPIReport(Routinevaccination)_2009_UpazilaHealthComplex_CODE.csv file
# data/dhis2/data_3/01EPIReport(Routinevaccination)_2009_UpazilaHealthComplex_CODE.csv
# Writing in chunks data/dhis2/data_3/01EPIReport(Routinevaccination)_2009_UpazilaHealthComplex_CODE.csv file
# Pausing the process for 30 seconds
# Restarting the process for data/dhis2/data_3/01EPIReport(Routinevaccination)_2009_UpazilaHealthComplex_NAME.csv file
# Writing in chunks data/dhis2/data_3/01EPIReport(Routinevaccination)_2009_UpazilaHealthComplex_NAME.csv file
# Pausing the process for 30 seconds
# Starting the process for 01EPIReport(Routinevaccination)_2009_District files: with geo codes and names respectively
# Constructing file path for 01EPIReport(Routinevaccination)_2009_District file
# Getting API query for data/dhis2/data_3/01EPIReport(Routinevaccination)_2009_District_CODE.csv file
# data/dhis2/data_3/01EPIReport(Routinevaccination)_2009_District_CODE.csv
# Writing in chunks data/dhis2/data_3/01EPIReport(Routinevaccination)_2009_District_CODE.csv file
# Pausing the process for 30 seconds
# Restarting the process for data/dhis2/data_3/01EPIReport(Routinevaccination)_2009_District_NAME.csv file
# Writing in chunks data/dhis2/data_3/01EPIReport(Routinevaccination)_2009_District_NAME.csv file
# Pausing the process for 30 seconds
# Starting the process for 01EPIReport(Routinevaccination)_2009_DistrictHospital_GeneralHospital files: with geo codes and names respectively
# Constructing file path for 01EPIReport(Routinevaccination)_2009_DistrictHospital_GeneralHospital file
# Getting API query for data/dhis2/data_3/01EPIReport(Routinevaccination)_2009_DistrictHospital_GeneralHospital_CODE.csv file
# data/dhis2/data_3/01EPIReport(Routinevaccination)_2009_DistrictHospital_GeneralHospital_CODE.csv
# Writing in chunks data/dhis2/data_3/01EPIReport(Routinevaccination)_2009_DistrictHospital_GeneralHospital_CODE.csv file
# Pausing the process for 30 seconds
# Restarting the process for data/dhis2/data_3/01EPIReport(Routinevaccination)_2009_DistrictHospital_GeneralHospital_NAME.csv file
# Writing in chunks data/dhis2/data_3/01EPIReport(Routinevaccination)_2009_DistrictHospital_GeneralHospital_NAME.csv file
# Pausing the process for 30 seconds
# Starting the process for 01EPIReport(Routinevaccination)_2009_DistrictNGO&PrivateTotal files: with geo codes and names respectively
# Constructing file path for 01EPIReport(Routinevaccination)_2009_DistrictNGO&PrivateTotal file
# Getting API query for data/dhis2/data_3/01EPIReport(Routinevaccination)_2009_DistrictNGO&PrivateTotal_CODE.csv file
# data/dhis2/data_3/01EPIReport(Routinevaccination)_2009_DistrictNGO&PrivateTotal_CODE.csv
# Writing in chunks data/dhis2/data_3/01EPIReport(Routinevaccination)_2009_DistrictNGO&PrivateTotal_CODE.csv file
# Pausing the process for 30 seconds
# Restarting the process for data/dhis2/data_3/01EPIReport(Routinevaccination)_2009_DistrictNGO&PrivateTotal_NAME.csv file
# Writing in chunks data/dhis2/data_3/01EPIReport(Routinevaccination)_2009_DistrictNGO&PrivateTotal_NAME.csv file
# Pausing the process for 30 seconds
# Starting the process for 01EPIReport(Routinevaccination)_2009_UNICEF-MNHIdistrict files: with geo codes and names respectively
# Constructing file path for 01EPIReport(Routinevaccination)_2009_UNICEF-MNHIdistrict file
# Getting API query for data/dhis2/data_3/01EPIReport(Routinevaccination)_2009_UNICEF-MNHIdistrict_CODE.csv file
# data/dhis2/data_3/01EPIReport(Routinevaccination)_2009_UNICEF-MNHIdistrict_CODE.csv
# Writing in chunks data/dhis2/data_3/01EPIReport(Routinevaccination)_2009_UNICEF-MNHIdistrict_CODE.csv file
# Pausing the process for 30 seconds
# Restarting the process for data/dhis2/data_3/01EPIReport(Routinevaccination)_2009_UNICEF-MNHIdistrict_NAME.csv file
# Writing in chunks data/dhis2/data_3/01EPIReport(Routinevaccination)_2009_UNICEF-MNHIdistrict_NAME.csv file
# Pausing the process for 30 seconds
# Starting the process for 01EPIReport(Routinevaccination)_2010_DistrictandNational_DivisionallevelHF files: with geo codes and names respectively
# Constructing file path for 01EPIReport(Routinevaccination)_2010_DistrictandNational_DivisionallevelHF file
# Getting API query for data/dhis2/data_3/01EPIReport(Routinevaccination)_2010_DistrictandNational_DivisionallevelHF_CODE.csv file
# data/dhis2/data_3/01EPIReport(Routinevaccination)_2010_DistrictandNational_DivisionallevelHF_CODE.csv
# Writing in chunks data/dhis2/data_3/01EPIReport(Routinevaccination)_2010_DistrictandNational_DivisionallevelHF_CODE.csv file
# Pausing the process for 30 seconds
# Restarting the process for data/dhis2/data_3/01EPIReport(Routinevaccination)_2010_DistrictandNational_DivisionallevelHF_NAME.csv file
# Writing in chunks data/dhis2/data_3/01EPIReport(Routinevaccination)_2010_DistrictandNational_DivisionallevelHF_NAME.csv file
# Pausing the process for 30 seconds
# Starting the process for 01EPIReport(Routinevaccination)_2010_UnionandUpazilalevelHF files: with geo codes and names respectively
# Constructing file path for 01EPIReport(Routinevaccination)_2010_UnionandUpazilalevelHF file
# Getting API query for data/dhis2/data_3/01EPIReport(Routinevaccination)_2010_UnionandUpazilalevelHF_CODE.csv file
# data/dhis2/data_3/01EPIReport(Routinevaccination)_2010_UnionandUpazilalevelHF_CODE.csv
# Writing in chunks data/dhis2/data_3/01EPIReport(Routinevaccination)_2010_UnionandUpazilalevelHF_CODE.csv file
# Pausing the process for 30 seconds
# Restarting the process for data/dhis2/data_3/01EPIReport(Routinevaccination)_2010_UnionandUpazilalevelHF_NAME.csv file
# Writing in chunks data/dhis2/data_3/01EPIReport(Routinevaccination)_2010_UnionandUpazilalevelHF_NAME.csv file
# Pausing the process for 30 seconds
# Starting the process for 01EPIReport(Routinevaccination)_2010_UpazilaandDistrictlevelHF files: with geo codes and names respectively
# Constructing file path for 01EPIReport(Routinevaccination)_2010_UpazilaandDistrictlevelHF file
# Getting API query for data/dhis2/data_3/01EPIReport(Routinevaccination)_2010_UpazilaandDistrictlevelHF_CODE.csv file
# data/dhis2/data_3/01EPIReport(Routinevaccination)_2010_UpazilaandDistrictlevelHF_CODE.csv
# Writing in chunks data/dhis2/data_3/01EPIReport(Routinevaccination)_2010_UpazilaandDistrictlevelHF_CODE.csv file
# Pausing the process for 30 seconds
# Restarting the process for data/dhis2/data_3/01EPIReport(Routinevaccination)_2010_UpazilaandDistrictlevelHF_NAME.csv file
# Writing in chunks data/dhis2/data_3/01EPIReport(Routinevaccination)_2010_UpazilaandDistrictlevelHF_NAME.csv file
# Pausing the process for 30 seconds
# Starting the process for 01EPIReport(Routinevaccination)_
CODE.csv file
# data/dhis2/data_3/01EPIReport(Routinevaccination)_2014_DistrictHospital_GeneralHospital_CODE.csv
# Writing in chunks data/dhis2/data_3/01EPIReport(Routinevaccination)_2014_DistrictHospital_GeneralHospital_CODE.csv file
# Pausing the process for 30 seconds
# Restarting the process for data/dhis2/data_3/01EPIReport(Routinevaccination)_2014_DistrictHospital_GeneralHospital_NAME.csv file
# Writing in chunks data/dhis2/data_3/01EPIReport(Routinevaccination)_2014_DistrictHospital_GeneralHospital_NAME.csv file
# Pausing the process for 30 seconds
# Starting the process for 01EPIReport(Routinevaccination)_2014_DistrictNGO&PrivateTotal files: with geo codes and names respectively
# Constructing file path for 01EPIReport(Routinevaccination)_2014_DistrictNGO&PrivateTotal file
# Getting API query for data/dhis2/data_3/01EPIReport(Routinevaccination)_2014_DistrictNGO&PrivateTotal_CODE.csv file
# data/dhis2/data_3/01EPIReport(Routinevaccination)_2014_DistrictNGO&PrivateTotal_CODE.csv
# Writing in chunks data/dhis2/data_3/01EPIReport(Routinevaccination)_2014_DistrictNGO&PrivateTotal_CODE.csv file
# Pausing the process for 30 seconds
# Restarting the process for data/dhis2/data_3/01EPIReport(Routinevaccination)_2014_DistrictNGO&PrivateTotal_NAME.csv file
# Writing in chunks data/dhis2/data_3/01EPIReport(Routinevaccination)_2014_DistrictNGO&PrivateTotal_NAME.csv file
# Pausing the process for 30 seconds
# Starting the process for 01EPIReport(Routinevaccination)_2014_UNICEF-MNHIdistrict files: with geo codes and names respectively
# Constructing file path for 01EPIReport(Routinevaccination)_2014_UNICEF-MNHIdistrict file
# Getting API query for data/dhis2/data_3/01EPIReport(Routinevaccination)_2014_UNICEF-MNHIdistrict_CODE.csv file
# data/dhis2/data_3/01EPIReport(Routinevaccination)_2014_UNICEF-MNHIdistrict_CODE.csv
# Writing in chunks data/dhis2/data_3/01EPIReport(Routinevaccination)_2014_UNICEF-MNHIdistrict_CODE.csv file
# Pausing the process for 30 seconds
# Restarting the process for data/dhis2/data_3/01EPIReport(Routinevaccination)_2014_UNICEF-MNHIdistrict_NAME.csv file
# Writing in chunks data/dhis2/data_3/01EPIReport(Routinevaccination)_2014_UNICEF-MNHIdistrict_NAME.csv file
# Pausing the process for 30 seconds
# Starting the process for 01EPIReport(Routinevaccination)_2015_DistrictandNational_DivisionallevelHF files: with geo codes and names respectively
# Constructing file path for 01EPIReport(Routinevaccination)_2015_DistrictandNational_DivisionallevelHF file
# Getting API query for data/dhis2/data_3/01EPIReport(Routinevaccination)_2015_DistrictandNational_DivisionallevelHF_CODE.csv file
# data/dhis2/data_3/01EPIReport(Routinevaccination)_2015_DistrictandNational_DivisionallevelHF_CODE.csv
# Writing in chunks data/dhis2/data_3/01EPIReport(Routinevaccination)_2015_DistrictandNational_DivisionallevelHF_CODE.csv file
# Pausing the process for 30 seconds
# Restarting the process for data/dhis2/data_3/01EPIReport(Routinevaccination)_2015_DistrictandNational_DivisionallevelHF_NAME.csv file
# Writing in chunks data/dhis2/data_3/01EPIReport(Routinevaccination)_2015_DistrictandNational_DivisionallevelHF_NAME.csv file
# Pausing the process for 30 seconds
# Starting the process for 01EPIReport(Routinevaccination)_2015_UnionandUpazilalevelHF files: with geo codes and names respectively
# Constructing file path for 01EPIReport(Routinevaccination)_2015_UnionandUpazilalevelHF file
# Getting API query for data/dhis2/data_3/01EPIReport(Routinevaccination)_2015_UnionandUpazilalevelHF_CODE.csv file
# data/dhis2/data_3/01EPIReport(Routinevaccination)_2015_UnionandUpazilalevelHF_CODE.csv
# Writing in chunks data/dhis2/data_3/01EPIReport(Routinevaccination)_2015_UnionandUpazilalevelHF_CODE.csv file
# Pausing the process for 30 seconds
# Restarting the process for data/dhis2/data_3/01EPIReport(Routinevaccination)_2015_UnionandUpazilalevelHF_NAME.csv file
# Writing in chunks data/dhis2/data_3/01EPIReport(Routinevaccination)_2015_UnionandUpazilalevelHF_NAME.csv file
# Pausing the process for 30 seconds
# Starting the process for 01EPIReport(Routinevaccination)_2015_UpazilaandDistrictlevelHF files: with geo codes and names respectively
# Constructing file path for 01EPIReport(Routinevaccination)_2015_UpazilaandDistrictlevelHF file
# Getting API query for data/dhis2/data_3/01EPIReport(Routinevaccination)_2015_UpazilaandDistrictlevelHF_CODE.csv file
# data/dhis2/data_3/01EPIReport(Routinevaccination)_2015_UpazilaandDistrictlevelHF_CODE.csv
# Writing in chunks data/dhis2/data_3/01EPIReport(Routinevaccination)_2015_UpazilaandDistrictlevelHF_CODE.csv file
# Pausing the process for 30 seconds
# Restarting the process for data/dhis2/data_3/01EPIReport(Routinevaccination)_2015_UpazilaandDistrictlevelHF_NAME.csv file
# Writing in chunks data/dhis2/data_3/01EPIReport(Routinevaccination)_2015_UpazilaandDistrictlevelHF_NAME.csv file
# Pausing the process for 30 seconds
# Starting the process for 01EPIReport(Routinevaccination)_2015_Upazila files: with geo codes and names respectively
# Constructing file path for 01EPIReport(Routinevaccination)_2015_Upazila file
# Getting API query for data/dhis2/data_3/01EPIReport(Routinevaccination)_2015_Upazila_CODE.csv file
# data/dhis2/data_3/01EPIReport(Routinevaccination)_2015_Upazila_CODE.csv
# Writing in chunks data/dhis2/data_3/01EPIReport(Routinevaccination)_2015_Upazila_CODE.csv file
# Pausing the process for 30 seconds
# Restarting the process for data/dhis2/data_3/01EPIReport(Routinevaccination)_2015_Upazila_NAME.csv file
# Writing in chunks data/dhis2/data_3/01EPIReport(Routinevaccination)_2015_Upazila_NAME.csv file
# Pausing the process for 30 seconds
# Starting the process for 01EPIReport(Routinevaccination)_2015_UpazilaHealthComplex files: with geo codes and names respectively
# Constructing file path for 01EPIReport(Routinevaccination)_2015_UpazilaHealthComplex file
# Getting API query for data/dhis2/data_3/01EPIReport(Routinevaccination)_2015_UpazilaHealthComplex_CODE.csv file
# data/dhis2/data_3/01EPIReport(Routinevaccination)_2015_UpazilaHealthComplex_CODE.csv
# Writing in chunks data/dhis2/data_3/01EPIReport(Routinevaccination)_2015_UpazilaHealthComplex_CODE.csv file
# Pausing the process for 30 seconds
# ...
# Getting API query for data/dhis2/data_3/11EMEN(MBFFI)_2016_UpazilaHealthComplex_CODE.csv file
# data/dhis2/data_3/11EMEN(MBFFI)_2016_UpazilaHealthComplex_CODE.csv
# Writing in chunks data/dhis2/data_3/11EMEN(MBFFI)_2016_UpazilaHealthComplex_CODE.csv file
# Pausing the process for 30 seconds
# Restarting the process for data/dhis2/data_3/11EMEN(MBFFI)_2016_UpazilaHealthComplex_NAME.csv file
# Writing in chunks data/dhis2/data_3/11EMEN(MBFFI)_2016_UpazilaHealthComplex_NAME.csv file
# Pausing the process for 30 seconds
# Starting the process for 11EMEN(MBFFI)_2016_District files: with geo codes and names respectively
# Constructing file path for 11EMEN(MBFFI)_2016_District file
# Getting API query for data/dhis2/data_3/11EMEN(MBFFI)_2016_District_CODE.csv file
# data/dhis2/data_3/11EMEN(MBFFI)_2016_District_CODE.csv
# Writing in chunks data/dhis2/data_3/11EMEN(MBFFI)_2016_District_CODE.csv file
# Pausing the process for 30 seconds
# Restarting the process for data/dhis2/data_3/11EMEN(MBFFI)_2016_District_NAME.csv file
# Writing in chunks data/dhis2/data_3/11EMEN(MBFFI)_2016_District_NAME.csv file
# Pausing the process for 30 seconds
# Starting the process for 11EMEN(MBFFI)_2016_DistrictHospital_GeneralHospital files: with geo codes and names respectively
# Constructing file path for 11EMEN(MBFFI)_2016_DistrictHospital_GeneralHospital file
# Getting API query for data/dhis2/data_3/11EMEN(MBFFI)_2016_DistrictHospital_GeneralHospital_CODE.csv file
# data/dhis2/data_3/11EMEN(MBFFI)_2016_DistrictHospital_GeneralHospital_CODE.csv
# Writing in chunks data/dhis2/data_3/11EMEN(MBFFI)_2016_DistrictHospital_GeneralHospital_CODE.csv file
# Pausing the process for 30 seconds
# Restarting the process for data/dhis2/data_3/11EMEN(MBFFI)_2016_DistrictHospital_GeneralHospital_NAME.csv file
# Writing in chunks data/dhis2/data_3/11EMEN(MBFFI)_2016_DistrictHospital_GeneralHospital_NAME.csv file
# Pausing the process for 30 seconds
# Starting the process for 11EMEN(MBFFI)_2016_DistrictNGO&PrivateTotal files: with geo codes and names respectively
# Constructing file path for 11EMEN(MBFFI)_2016_DistrictNGO&PrivateTotal file
# Getting API query for data/dhis2/data_3/11EMEN(MBFFI)_2016_DistrictNGO&PrivateTotal_CODE.csv file
# data/dhis2/data_3/11EMEN(MBFFI)_2016_DistrictNGO&PrivateTotal_CODE.csv
# Writing in chunks data/dhis2/data_3/11EMEN(MBFFI)_2016_DistrictNGO&PrivateTotal_CODE.csv file
# Pausing the process for 30 seconds
# Restarting the process for data/dhis2/data_3/11EMEN(MBFFI)_2016_DistrictNGO&PrivateTotal_NAME.csv file
# Writing in chunks data/dhis2/data_3/11EMEN(MBFFI)_2016_DistrictNGO&PrivateTotal_NAME.csv file
# Pausing the process for 30 seconds
# Starting the process for 11EMEN(MBFFI)_2016_UNICEF-MNHIdistrict files: with geo codes and names respectively
# Constructing file path for 11EMEN(MBFFI)_2016_UNICEF-MNHIdistrict file
# Getting API query for data/dhis2/data_3/11EMEN(MBFFI)_2016_UNICEF-MNHIdistrict_CODE.csv file
# data/dhis2/data_3/11EMEN(MBFFI)_2016_UNICEF-MNHIdistrict_CODE.csv
# Writing in chunks data/dhis2/data_3/11EMEN(MBFFI)_2016_UNICEF-MNHIdistrict_CODE.csv file
# Pausing the process for 30 seconds
# Restarting the process for data/dhis2/data_3/11EMEN(MBFFI)_2016_UNICEF-MNHIdistrict_NAME.csv file
# Writing in chunks data/dhis2/data_3/11EMEN(MBFFI)_2016_UNICEF-MNHIdistrict_NAME.csv file
# Pausing the process for 30 seconds
# Starting the process for 11EMEN(MBFFI)_2017_DistrictandNational_DivisionallevelHF files: with geo codes and names respectively
# Constructing file path for 11EMEN(MBFFI)_2017_DistrictandNational_DivisionallevelHF file
# Getting API query for data/dhis2/data_3/11EMEN(MBFFI)_2017_DistrictandNational_DivisionallevelHF_CODE.csv file
# data/dhis2/data_3/11EMEN(MBFFI)_2017_DistrictandNational_DivisionallevelHF_CODE.csv
# Writing in chunks data/dhis2/data_3/11EMEN(MBFFI)_2017_DistrictandNational_DivisionallevelHF_CODE.csv file
# Pausing the process for 30 seconds
# Restarting the process for data/dhis2/data_3/11EMEN(MBFFI)_2017_DistrictandNational_DivisionallevelHF_NAME.csv file
# Writing in chunks data/dhis2/data_3/11EMEN(MBFFI)_2017_DistrictandNational_DivisionallevelHF_NAME.csv file
# Pausing the process for 30 seconds
# Starting the process for 11EMEN(MBFFI)_2017_UnionandUpazilalevelHF files: with geo codes and names respectively
# Constructing file path for 11EMEN(MBFFI)_2017_UnionandUpazilalevelHF file
# Getting API query for data/dhis2/data_3/11EMEN(MBFFI)_2017_UnionandUpazilalevelHF_CODE.csv file
# data/dhis2/data_3/11EMEN(MBFFI)_2017_UnionandUpazilalevelHF_CODE.csv
# Writing in chunks data/dhis2/data_3/11EMEN(MBFFI)_2017_UnionandUpazilalevelHF_CODE.csv file
# Pausing the process for 30 seconds
# Restarting the process for data/dhis2/data_3/11EMEN(MBFFI)_2017_UnionandUpazilalevelHF_NAME.csv file
# Writing in chunks data/dhis2/data_3/11EMEN(MBFFI)_2017_UnionandUpazilalevelHF_NAME.csv file
# Pausing the process for 30 seconds
# Starting the process for 11EMEN(MBFFI)_2017_UpazilaandDistrictlevelHF files: with geo codes and names respectively
# Constructing file path for 11EMEN(MBFFI)_2017_UpazilaandDistrictlevelHF file
# Getting API query for data/dhis2/data_3/11EMEN(MBFFI)_2017_UpazilaandDistrictlevelHF_CODE.csv file
# data/dhis2/data_3/11EMEN(MBFFI)_2017_UpazilaandDistrictlevelHF_CODE.csv
# Writing in chunks data/dhis2/data_3/11EMEN(MBFFI)_2017_UpazilaandDistrictlevelHF_CODE.csv file
# Pausing the process for 30 seconds
# Restarting the process for data/dhis2/data_3/11EMEN(MBFFI)_2017_UpazilaandDistrictlevelHF_NAME.csv file
# Writing in chunks data/dhis2/data_3/11EMEN(MBFFI)_2017_UpazilaandDistrictlevelHF_NAME.csv file
# Pausing the process for 30 seconds
# Starting the process for 11EMEN(MBFFI)_2017_Upazila files: with geo codes and names respectively
# Constructing file path for 11EMEN(MBFFI)_2017_Upazila file
# Getting API query for data/dhis2/data_3/11EMEN(MBFFI)_2017_Upazila_CODE.csv file
# data/dhis2/data_3/11EMEN(MBFFI)_2017_Upazila_CODE.csv
# Writing in chunks data/dhis2/data_3/11EMEN(MBFFI)_2017_Upazila_CODE.csv file
# Pausing the process for 30 seconds
# Restarting the process for data/dhis2/data_3/11EMEN(MBFFI)_2017_Upazila_NAME.csv file
# Writing in chunks data/dhis2/data_3/11EMEN(MBFFI)_2017_Upazila_NAME.csv file
# Pausing the process for 30 seconds
# Starting the process for 11EMEN(MBFFI)_2017_UpazilaHealthComplex files: with geo codes and names respectively
# Constructing file path for 11EMEN(MBFFI)_2017_UpazilaHealthComplex file
# Getting API query for data/dhis2/data_3/11EMEN(MBFFI)_2017_UpazilaHealthComplex_CODE.csv file
# data/dhis2/data_3/11EMEN(MBFFI)_2017_UpazilaHealthComplex_CODE.csv
# Writing in chunks data/dhis2/data_3/11EMEN(MBFFI)_2017_UpazilaHealthComplex_CODE.csv file
# Pausing the process for 30 seconds
# Restarting the process for data/dhis2/data_3/11EMEN(MBFFI)_2017_UpazilaHealthComplex_NAME.csv file
# Writing in chunks data/dhis2/data_3/11EMEN(MBFFI)_2017_UpazilaHealthComplex_NAME.csv file
# Pausing the process for 30 seconds
# Starting the process for 11EMEN(MBFFI)_2017_District files: with geo codes and names respectively
# Constructing file path for 11EMEN(MBFFI)_2017_District file
# Getting API query for data/dhis2/data_3/11EMEN(MBFFI)_2017_District_CODE.csv file
# data/dhis2/data_3/11EMEN(MBFFI)_2017_District_CODE.csv
# Writing in chunks data/dhis2/data_3/11EMEN(MBFFI)_2017_District_CODE.csv file
# Pausing the process for 30 seconds
# Restarting the process for data/dhis2/data_3/11EMEN(MBFFI)_2017_District_NAME.csv file
# Writing in chunks data/dhis2/data_3/11EMEN(MBFFI)_2017_District_NAME.csv file
# Pausing the process for 30 seconds
# Starting the process for 11EMEN(MBFFI)_2017_DistrictHospital_GeneralHospital files: with geo codes and names respectively
# Constructing file path for 11EMEN(MBFFI)_2017_DistrictHospital_GeneralHospital file
# Getting API query for data/dhis2/data_3/11EMEN(MBFFI)_2017_DistrictHospital_GeneralHospital_CODE.csv file
# data/dhis2/data_3/11EMEN(MBFFI)_2017_DistrictHospital_GeneralHospital_CODE.csv
# Writing in chunks data/dhis2/data_3/11EMEN(MBFFI)_2017_DistrictHospital_GeneralHospital_CODE.csv file
# Pausing the process for 30 seconds
# Restarting the process for data/dhis2/data_3/11EMEN(MBFFI)_2017_DistrictHospital_GeneralHospital_NAME.csv file
# Writing in chunks data/dhis2/data_3/11EMEN(MBFFI)_2017_DistrictHospital_GeneralHospital_NAME.csv file
# Pausing the process for 30 seconds
# Starting the process for 11EMEN(MBFFI)_2017_DistrictNGO&PrivateTotal files: with geo codes and names respectively
# Constructing file path for 11EMEN(MBFFI)_2017_DistrictNGO&PrivateTotal file
# Getting API query for data/dhis2/data_3/11EMEN(MBFFI)_2017_DistrictNGO&PrivateTotal_CODE.csv file
# data/dhis2/data_3/11EMEN(MBFFI)_2017_DistrictNGO&PrivateTotal_CODE.csv
# Writing in chunks data/dhis2/data_3/11EMEN(MBFFI)_2017_DistrictNGO&PrivateTotal_CODE.csv file
# Pausing the process for 30 seconds
# Restarting the process for data/dhis2/data_3/11EMEN(MBFFI)_2017_DistrictNGO&PrivateTotal_NAME.csv file
# Writing in chunks data/dhis2/data_3/11EMEN(MBFFI)_2017_DistrictNGO&PrivateTotal_NAME.csv file
# Pausing the process for 30 seconds
# Starting the process for 11EMEN(MBFFI)_2017_UNICEF-MNHIdistrict files: with geo codes and names respectively
# Constructing file path for 11EMEN(MBFFI)_2017_UNICEF-MNHIdistrict file
# Getting API query for data/dhis2/data_3/11EMEN(MBFFI)_2017_UNICEF-MNHIdistrict_CODE.csv file
# data/dhis2/data_3/11EMEN(MBFFI)_2017_UNICEF-MNHIdistrict_CODE.csv
# Writing in chunks data/dhis2/data_3/11EMEN(MBFFI)_2017_UNICEF-MNHIdistrict_CODE.csv file
# Pausing the process for 30 seconds
# Restarting the process for data/dhis2/data_3/11EMEN(MBFFI)_2017_UNICEF-MNHIdistrict_NAME.csv file
# Writing in chunks data/dhis2/data_3/11EMEN(MBFFI)_2017_UNICEF-MNHIdistrict_NAME.csv file
# Pausing the process for 30 seconds
# Starting the process for 11EMEN(MBFFI)_2018_DistrictandNational_DivisionallevelHF files: with geo codes and names respectively
# Constructing file path for 11EMEN(MBFFI)_2018_DistrictandNational_DivisionallevelHF file
# Getting API query for data/dhis2/data_3/11EMEN(MBFFI)_2018_DistrictandNational_DivisionallevelHF_CODE.csv file
# data/dhis2/data_3/11EMEN(MBFFI)_2018_DistrictandNational_DivisionallevelHF_CODE.csv
# Writing in chunks data/dhis2/data_3/11EMEN(MBFFI)_2018_DistrictandNational_DivisionallevelHF_CODE.csv file
# Pausing the process for 30 seconds
# Restarting the process for data/dhis2/data_3/11EMEN(MBFFI)_2018_DistrictandNational_DivisionallevelHF_NAME.csv file
# Writing in chunks data/dhis2/data_3/11EMEN(MBFFI)_2018_DistrictandNational_DivisionallevelHF_NAME.csv file
# Pausing the process for 30 seconds
# Starting the process for 11EMEN(MBFFI)_2018_UnionandUpazilalevelHF files: with geo codes and names respectively
# Constructing file path for 11EMEN(MBFFI)_2018_UnionandUpazilalevelHF file
# Getting API query for data/dhis2/data_3/11EMEN(MBFFI)_2018_UnionandUpazilalevelHF_CODE.csv file
# data/dhis2/data_3/11EMEN(MBFFI)_2018_UnionandUpazilalevelHF_CODE.csv
# Writing in chunks data/dhis2/data_3/11EMEN(MBFFI)_2018_UnionandUpazilalevelHF_CODE.csv file
# Pausing the process for 30 seconds
# Restarting the process for data/dhis2/data_3/11EMEN(MBFFI)_2018_UnionandUpazilalevelHF_NAME.csv file
# Writing in chunks data/dhis2/data_3/11EMEN(MBFFI)_2018_UnionandUpazilalevelHF_NAME.csv file
# Pausing the process for 30 seconds
# Starting the process for 11EMEN(MBFFI)_2018_UpazilaandDistrictlevelHF files: with geo codes and names respectively
# Constructing file path for 11EMEN(MBFFI)_2018_UpazilaandDistrictlevelHF file
# Getting API query for data/dhis2/data_3/11EMEN(MBFFI)_2018_UpazilaandDistrictlevelHF_CODE.csv file
# data/dhis2/data_3/11EMEN(MBFFI)_2018_UpazilaandDistrictlevelHF_CODE.csv
# Writing in chunks data/dhis2/data_3/11EMEN(MBFFI)_2018_UpazilaandDistrictlevelHF_CODE.csv file
# Pausing the process for 30 seconds
# Restarting the process for data/dhis2/data_3/11EMEN(MBFFI)_2018_UpazilaandDistrictlevelHF_NAME.csv file
# Writing in chunks data/dhis2/data_3/11EMEN(MBFFI)_2018_UpazilaandDistrictlevelHF_NAME.csv file
# Pausing the process for 30 seconds
# Starting the process for 11EMEN(MBFFI)_2018_Upazila files: with geo codes and names respectively
# Constructing file path for 11EMEN(MBFFI)_2018_Upazila file
# Getting API query for data/dhis2/data_3/11EMEN(MBFFI)_2018_Upazila_CODE.csv file
# data/dhis2/data_3/11EMEN(MBFFI)_2018_Upazila_CODE.csv
# Writing in chunks data/dhis2/data_3/11EMEN(MBFFI)_2018_Upazila_CODE.csv file
# Pausing the process for 30 seconds
# Restarting the process for data/dhis2/data_3/11EMEN(MBFFI)_2018_Upazila_NAME.csv file
# Writing in chunks data/dhis2/data_3/11EMEN(MBFFI)_2018_Upazila_NAME.csv file
# Pausing the process for 30 seconds
# Starting the process for 11EMEN(MBFFI)_2018_UpazilaHealthComplex files: with geo codes and names respectively
# Constructing file path for 11EMEN(MBFFI)_2018_UpazilaHealthComplex file
# Getting API query for data/dhis2/data_3/11EMEN(MBFFI)_2018_UpazilaHealthComplex_CODE.csv file
# data/dhis2/data_3/11EMEN(MBFFI)_2018_UpazilaHealthComplex_CODE.csv
# Writing in chunks data/dhis2/data_3/11EMEN(MBFFI)_2018_UpazilaHealthComplex_CODE.csv file
# Pausing the process for 30 seconds
# Restarting the process for data/dhis2/data_3/11EMEN(MBFFI)_2018_UpazilaHealthComplex_NAME.csv file
# Writing in chunks data/dhis2/data_3/11EMEN(MBFFI)_2018_UpazilaHealthComplex_NAME.csv file
# Pausing the process for 30 seconds
# Starting the process for 11EMEN(MBFFI)_2018_District files: with geo codes and names respectively
# Constructing file path for 11EMEN(MBFFI)_2018_District file
# Getting API query for data/dhis2/data_3/11EMEN(MBFFI)_2018_District_CODE.csv file
# data/dhis2/data_3/11EMEN(MBFFI)_2018_District_CODE.csv
# Writing in chunks data/dhis2/data_3/11EMEN(MBFFI)_2018_District_CODE.csv file
# Pausing the process for 30 seconds
# Restarting the process for data/dhis2/data_3/11EMEN(MBFFI)_2018_District_NAME.csv file
# Writing in chunks data/dhis2/data_3/11EMEN(MBFFI)_2018_District_NAME.csv file
# Pausing the process for 30 seconds
# Starting the process for 11EMEN(MBFFI)_2018_DistrictHospital_GeneralHospital files: with geo codes and names respectively
# Constructing file path for 11EMEN(MBFFI)_2018_DistrictHospital_GeneralHospital file
# Getting API query for data/dhis2/data_3/11EMEN(MBFFI)_2018_DistrictHospital_GeneralHospital_CODE.csv file
# data/dhis2/data_3/11EMEN(MBFFI)_2018_DistrictHospital_GeneralHospital_CODE.csv
# Writing in chunks data/dhis2/data_3/11EMEN(MBFFI)_2018_DistrictHospital_GeneralHospital_CODE.csv file
# Pausing the process for 30 seconds
# Restarting the process for data/dhis2/data_3/11EMEN(MBFFI)_2018_DistrictHospital_GeneralHospital_NAME.csv file
# Writing in chunks data/dhis2/data_3/11EMEN(MBFFI)_2018_DistrictHospital_GeneralHospital_NAME.csv file
# Pausing the process for 30 seconds
# Starting the process for 11EMEN(MBFFI)_2018_DistrictNGO&PrivateTotal files: with geo codes and names respectively
# Constructing file path for 11EMEN(MBFFI)_2018_DistrictNGO&PrivateTotal file
# Getting API query for data/dhis2/data_3/11EMEN(MBFFI)_2018_DistrictNGO&PrivateTotal_CODE.csv file
# data/dhis2/data_3/11EMEN(MBFFI)_2018_DistrictNGO&PrivateTotal_CODE.csv
# Writing in chunks data/dhis2/data_3/11EMEN(MBFFI)_2018_DistrictNGO&PrivateTotal_CODE.csv file
# Pausing the process for 30 seconds
# Restarting the process for data/dhis2/data_3/11EMEN(MBFFI)_2018_DistrictNGO&PrivateTotal_NAME.csv file
# Writing in chunks data/dhis2/data_3/11EMEN(MBFFI)_2018_DistrictNGO&PrivateTotal_NAME.csv file
# Pausing the process for 30 seconds
# Starting the process for 11EMEN(MBFFI)_2018_UNICEF-MNHIdistrict files: with geo codes and names respectively
# Constructing file path for 11EMEN(MBFFI)_2018_UNICEF-MNHIdistrict file
# Getting API query for data/dhis2/data_3/11EMEN(MBFFI)_2018_UNICEF-MNHIdistrict_CODE.csv file
# data/dhis2/data_3/11EMEN(MBFFI)_2018_UNICEF-MNHIdistrict_CODE.csv
# Writing in chunks data/dhis2/data_3/11EMEN(MBFFI)_2018_UNICEF-MNHIdistrict_CODE.csv file
# Pausing the process for 30 seconds
# Restarting the process for data/dhis2/data_3/11EMEN(MBFFI)_2018_UNICEF-MNHIdistrict_NAME.csv file
# Writing in chunks data/dhis2/data_3/11EMEN(MBFFI)_2018_UNICEF-MNHIdistrict_NAME.csv file
# Pausing the process for 30 seconds
