# %% [markdown]
# # DHIS2 Data Download Web API - Central Server V2
# ## Downloading Health Indicators

# %%
import os
import time
import requests
import pandas as pd

# %%
WD = '/Users/edinhamzic/Symphony/wb_bangladesh/'
os.chdir(WD)
os.getcwd()
# Out:
# '/Users/edinhamzic/Symphony/wb_bangladesh'

# %% [markdown]
# ## Organisation Units
# ### Organisation Unit Levels

# %%
organisationUnitsLevels = 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/26/organisationUnitLevels.json?paging=false'
with requests.Session() as s:
    organisationUnitsLevels_json = s.get(organisationUnitsLevels,auth=('wbbigdata_view', 'DGHS@1234#')).json()
pd.DataFrame.from_dict(organisationUnitsLevels_json['organisationUnitLevels'])
# Out:
#                                  displayName           id
# 0        Community Clinic and Union Level HF  P3xaO9CNrVY
# 1                                    Country  kv8G6cp7G8n
# 2  District and National/Divisional level HF  TY67fOo5ywC
# 3                                   Division  hrLzNYoLILu
# 4                                    Level 7  sVti5YayDAf
# 5                 Union and Upazila level HF  IWh6WrGXOyN
# 6              Upazila and District level HF  WDBz0AfvG8C

# %% [markdown]
# ### Organisation Unit Groups

# %%
organisationUnitGroups = 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/26/organisationUnitGroups.json?paging=false'
with requests.Session() as s:
    organisationUnitGroups_json = s.get(organisationUnitGroups,auth=('wbbigdata_view', 'DGHS@1234#')).json()
organisationUnitGroups_json = pd.DataFrame.from_dict(organisationUnitGroups_json['organisationUnitGroups'])

# %%
geos = {'District and National_Divisional level HF':'3',
        'Union and Upazila level HF': '5',
        'Upazila and District level HF': '4',
        'Upazila':'XpE4AlQZRkV',
        'Upazila Health Complex':'TwFxBSq8iAg',
        'District': 'PyK69cVqr5l',
        'District Hospital_General Hospital':'yiUFzYnD1f9',
        'District NGO & Private Total': 'Uey6NprfqrE'}
geo_types = {'District and National_Divisional level HF':'LEVEL',
        'Union and Upazila level HF': 'LEVEL',
        'Upazila and District level HF': 'LEVEL',
        'Upazila':'GROUP',
        'Upazila Health Complex':'GROUP',
        'District': 'GROUP',
        'District Hospital_General Hospital':'GROUP',
        'District NGO & Private Total': 'GROUP'
            }
print(geos)
print(geo_types)
# Out:
# {'District and National_Divisional level HF': '3', 'Union and Upazila level HF': '5', 'Upazila and District level HF': '4', 'Upazila': 'XpE4AlQZRkV', 'Upazila Health Complex': 'TwFxBSq8iAg', 'District': 'PyK69cVqr5l', 'District Hospital_General Hospital': 'yiUFzYnD1f9', 'District NGO & Private Total': 'Uey6NprfqrE'}
# {'District and National_Divisional level HF': 'LEVEL', 'Union and Upazila level HF': 'LEVEL', 'Upazila and District level HF': 'LEVEL', 'Upazila': 'GROUP', 'Upazila Health Complex': 'GROUP', 'District': 'GROUP', 'District Hospital_General Hospital': 'GROUP', 'District NGO & Private Total': 'GROUP'}

# %% [markdown]
# ## Predefined Health Indicators

# %%
health_indicators = pd.read_csv('data/dhis2/health_indicators/health_indicators.csv',index_col=None)
health_indicators
# Out:
#                                  Health Indicators  \
# 0                              01. Maternal Health
# 1                                 02. Child Health
# 2                                 03. Immunization
# 3                                      04. Newborn
# 4                                    05. Logistics
# 5        06. Vaccine & Logistics stock of District
# 6  07. Vaccine & Logistics stock of Upazila/Mun/CC
# 7                             Antenatal Care (ANC)
#
#                                                  IDs
# 0  ?dimension=dx:sjorO3gQABy;nHvaVDaRcQU;llFRYYZL...
# 1  ?dimension=dx:LwxiPaHQwif;IQ1WyeMu4PS;Pd6AH5ko...
# 2  ?dimension=dx:a2UI5138tBe;w0rSItvQO65;vHWCFOMx...
# 3  ?dimension=dx:f46jAdwYWDD;FzTEiMtiSQN;n8sW5SK2...
# 4              ?dimension=dx:t3oOvEIdZuw;gCIHrhpVM3p
# 5  ?dimension=dx:EI3rYMbue2l;x8f1fsbgspb;Hxwqpvzm...
# 6  ?dimension=dx:oWkwB8F0w3f;cdqjn347Zbe;MXblPCxm...
# 7  ?dimension=dx:lqGV3xf4MnW;EMN9ubIGpGh;wpDTeNQUuEb

# %% [markdown]
# ## Time Periods

# %%
years = {'2009':2009, '2010':2010, '2011':2011, '2012':2012,
         '2013':2013, '2014':2014, '2015':2015, '2016':2016,
         '2017':2017, '2018':2018,

        }
years
# Out:
# {'2009': 2009,
#  '2010': 2010,
#  '2011': 2011,
#  '2012': 2012,
#  '2013': 2013,
#  '2014': 2014,
#  '2015': 2015,
#  '2016': 2016,
#  '2017': 2017,
#  '2018': 2018}

# %% [markdown]
# ## Building the API queries

# %% [markdown]
# ## Functions

# %%
def create_api_queries(indicators, period, geos, geo_types):
    api_queries = {}
    for i in range(len(indicators)):
        for year_item, year_value in period.items():
            for geo_item, geo_value in geos.items():
                dhis_main = 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv'
                dataElementGroups_variables= indicators['IDs'][i]
                geo_variables = f'&dimension=ou:OU_{geo_types[geo_item]}-{geo_value};'
                time_variables = f'dNLjKwsVjod&filter=pe:{year_item};LAST_12_MONTHS&displayProperty=NAME&outputIdScheme='
                url = dhis_main + dataElementGroups_variables + geo_variables + time_variables
                file_name = indicators['Health Indicators'][i] + '_' + year_item + '_' + geo_item
                file_name = file_name.replace(" ", "").replace(".", "")
                api_queries[file_name] = url
    return api_queries

def data_download(api_queries, pause_length, dest_dir):
    for file_name, api_query in api_queries.items():
        print(f"Starting the process for {file_name} files: with geo codes and names respectively")
        print(f"Constructing file path for {file_name} file")
        file_with_codes = os.path.join(dest_dir, file_name + '_CODE' + '.csv') 
        file_with_names = os.path.join(dest_dir, file_name + '_NAME' + '.csv') 
        if file_name + '_CODE' + '.csv' in os.listdir(dest_dir):
            print(f"{file_name} file already downloaded")
        else:
            with requests.Session() as s:
                print(f"Getting API query for {file_with_codes} file")
                data_codes = s.get(api_query + 'CODE', auth=('wbbigdata_view', 'DGHS@1234#'),stream=True)
                with open(file_with_codes, 'wb') as f:
                    print(file_with_codes)
                    print(f"Writing in chunks {file_with_codes} file")
                    for chunk in data_codes.iter_content(chunk_size=1024):
                        if chunk:
                            f.write(chunk)
                print(f"Pausing the process for {pause_length} seconds")
                time.sleep(pause_length)
                
        if file_name + '_NAME' + '.csv' in os.listdir(dest_dir):
            print(f"{file_name} file already downloaded")
        else:
            with requests.Session() as s:
                print(f"Restarting the process for {file_with_names} file")
                data_names = s.get(api_query + 'NAME', auth=('wbbigdata_view', 'DGHS@1234#'),stream=True)
                with open(file_with_names, 'wb') as f:
                    print(f"Writing in chunks {file_with_names} file")
                    for chunk in data_names.iter_content(chunk_size=1024):
                        if chunk:
                            f.write(chunk)
            print(f"Pausing the process for {pause_length} seconds")
            time.sleep(pause_length)

# %% [markdown]
# ### Periods

# %%
years
# Out:
# {'2009': 2009,
#  '2010': 2010,
#  '2011': 2011,
#  '2012': 2012,
#  '2013': 2013,
#  '2014': 2014,
#  '2015': 2015,
#  '2016': 2016,
#  '2017': 2017,
#  '2018': 2018}

# %% [markdown]
# ### Geos

# %%
geos
# Out:
# {'District': 'PyK69cVqr5l',
#  'District Hospital_General Hospital': 'yiUFzYnD1f9',
#  'District NGO & Private Total': 'Uey6NprfqrE',
#  'District and National_Divisional level HF': '3',
#  'Union and Upazila level HF': '5',
#  'Upazila': 'XpE4AlQZRkV',
#  'Upazila Health Complex': 'TwFxBSq8iAg',
#  'Upazila and District level HF': '4'}

# %% [markdown]
# ### Geo Types

# %%
geo_types
# Out:
# {'District': 'GROUP',
#  'District Hospital_General Hospital': 'GROUP',
#  'District NGO & Private Total': 'GROUP',
#  'District and National_Divisional level HF': 'LEVEL',
#  'Union and Upazila level HF': 'LEVEL',
#  'Upazila': 'GROUP',
#  'Upazila Health Complex': 'GROUP',
#  'Upazila and District level HF': 'LEVEL'}

# %% [markdown]
# ### Downloading data

# %%
health_indicators
# Out:
#                                  Health Indicators  \
# 0                              01. Maternal Health
# 1                                 02. Child Health
# 2                                 03. Immunization
# 3                                      04. Newborn
# 4                                    05. Logistics
# 5        06. Vaccine & Logistics stock of District
# 6  07. Vaccine & Logistics stock of Upazila/Mun/CC
# 7                             Antenatal Care (ANC)
#
#                                                  IDs
# 0  ?dimension=dx:sjorO3gQABy;nHvaVDaRcQU;llFRYYZL...
# 1  ?dimension=dx:LwxiPaHQwif;IQ1WyeMu4PS;Pd6AH5ko...
# 2  ?dimension=dx:a2UI5138tBe;w0rSItvQO65;vHWCFOMx...
# 3  ?dimension=dx:f46jAdwYWDD;FzTEiMtiSQN;n8sW5SK2...
# 4              ?dimension=dx:t3oOvEIdZuw;gCIHrhpVM3p
# 5  ?dimension=dx:EI3rYMbue2l;x8f1fsbgspb;Hxwqpvzm...
# 6  ?dimension=dx:oWkwB8F0w3f;cdqjn347Zbe;MXblPCxm...
# 7  ?dimension=dx:lqGV3xf4MnW;EMN9ubIGpGh;wpDTeNQUuEb

# %%
dghis_queries = create_api_queries(indicators=health_indicators, 
                                   period=years, 
                                   geos=geos, 
                                   geo_types=geo_types)

# %%
dghis_queries
# Out:
# {'01MaternalHealth_2009_District': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:sjorO3gQABy;nHvaVDaRcQU;llFRYYZLkur;IVpv2Tj5rbj;UeBuoOKVSt9;DA4SHBTcotS;EN6VvWHuz6H;suIr6bcCKVv;ejt6ia79ixB;IQEbbjwChym;CRstBHmZrRi;pqxYwxpF3yV;eykgM4I5jQF&dimension=ou:OU_GROUP-PyK69cVqr5l;dNLjKwsVjod&filter=pe:2009;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  '01MaternalHealth_2009_DistrictHospital_GeneralHospital': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:sjorO3gQABy;nHvaVDaRcQU;llFRYYZLkur;IVpv2Tj5rbj;UeBuoOKVSt9;DA4SHBTcotS;EN6VvWHuz6H;suIr6bcCKVv;ejt6ia79ixB;IQEbbjwChym;CRstBHmZrRi;pqxYwxpF3yV;eykgM4I5jQF&dimension=ou:OU_GROUP-yiUFzYnD1f9;dNLjKwsVjod&filter=pe:2009;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  '01MaternalHealth_2009_DistrictNGO&PrivateTotal': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:sjorO3gQABy;nHvaVDaRcQU;llFRYYZLkur;IVpv2Tj5rbj;UeBuoOKVSt9;DA4SHBTcotS;EN6VvWHuz6H;suIr6bcCKVv;ejt6ia79ixB;IQEbbjwChym;CRstBHmZrRi;pqxYwxpF3yV;eykgM4I5jQF&dimension=ou:OU_GROUP-Uey6NprfqrE;dNLjKwsVjod&filter=pe:2009;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  '01MaternalHealth_2009_DistrictandNational_DivisionallevelHF': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:sjorO3gQABy;nHvaVDaRcQU;llFRYYZLkur;IVpv2Tj5rbj;UeBuoOKVSt9;DA4SHBTcotS;EN6VvWHuz6H;suIr6bcCKVv;ejt6ia79ixB;IQEbbjwChym;CRstBHmZrRi;pqxYwxpF3yV;eykgM4I5jQF&dimension=ou:OU_LEVEL-3;dNLjKwsVjod&filter=pe:2009;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  '01MaternalHealth_2009_UnionandUpazilalevelHF': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:sjorO3gQABy;nHvaVDaRcQU;llFRYYZLkur;IVpv2Tj5rbj;UeBuoOKVSt9;DA4SHBTcotS;EN6VvWHuz6H;suIr6bcCKVv;ejt6ia79ixB;IQEbbjwChym;CRstBHmZrRi;pqxYwxpF3yV;eykgM4I5jQF&dimension=ou:OU_LEVEL-5;dNLjKwsVjod&filter=pe:2009;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  '01MaternalHealth_2009_Upazila': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:sjorO3gQABy;nHvaVDaRcQU;llFRYYZLkur;IVpv2Tj5rbj;UeBuoOKVSt9;DA4SHBTcotS;EN6VvWHuz6H;suIr6bcCKVv;ejt6ia79ixB;IQEbbjwChym;CRstBHmZrRi;pqxYwxpF3yV;eykgM4I5jQF&dimension=ou:OU_GROUP-XpE4AlQZRkV;dNLjKwsVjod&filter=pe:2009;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  '01MaternalHealth_2009_UpazilaHealthComplex': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:sjorO3gQABy;nHvaVDaRcQU;llFRYYZLkur;IVpv2Tj5rbj;UeBuoOKVSt9;DA4SHBTcotS;EN6VvWHuz6H;suIr6bcCKVv;ejt6ia79ixB;IQEbbjwChym;CRstBHmZrRi;pqxYwxpF3yV;eykgM4I5jQF&dimension=ou:OU_GROUP-TwFxBSq8iAg;dNLjKwsVjod&filter=pe:2009;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  '01MaternalHealth_2009_UpazilaandDistrictlevelHF': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:sjorO3gQABy;nHvaVDaRcQU;llFRYYZLkur;IVpv2Tj5rbj;UeBuoOKVSt9;DA4SHBTcotS;EN6VvWHuz6H;suIr6bcCKVv;ejt6ia79ixB;IQEbbjwChym;CRstBHmZrRi;pqxYwxpF3yV;eykgM4I5jQF&dimension=ou:OU_LEVEL-4;dNLjKwsVjod&filter=pe:2009;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  '01MaternalHealth_2010_District': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:sjorO3gQABy;nHvaVDaRcQU;llFRYYZLkur;IVpv2Tj5rbj;UeBuoOKVSt9;DA4SHBTcotS;EN6VvWHuz6H;suIr6bcCKVv;ejt6ia79ixB;IQEbbjwChym;CRstBHmZrRi;pqxYwxpF3yV;eykgM4I5jQF&dimension=ou:OU_GROUP-PyK69cVqr5l;dNLjKwsVjod&filter=pe:2010;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  '01MaternalHealth_2010_DistrictHospital_GeneralHospital': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:sjorO3gQABy;nHvaVDaRcQU;llFRYYZLkur;IVpv2Tj5rbj;UeBuoOKVSt9;DA4SHBTcotS;EN6VvWHuz6H;suIr6bcCKVv;ejt6ia79ixB;IQEbbjwChym;CRstBHmZrRi;pqxYwxpF3yV;eykgM4I5jQF&dimension=ou:OU_GROUP-yiUFzYnD1f9;dNLjKwsVjod&filter=pe:2010;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  '01MaternalHealth_2010_DistrictNGO&PrivateTotal': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:sjorO3gQABy;nHvaVDaRcQU;llFRYYZLkur;IVpv2Tj5rbj;UeBuoOKVSt9;DA4SHBTcotS;EN6VvWHuz6H;suIr6bcCKVv;ejt6ia79ixB;IQEbbjwChym;CRstBHmZrRi;pqxYwxpF3yV;eykgM4I5jQF&dimension=ou:OU_GROUP-Uey6NprfqrE;dNLjKwsVjod&filter=pe:2010;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  '01MaternalHealth_2010_DistrictandNational_DivisionallevelHF': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:sjorO3gQABy;nHvaVDaRcQU;llFRYYZLkur;IVpv2Tj5rbj;UeBuoOKVSt9;DA4SHBTcotS;EN6VvWHuz6H;suIr6bcCKVv;ejt6ia79ixB;IQEbbjwChym;CRstBHmZrRi;pqxYwxpF3yV;eykgM4I5jQF&dimension=ou:OU_LEVEL-3;dNLjKwsVjod&filter=pe:2010;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  '01MaternalHealth_2010_UnionandUpazilalevelHF': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:sjorO3gQABy;nHvaVDaRcQU;llFRYYZLkur;IVpv2Tj5rbj;UeBuoOKVSt9;DA4SHBTcotS;EN6VvWHuz6H;suIr6bcCKVv;ejt6ia79ixB;IQEbbjwChym;CRstBHmZrRi;pqxYwxpF3yV;eykgM4I5jQF&dimension=ou:OU_LEVEL-5;dNLjKwsVjod&filter=pe:2010;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  '01MaternalHealth_2010_Upazila': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:sjorO3gQABy;nHvaVDaRcQU;llFRYYZLkur;IVpv2Tj5rbj;UeBuoOKVSt9;DA4SHBTcotS;EN6VvWHuz6H;suIr6bcCKVv;ejt6ia79ixB;IQEbbjwChym;CRstBHmZrRi;pqxYwxpF3yV;eykgM4I5jQF&dimension=ou:OU_GROUP-XpE4AlQZRkV;dNLjKwsVjod&filter=pe:2010;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  '01MaternalHealth_2010_UpazilaHealthComplex': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:sjorO3gQABy;nHvaVDaRcQU;llFRYYZLkur;IVpv2Tj5rbj;UeBuoOKVSt9;DA4SHBTcotS;EN6VvWHuz6H;suIr6bcCKVv;ejt6ia79ixB;IQEbbjwChym;CRstBHmZrRi;pqxYwxpF3yV;eykgM4I5jQF&dimension=ou:OU_GROUP-TwFxBSq8iAg;dNLjKwsVjod&filter=pe:2010;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  '01MaternalHealth_2010_UpazilaandDistrictlevelHF': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:sjorO3gQABy;nHvaVDaRcQU;llFRYYZLkur;IVpv2Tj5rbj;UeBuoOKVSt9;DA4SHBTcotS;EN6VvWHuz6H;suIr6bcCKVv;ejt6ia79ixB;IQEbbjwChym;CRstBHmZrRi;pqxYwxpF3yV;eykgM4I5jQF&dimension=ou:OU_LEVEL-4;dNLjKwsVjod&filter=pe:2010;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  '01MaternalHealth_2011_District': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:sjorO3gQABy;nHvaVDaRcQU;llFRYYZLkur;IVpv2Tj5rbj;UeBuoOKVSt9;DA4SHBTcotS;EN6VvWHuz6H;suIr6bcCKVv;ejt6ia79ixB;IQEbbjwChym;CRstBHmZrRi;pqxYwxpF3yV;eykgM4I5jQF&dimension=ou:OU_GROUP-PyK69cVqr5l;dNLjKwsVjod&filter=pe:2011;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  '01MaternalHealth_2011_DistrictHospital_GeneralHospital': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:sjorO3gQABy;nHvaVDaRcQU;llFRYYZLkur;IVpv2Tj5rbj;UeBuoOKVSt9;DA4SHBTcotS;EN6VvWHuz6H;suIr6bcCKVv;ejt6ia79ixB;IQEbbjwChym;CRstBHmZrRi;pqxYwxpF3yV;eykgM4I5jQF&dimension=ou:OU_GROUP-yiUFzYnD1f9;dNLjKwsVjod&filter=pe:2011;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  '01MaternalHealth_2011_DistrictNGO&PrivateTotal': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:sjorO3gQABy;nHvaVDaRcQU;llFRYYZLkur;IVpv2Tj5rbj;UeBuoOKVSt9;DA4SHBTcotS;EN6VvWHuz6H;suIr6bcCKVv;ejt6ia79ixB;IQEbbjwChym;CRstBHmZrRi;pqxYwxpF3yV;eykgM4I5jQF&dimension=ou:OU_GROUP-Uey6NprfqrE;dNLjKwsVjod&filter=pe:2011;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  '01MaternalHealth_2011_DistrictandNational_DivisionallevelHF': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:sjorO3gQABy;nHvaVDaRcQU;llFRYYZLkur;IVpv2Tj5rbj;UeBuoOKVSt9;DA4SHBTcotS;EN6VvWHuz6H;suIr6bcCKVv;ejt6ia79ixB;IQEbbjwChym;CRstBHmZrRi;pqxYwxpF3yV;eykgM4I5jQF&dimension=ou:OU_LEVEL-3;dNLjKwsVjod&filter=pe:2011;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  '01MaternalHealth_2011_UnionandUpazilalevelHF': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:sjorO3gQABy;nHvaVDaRcQU;llFRYYZLkur;IVpv2Tj5rbj;UeBuoOKVSt9;DA4SHBTcotS;EN6VvWHuz6H;suIr6bcCKVv;ejt6ia79ixB;IQEbbjwChym;CRstBHmZrRi;pqxYwxpF3yV;eykgM4I5jQF&dimension=ou:OU_LEVEL-5;dNLjKwsVjod&filter=pe:2011;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  '01MaternalHealth_2011_Upazila': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:sjorO3gQABy;nHvaVDaRcQU;llFRYYZLkur;IVpv2Tj5rbj;UeBuoOKVSt9;DA4SHBTcotS;EN6VvWHuz6H;suIr6bcCKVv;ejt6ia79ixB;IQEbbjwChym;CRstBHmZrRi;pqxYwxpF3yV;eykgM4I5jQF&dimension=ou:OU_GROUP-XpE4AlQZRkV;dNLjKwsVjod&filter=pe:2011;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  '01MaternalHealth_2011_UpazilaHealthComplex': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:sjorO3gQABy;nHvaVDaRcQU;llFRYYZLkur;IVpv2Tj5rbj;UeBuoOKVSt9;DA4SHBTcotS;EN6VvWHuz6H;suIr6bcCKVv;ejt6ia79ixB;IQEbbjwChym;CRstBHmZrRi;pqxYwxpF3yV;eykgM4I5jQF&dimension=ou:OU_GROUP-TwFxBSq8iAg;dNLjKwsVjod&filter=pe:2011;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  '01MaternalHealth_2011_UpazilaandDistrictlevelHF': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:sjorO3gQABy;nHvaVDaRcQU;llFRYYZLkur;IVpv2Tj5rbj;UeBuoOKVSt9;DA4SHBTcotS;EN6VvWHuz6H;suIr6bcCKVv;ejt6ia79ixB;IQEbbjwChym;CRstBHmZrRi;pqxYwxpF3yV;eykgM4I5jQF&dimension=ou:OU_LEVEL-4;dNLjKwsVjod&filter=pe:2011;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  '01MaternalHealth_2012_District': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:sjorO3gQABy;nHvaVDaRcQU;llFRYYZLkur;IVpv2Tj5rbj;UeBuoOKVSt9;DA4SHBTcotS;EN6VvWHuz6H;suIr6bcCKVv;ejt6ia79ixB;IQEbbjwChym;CRstBHmZrRi;pqxYwxpF3yV;eykgM4I5jQF&dimension=ou:OU_GROUP-PyK69cVqr5l;dNLjKwsVjod&filter=pe:2012;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  '01MaternalHealth_2012_DistrictHospital_GeneralHospital': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:sjorO3gQABy;nHvaVDaRcQU;llFRYYZLkur;IVpv2Tj5rbj;UeBuoOKVSt9;DA4SHBTcotS;EN6VvWHuz6H;suIr6bcCKVv;ejt6ia79ixB;IQEbbjwChym;CRstBHmZrRi;pqxYwxpF3yV;eykgM4I5jQF&dimension=ou:OU_GROUP-yiUFzYnD1f9;dNLjKwsVjod&filter=pe:2012;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  '01MaternalHealth_2012_DistrictNGO&PrivateTotal': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:sjorO3gQABy;nHvaVDaRcQU;llFRYYZLkur;IVpv2Tj5rbj;UeBuoOKVSt9;DA4SHBTcotS;EN6VvWHuz6H;suIr6bcCKVv;ejt6ia79ixB;IQEbbjwChym;CRstBHmZrRi;pqxYwxpF3yV;eykgM4I5jQF&dimension=ou:OU_GROUP-Uey6NprfqrE;dNLjKwsVjod&filter=pe:2012;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  '01MaternalHealth_2012_DistrictandNational_DivisionallevelHF': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:sjorO3gQABy;nHvaVDaRcQU;llFRYYZLkur;IVpv2Tj5rbj;UeBuoOKVSt9;DA4SHBTcotS;EN6VvWHuz6H;suIr6bcCKVv;ejt6ia79ixB;IQEbbjwChym;CRstBHmZrRi;pqxYwxpF3yV;eykgM4I5jQF&dimension=ou:OU_LEVEL-3;dNLjKwsVjod&filter=pe:2012;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  '01MaternalHealth_2012_UnionandUpazilalevelHF': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:sjorO3gQABy;nHvaVDaRcQU;llFRYYZLkur;IVpv2Tj5rbj;UeBuoOKVSt9;DA4SHBTcotS;EN6VvWHuz6H;suIr6bcCKVv;ejt6ia79ixB;IQEbbjwChym;CRstBHmZrRi;pqxYwxpF3yV;eykgM4I5jQF&dimension=ou:OU_LEVEL-5;dNLjKwsVjod&filter=pe:2012;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  '01MaternalHealth_2012_Upazila': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:sjorO3gQABy;nHvaVDaRcQU;llFRYYZLkur;IVpv2Tj5rbj;UeBuoOKVSt9;DA4SHBTcotS;EN6VvWHuz6H;suIr6bcCKVv;ejt6ia79ixB;IQEbbjwChym;CRstBHmZrRi;pqxYwxpF3yV;eykgM4I5jQF&dimension=ou:OU_GROUP-XpE4AlQZRkV;dNLjKwsVjod&filter=pe:2012;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  '01MaternalHealth_2012_UpazilaHealthComplex': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:sjorO3gQABy;nHvaVDaRcQU;llFRYYZLkur;IVpv2Tj5rbj;UeBuoOKVSt9;DA4SHBTcotS;EN6VvWHuz6H;suIr6bcCKVv;ejt6ia79ixB;IQEbbjwChym;CRstBHmZrRi;pqxYwxpF3yV;eykgM4I5jQF&dimension=ou:OU_GROUP-TwFxBSq8iAg;dNLjKwsVjod&filter=pe:2012;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  '01MaternalHealth_2012_UpazilaandDistrictlevelHF': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:sjorO3gQABy;nHvaVDaRcQU;llFRYYZLkur;IVpv2Tj5rbj;UeBuoOKVSt9;DA4SHBTcotS;EN6VvWHuz6H;suIr6bcCKVv;ejt6ia79ixB;IQEbbjwChym;CRstBHmZrRi;pqxYwxpF3yV;eykgM4I5jQF&dimension=ou:OU_LEVEL-4;dNLjKwsVjod&filter=pe:2012;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  '01MaternalHealth_2013_District': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:sjorO3gQABy;nHvaVDaRcQU;llFRYYZLkur;IVpv2Tj5rbj;UeBuoOKVSt9;DA4SHBTcotS;EN6VvWHuz6H;suIr6bcCKVv;ejt6ia79ixB;IQEbbjwChym;CRstBHmZrRi;pqxYwxpF3yV;eykgM4I5jQF&dimension=ou:OU_GROUP-PyK69cVqr5l;dNLjKwsVjod&filter=pe:2013;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  '01MaternalHealth_2013_DistrictHospital_GeneralHospital': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:sjorO3gQABy;nHvaVDaRcQU;llFRYYZLkur;IVpv2Tj5rbj;UeBuoOKVSt9;DA4SHBTcotS;EN6VvWHuz6H;suIr6bcCKVv;ejt6ia79ixB;IQEbbjwChym;CRstBHmZrRi;pqxYwxpF3yV;eykgM4I5jQF&dimension=ou:OU_GROUP-yiUFzYnD1f9;dNLjKwsVjod&filter=pe:2013;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  '01MaternalHealth_2013_DistrictNGO&PrivateTotal': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:sjorO3gQABy;nHvaVDaRcQU;llFRYYZLkur;IVpv2Tj5rbj;UeBuoOKVSt9;DA4SHBTcotS;EN6VvWHuz6H;suIr6bcCKVv;ejt6ia79ixB;IQEbbjwChym;CRstBHmZrRi;pqxYwxpF3yV;eykgM4I5jQF&dimension=ou:OU_GROUP-Uey6NprfqrE;dNLjKwsVjod&filter=pe:2013;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  '01MaternalHealth_2013_DistrictandNational_DivisionallevelHF': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:sjorO3gQABy;nHvaVDaRcQU;llFRYYZLkur;IVpv2Tj5rbj;UeBuoOKVSt9;DA4SHBTcotS;EN6VvWHuz6H;suIr6bcCKVv;ejt6ia79ixB;IQEbbjwChym;CRstBHmZrRi;pqxYwxpF3yV;eykgM4I5jQF&dimension=ou:OU_LEVEL-3;dNLjKwsVjod&filter=pe:2013;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  '01MaternalHealth_2013_UnionandUpazilalevelHF': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:sjorO3gQABy;nHvaVDaRcQU;llFRYYZLkur;IVpv2Tj5rbj;UeBuoOKVSt9;DA4SHBTcotS;EN6VvWHuz6H;suIr6bcCKVv;ejt6ia79ixB;IQEbbjwChym;CRstBHmZrRi;pqxYwxpF3yV;eykgM4I5jQF&dimension=ou:OU_LEVEL-5;dNLjKwsVjod&filter=pe:2013;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  '01MaternalHealth_2013_Upazila': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:sjorO3gQABy;nHvaVDaRcQU;llFRYYZLkur;IVpv2Tj5rbj;UeBuoOKVSt9;DA4SHBTcotS;EN6VvWHuz6H;suIr6bcCKVv;ejt6ia79ixB;IQEbbjwChym;CRstBHmZrRi;pqxYwxpF3yV;eykgM4I5jQF&dimension=ou:OU_GROUP-XpE4AlQZRkV;dNLjKwsVjod&filter=pe:2013;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  '01MaternalHealth_2013_UpazilaHealthComplex': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:sjorO3gQABy;nHvaVDaRcQU;llFRYYZLkur;IVpv2Tj5rbj;UeBuoOKVSt9;DA4SHBTcotS;EN6VvWHuz6H;suIr6bcCKVv;ejt6ia79ixB;IQEbbjwChym;CRstBHmZrRi;pqxYwxpF3yV;eykgM4I5jQF&dimension=ou:OU_GROUP-TwFxBSq8iAg;dNLjKwsVjod&filter=pe:2013;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  '01MaternalHealth_2013_UpazilaandDistrictlevelHF': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:sjorO3gQABy;nHvaVDaRcQU;llFRYYZLkur;IVpv2Tj5rbj;UeBuoOKVSt9;DA4SHBTcotS;EN6VvWHuz6H;suIr6bcCKVv;ejt6ia79ixB;IQEbbjwChym;CRstBHmZrRi;pqxYwxpF3yV;eykgM4I5jQF&dimension=ou:OU_LEVEL-4;dNLjKwsVjod&filter=pe:2013;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  '01MaternalHealth_2014_District': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:sjorO3gQABy;nHvaVDaRcQU;llFRYYZLkur;IVpv2Tj5rbj;UeBuoOKVSt9;DA4SHBTcotS;EN6VvWHuz6H;suIr6bcCKVv;ejt6ia79ixB;IQEbbjwChym;CRstBHmZrRi;pqxYwxpF3yV;eykgM4I5jQF&dimension=ou:OU_GROUP-PyK69cVqr5l;dNLjKwsVjod&filter=pe:2014;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  '01MaternalHealth_2014_DistrictHospital_GeneralHospital': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:sjorO3gQABy;nHvaVDaRcQU;llFRYYZLkur;IVpv2Tj5rbj;UeBuoOKVSt9;DA4SHBTcotS;EN6VvWHuz6H;suIr6bcCKVv;ejt6ia79ixB;IQEbbjwChym;CRstBHmZrRi;pqxYwxpF3yV;eykgM4I5jQF&dimension=ou:OU_GROUP-yiUFzYnD1f9;dNLjKwsVjod&filter=pe:2014;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  '01MaternalHealth_2014_DistrictNGO&PrivateTotal': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:sjorO3gQABy;nHvaVDaRcQU;llFRYYZLkur;IVpv2Tj5rbj;UeBuoOKVSt9;DA4SHBTcotS;EN6VvWHuz6H;suIr6bcCKVv;ejt6ia79ixB;IQEbbjwChym;CRstBHmZrRi;pqxYwxpF3yV;eykgM4I5jQF&dimension=ou:OU_GROUP-Uey6NprfqrE;dNLjKwsVjod&filter=pe:2014;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  '01MaternalHealth_2014_DistrictandNational_DivisionallevelHF': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:sjorO3gQABy;nHvaVDaRcQU;llFRYYZLkur;IVpv2Tj5rbj;UeBuoOKVSt9;DA4SHBTcotS;EN6VvWHuz6H;suIr6bcCKVv;ejt6ia79ixB;IQEbbjwChym;CRstBHmZrRi;pqxYwxpF3yV;eykgM4I5jQF&dimension=ou:OU_LEVEL-3;dNLjKwsVjod&filter=pe:2014;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  '01MaternalHealth_2014_UnionandUpazilalevelHF': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:sjorO3gQABy;nHvaVDaRcQU;llFRYYZLkur;IVpv2Tj5rbj;UeBuoOKVSt9;DA4SHBTcotS;EN6VvWHuz6H;suIr6bcCKVv;ejt6ia79ixB;IQEbbjwChym;CRstBHmZrRi;pqxYwxpF3yV;eykgM4I5jQF&dimension=ou:OU_LEVEL-5;dNLjKwsVjod&filter=pe:2014;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  '01MaternalHealth_2014_Upazila': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:sjorO3gQABy;nHvaVDaRcQU;llFRYYZLkur;IVpv2Tj5rbj;UeBuoOKVSt9;DA4SHBTcotS;EN6VvWHuz6H;suIr6bcCKVv;ejt6ia79ixB;IQEbbjwChym;CRstBHmZrRi;pqxYwxpF3yV;eykgM4I5jQF&dimension=ou:OU_GROUP-XpE4AlQZRkV;dNLjKwsVjod&filter=pe:2014;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  '01MaternalHealth_2014_UpazilaHealthComplex': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:sjorO3gQABy;nHvaVDaRcQU;llFRYYZLkur;IVpv2Tj5rbj;UeBuoOKVSt9;DA4SHBTcotS;EN6VvWHuz6H;suIr6bcCKVv;ejt6ia79ixB;IQEbbjwChym;CRstBHmZrRi;pqxYwxpF3yV;eykgM4I5jQF&dimension=ou:OU_GROUP-TwFxBSq8iAg;dNLjKwsVjod&filter=pe:2014;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  '01MaternalHealth_2014_UpazilaandDistrictlevelHF': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:sjorO3gQABy;nHvaVDaRcQU;llFRYYZLkur;IVpv2Tj5rbj;UeBuoOKVSt9;DA4SHBTcotS;EN6VvWHuz6H;suIr6bcCKVv;ejt6ia79ixB;IQEbbjwChym;CRstBHmZrRi;pqxYwxpF3yV;eykgM4I5jQF&dimension=ou:OU_LEVEL-4;dNLjKwsVjod&filter=pe:2014;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  '01MaternalHealth_2015_District': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:sjorO3gQABy;nHvaVDaRcQU;llFRYYZLkur;IVpv2Tj5rbj;UeBuoOKVSt9;DA4SHBTcotS;EN6VvWHuz6H;suIr6bcCKVv;ejt6ia79ixB;IQEbbjwChym;CRstBHmZrRi;pqxYwxpF3yV;eykgM4I5jQF&dimension=ou:OU_GROUP-PyK69cVqr5l;dNLjKwsVjod&filter=pe:2015;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  '01MaternalHealth_2015_DistrictHospital_GeneralHospital': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:sjorO3gQABy;nHvaVDaRcQU;llFRYYZLkur;IVpv2Tj5rbj;UeBuoOKVSt9;DA4SHBTcotS;EN6VvWHuz6H;suIr6bcCKVv;ejt6ia79ixB;IQEbbjwChym;CRstBHmZrRi;pqxYwxpF3yV;eykgM4I5jQF&dimension=ou:OU_GROUP-yiUFzYnD1f9;dNLjKwsVjod&filter=pe:2015;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  '01MaternalHealth_2015_DistrictNGO&PrivateTotal': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:sjorO3gQABy;nHvaVDaRcQU;llFRYYZLkur;IVpv2Tj5rbj;UeBuoOKVSt9;DA4SHBTcotS;EN6VvWHuz6H;suIr6bcCKVv;ejt6ia79ixB;IQEbbjwChym;CRstBHmZrRi;pqxYwxpF3yV;eykgM4I5jQF&dimension=ou:OU_GROUP-Uey6NprfqrE;dNLjKwsVjod&filter=pe:2015;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  '01MaternalHealth_2015_DistrictandNational_DivisionallevelHF': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:sjorO3gQABy;nHvaVDaRcQU;llFRYYZLkur;IVpv2Tj5rbj;UeBuoOKVSt9;DA4SHBTcotS;EN6VvWHuz6H;suIr6bcCKVv;ejt6ia79ixB;IQEbbjwChym;CRstBHmZrRi;pqxYwxpF3yV;eykgM4I5jQF&dimension=ou:OU_LEVEL-3;dNLjKwsVjod&filter=pe:2015;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  '01MaternalHealth_2015_UnionandUpazilalevelHF': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:sjorO3gQABy;nHvaVDaRcQU;llFRYYZLkur;IVpv2Tj5rbj;UeBuoOKVSt9;DA4SHBTcotS;EN6VvWHuz6H;suIr6bcCKVv;ejt6ia79ixB;IQEbbjwChym;CRstBHmZrRi;pqxYwxpF3yV;eykgM4I5jQF&dimension=ou:OU_LEVEL-5;dNLjKwsVjod&filter=pe:2015;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  '01MaternalHealth_2015_Upazila': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:sjorO3gQABy;nHvaVDaRcQU;llFRYYZLkur;IVpv2Tj5rbj;UeBuoOKVSt9;DA4SHBTcotS;EN6VvWHuz6H;suIr6bcCKVv;ejt6ia79ixB;IQEbbjwChym;CRstBHmZrRi;pqxYwxpF3yV;eykgM4I5jQF&dimension=ou:OU_GROUP-XpE4AlQZRkV;dNLjKwsVjod&filter=pe:2015;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  '01MaternalHealth_2015_UpazilaHealthComplex': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:sjorO3gQABy;nHvaVDaRcQU;llFRYYZLkur;IVpv2Tj5rbj;UeBuoOKVSt9;DA4SHBTcotS;EN6VvWHuz6H;suIr6bcCKVv;ejt6ia79ixB;IQEbbjwChym;CRstBHmZrRi;pqxYwxpF3yV;eykgM4I5jQF&dimension=ou:OU_GROUP-TwFxBSq8iAg;dNLjKwsVjod&filter=pe:2015;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  '01MaternalHealth_2015_UpazilaandDistrictlevelHF': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:sjorO3gQABy;nHvaVDaRcQU;llFRYYZLkur;IVpv2Tj5rbj;UeBuoOKVSt9;DA4SHBTcotS;EN6VvWHuz6H;suIr6bcCKVv;ejt6ia79ixB;IQEbbjwChym;CRstBHmZrRi;pqxYwxpF3yV;eykgM4I5jQF&dimension=ou:OU_LEVEL-4;dNLjKwsVjod&filter=pe:2015;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  '01MaternalHealth_2016_District': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:sjorO3gQABy;nHvaVDaRcQU;llFRYYZLkur;IVpv2Tj5rbj;UeBuoOKVSt9;DA4SHBTcotS;EN6VvWHuz6H;suIr6bcCKVv;ejt6ia79ixB;IQEbbjwChym;CRstBHmZrRi;pqxYwxpF3yV;eykgM4I5jQF&dimension=ou:OU_GROUP-PyK69cVqr5l;dNLjKwsVjod&filter=pe:2016;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  '01MaternalHealth_2016_DistrictHospital_GeneralHospital': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:sjorO3gQABy;nHvaVDaRcQU;llFRYYZLkur;IVpv2Tj5rbj;UeBuoOKVSt9;DA4SHBTcotS;EN6VvWHuz6H;suIr6bcCKVv;ejt6ia79ixB;IQEbbjwChym;CRstBHmZrRi;pqxYwxpF3yV;eykgM4I5jQF&dimension=ou:OU_GROUP-yiUFzYnD1f9;dNLjKwsVjod&filter=pe:2016;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  '01MaternalHealth_2016_DistrictNGO&PrivateTotal': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:sjorO3gQABy;nHvaVDaRcQU;llFRYYZLkur;IVpv2Tj5rbj;UeBuoOKVSt9;DA4SHBTcotS;EN6VvWHuz6H;suIr6bcCKVv;ejt6ia79ixB;IQEbbjwChym;CRstBHmZrRi;pqxYwxpF3yV;eykgM4I5jQF&dimension=ou:OU_GROUP-Uey6NprfqrE;dNLjKwsVjod&filter=pe:2016;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  '01MaternalHealth_2016_DistrictandNational_DivisionallevelHF': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:sjorO3gQABy;nHvaVDaRcQU;llFRYYZLkur;IVpv2Tj5rbj;UeBuoOKVSt9;DA4SHBTcotS;EN6VvWHuz6H;suIr6bcCKVv;ejt6ia79ixB;IQEbbjwChym;CRstBHmZrRi;pqxYwxpF3yV;eykgM4I5jQF&dimension=ou:OU_LEVEL-3;dNLjKwsVjod&filter=pe:2016;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  '01MaternalHealth_2016_UnionandUpazilalevelHF': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:sjorO3gQABy;nHvaVDaRcQU;llFRYYZLkur;IVpv2Tj5rbj;UeBuoOKVSt9;DA4SHBTcotS;EN6VvWHuz6H;suIr6bcCKVv;ejt6ia79ixB;IQEbbjwChym;CRstBHmZrRi;pqxYwxpF3yV;eykgM4I5jQF&dimension=ou:OU_LEVEL-5;dNLjKwsVjod&filter=pe:2016;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  '01MaternalHealth_2016_Upazila': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:sjorO3gQABy;nHvaVDaRcQU;llFRYYZLkur;IVpv2Tj5rbj;UeBuoOKVSt9;DA4SHBTcotS;EN6VvWHuz6H;suIr6bcCKVv;ejt6ia79ixB;IQEbbjwChym;CRstBHmZrRi;pqxYwxpF3yV;eykgM4I5jQF&dimension=ou:OU_GROUP-XpE4AlQZRkV;dNLjKwsVjod&filter=pe:2016;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  '01MaternalHealth_2016_UpazilaHealthComplex': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:sjorO3gQABy;nHvaVDaRcQU;llFRYYZLkur;IVpv2Tj5rbj;UeBuoOKVSt9;DA4SHBTcotS;EN6VvWHuz6H;suIr6bcCKVv;ejt6ia79ixB;IQEbbjwChym;CRstBHmZrRi;pqxYwxpF3yV;eykgM4I5jQF&dimension=ou:OU_GROUP-TwFxBSq8iAg;dNLjKwsVjod&filter=pe:2016;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  '01MaternalHealth_2016_UpazilaandDistrictlevelHF': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:sjorO3gQABy;nHvaVDaRcQU;llFRYYZLkur;IVpv2Tj5rbj;UeBuoOKVSt9;DA4SHBTcotS;EN6VvWHuz6H;suIr6bcCKVv;ejt6ia79ixB;IQEbbjwChym;CRstBHmZrRi;pqxYwxpF3yV;eykgM4I5jQF&dimension=ou:OU_LEVEL-4;dNLjKwsVjod&filter=pe:2016;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  '01MaternalHealth_2017_District': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:sjorO3gQABy;nHvaVDaRcQU;llFRYYZLkur;IVpv2Tj5rbj;UeBuoOKVSt9;DA4SHBTcotS;EN6VvWHuz6H;suIr6bcCKVv;ejt6ia79ixB;IQEbbjwChym;CRstBHmZrRi;pqxYwxpF3yV;eykgM4I5jQF&dimension=ou:OU_GROUP-PyK69cVqr5l;dNLjKwsVjod&filter=pe:2017;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  '01MaternalHealth_2017_DistrictHospital_GeneralHospital': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:sjorO3gQABy;nHvaVDaRcQU;llFRYYZLkur;IVpv2Tj5rbj;UeBuoOKVSt9;DA4SHBTcotS;EN6VvWHuz6H;suIr6bcCKVv;ejt6ia79ixB;IQEbbjwChym;CRstBHmZrRi;pqxYwxpF3yV;eykgM4I5jQF&dimension=ou:OU_GROUP-yiUFzYnD1f9;dNLjKwsVjod&filter=pe:2017;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  '01MaternalHealth_2017_DistrictNGO&PrivateTotal': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:sjorO3gQABy;nHvaVDaRcQU;llFRYYZLkur;IVpv2Tj5rbj;UeBuoOKVSt9;DA4SHBTcotS;EN6VvWHuz6H;suIr6bcCKVv;ejt6ia79ixB;IQEbbjwChym;CRstBHmZrRi;pqxYwxpF3yV;eykgM4I5jQF&dimension=ou:OU_GROUP-Uey6NprfqrE;dNLjKwsVjod&filter=pe:2017;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  '01MaternalHealth_2017_DistrictandNational_DivisionallevelHF': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:sjorO3gQABy;nHvaVDaRcQU;llFRYYZLkur;IVpv2Tj5rbj;UeBuoOKVSt9;DA4SHBTcotS;EN6VvWHuz6H;suIr6bcCKVv;ejt6ia79ixB;IQEbbjwChym;CRstBHmZrRi;pqxYwxpF3yV;eykgM4I5jQF&dimension=ou:OU_LEVEL-3;dNLjKwsVjod&filter=pe:2017;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  '01MaternalHealth_2017_UnionandUpazilalevelHF': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:sjorO3gQABy;nHvaVDaRcQU;llFRYYZLkur;IVpv2Tj5rbj;UeBuoOKVSt9;DA4SHBTcotS;EN6VvWHuz6H;suIr6bcCKVv;ejt6ia79ixB;IQEbbjwChym;CRstBHmZrRi;pqxYwxpF3yV;eykgM4I5jQF&dimension=ou:OU_LEVEL-5;dNLjKwsVjod&filter=pe:2017;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  '01MaternalHealth_2017_Upazila': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:sjorO3gQABy;nHvaVDaRcQU;llFRYYZLkur;IVpv2Tj5rbj;UeBuoOKVSt9;DA4SHBTcotS;EN6VvWHuz6H;suIr6bcCKVv;ejt6ia79ixB;IQEbbjwChym;CRstBHmZrRi;pqxYwxpF3yV;eykgM4I5jQF&dimension=ou:OU_GROUP-XpE4AlQZRkV;dNLjKwsVjod&filter=pe:2017;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  '01MaternalHealth_2017_UpazilaHealthComplex': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:sjorO3gQABy;nHvaVDaRcQU;llFRYYZLkur;IVpv2Tj5rbj;UeBuoOKVSt9;DA4SHBTcotS;EN6VvWHuz6H;suIr6bcCKVv;ejt6ia79ixB;IQEbbjwChym;CRstBHmZrRi;pqxYwxpF3yV;eykgM4I5jQF&dimension=ou:OU_GROUP-TwFxBSq8iAg;dNLjKwsVjod&filter=pe:2017;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  '01MaternalHealth_2017_UpazilaandDistrictlevelHF': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:sjorO3gQABy;nHvaVDaRcQU;llFRYYZLkur;IVpv2Tj5rbj;UeBuoOKVSt9;DA4SHBTcotS;EN6VvWHuz6H;suIr6bcCKVv;ejt6ia79ixB;IQEbbjwChym;CRstBHmZrRi;pqxYwxpF3yV;eykgM4I5jQF&dimension=ou:OU_LEVEL-4;dNLjKwsVjod&filter=pe:2017;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  '01MaternalHealth_2018_District': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:sjorO3gQABy;nHvaVDaRcQU;llFRYYZLkur;IVpv2Tj5rbj;UeBuoOKVSt9;DA4SHBTcotS;EN6VvWHuz6H;suIr6bcCKVv;ejt6ia79ixB;IQEbbjwChym;CRstBHmZrRi;pqxYwxpF3yV;eykgM4I5jQF&dimension=ou:OU_GROUP-PyK69cVqr5l;dNLjKwsVjod&filter=pe:2018;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  '01MaternalHealth_2018_DistrictHospital_GeneralHospital': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:sjorO3gQABy;nHvaVDaRcQU;llFRYYZLkur;IVpv2Tj5rbj;UeBuoOKVSt9;DA4SHBTcotS;EN6VvWHuz6H;suIr6bcCKVv;ejt6ia79ixB;IQEbbjwChym;CRstBHmZrRi;pqxYwxpF3yV;eykgM4I5jQF&dimension=ou:OU_GROUP-yiUFzYnD1f9;dNLjKwsVjod&filter=pe:2018;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  '01MaternalHealth_2018_DistrictNGO&PrivateTotal': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:sjorO3gQABy;nHvaVDaRcQU;llFRYYZLkur;IVpv2Tj5rbj;UeBuoOKVSt9;DA4SHBTcotS;EN6VvWHuz6H;suIr6bcCKVv;ejt6ia79ixB;IQEbbjwChym;CRstBHmZrRi;pqxYwxpF3yV;eykgM4I5jQF&dimension=ou:OU_GROUP-Uey6NprfqrE;dNLjKwsVjod&filter=pe:2018;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  '01MaternalHealth_2018_DistrictandNational_DivisionallevelHF': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:sjorO3gQABy;nHvaVDaRcQU;llFRYYZLkur;IVpv2Tj5rbj;UeBuoOKVSt9;DA4SHBTcotS;EN6VvWHuz6H;suIr6bcCKVv;ejt6ia79ixB;IQEbbjwChym;CRstBHmZrRi;pqxYwxpF3yV;eykgM4I5jQF&dimension=ou:OU_LEVEL-3;dNLjKwsVjod&filter=pe:2018;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  '01MaternalHealth_2018_UnionandUpazilalevelHF': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:sjorO3gQABy;nHvaVDaRcQU;llFRYYZLkur;IVpv2Tj5rbj;UeBuoOKVSt9;DA4SHBTcotS;EN6VvWHuz6H;suIr6bcCKVv;ejt6ia79ixB;IQEbbjwChym;CRstBHmZrRi;pqxYwxpF3yV;eykgM4I5jQF&dimension=ou:OU_LEVEL-5;dNLjKwsVjod&filter=pe:2018;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  '01MaternalHealth_2018_Upazila': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:sjorO3gQABy;nHvaVDaRcQU;llFRYYZLkur;IVpv2Tj5rbj;UeBuoOKVSt9;DA4SHBTcotS;EN6VvWHuz6H;suIr6bcCKVv;ejt6ia79ixB;IQEbbjwChym;CRstBHmZrRi;pqxYwxpF3yV;eykgM4I5jQF&dimension=ou:OU_GROUP-XpE4AlQZRkV;dNLjKwsVjod&filter=pe:2018;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  '01MaternalHealth_2018_UpazilaHealthComplex': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:sjorO3gQABy;nHvaVDaRcQU;llFRYYZLkur;IVpv2Tj5rbj;UeBuoOKVSt9;DA4SHBTcotS;EN6VvWHuz6H;suIr6bcCKVv;ejt6ia79ixB;IQEbbjwChym;CRstBHmZrRi;pqxYwxpF3yV;eykgM4I5jQF&dimension=ou:OU_GROUP-TwFxBSq8iAg;dNLjKwsVjod&filter=pe:2018;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  '01MaternalHealth_2018_UpazilaandDistrictlevelHF': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:sjorO3gQABy;nHvaVDaRcQU;llFRYYZLkur;IVpv2Tj5rbj;UeBuoOKVSt9;DA4SHBTcotS;EN6VvWHuz6H;suIr6bcCKVv;ejt6ia79ixB;IQEbbjwChym;CRstBHmZrRi;pqxYwxpF3yV;eykgM4I5jQF&dimension=ou:OU_LEVEL-4;dNLjKwsVjod&filter=pe:2018;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  '02ChildHealth_2009_District': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:LwxiPaHQwif;IQ1WyeMu4PS;Pd6AH5koIb3;t4CnonJDTnt;RRWmViud0qT;wzLKMAyhQPp;b6SWIKqm2pB;QVoVu8biqp6;R4d4BKvjEZj&dimension=ou:OU_GROUP-PyK69cVqr5l;dNLjKwsVjod&filter=pe:2009;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  '02ChildHealth_2009_DistrictHospital_GeneralHospital': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:LwxiPaHQwif;IQ1WyeMu4PS;Pd6AH5koIb3;t4CnonJDTnt;RRWmViud0qT;wzLKMAyhQPp;b6SWIKqm2pB;QVoVu8biqp6;R4d4BKvjEZj&dimension=ou:OU_GROUP-yiUFzYnD1f9;dNLjKwsVjod&filter=pe:2009;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  '02ChildHealth_2009_DistrictNGO&PrivateTotal': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:LwxiPaHQwif;IQ1WyeMu4PS;Pd6AH5koIb3;t4CnonJDTnt;RRWmViud0qT;wzLKMAyhQPp;b6SWIKqm2pB;QVoVu8biqp6;R4d4BKvjEZj&dimension=ou:OU_GROUP-Uey6NprfqrE;dNLjKwsVjod&filter=pe:2009;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  '02ChildHealth_2009_DistrictandNational_DivisionallevelHF': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:LwxiPaHQwif;IQ1WyeMu4PS;Pd6AH5koIb3;t4CnonJDTnt;RRWmViud0qT;wzLKMAyhQPp;b6SWIKqm2pB;QVoVu8biqp6;R4d4BKvjEZj&dimension=ou:OU_LEVEL-3;dNLjKwsVjod&filter=pe:2009;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  '02ChildHealth_2009_UnionandUpazilalevelHF': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:LwxiPaHQwif;IQ1WyeMu4PS;Pd6AH5koIb3;t4CnonJDTnt;RRWmViud0qT;wzLKMAyhQPp;b6SWIKqm2pB;QVoVu8biqp6;R4d4BKvjEZj&dimension=ou:OU_LEVEL-5;dNLjKwsVjod&filter=pe:2009;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  '02ChildHealth_2009_Upazila': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:LwxiPaHQwif;IQ1WyeMu4PS;Pd6AH5koIb3;t4CnonJDTnt;RRWmViud0qT;wzLKMAyhQPp;b6SWIKqm2pB;QVoVu8biqp6;R4d4BKvjEZj&dimension=ou:OU_GROUP-XpE4AlQZRkV;dNLjKwsVjod&filter=pe:2009;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  '02ChildHealth_2009_UpazilaHealthComplex': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:LwxiPaHQwif;IQ1WyeMu4PS;Pd6AH5koIb3;t4CnonJDTnt;RRWmViud0qT;wzLKMAyhQPp;b6SWIKqm2pB;QVoVu8biqp6;R4d4BKvjEZj&dimension=ou:OU_GROUP-TwFxBSq8iAg;dNLjKwsVjod&filter=pe:2009;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  '02ChildHealth_2009_UpazilaandDistrictlevelHF': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:LwxiPaHQwif;IQ1WyeMu4PS;Pd6AH5koIb3;t4CnonJDTnt;RRWmViud0qT;wzLKMAyhQPp;b6SWIKqm2pB;QVoVu8biqp6;R4d4BKvjEZj&dimension=ou:OU_LEVEL-4;dNLjKwsVjod&filter=pe:2009;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  '02ChildHealth_2010_District': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:LwxiPaHQwif;IQ1WyeMu4PS;Pd6AH5koIb3;t4CnonJDTnt;RRWmViud0qT;wzLKMAyhQPp;b6SWIKqm2pB;QVoVu8biqp6;R4d4BKvjEZj&dimension=ou:OU_GROUP-PyK69cVqr5l;dNLjKwsVjod&filter=pe:2010;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  '02ChildHealth_2010_DistrictHospital_GeneralHospital': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:LwxiPaHQwif;IQ1WyeMu4PS;Pd6AH5koIb3;t4CnonJDTnt;RRWmViud0qT;wzLKMAyhQPp;b6SWIKqm2pB;QVoVu8biqp6;R4d4BKvjEZj&dimension=ou:OU_GROUP-yiUFzYnD1f9;dNLjKwsVjod&filter=pe:2010;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  '02ChildHealth_2010_DistrictNGO&PrivateTotal': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:LwxiPaHQwif;IQ1WyeMu4PS;Pd6AH5koIb3;t4CnonJDTnt;RRWmViud0qT;wzLKMAyhQPp;b6SWIKqm2pB;QVoVu8biqp6;R4d4BKvjEZj&dimension=ou:OU_GROUP-Uey6NprfqrE;dNLjKwsVjod&filter=pe:2010;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  '02ChildHealth_2010_DistrictandNational_DivisionallevelHF': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:LwxiPaHQwif;IQ1WyeMu4PS;Pd6AH5koIb3;t4CnonJDTnt;RRWmViud0qT;wzLKMAyhQPp;b6SWIKqm2pB;QVoVu8biqp6;R4d4BKvjEZj&dimension=ou:OU_LEVEL-3;dNLjKwsVjod&filter=pe:2010;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  '02ChildHealth_2010_UnionandUpazilalevelHF': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:LwxiPaHQwif;IQ1WyeMu4PS;Pd6AH5koIb3;t4CnonJDTnt;RRWmViud0qT;wzLKMAyhQPp;b6SWIKqm2pB;QVoVu8biqp6;R4d4BKvjEZj&dimension=ou:OU_LEVEL-5;dNLjKwsVjod&filter=pe:2010;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  '02ChildHealth_2010_Upazila': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:LwxiPaHQwif;IQ1WyeMu4PS;Pd6AH5koIb3;t4CnonJDTnt;RRWmViud0qT;wzLKMAyhQPp;b6SWIKqm2pB;QVoVu8biqp6;R4d4BKvjEZj&dimension=ou:OU_GROUP-XpE4AlQZRkV;dNLjKwsVjod&filter=pe:2010;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  '02ChildHealth_2010_UpazilaHealthComplex': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:LwxiPaHQwif;IQ1WyeMu4PS;Pd6AH5koIb3;t4CnonJDTnt;RRWmViud0qT;wzLKMAyhQPp;b6SWIKqm2pB;QVoVu8biqp6;R4d4BKvjEZj&dimension=ou:OU_GROUP-TwFxBSq8iAg;dNLjKwsVjod&filter=pe:2010;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  '02ChildHealth_2010_UpazilaandDistrictlevelHF': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:LwxiPaHQwif;IQ1WyeMu4PS;Pd6AH5koIb3;t4CnonJDTnt;RRWmViud0qT;wzLKMAyhQPp;b6SWIKqm2pB;QVoVu8biqp6;R4d4BKvjEZj&dimension=ou:OU_LEVEL-4;dNLjKwsVjod&filter=pe:2010;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  '02ChildHealth_2011_District': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:LwxiPaHQwif;IQ1WyeMu4PS;Pd6AH5koIb3;t4CnonJDTnt;RRWmViud0qT;wzLKMAyhQPp;b6SWIKqm2pB;QVoVu8biqp6;R4d4BKvjEZj&dimension=ou:OU_GROUP-PyK69cVqr5l;dNLjKwsVjod&filter=pe:2011;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  '02ChildHealth_2011_DistrictHospital_GeneralHospital': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:LwxiPaHQwif;IQ1WyeMu4PS;Pd6AH5koIb3;t4CnonJDTnt;RRWmViud0qT;wzLKMAyhQPp;b6SWIKqm2pB;QVoVu8biqp6;R4d4BKvjEZj&dimension=ou:OU_GROUP-yiUFzYnD1f9;dNLjKwsVjod&filter=pe:2011;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  '02ChildHealth_2011_DistrictNGO&PrivateTotal': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:LwxiPaHQwif;IQ1WyeMu4PS;Pd6AH5koIb3;t4CnonJDTnt;RRWmViud0qT;wzLKMAyhQPp;b6SWIKqm2pB;QVoVu8biqp6;R4d4BKvjEZj&dimension=ou:OU_GROUP-Uey6NprfqrE;dNLjKwsVjod&filter=pe:2011;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  '02ChildHealth_2011_DistrictandNational_DivisionallevelHF': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:LwxiPaHQwif;IQ1WyeMu4PS;Pd6AH5koIb3;t4CnonJDTnt;RRWmViud0qT;wzLKMAyhQPp;b6SWIKqm2pB;QVoVu8biqp6;R4d4BKvjEZj&dimension=ou:OU_LEVEL-3;dNLjKwsVjod&filter=pe:2011;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  '02ChildHealth_2011_UnionandUpazilalevelHF': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:LwxiPaHQwif;IQ1WyeMu4PS;Pd6AH5koIb3;t4CnonJDTnt;RRWmViud0qT;wzLKMAyhQPp;b6SWIKqm2pB;QVoVu8biqp6;R4d4BKvjEZj&dimension=ou:OU_LEVEL-5;dNLjKwsVjod&filter=pe:2011;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  '02ChildHealth_2011_Upazila': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:LwxiPaHQwif;IQ1WyeMu4PS;Pd6AH5koIb3;t4CnonJDTnt;RRWmViud0qT;wzLKMAyhQPp;b6SWIKqm2pB;QVoVu8biqp6;R4d4BKvjEZj&dimension=ou:OU_GROUP-XpE4AlQZRkV;dNLjKwsVjod&filter=pe:2011;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  '02ChildHealth_2011_UpazilaHealthComplex': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:LwxiPaHQwif;IQ1WyeMu4PS;Pd6AH5koIb3;t4CnonJDTnt;RRWmViud0qT;wzLKMAyhQPp;b6SWIKqm2pB;QVoVu8biqp6;R4d4BKvjEZj&dimension=ou:OU_GROUP-TwFxBSq8iAg;dNLjKwsVjod&filter=pe:2011;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  '02ChildHealth_2011_UpazilaandDistrictlevelHF': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:LwxiPaHQwif;IQ1WyeMu4PS;Pd6AH5koIb3;t4CnonJDTnt;RRWmViud0qT;wzLKMAyhQPp;b6SWIKqm2pB;QVoVu8biqp6;R4d4BKvjEZj&dimension=ou:OU_LEVEL-4;dNLjKwsVjod&filter=pe:2011;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  '02ChildHealth_2012_District': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:LwxiPaHQwif;IQ1WyeMu4PS;Pd6AH5koIb3;t4CnonJDTnt;RRWmViud0qT;wzLKMAyhQPp;b6SWIKqm2pB;QVoVu8biqp6;R4d4BKvjEZj&dimension=ou:OU_GROUP-PyK69cVqr5l;dNLjKwsVjod&filter=pe:2012;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  '02ChildHealth_2012_DistrictHospital_GeneralHospital': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:LwxiPaHQwif;IQ1WyeMu4PS;Pd6AH5koIb3;t4CnonJDTnt;RRWmViud0qT;wzLKMAyhQPp;b6SWIKqm2pB;QVoVu8biqp6;R4d4BKvjEZj&dimension=ou:OU_GROUP-yiUFzYnD1f9;dNLjKwsVjod&filter=pe:2012;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  '02ChildHealth_2012_DistrictNGO&PrivateTotal': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:LwxiPaHQwif;IQ1WyeMu4PS;Pd6AH5koIb3;t4CnonJDTnt;RRWmViud0qT;wzLKMAyhQPp;b6SWIKqm2pB;QVoVu8biqp6;R4d4BKvjEZj&dimension=ou:OU_GROUP-Uey6NprfqrE;dNLjKwsVjod&filter=pe:2012;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  '02ChildHealth_2012_DistrictandNational_DivisionallevelHF': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:LwxiPaHQwif;IQ1WyeMu4PS;Pd6AH5koIb3;t4CnonJDTnt;RRWmViud0qT;wzLKMAyhQPp;b6SWIKqm2pB;QVoVu8biqp6;R4d4BKvjEZj&dimension=ou:OU_LEVEL-3;dNLjKwsVjod&filter=pe:2012;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  '02ChildHealth_2012_UnionandUpazilalevelHF': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:LwxiPaHQwif;IQ1WyeMu4PS;Pd6AH5koIb3;t4CnonJDTnt;RRWmViud0qT;wzLKMAyhQPp;b6SWIKqm2pB;QVoVu8biqp6;R4d4BKvjEZj&dimension=ou:OU_LEVEL-5;dNLjKwsVjod&filter=pe:2012;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  '02ChildHealth_2012_Upazila': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:LwxiPaHQwif;IQ1WyeMu4PS;Pd6AH5koIb3;t4CnonJDTnt;RRWmViud0qT;wzLKMAyhQPp;b6SWIKqm2pB;QVoVu8biqp6;R4d4BKvjEZj&dimension=ou:OU_GROUP-XpE4AlQZRkV;dNLjKwsVjod&filter=pe:2012;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  '02ChildHealth_2012_UpazilaHealthComplex': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:LwxiPaHQwif;IQ1WyeMu4PS;Pd6AH5koIb3;t4CnonJDTnt;RRWmViud0qT;wzLKMAyhQPp;b6SWIKqm2pB;QVoVu8biqp6;R4d4BKvjEZj&dimension=ou:OU_GROUP-TwFxBSq8iAg;dNLjKwsVjod&filter=pe:2012;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  '02ChildHealth_2012_UpazilaandDistrictlevelHF': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:LwxiPaHQwif;IQ1WyeMu4PS;Pd6AH5koIb3;t4CnonJDTnt;RRWmViud0qT;wzLKMAyhQPp;b6SWIKqm2pB;QVoVu8biqp6;R4d4BKvjEZj&dimension=ou:OU_LEVEL-4;dNLjKwsVjod&filter=pe:2012;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  '02ChildHealth_2013_District': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:LwxiPaHQwif;IQ1WyeMu4PS;Pd6AH5koIb3;t4CnonJDTnt;RRWmViud0qT;wzLKMAyhQPp;b6SWIKqm2pB;QVoVu8biqp6;R4d4BKvjEZj&dimension=ou:OU_GROUP-PyK69cVqr5l;dNLjKwsVjod&filter=pe:2013;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  '02ChildHealth_2013_DistrictHospital_GeneralHospital': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:LwxiPaHQwif;IQ1WyeMu4PS;Pd6AH5koIb3;t4CnonJDTnt;RRWmViud0qT;wzLKMAyhQPp;b6SWIKqm2pB;QVoVu8biqp6;R4d4BKvjEZj&dimension=ou:OU_GROUP-yiUFzYnD1f9;dNLjKwsVjod&filter=pe:2013;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  '02ChildHealth_2013_DistrictNGO&PrivateTotal': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:LwxiPaHQwif;IQ1WyeMu4PS;Pd6AH5koIb3;t4CnonJDTnt;RRWmViud0qT;wzLKMAyhQPp;b6SWIKqm2pB;QVoVu8biqp6;R4d4BKvjEZj&dimension=ou:OU_GROUP-Uey6NprfqrE;dNLjKwsVjod&filter=pe:2013;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  '02ChildHealth_2013_DistrictandNational_DivisionallevelHF': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:LwxiPaHQwif;IQ1WyeMu4PS;Pd6AH5koIb3;t4CnonJDTnt;RRWmViud0qT;wzLKMAyhQPp;b6SWIKqm2pB;QVoVu8biqp6;R4d4BKvjEZj&dimension=ou:OU_LEVEL-3;dNLjKwsVjod&filter=pe:2013;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  '02ChildHealth_2013_UnionandUpazilalevelHF': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:LwxiPaHQwif;IQ1WyeMu4PS;Pd6AH5koIb3;t4CnonJDTnt;RRWmViud0qT;wzLKMAyhQPp;b6SWIKqm2pB;QVoVu8biqp6;R4d4BKvjEZj&dimension=ou:OU_LEVEL-5;dNLjKwsVjod&filter=pe:2013;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  '02ChildHealth_2013_Upazila': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:LwxiPaHQwif;IQ1WyeMu4PS;Pd6AH5koIb3;t4CnonJDTnt;RRWmViud0qT;wzLKMAyhQPp;b6SWIKqm2pB;QVoVu8biqp6;R4d4BKvjEZj&dimension=ou:OU_GROUP-XpE4AlQZRkV;dNLjKwsVjod&filter=pe:2013;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  '02ChildHealth_2013_UpazilaHealthComplex': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:LwxiPaHQwif;IQ1WyeMu4PS;Pd6AH5koIb3;t4CnonJDTnt;RRWmViud0qT;wzLKMAyhQPp;b6SWIKqm2pB;QVoVu8biqp6;R4d4BKvjEZj&dimension=ou:OU_GROUP-TwFxBSq8iAg;dNLjKwsVjod&filter=pe:2013;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  '02ChildHealth_2013_UpazilaandDistrictlevelHF': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:LwxiPaHQwif;IQ1WyeMu4PS;Pd6AH5koIb3;t4CnonJDTnt;RRWmViud0qT;wzLKMAyhQPp;b6SWIKqm2pB;QVoVu8biqp6;R4d4BKvjEZj&dimension=ou:OU_LEVEL-4;dNLjKwsVjod&filter=pe:2013;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  '02ChildHealth_2014_District': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:LwxiPaHQwif;IQ1WyeMu4PS;Pd6AH5koIb3;t4CnonJDTnt;RRWmViud0qT;wzLKMAyhQPp;b6SWIKqm2pB;QVoVu8biqp6;R4d4BKvjEZj&dimension=ou:OU_GROUP-PyK69cVqr5l;dNLjKwsVjod&filter=pe:2014;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  '02ChildHealth_2014_DistrictHospital_GeneralHospital': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:LwxiPaHQwif;IQ1WyeMu4PS;Pd6AH5koIb3;t4CnonJDTnt;RRWmViud0qT;wzLKMAyhQPp;b6SWIKqm2pB;QVoVu8biqp6;R4d4BKvjEZj&dimension=ou:OU_GROUP-yiUFzYnD1f9;dNLjKwsVjod&filter=pe:2014;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  '02ChildHealth_2014_DistrictNGO&PrivateTotal': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:LwxiPaHQwif;IQ1WyeMu4PS;Pd6AH5koIb3;t4CnonJDTnt;RRWmViud0qT;wzLKMAyhQPp;b6SWIKqm2pB;QVoVu8biqp6;R4d4BKvjEZj&dimension=ou:OU_GROUP-Uey6NprfqrE;dNLjKwsVjod&filter=pe:2014;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  '02ChildHealth_2014_DistrictandNational_DivisionallevelHF': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:LwxiPaHQwif;IQ1WyeMu4PS;Pd6AH5koIb3;t4CnonJDTnt;RRWmViud0qT;wzLKMAyhQPp;b6SWIKqm2pB;QVoVu8biqp6;R4d4BKvjEZj&dimension=ou:OU_LEVEL-3;dNLjKwsVjod&filter=pe:2014;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  '02ChildHealth_2014_UnionandUpazilalevelHF': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:LwxiPaHQwif;IQ1WyeMu4PS;Pd6AH5koIb3;t4CnonJDTnt;RRWmViud0qT;wzLKMAyhQPp;b6SWIKqm2pB;QVoVu8biqp6;R4d4BKvjEZj&dimension=ou:OU_LEVEL-5;dNLjKwsVjod&filter=pe:2014;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  '02ChildHealth_2014_Upazila': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:LwxiPaHQwif;IQ1WyeMu4PS;Pd6AH5koIb3;t4CnonJDTnt;RRWmViud0qT;wzLKMAyhQPp;b6SWIKqm2pB;QVoVu8biqp6;R4d4BKvjEZj&dimension=ou:OU_GROUP-XpE4AlQZRkV;dNLjKwsVjod&filter=pe:2014;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  '02ChildHealth_2014_UpazilaHealthComplex': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:LwxiPaHQwif;IQ1WyeMu4PS;Pd6AH5koIb3;t4CnonJDTnt;RRWmViud0qT;wzLKMAyhQPp;b6SWIKqm2pB;QVoVu8biqp6;R4d4BKvjEZj&dimension=ou:OU_GROUP-TwFxBSq8iAg;dNLjKwsVjod&filter=pe:2014;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  '02ChildHealth_2014_UpazilaandDistrictlevelHF': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:LwxiPaHQwif;IQ1WyeMu4PS;Pd6AH5koIb3;t4CnonJDTnt;RRWmViud0qT;wzLKMAyhQPp;b6SWIKqm2pB;QVoVu8biqp6;R4d4BKvjEZj&dimension=ou:OU_LEVEL-4;dNLjKwsVjod&filter=pe:2014;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
# ...
#  'AntenatalCare(ANC)_2011_UpazilaandDistrictlevelHF': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:lqGV3xf4MnW;EMN9ubIGpGh;wpDTeNQUuEb&dimension=ou:OU_LEVEL-4;dNLjKwsVjod&filter=pe:2011;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  'AntenatalCare(ANC)_2012_District': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:lqGV3xf4MnW;EMN9ubIGpGh;wpDTeNQUuEb&dimension=ou:OU_GROUP-PyK69cVqr5l;dNLjKwsVjod&filter=pe:2012;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  'AntenatalCare(ANC)_2012_DistrictHospital_GeneralHospital': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:lqGV3xf4MnW;EMN9ubIGpGh;wpDTeNQUuEb&dimension=ou:OU_GROUP-yiUFzYnD1f9;dNLjKwsVjod&filter=pe:2012;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  'AntenatalCare(ANC)_2012_DistrictNGO&PrivateTotal': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:lqGV3xf4MnW;EMN9ubIGpGh;wpDTeNQUuEb&dimension=ou:OU_GROUP-Uey6NprfqrE;dNLjKwsVjod&filter=pe:2012;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  'AntenatalCare(ANC)_2012_DistrictandNational_DivisionallevelHF': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:lqGV3xf4MnW;EMN9ubIGpGh;wpDTeNQUuEb&dimension=ou:OU_LEVEL-3;dNLjKwsVjod&filter=pe:2012;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  'AntenatalCare(ANC)_2012_UnionandUpazilalevelHF': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:lqGV3xf4MnW;EMN9ubIGpGh;wpDTeNQUuEb&dimension=ou:OU_LEVEL-5;dNLjKwsVjod&filter=pe:2012;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  'AntenatalCare(ANC)_2012_Upazila': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:lqGV3xf4MnW;EMN9ubIGpGh;wpDTeNQUuEb&dimension=ou:OU_GROUP-XpE4AlQZRkV;dNLjKwsVjod&filter=pe:2012;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  'AntenatalCare(ANC)_2012_UpazilaHealthComplex': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:lqGV3xf4MnW;EMN9ubIGpGh;wpDTeNQUuEb&dimension=ou:OU_GROUP-TwFxBSq8iAg;dNLjKwsVjod&filter=pe:2012;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  'AntenatalCare(ANC)_2012_UpazilaandDistrictlevelHF': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:lqGV3xf4MnW;EMN9ubIGpGh;wpDTeNQUuEb&dimension=ou:OU_LEVEL-4;dNLjKwsVjod&filter=pe:2012;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  'AntenatalCare(ANC)_2013_District': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:lqGV3xf4MnW;EMN9ubIGpGh;wpDTeNQUuEb&dimension=ou:OU_GROUP-PyK69cVqr5l;dNLjKwsVjod&filter=pe:2013;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  'AntenatalCare(ANC)_2013_DistrictHospital_GeneralHospital': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:lqGV3xf4MnW;EMN9ubIGpGh;wpDTeNQUuEb&dimension=ou:OU_GROUP-yiUFzYnD1f9;dNLjKwsVjod&filter=pe:2013;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  'AntenatalCare(ANC)_2013_DistrictNGO&PrivateTotal': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:lqGV3xf4MnW;EMN9ubIGpGh;wpDTeNQUuEb&dimension=ou:OU_GROUP-Uey6NprfqrE;dNLjKwsVjod&filter=pe:2013;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  'AntenatalCare(ANC)_2013_DistrictandNational_DivisionallevelHF': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:lqGV3xf4MnW;EMN9ubIGpGh;wpDTeNQUuEb&dimension=ou:OU_LEVEL-3;dNLjKwsVjod&filter=pe:2013;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  'AntenatalCare(ANC)_2013_UnionandUpazilalevelHF': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:lqGV3xf4MnW;EMN9ubIGpGh;wpDTeNQUuEb&dimension=ou:OU_LEVEL-5;dNLjKwsVjod&filter=pe:2013;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  'AntenatalCare(ANC)_2013_Upazila': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:lqGV3xf4MnW;EMN9ubIGpGh;wpDTeNQUuEb&dimension=ou:OU_GROUP-XpE4AlQZRkV;dNLjKwsVjod&filter=pe:2013;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  'AntenatalCare(ANC)_2013_UpazilaHealthComplex': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:lqGV3xf4MnW;EMN9ubIGpGh;wpDTeNQUuEb&dimension=ou:OU_GROUP-TwFxBSq8iAg;dNLjKwsVjod&filter=pe:2013;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  'AntenatalCare(ANC)_2013_UpazilaandDistrictlevelHF': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:lqGV3xf4MnW;EMN9ubIGpGh;wpDTeNQUuEb&dimension=ou:OU_LEVEL-4;dNLjKwsVjod&filter=pe:2013;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  'AntenatalCare(ANC)_2014_District': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:lqGV3xf4MnW;EMN9ubIGpGh;wpDTeNQUuEb&dimension=ou:OU_GROUP-PyK69cVqr5l;dNLjKwsVjod&filter=pe:2014;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  'AntenatalCare(ANC)_2014_DistrictHospital_GeneralHospital': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:lqGV3xf4MnW;EMN9ubIGpGh;wpDTeNQUuEb&dimension=ou:OU_GROUP-yiUFzYnD1f9;dNLjKwsVjod&filter=pe:2014;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  'AntenatalCare(ANC)_2014_DistrictNGO&PrivateTotal': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:lqGV3xf4MnW;EMN9ubIGpGh;wpDTeNQUuEb&dimension=ou:OU_GROUP-Uey6NprfqrE;dNLjKwsVjod&filter=pe:2014;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  'AntenatalCare(ANC)_2014_DistrictandNational_DivisionallevelHF': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:lqGV3xf4MnW;EMN9ubIGpGh;wpDTeNQUuEb&dimension=ou:OU_LEVEL-3;dNLjKwsVjod&filter=pe:2014;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  'AntenatalCare(ANC)_2014_UnionandUpazilalevelHF': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:lqGV3xf4MnW;EMN9ubIGpGh;wpDTeNQUuEb&dimension=ou:OU_LEVEL-5;dNLjKwsVjod&filter=pe:2014;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  'AntenatalCare(ANC)_2014_Upazila': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:lqGV3xf4MnW;EMN9ubIGpGh;wpDTeNQUuEb&dimension=ou:OU_GROUP-XpE4AlQZRkV;dNLjKwsVjod&filter=pe:2014;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  'AntenatalCare(ANC)_2014_UpazilaHealthComplex': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:lqGV3xf4MnW;EMN9ubIGpGh;wpDTeNQUuEb&dimension=ou:OU_GROUP-TwFxBSq8iAg;dNLjKwsVjod&filter=pe:2014;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  'AntenatalCare(ANC)_2014_UpazilaandDistrictlevelHF': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:lqGV3xf4MnW;EMN9ubIGpGh;wpDTeNQUuEb&dimension=ou:OU_LEVEL-4;dNLjKwsVjod&filter=pe:2014;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  'AntenatalCare(ANC)_2015_District': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:lqGV3xf4MnW;EMN9ubIGpGh;wpDTeNQUuEb&dimension=ou:OU_GROUP-PyK69cVqr5l;dNLjKwsVjod&filter=pe:2015;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  'AntenatalCare(ANC)_2015_DistrictHospital_GeneralHospital': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:lqGV3xf4MnW;EMN9ubIGpGh;wpDTeNQUuEb&dimension=ou:OU_GROUP-yiUFzYnD1f9;dNLjKwsVjod&filter=pe:2015;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  'AntenatalCare(ANC)_2015_DistrictNGO&PrivateTotal': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:lqGV3xf4MnW;EMN9ubIGpGh;wpDTeNQUuEb&dimension=ou:OU_GROUP-Uey6NprfqrE;dNLjKwsVjod&filter=pe:2015;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  'AntenatalCare(ANC)_2015_DistrictandNational_DivisionallevelHF': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:lqGV3xf4MnW;EMN9ubIGpGh;wpDTeNQUuEb&dimension=ou:OU_LEVEL-3;dNLjKwsVjod&filter=pe:2015;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  'AntenatalCare(ANC)_2015_UnionandUpazilalevelHF': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:lqGV3xf4MnW;EMN9ubIGpGh;wpDTeNQUuEb&dimension=ou:OU_LEVEL-5;dNLjKwsVjod&filter=pe:2015;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  'AntenatalCare(ANC)_2015_Upazila': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:lqGV3xf4MnW;EMN9ubIGpGh;wpDTeNQUuEb&dimension=ou:OU_GROUP-XpE4AlQZRkV;dNLjKwsVjod&filter=pe:2015;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  'AntenatalCare(ANC)_2015_UpazilaHealthComplex': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:lqGV3xf4MnW;EMN9ubIGpGh;wpDTeNQUuEb&dimension=ou:OU_GROUP-TwFxBSq8iAg;dNLjKwsVjod&filter=pe:2015;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  'AntenatalCare(ANC)_2015_UpazilaandDistrictlevelHF': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:lqGV3xf4MnW;EMN9ubIGpGh;wpDTeNQUuEb&dimension=ou:OU_LEVEL-4;dNLjKwsVjod&filter=pe:2015;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  'AntenatalCare(ANC)_2016_District': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:lqGV3xf4MnW;EMN9ubIGpGh;wpDTeNQUuEb&dimension=ou:OU_GROUP-PyK69cVqr5l;dNLjKwsVjod&filter=pe:2016;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  'AntenatalCare(ANC)_2016_DistrictHospital_GeneralHospital': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:lqGV3xf4MnW;EMN9ubIGpGh;wpDTeNQUuEb&dimension=ou:OU_GROUP-yiUFzYnD1f9;dNLjKwsVjod&filter=pe:2016;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  'AntenatalCare(ANC)_2016_DistrictNGO&PrivateTotal': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:lqGV3xf4MnW;EMN9ubIGpGh;wpDTeNQUuEb&dimension=ou:OU_GROUP-Uey6NprfqrE;dNLjKwsVjod&filter=pe:2016;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  'AntenatalCare(ANC)_2016_DistrictandNational_DivisionallevelHF': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:lqGV3xf4MnW;EMN9ubIGpGh;wpDTeNQUuEb&dimension=ou:OU_LEVEL-3;dNLjKwsVjod&filter=pe:2016;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  'AntenatalCare(ANC)_2016_UnionandUpazilalevelHF': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:lqGV3xf4MnW;EMN9ubIGpGh;wpDTeNQUuEb&dimension=ou:OU_LEVEL-5;dNLjKwsVjod&filter=pe:2016;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  'AntenatalCare(ANC)_2016_Upazila': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:lqGV3xf4MnW;EMN9ubIGpGh;wpDTeNQUuEb&dimension=ou:OU_GROUP-XpE4AlQZRkV;dNLjKwsVjod&filter=pe:2016;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  'AntenatalCare(ANC)_2016_UpazilaHealthComplex': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:lqGV3xf4MnW;EMN9ubIGpGh;wpDTeNQUuEb&dimension=ou:OU_GROUP-TwFxBSq8iAg;dNLjKwsVjod&filter=pe:2016;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  'AntenatalCare(ANC)_2016_UpazilaandDistrictlevelHF': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:lqGV3xf4MnW;EMN9ubIGpGh;wpDTeNQUuEb&dimension=ou:OU_LEVEL-4;dNLjKwsVjod&filter=pe:2016;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  'AntenatalCare(ANC)_2017_District': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:lqGV3xf4MnW;EMN9ubIGpGh;wpDTeNQUuEb&dimension=ou:OU_GROUP-PyK69cVqr5l;dNLjKwsVjod&filter=pe:2017;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  'AntenatalCare(ANC)_2017_DistrictHospital_GeneralHospital': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:lqGV3xf4MnW;EMN9ubIGpGh;wpDTeNQUuEb&dimension=ou:OU_GROUP-yiUFzYnD1f9;dNLjKwsVjod&filter=pe:2017;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  'AntenatalCare(ANC)_2017_DistrictNGO&PrivateTotal': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:lqGV3xf4MnW;EMN9ubIGpGh;wpDTeNQUuEb&dimension=ou:OU_GROUP-Uey6NprfqrE;dNLjKwsVjod&filter=pe:2017;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  'AntenatalCare(ANC)_2017_DistrictandNational_DivisionallevelHF': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:lqGV3xf4MnW;EMN9ubIGpGh;wpDTeNQUuEb&dimension=ou:OU_LEVEL-3;dNLjKwsVjod&filter=pe:2017;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  'AntenatalCare(ANC)_2017_UnionandUpazilalevelHF': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:lqGV3xf4MnW;EMN9ubIGpGh;wpDTeNQUuEb&dimension=ou:OU_LEVEL-5;dNLjKwsVjod&filter=pe:2017;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  'AntenatalCare(ANC)_2017_Upazila': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:lqGV3xf4MnW;EMN9ubIGpGh;wpDTeNQUuEb&dimension=ou:OU_GROUP-XpE4AlQZRkV;dNLjKwsVjod&filter=pe:2017;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  'AntenatalCare(ANC)_2017_UpazilaHealthComplex': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:lqGV3xf4MnW;EMN9ubIGpGh;wpDTeNQUuEb&dimension=ou:OU_GROUP-TwFxBSq8iAg;dNLjKwsVjod&filter=pe:2017;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  'AntenatalCare(ANC)_2017_UpazilaandDistrictlevelHF': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:lqGV3xf4MnW;EMN9ubIGpGh;wpDTeNQUuEb&dimension=ou:OU_LEVEL-4;dNLjKwsVjod&filter=pe:2017;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  'AntenatalCare(ANC)_2018_District': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:lqGV3xf4MnW;EMN9ubIGpGh;wpDTeNQUuEb&dimension=ou:OU_GROUP-PyK69cVqr5l;dNLjKwsVjod&filter=pe:2018;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  'AntenatalCare(ANC)_2018_DistrictHospital_GeneralHospital': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:lqGV3xf4MnW;EMN9ubIGpGh;wpDTeNQUuEb&dimension=ou:OU_GROUP-yiUFzYnD1f9;dNLjKwsVjod&filter=pe:2018;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  'AntenatalCare(ANC)_2018_DistrictNGO&PrivateTotal': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:lqGV3xf4MnW;EMN9ubIGpGh;wpDTeNQUuEb&dimension=ou:OU_GROUP-Uey6NprfqrE;dNLjKwsVjod&filter=pe:2018;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  'AntenatalCare(ANC)_2018_DistrictandNational_DivisionallevelHF': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:lqGV3xf4MnW;EMN9ubIGpGh;wpDTeNQUuEb&dimension=ou:OU_LEVEL-3;dNLjKwsVjod&filter=pe:2018;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  'AntenatalCare(ANC)_2018_UnionandUpazilalevelHF': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:lqGV3xf4MnW;EMN9ubIGpGh;wpDTeNQUuEb&dimension=ou:OU_LEVEL-5;dNLjKwsVjod&filter=pe:2018;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  'AntenatalCare(ANC)_2018_Upazila': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:lqGV3xf4MnW;EMN9ubIGpGh;wpDTeNQUuEb&dimension=ou:OU_GROUP-XpE4AlQZRkV;dNLjKwsVjod&filter=pe:2018;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  'AntenatalCare(ANC)_2018_UpazilaHealthComplex': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:lqGV3xf4MnW;EMN9ubIGpGh;wpDTeNQUuEb&dimension=ou:OU_GROUP-TwFxBSq8iAg;dNLjKwsVjod&filter=pe:2018;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme=',
#  'AntenatalCare(ANC)_2018_UpazilaandDistrictlevelHF': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?dimension=dx:lqGV3xf4MnW;EMN9ubIGpGh;wpDTeNQUuEb&dimension=ou:OU_LEVEL-4;dNLjKwsVjod&filter=pe:2018;LAST_12_MONTHS&displayProperty=NAME&outputIdScheme='}

# %%
len(dghis_queries)
# Out:
# 640

# %%
data_download(api_queries=dghis_queries, pause_length=45, dest_dir='data/dhis2/health_indicators/')
# Out:
# Starting the process for 01MaternalHealth_2009_DistrictandNational_DivisionallevelHF files: with geo codes and names respectively
# Constructing file path for 01MaternalHealth_2009_DistrictandNational_DivisionallevelHF file
# Getting API query for data/dhis2/health_indicators/01MaternalHealth_2009_DistrictandNational_DivisionallevelHF_UID.csv file
# data/dhis2/health_indicators/01MaternalHealth_2009_DistrictandNational_DivisionallevelHF_UID.csv
# Writing in chunks data/dhis2/health_indicators/01MaternalHealth_2009_DistrictandNational_DivisionallevelHF_UID.csv file
# Pausing the process for 45 seconds
# Getting API query for data/dhis2/health_indicators/01MaternalHealth_2009_DistrictandNational_DivisionallevelHF_CODE.csv file
# data/dhis2/health_indicators/01MaternalHealth_2009_DistrictandNational_DivisionallevelHF_CODE.csv
# Writing in chunks data/dhis2/health_indicators/01MaternalHealth_2009_DistrictandNational_DivisionallevelHF_CODE.csv file
# Pausing the process for 45 seconds
# Restarting the process for data/dhis2/health_indicators/01MaternalHealth_2009_DistrictandNational_DivisionallevelHF_NAME.csv file
# Writing in chunks data/dhis2/health_indicators/01MaternalHealth_2009_DistrictandNational_DivisionallevelHF_NAME.csv file
# Pausing the process for 45 seconds
# Starting the process for 01MaternalHealth_2009_UnionandUpazilalevelHF files: with geo codes and names respectively
# Constructing file path for 01MaternalHealth_2009_UnionandUpazilalevelHF file
# Getting API query for data/dhis2/health_indicators/01MaternalHealth_2009_UnionandUpazilalevelHF_UID.csv file
# data/dhis2/health_indicators/01MaternalHealth_2009_UnionandUpazilalevelHF_UID.csv
# Writing in chunks data/dhis2/health_indicators/01MaternalHealth_2009_UnionandUpazilalevelHF_UID.csv file
# Pausing the process for 45 seconds
# Getting API query for data/dhis2/health_indicators/01MaternalHealth_2009_UnionandUpazilalevelHF_CODE.csv file
# data/dhis2/health_indicators/01MaternalHealth_2009_UnionandUpazilalevelHF_CODE.csv
# Writing in chunks data/dhis2/health_indicators/01MaternalHealth_2009_UnionandUpazilalevelHF_CODE.csv file
# Pausing the process for 45 seconds
