# %% [markdown]
# # DHIS2 Data Download Web API - Central Server

# %% [markdown]
# - Overview:
#     - Organisation units: 27261
#     - Number of indicator groups: 51
#     - Number of datasets: 104
#     - Number of data elements: 131

# %%
import os
import time
import requests
import pandas as pd

# %% [markdown]
# ## Organisation Units
# ### Organisation Unit Levels

# %%
organisationUnitsLevels = 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/26/organisationUnitLevels.json?paging=false'
with requests.Session() as s:
    organisationUnitsLevels_json = s.get(organisationUnitsLevels,auth=('wbbigdata_view', 'DGHS@1234#')).json()
pd.DataFrame.from_dict(organisationUnitsLevels_json['organisationUnitLevels'])
# Out:
#                                  displayName           id
# 0        Community Clinic and Union Level HF  P3xaO9CNrVY
# 1                                    Country  kv8G6cp7G8n
# 2  District and National/Divisional level HF  TY67fOo5ywC
# 3                                   Division  hrLzNYoLILu
# 4                                    Level 7  sVti5YayDAf
# 5                 Union and Upazila level HF  IWh6WrGXOyN
# 6              Upazila and District level HF  WDBz0AfvG8C

# %% [markdown]
# ### Organisation Unit Groups

# %%
organisationUnitGroups = 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/26/organisationUnitGroups.json?paging=false'
with requests.Session() as s:
    organisationUnitGroups_json = s.get(organisationUnitGroups,auth=('wbbigdata_view', 'DGHS@1234#')).json()
organisationUnitGroups_json = pd.DataFrame.from_dict(organisationUnitGroups_json['organisationUnitGroups'])

# %% [markdown]
# ```
# geos = {'District and National/Divisional level HF':'TY67fOo5ywC',
#         'Union and Upazila level HF': 'IWh6WrGXOyN',
#         'Upazila and District level HF': 'WDBz0AfvG8C',
#         'Upazila':'XpE4AlQZRkV',
#         'Upazila Health Complex':'TwFxBSq8iAg',
#         'District': 'PyK69cVqr5l',
#         'District Hospital/General Hospital':'yiUFzYnD1f9',
#         'District NGO & Private Total': 'Uey6NprfqrE',
#         'UNICEF-MNHI district': 'PX8DLtPxleW'}
# geo_types = {'District and National/Divisional level HF':'LEVEL',
#         'Union and Upazila level HF': 'LEVEL',
#         'Upazila and District level HF': 'LEVEL',
#         'Upazila':'GROUP',
#         'Upazila Health Complex':'GROUP',
#         'District': 'GROUP',
#         'District Hospital/General Hospital':'GROUP',
#         'District NGO & Private Total': 'GROUP',
#         'UNICEF-MNHI district': 'GROUP'}
# print(geos)
# print(geo_types)
# ```

# %%
geos = {'Upazila':'XpE4AlQZRkV',
        'District': 'PyK69cVqr5l'
       }
geo_types = {'Upazila':'GROUP',
             'District': 'GROUP'
            }
print(geos)
print(geo_types)
# Out:
# {'Upazila': 'XpE4AlQZRkV', 'District': 'PyK69cVqr5l'}
# {'Upazila': 'GROUP', 'District': 'GROUP'}

# %%
dhis2_api = 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/resources'
with requests.Session() as s:
    dhis2_api_json = s.get(dhis2_api,auth=('wbbigdata_view', 'DGHS@1234#')).json()
dhis2_api_json
# Out:
# {'resources': [{'displayName': 'Indicators',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/indicators',
#    'plural': 'indicators',
#    'singular': 'indicator'},
#   {'displayName': 'Users',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/users',
#    'plural': 'users',
#    'singular': 'user'},
#   {'displayName': 'Program Data Elements',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/programDataElements',
#    'plural': 'programDataElements',
#    'singular': 'programDataElement'},
#   {'displayName': 'Data Element Operands',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/dataElementOperands',
#    'plural': 'dataElementOperands',
#    'singular': 'dataElementOperand'},
#   {'displayName': 'Sections',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/sections',
#    'plural': 'sections',
#    'singular': 'section'},
#   {'displayName': 'Predictors',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/predictors',
#    'plural': 'predictors',
#    'singular': 'predictor'},
#   {'displayName': 'Data Elements',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/dataElements',
#    'plural': 'dataElements',
#    'singular': 'dataElement'},
#   {'displayName': 'Legend Sets',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/legendSets',
#    'plural': 'legendSets',
#    'singular': 'legendSet'},
#   {'displayName': 'Data Approval Levels',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/dataApprovalLevels',
#    'plural': 'dataApprovalLevels',
#    'singular': 'dataApprovalLevel'},
#   {'displayName': 'Tracked Entity Types',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/trackedEntityTypes',
#    'plural': 'trackedEntityTypes',
#    'singular': 'trackedEntityType'},
#   {'displayName': 'File Resources',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/fileResources',
#    'plural': 'fileResources',
#    'singular': 'fileResource'},
#   {'displayName': 'Category Option Groups',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/categoryOptionGroups',
#    'plural': 'categoryOptionGroups',
#    'singular': 'categoryOptionGroup'},
#   {'displayName': 'Event Reports',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/eventReports',
#    'plural': 'eventReports',
#    'singular': 'eventReport'},
#   {'displayName': 'Indicator Types',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/indicatorTypes',
#    'plural': 'indicatorTypes',
#    'singular': 'indicatorType'},
#   {'displayName': 'Maps',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/maps',
#    'plural': 'maps',
#    'singular': 'map'},
#   {'displayName': 'Program Rules',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/programRules',
#    'plural': 'programRules',
#    'singular': 'programRule'},
#   {'displayName': 'O Auth2 Clients',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/oAuth2Clients',
#    'plural': 'oAuth2Clients',
#    'singular': 'oAuth2Client'},
#   {'displayName': 'Dashboards',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/dashboards',
#    'plural': 'dashboards',
#    'singular': 'dashboard'},
#   {'displayName': 'Category Option Group Sets',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/categoryOptionGroupSets',
#    'plural': 'categoryOptionGroupSets',
#    'singular': 'categoryOptionGroupSet'},
#   {'displayName': 'Option Sets',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/optionSets',
#    'plural': 'optionSets',
#    'singular': 'optionSet'},
#   {'displayName': 'External File Resources',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/externalFileResources',
#    'plural': 'externalFileResources',
#    'singular': 'externalFileResource'},
#   {'displayName': 'Report Tables',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/reportTables',
#    'plural': 'reportTables',
#    'singular': 'reportTable'},
#   {'displayName': 'Option Group Sets',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/optionGroupSets',
#    'plural': 'optionGroupSets',
#    'singular': 'optionGroupSet'},
#   {'displayName': 'Relationship Types',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/relationshipTypes',
#    'plural': 'relationshipTypes',
#    'singular': 'relationshipType'},
#   {'displayName': 'Program Notification Templates',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/programNotificationTemplates',
#    'plural': 'programNotificationTemplates',
#    'singular': 'programNotificationTemplate'},
#   {'displayName': 'Indicator Group Sets',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/indicatorGroupSets',
#    'plural': 'indicatorGroupSets',
#    'singular': 'indicatorGroupSet'},
#   {'displayName': 'Tracked Entity Attributes',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/trackedEntityAttributes',
#    'plural': 'trackedEntityAttributes',
#    'singular': 'trackedEntityAttribute'},
#   {'displayName': 'Data Approval Workflows',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/dataApprovalWorkflows',
#    'plural': 'dataApprovalWorkflows',
#    'singular': 'dataApprovalWorkflow'},
#   {'displayName': 'Program Tracked Entity Attribute Groups',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/programTrackedEntityAttributeGroups',
#    'plural': 'programTrackedEntityAttributeGroups',
#    'singular': 'programTrackedEntityAttributeGroup'},
#   {'displayName': 'Program Rule Variables',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/programRuleVariables',
#    'plural': 'programRuleVariables',
#    'singular': 'programRuleVariable'},
#   {'displayName': 'User Roles',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/userRoles',
#    'plural': 'userRoles',
#    'singular': 'userRole'},
#   {'displayName': 'Program Indicators',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/programIndicators',
#    'plural': 'programIndicators',
#    'singular': 'programIndicator'},
#   {'displayName': 'Data Set Notification Templates',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/dataSetNotificationTemplates',
#    'plural': 'dataSetNotificationTemplates',
#    'singular': 'dataSetNotificationTemplate'},
#   {'displayName': 'Min Max Data Elements',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/minMaxDataElements',
#    'plural': 'minMaxDataElements',
#    'singular': 'minMaxDataElement'},
#   {'displayName': 'Indicator Groups',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/indicatorGroups',
#    'plural': 'indicatorGroups',
#    'singular': 'indicatorGroup'},
#   {'displayName': 'Documents',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/documents',
#    'plural': 'documents',
#    'singular': 'document'},
#   {'displayName': 'Data Entry Forms',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/dataEntryForms',
#    'plural': 'dataEntryForms',
#    'singular': 'dataEntryForm'},
#   {'displayName': 'Sms Commands',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/smsCommands',
#    'plural': 'smsCommands',
#    'singular': 'smsCommand'},
#   {'displayName': 'Constants',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/constants',
#    'plural': 'constants',
#    'singular': 'constant'},
#   {'displayName': 'Job Configurations',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/jobConfigurations',
#    'plural': 'jobConfigurations',
#    'singular': 'jobConfiguration'},
#   {'displayName': 'Programs',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/programs',
#    'plural': 'programs',
#    'singular': 'program'},
#   {'displayName': 'Sql Views',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/sqlViews',
#    'plural': 'sqlViews',
#    'singular': 'sqlView'},
#   {'displayName': 'Charts',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/charts',
#    'plural': 'charts',
#    'singular': 'chart'},
#   {'displayName': 'Category Combos',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/categoryCombos',
#    'plural': 'categoryCombos',
#    'singular': 'categoryCombo'},
#   {'displayName': 'Map Views',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/mapViews',
#    'plural': 'mapViews',
#    'singular': 'mapView'},
#   {'displayName': 'Option Groups',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/optionGroups',
#    'plural': 'optionGroups',
#    'singular': 'optionGroup'},
#   {'displayName': 'Category Option Combos',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/categoryOptionCombos',
#    'plural': 'categoryOptionCombos',
#    'singular': 'categoryOptionCombo'},
#   {'displayName': 'Options',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/options',
#    'plural': 'options',
#    'singular': 'option'},
#   {'displayName': 'Data Sets',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/dataSets',
#    'plural': 'dataSets',
#    'singular': 'dataSet'},
#   {'displayName': 'Interpretations',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/interpretations',
#    'plural': 'interpretations',
#    'singular': 'interpretation'},
#   {'displayName': 'Validation Notification Templates',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/validationNotificationTemplates',
#    'plural': 'validationNotificationTemplates',
#    'singular': 'validationNotificationTemplate'},
#   {'displayName': 'External Map Layers',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/externalMapLayers',
#    'plural': 'externalMapLayers',
#    'singular': 'externalMapLayer'},
#   {'displayName': 'Validation Rules',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/validationRules',
#    'plural': 'validationRules',
#    'singular': 'validationRule'},
#   {'displayName': 'Categories',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/categories',
#    'plural': 'categories',
#    'singular': 'category'},
#   {'displayName': 'Organisation Unit Levels',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/organisationUnitLevels',
#    'plural': 'organisationUnitLevels',
#    'singular': 'organisationUnitLevel'},
#   {'displayName': 'Color Sets',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/colorSets',
#    'plural': 'colorSets',
#    'singular': 'colorSet'},
#   {'displayName': 'Data Element Groups',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/dataElementGroups',
#    'plural': 'dataElementGroups',
#    'singular': 'dataElementGroup'},
#   {'displayName': 'Validation Results',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/validationResults',
#    'plural': 'validationResults',
#    'singular': 'validationResult'},
#   {'displayName': 'Dashboard Items',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/dashboardItems',
#    'plural': 'dashboardItems',
#    'singular': 'dashboardItem'},
#   {'displayName': 'Event Charts',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/eventCharts',
#    'plural': 'eventCharts',
#    'singular': 'eventChart'},
#   {'displayName': 'Program Rule Actions',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/programRuleActions',
#    'plural': 'programRuleActions',
#    'singular': 'programRuleAction'},
#   {'displayName': 'Metadata Versions',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/metadata/version',
#    'plural': 'metadataVersions',
#    'singular': 'metadataVersion'},
#   {'displayName': 'Message Conversations',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/messageConversations',
#    'plural': 'messageConversations',
#    'singular': 'messageConversation'},
#   {'displayName': 'Program Stages',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/programStages',
#    'plural': 'programStages',
#    'singular': 'programStage'},
#   {'displayName': 'Program Stage Sections',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/programStageSections',
#    'plural': 'programStageSections',
#    'singular': 'programStageSection'},
#   {'displayName': 'Program Sections',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/programSections',
#    'plural': 'programSections',
#    'singular': 'programSection'},
#   {'displayName': 'Analytics Table Hooks',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/analyticsTableHooks',
#    'plural': 'analyticsTableHooks',
#    'singular': 'analyticsTableHook'},
#   {'displayName': 'Validation Rule Groups',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/validationRuleGroups',
#    'plural': 'validationRuleGroups',
#    'singular': 'validationRuleGroup'},
#   {'displayName': 'Organisation Unit Groups',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/organisationUnitGroups',
#    'plural': 'organisationUnitGroups',
#    'singular': 'organisationUnitGroup'},
#   {'displayName': 'Organisation Unit Group Sets',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/organisationUnitGroupSets',
#    'plural': 'organisationUnitGroupSets',
#    'singular': 'organisationUnitGroupSet'},
#   {'displayName': 'Category Options',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/categoryOptions',
#    'plural': 'categoryOptions',
#    'singular': 'categoryOption'},
#   {'displayName': 'Attributes',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/attributes',
#    'plural': 'attributes',
#    'singular': 'attribute'},
#   {'displayName': 'Tracked Entity Instances',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/trackedEntityInstances',
#    'plural': 'trackedEntityInstances',
#    'singular': 'trackedEntityInstance'},
#   {'displayName': 'Push Analysis',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/pushAnalysis',
#    'plural': 'pushAnalysis',
#    'singular': 'pushAnalysis'},
#   {'displayName': 'Organisation Units',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/organisationUnits',
#    'plural': 'organisationUnits',
#    'singular': 'organisationUnit'},
#   {'displayName': 'Data Element Group Sets',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/dataElementGroupSets',
#    'plural': 'dataElementGroupSets',
#    'singular': 'dataElementGroupSet'},
#   {'displayName': 'User Groups',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/userGroups',
#    'plural': 'userGroups',
#    'singular': 'userGroup'},
#   {'displayName': 'Program Indicator Groups',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/programIndicatorGroups',
#    'plural': 'programIndicatorGroups',
#    'singular': 'programIndicatorGroup'},
#   {'displayName': 'Reports',
#    'href': 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/reports',
#    'plural': 'reports',
#    'singular': 'report'}]}

# %% [markdown]
# ## Predefined Data Elements

# %%
dataElementGroups = 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/26/dataElementGroups'
with requests.Session() as s:
    dataElementGroups_json = s.get(dataElementGroups,auth=('wbbigdata_view', 'DGHS@1234#')).json()

# %%
pd.DataFrame(dataElementGroups_json['dataElementGroups']).iloc[0:10]
# Out:
#                             displayName           id
# 0  01. EPI Report (Routine vaccination)  o8p6P5eLyDZ
# 1                 02. EPI Upazila Stock  YVD3pxIrl9M
# 2                03. EPI District Stock  lsKz7YoTeAA
# 3          04. EPI District Requisition  W7RaJnzf3Id
# 4               05. EPI District Supply  sD0LRbRVX7I
# 5                06. EPI Upazila Supply  ZFVpdQk8RQh
# 6                             07. EmONC  FZJWJUJ1nyM
# 7                              08. IMCI  bm68OgySJMb
# 8                09. Adolescent Health   eep3tXrAYAh
# 9                               10. KMC  niipJz6kBoU

# %%
data_elements = {'01. EPI Report (Routine vaccination)':'o8p6P5eLyDZ',
                 '02. EPI Upazila Stock': 'YVD3pxIrl9M',
                 '03. EPI District Stock': 'lsKz7YoTeAA',
                 '04. EPI District Requisition': 'W7RaJnzf3Id',
                 '05. EPI District Supply': 'sD0LRbRVX7I',
                 '06. EPI Upazila Supply': 'ZFVpdQk8RQh',
                 '07. EmONC': 'FZJWJUJ1nyM',
                 '08. IMCI': 'bm68OgySJMb',
                 '09. Adolescent Health': 'eep3tXrAYAh',
                 '10. KMC': 'niipJz6kBoU',
                 '11. EMEN (MBFFI)': 'i7msFlsuJRz'
                }
data_elements
# Out:
# {'01. EPI Report (Routine vaccination)': 'o8p6P5eLyDZ',
#  '02. EPI Upazila Stock': 'YVD3pxIrl9M',
#  '03. EPI District Stock': 'lsKz7YoTeAA',
#  '04. EPI District Requisition': 'W7RaJnzf3Id',
#  '05. EPI District Supply': 'sD0LRbRVX7I',
#  '06. EPI Upazila Supply': 'ZFVpdQk8RQh',
#  '07. EmONC': 'FZJWJUJ1nyM',
#  '08. IMCI': 'bm68OgySJMb',
#  '09. Adolescent Health': 'eep3tXrAYAh',
#  '10. KMC': 'niipJz6kBoU',
#  '11. EMEN (MBFFI)': 'i7msFlsuJRz'}

# %%
data_element_names = {'o8p6P5eLyDZ': '01. EPI Report (Routine vaccination)',
                      'YVD3pxIrl9M': '02. EPI Upazila Stock',
                      'lsKz7YoTeAA': '03. EPI District Stock',
                      'W7RaJnzf3Id': '04. EPI District Requisition',
                      'sD0LRbRVX7I': '05. EPI District Supply',
                      'ZFVpdQk8RQh': '06. EPI Upazila Supply',
                      'FZJWJUJ1nyM': '07. EmONC',
                      'bm68OgySJMb': '08. IMCI',
                      'eep3tXrAYAh': '09. Adolescent Health',
                      'niipJz6kBoU': '10. KMC',
                      'i7msFlsuJRz': '11. EMEN (MBFFI)',
                     }
data_element_names
# Out:
# {'FZJWJUJ1nyM': '07. EmONC',
#  'W7RaJnzf3Id': '04. EPI District Requisition',
#  'YVD3pxIrl9M': '02. EPI Upazila Stock',
#  'ZFVpdQk8RQh': '06. EPI Upazila Supply',
#  'bm68OgySJMb': '08. IMCI',
#  'eep3tXrAYAh': '09. Adolescent Health',
#  'i7msFlsuJRz': '11. EMEN (MBFFI)',
#  'lsKz7YoTeAA': '03. EPI District Stock',
#  'niipJz6kBoU': '10. KMC',
#  'o8p6P5eLyDZ': '01. EPI Report (Routine vaccination)',
#  'sD0LRbRVX7I': '05. EPI District Supply'}

# %%
data_elements_2 = {'Hospital Bed Statement': 'JaPrbUeLJyn',
                   'Hospital In-Patient Department': 'iFu9wuzezQW',
                   'Hospital Out Patient Department': 'eSBMP55stvD',
                   'Eye Hospital In-Patient Department': 'O3zvP63vE5Y',
                   'Eye Hospital Out Patient Department': 'hiqGoKxpxkF',
                   'Eye Patient Screening Programme': 'OxVBM5qdKaC',
                   'Upazila Profile': 'GmJbKtrcLfh',
                   'under 5 Nutrition service': 'hJBwYMkPGyF',
                   'NGOs & Urban on Nutrition': 'LKIt7v1DKd2'
                }
data_elements_2
# Out:
# {'Eye Hospital In-Patient Department': 'O3zvP63vE5Y',
#  'Eye Hospital Out Patient Department': 'hiqGoKxpxkF',
#  'Eye Patient Screening Programme': 'OxVBM5qdKaC',
#  'Hospital Bed Statement': 'JaPrbUeLJyn',
#  'Hospital In-Patient Department': 'iFu9wuzezQW',
#  'Hospital Out Patient Department': 'eSBMP55stvD',
#  'NGOs & Urban on Nutrition': 'LKIt7v1DKd2',
#  'Upazila Profile': 'GmJbKtrcLfh',
#  'under 5 Nutrition service': 'hJBwYMkPGyF'}

# %%
data_element_names_2 = {'JaPrbUeLJyn': 'Hospital Bed Statement',
                        'iFu9wuzezQW': 'Hospital In-Patient Department',
                        'eSBMP55stvD': 'Hospital Out Patient Department',
                        'O3zvP63vE5Y': 'Eye Hospital In-Patient Department',
                        'hiqGoKxpxkF': 'Eye Hospital Out Patient Department',
                        'OxVBM5qdKaC': 'Eye Patient Screening Programme',
                        'GmJbKtrcLfh': 'Upazila Profile',
                        'hJBwYMkPGyF': 'under 5 Nutrition service',
                        'LKIt7v1DKd2': 'NGOs & Urban on Nutrition'
                       }
data_element_names_2
# Out:
# {'GmJbKtrcLfh': 'Upazila Profile',
#  'JaPrbUeLJyn': 'Hospital Bed Statement',
#  'LKIt7v1DKd2': 'NGOs & Urban on Nutrition',
#  'O3zvP63vE5Y': 'Eye Hospital In-Patient Department',
#  'OxVBM5qdKaC': 'Eye Patient Screening Programme',
#  'eSBMP55stvD': 'Hospital Out Patient Department',
#  'hJBwYMkPGyF': 'under 5 Nutrition service',
#  'hiqGoKxpxkF': 'Eye Hospital Out Patient Department',
#  'iFu9wuzezQW': 'Hospital In-Patient Department'}

# %% [markdown]
# ## Time Periods

# %%
years = {'2009':2009, '2010':2010, '2011':2011, '2012':2012,
         '2013':2013, '2014':2014, '2015':2015, '2016':2016,
         '2017':2017, '2018':2018,

        }
years
# Out:
# {'2009': 2009,
#  '2010': 2010,
#  '2011': 2011,
#  '2012': 2012,
#  '2013': 2013,
#  '2014': 2014,
#  '2015': 2015,
#  '2016': 2016,
#  '2017': 2017,
#  '2018': 2018}

# %% [markdown]
# ## Building the API queries

# %% [markdown]
# ## Functions

# %%
def extract_dataElementVariables(data_elements, pause_length):
    data_elements_dict = {}
    for element_name, element_id in data_elements.items():
        url_main = 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/26/dataElementGroups/'
        url = url_main + element_id
        print(url)
        with requests.Session() as s:
            tmp = s.get(url, auth=('wbbigdata_view', 'DGHS@1234#')).json()['dataElements']
        tmp = pd.DataFrame.from_dict(tmp)
        tmp_out = [variable_id for variable_id in tmp.iloc[:,0]]
        length_tmp = len(tmp_out)
        tmp = (';').join(tmp_out) 
        data_elements_dict[element_id] = tmp
        del(tmp, tmp_out)
        print(length_tmp)
        print(data_elements_dict[element_id])
        time.sleep(pause_length)
    return data_elements_dict

def create_api_queries(variables, dataElements_names, period, geos, geo_types):
    api_queries = {}
    for element_item, element_value in variables.items():
        for year_item, year_value in period.items():
            for geo_item, geo_value in geos.items():
                dhis_main = 'https://centraldhis.mohfw.gov.bd/dhismohfw/api/29/analytics.csv?'
                dataElementGroups_variables= f'dimension=dx:{element_value}'
                geo_variables = f'&dimension=ou:OU_{geo_types[geo_item]}-{geo_value};'
                time_variables = f'dNLjKwsVjod&filter=pe:{year_item};LAST_12_MONTHS&displayProperty=NAME&outputIdScheme='
                url = dhis_main + dataElementGroups_variables + geo_variables + time_variables
                file_name = dataElements_names[element_item] + '_' + year_item + '_' + geo_item
                file_name = file_name.replace(" ", "").replace(".", "")
                api_queries[file_name] = url
    return api_queries

def data_download(api_queries, pause_length):
    for file_name, api_query in api_queries.items():
        print(f"Starting the process for {file_name} files: with geo codes and names respectively")
        print(f"Constructing file path for {file_name} file")
        file_with_codes = 'data/' + file_name + 'CODE' + '.csv'
        file_with_names = 'data/' + file_name + 'NAME' + '.csv'
        with requests.Session() as s:
            print(f"Getting API query for {file_with_codes} file")
            data_codes = s.get(api_query + 'CODE', auth=('wbbigdata_view', 'DGHS@1234#'),stream=True)
            with open(file_with_codes, 'wb') as f:
                print(f"Writing in chunks {file_with_codes} file")
                for chunk in data_codes.iter_content(chunk_size=1024):
                    if chunk:
                        f.write(chunk)
            print(f"Pausing the process for {pause_length} seconds")
        time.sleep(pause_length)
        with requests.Session() as s:
            print(f"Restarting the process for {file_with_names} file")
            data_names = s.get(api_query + 'NAME', auth=('wbbigdata_view', 'DGHS@1234#'),stream=True)
            with open(file_with_names, 'wb') as f:
                print(f"Writing in chunks {file_with_names} file")
                for chunk in data_names.iter_content(chunk_size=1024):
                    if chunk:
                        f.write(chunk)
            print(f"Pausing the process for {pause_length} seconds")
        time.sleep(pause_length)

# %%
data_element_variables_list = extract_dataElementVariables(data_elements=data_elements_2, pause_length=30)
# Out:
# https://centraldhis.mohfw.gov.bd/dhismohfw/api/26/dataElementGroups/JaPrbUeLJyn
# 5
# IeQMbigrLAk;T7ThgDxkBn0;sNSYazCOL8e;mRA4gC3BfHj;dkH2pnlfHLY
# https://centraldhis.mohfw.gov.bd/dhismohfw/api/26/dataElementGroups/iFu9wuzezQW
# 6
# aAEGy6Tnyta;pR9xnxmz1oN;CYPuBbNOD1v;qE4nsBVOoJl;gbR7re68Dm8;yxhGZ5ldkio
# https://centraldhis.mohfw.gov.bd/dhismohfw/api/26/dataElementGroups/eSBMP55stvD
# 9
# xNYMeVeeTsc;U3ZpDakJ67z;DIiXf5r4Cbo;AwMPQdaeYIx;wM5QwrgAqKG;J7RKpEgAwnR;lKp7Mwv3ueH;NF5mYWDWxXz;BxSyR0F5wf8
# https://centraldhis.mohfw.gov.bd/dhismohfw/api/26/dataElementGroups/O3zvP63vE5Y
# 6
# aAEGy6Tnyta;pR9xnxmz1oN;CYPuBbNOD1v;qE4nsBVOoJl;gbR7re68Dm8;yxhGZ5ldkio
# https://centraldhis.mohfw.gov.bd/dhismohfw/api/26/dataElementGroups/hiqGoKxpxkF
# 9
# xNYMeVeeTsc;U3ZpDakJ67z;DIiXf5r4Cbo;AwMPQdaeYIx;wM5QwrgAqKG;J7RKpEgAwnR;lKp7Mwv3ueH;NF5mYWDWxXz;BxSyR0F5wf8
# https://centraldhis.mohfw.gov.bd/dhismohfw/api/26/dataElementGroups/OxVBM5qdKaC
# 4
# nqdkGCEtaYk;xNYMeVeeTsc;a1IGNvTmbSl;AwMPQdaeYIx
# https://centraldhis.mohfw.gov.bd/dhismohfw/api/26/dataElementGroups/GmJbKtrcLfh
# 14
# hxfHNR4y7xm;sOZDJ7q9jaJ;BEk91BPcuIw;ncpDsODEA9v;nghaYLzgHau;SRlBKcuUg7K;Zk8VQq9iebv;cjxwJ7TcrQa;dSDzDtBRlsc;cmujbci8vGN;spom6NWBG4w;A3vPHkld7uo;rETqtmHAOMt;hH0Pnf1PYHO
# https://centraldhis.mohfw.gov.bd/dhismohfw/api/26/dataElementGroups/hJBwYMkPGyF
# 11
# jxtGrMi58Zx;CT9YKOwKlG0;Pqu18cHKkED;tLMYjzDD1iS;SjkQqVK7AJ3;KlKOxmG9OpO;bGDy0AU1R7T;gpJQzatKvmH;fBHP37KRdL2;MIr8DwrCZKy;QPfQyp6AnYO
# https://centraldhis.mohfw.gov.bd/dhismohfw/api/26/dataElementGroups/LKIt7v1DKd2
# 27
# nmrda5BvDyY;oQpROGtfeBV;LjqPTGGvNRq;z0lqphEi3zR;eNU1NNF2pQx;D5LvPeAzKcB;Su9eBNb3k0d;ZhJQn2ezoWQ;sEUfcw9o8lY;BUpsWV0H2U1;LSNFSyDR2Ec;oPi0KdUUkmk;qLCS4bdnq7o;hqjBtX8dq6A;UiWsyUnZkrW;rQbBBYbKzRA;nz6YCeq2pX9;HOvSWWwUxTj;QOfP9d89cay;KMOqYX7Quh6;gNbxsqvtu9W;peOvSKekFoz;HvI2ctpIQHX;vqTWkrty3Jm;B4YEoNEG73p;tFMSQVmCup9;hqE1TN41cov

# %%
data_element_variables_list
# Out:
# {'GmJbKtrcLfh': 'hxfHNR4y7xm;sOZDJ7q9jaJ;BEk91BPcuIw;ncpDsODEA9v;nghaYLzgHau;SRlBKcuUg7K;Zk8VQq9iebv;cjxwJ7TcrQa;dSDzDtBRlsc;cmujbci8vGN;spom6NWBG4w;A3vPHkld7uo;rETqtmHAOMt;hH0Pnf1PYHO',
#  'JaPrbUeLJyn': 'IeQMbigrLAk;T7ThgDxkBn0;sNSYazCOL8e;mRA4gC3BfHj;dkH2pnlfHLY',
#  'LKIt7v1DKd2': 'nmrda5BvDyY;oQpROGtfeBV;LjqPTGGvNRq;z0lqphEi3zR;eNU1NNF2pQx;D5LvPeAzKcB;Su9eBNb3k0d;ZhJQn2ezoWQ;sEUfcw9o8lY;BUpsWV0H2U1;LSNFSyDR2Ec;oPi0KdUUkmk;qLCS4bdnq7o;hqjBtX8dq6A;UiWsyUnZkrW;rQbBBYbKzRA;nz6YCeq2pX9;HOvSWWwUxTj;QOfP9d89cay;KMOqYX7Quh6;gNbxsqvtu9W;peOvSKekFoz;HvI2ctpIQHX;vqTWkrty3Jm;B4YEoNEG73p;tFMSQVmCup9;hqE1TN41cov',
#  'O3zvP63vE5Y': 'aAEGy6Tnyta;pR9xnxmz1oN;CYPuBbNOD1v;qE4nsBVOoJl;gbR7re68Dm8;yxhGZ5ldkio',
#  'OxVBM5qdKaC': 'nqdkGCEtaYk;xNYMeVeeTsc;a1IGNvTmbSl;AwMPQdaeYIx',
#  'eSBMP55stvD': 'xNYMeVeeTsc;U3ZpDakJ67z;DIiXf5r4Cbo;AwMPQdaeYIx;wM5QwrgAqKG;J7RKpEgAwnR;lKp7Mwv3ueH;NF5mYWDWxXz;BxSyR0F5wf8',
#  'hJBwYMkPGyF': 'jxtGrMi58Zx;CT9YKOwKlG0;Pqu18cHKkED;tLMYjzDD1iS;SjkQqVK7AJ3;KlKOxmG9OpO;bGDy0AU1R7T;gpJQzatKvmH;fBHP37KRdL2;MIr8DwrCZKy;QPfQyp6AnYO',
#  'hiqGoKxpxkF': 'xNYMeVeeTsc;U3ZpDakJ67z;DIiXf5r4Cbo;AwMPQdaeYIx;wM5QwrgAqKG;J7RKpEgAwnR;lKp7Mwv3ueH;NF5mYWDWxXz;BxSyR0F5wf8',
#  'iFu9wuzezQW': 'aAEGy6Tnyta;pR9xnxmz1oN;CYPuBbNOD1v;qE4nsBVOoJl;gbR7re68Dm8;yxhGZ5ldkio'}

# %% [markdown]
# ### Periods

# %%
years
# Out:
# {'2009': 2009,
#  '2010': 2010,
#  '2011': 2011,
#  '2012': 2012,
#  '2013': 2013,
#  '2014': 2014,
#  '2015': 2015,
#  '2016': 2016,
#  '2017': 2017,
#  '2018': 2018}

# %% [markdown]
# ### Geos

# %%
geos
# Out:
# {'District': 'PyK69cVqr5l', 'Upazila': 'XpE4AlQZRkV'}

# %% [markdown]
# ### Geo Types

# %%
geo_types
# Out:
# {'District': 'GROUP', 'Upazila': 'GROUP'}

# %% [markdown]
# ### Downloading data

# %%
data_element_names_2
# Out:
# {'GmJbKtrcLfh': 'Upazila Profile',
#  'JaPrbUeLJyn': 'Hospital Bed Statement',
#  'LKIt7v1DKd2': 'NGOs & Urban on Nutrition',
#  'O3zvP63vE5Y': 'Eye Hospital In-Patient Department',
#  'OxVBM5qdKaC': 'Eye Patient Screening Programme',
#  'eSBMP55stvD': 'Hospital Out Patient Department',
#  'hJBwYMkPGyF': 'under 5 Nutrition service',
#  'hiqGoKxpxkF': 'Eye Hospital Out Patient Department',
#  'iFu9wuzezQW': 'Hospital In-Patient Department'}

# %%
dghis_queries = create_api_queries(variables=data_element_variables_list,
                                   dataElements_names=data_element_names_2, 
                                   period=years, 
                                   geos=geos, 
                                   geo_types=geo_types)

# %%
len(dghis_queries)
# Out:
# 180

# %% [markdown]
# ```
# test = {k: dghis_queries[k] for k in ('02EPIUpazilaStock_2009_Upazila', '02EPIUpazilaStock_2018_Upazila')}
# test
# ```

# %%
data_download(api_queries=dghis_queries, pause_length=60)
# Out:
# Starting the process for HospitalBedStatement_2009_Upazila files: with geo codes and names respectively
# Constructing file path for HospitalBedStatement_2009_Upazila file
# Getting API query for data/HospitalBedStatement_2009_UpazilaCODE.csv file
# Writing in chunks data/HospitalBedStatement_2009_UpazilaCODE.csv file
# Pausing the process for 60 seconds
# Restarting the process for data/HospitalBedStatement_2009_UpazilaNAME.csv file
# Writing in chunks data/HospitalBedStatement_2009_UpazilaNAME.csv file
# Pausing the process for 60 seconds
# Starting the process for HospitalBedStatement_2009_District files: with geo codes and names respectively
# Constructing file path for HospitalBedStatement_2009_District file
# Getting API query for data/HospitalBedStatement_2009_DistrictCODE.csv file
# Writing in chunks data/HospitalBedStatement_2009_DistrictCODE.csv file
# Pausing the process for 60 seconds
# Restarting the process for data/HospitalBedStatement_2009_DistrictNAME.csv file
# Writing in chunks data/HospitalBedStatement_2009_DistrictNAME.csv file
# Pausing the process for 60 seconds
# Starting the process for HospitalBedStatement_2010_Upazila files: with geo codes and names respectively
# Constructing file path for HospitalBedStatement_2010_Upazila file
# Getting API query for data/HospitalBedStatement_2010_UpazilaCODE.csv file
# Writing in chunks data/HospitalBedStatement_2010_UpazilaCODE.csv file
# Pausing the process for 60 seconds
# Restarting the process for data/HospitalBedStatement_2010_UpazilaNAME.csv file
# Writing in chunks data/HospitalBedStatement_2010_UpazilaNAME.csv file
# Pausing the process for 60 seconds
# Starting the process for HospitalBedStatement_2010_District files: with geo codes and names respectively
# Constructing file path for HospitalBedStatement_2010_District file
# Getting API query for data/HospitalBedStatement_2010_DistrictCODE.csv file
# Writing in chunks data/HospitalBedStatement_2010_DistrictCODE.csv file
# Pausing the process for 60 seconds
# Restarting the process for data/HospitalBedStatement_2010_DistrictNAME.csv file
# Writing in chunks data/HospitalBedStatement_2010_DistrictNAME.csv file
# Pausing the process for 60 seconds
# Starting the process for HospitalBedStatement_2011_Upazila files: with geo codes and names respectively
# Constructing file path for HospitalBedStatement_2011_Upazila file
# Getting API query for data/HospitalBedStatement_2011_UpazilaCODE.csv file
# Writing in chunks data/HospitalBedStatement_2011_UpazilaCODE.csv file
# Pausing the process for 60 seconds
# Restarting the process for data/HospitalBedStatement_2011_UpazilaNAME.csv file
# Writing in chunks data/HospitalBedStatement_2011_UpazilaNAME.csv file
# Pausing the process for 60 seconds
# Starting the process for HospitalBedStatement_2011_District files: with geo codes and names respectively
# Constructing file path for HospitalBedStatement_2011_District file
# Getting API query for data/HospitalBedStatement_2011_DistrictCODE.csv file
# Writing in chunks data/HospitalBedStatement_2011_DistrictCODE.csv file
# Pausing the process for 60 seconds
# Restarting the process for data/HospitalBedStatement_2011_DistrictNAME.csv file
# Writing in chunks data/HospitalBedStatement_2011_DistrictNAME.csv file
# Pausing the process for 60 seconds
# Starting the process for HospitalBedStatement_2012_Upazila files: with geo codes and names respectively
# Constructing file path for HospitalBedStatement_2012_Upazila file
# Getting API query for data/HospitalBedStatement_2012_UpazilaCODE.csv file
# Writing in chunks data/HospitalBedStatement_2012_UpazilaCODE.csv file
# Pausing the process for 60 seconds
# Restarting the process for data/HospitalBedStatement_2012_UpazilaNAME.csv file
# Writing in chunks data/HospitalBedStatement_2012_UpazilaNAME.csv file
# Pausing the process for 60 seconds
# Starting the process for HospitalBedStatement_2012_District files: with geo codes and names respectively
# Constructing file path for HospitalBedStatement_2012_District file
# Getting API query for data/HospitalBedStatement_2012_DistrictCODE.csv file
# Writing in chunks data/HospitalBedStatement_2012_DistrictCODE.csv file
# Pausing the process for 60 seconds
# Restarting the process for data/HospitalBedStatement_2012_DistrictNAME.csv file
# Writing in chunks data/HospitalBedStatement_2012_DistrictNAME.csv file
# Pausing the process for 60 seconds
# Starting the process for HospitalBedStatement_2013_Upazila files: with geo codes and names respectively
# Constructing file path for HospitalBedStatement_2013_Upazila file
# Getting API query for data/HospitalBedStatement_2013_UpazilaCODE.csv file
# Writing in chunks data/HospitalBedStatement_2013_UpazilaCODE.csv file
# Pausing the process for 60 seconds
# Restarting the process for data/HospitalBedStatement_2013_UpazilaNAME.csv file
# Writing in chunks data/HospitalBedStatement_2013_UpazilaNAME.csv file
# Pausing the process for 60 seconds
# Starting the process for HospitalBedStatement_2013_District files: with geo codes and names respectively
# Constructing file path for HospitalBedStatement_2013_District file
# Getting API query for data/HospitalBedStatement_2013_DistrictCODE.csv file
# Writing in chunks data/HospitalBedStatement_2013_DistrictCODE.csv file
# Pausing the process for 60 seconds
# Restarting the process for data/HospitalBedStatement_2013_DistrictNAME.csv file
# Writing in chunks data/HospitalBedStatement_2013_DistrictNAME.csv file
# Pausing the process for 60 seconds
# Starting the process for HospitalBedStatement_2014_Upazila files: with geo codes and names respectively
# Constructing file path for HospitalBedStatement_2014_Upazila file
# Getting API query for data/HospitalBedStatement_2014_UpazilaCODE.csv file
# Writing in chunks data/HospitalBedStatement_2014_UpazilaCODE.csv file
# Pausing the process for 60 seconds
# Restarting the process for data/HospitalBedStatement_2014_UpazilaNAME.csv file
# Writing in chunks data/HospitalBedStatement_2014_UpazilaNAME.csv file
# Pausing the process for 60 seconds
# Starting the process for HospitalBedStatement_2014_District files: with geo codes and names respectively
# Constructing file path for HospitalBedStatement_2014_District file
# Getting API query for data/HospitalBedStatement_2014_DistrictCODE.csv file
# Writing in chunks data/HospitalBedStatement_2014_DistrictCODE.csv file
# Pausing the process for 60 seconds
# Restarting the process for data/HospitalBedStatement_2014_DistrictNAME.csv file
# Writing in chunks data/HospitalBedStatement_2014_DistrictNAME.csv file
# Pausing the process for 60 seconds
# Starting the process for HospitalBedStatement_2015_Upazila files: with geo codes and names respectively
# Constructing file path for HospitalBedStatement_2015_Upazila file
# Getting API query for data/HospitalBedStatement_2015_UpazilaCODE.csv file
# Writing in chunks data/HospitalBedStatement_2015_UpazilaCODE.csv file
# Pausing the process for 60 seconds
# Restarting the process for data/HospitalBedStatement_2015_UpazilaNAME.csv file
# Writing in chunks data/HospitalBedStatement_2015_UpazilaNAME.csv file
# Pausing the process for 60 seconds
# Starting the process for HospitalBedStatement_2015_District files: with geo codes and names respectively
# Constructing file path for HospitalBedStatement_2015_District file
# Getting API query for data/HospitalBedStatement_2015_DistrictCODE.csv file
# Writing in chunks data/HospitalBedStatement_2015_DistrictCODE.csv file
# Pausing the process for 60 seconds
# Restarting the process for data/HospitalBedStatement_2015_DistrictNAME.csv file
# Writing in chunks data/HospitalBedStatement_2015_DistrictNAME.csv file
# Pausing the process for 60 seconds
# Starting the process for HospitalBedStatement_2016_Upazila files: with geo codes and names respectively
# Constructing file path for HospitalBedStatement_2016_Upazila file
# Getting API query for data/HospitalBedStatement_2016_UpazilaCODE.csv file
# Writing in chunks data/HospitalBedStatement_2016_UpazilaCODE.csv file
# Pausing the process for 60 seconds
# Restarting the process for data/HospitalBedStatement_2016_UpazilaNAME.csv file
# Writing in chunks data/HospitalBedStatement_2016_UpazilaNAME.csv file
# Pausing the process for 60 seconds
# Starting the process for HospitalBedStatement_2016_District files: with geo codes and names respectively
# Constructing file path for HospitalBedStatement_2016_District file
# Getting API query for data/HospitalBedStatement_2016_DistrictCODE.csv file
# Writing in chunks data/HospitalBedStatement_2016_DistrictCODE.csv file
# Pausing the process for 60 seconds
# Restarting the process for data/HospitalBedStatement_2016_DistrictNAME.csv file
# Writing in chunks data/HospitalBedStatement_2016_DistrictNAME.csv file
# Pausing the process for 60 seconds
# Starting the process for HospitalBedStatement_2017_Upazila files: with geo codes and names respectively
# Constructing file path for HospitalBedStatement_2017_Upazila file
# Getting API query for data/HospitalBedStatement_2017_UpazilaCODE.csv file
# Writing in chunks data/HospitalBedStatement_2017_UpazilaCODE.csv file
# Pausing the process for 60 seconds
# Restarting the process for data/HospitalBedStatement_2017_UpazilaNAME.csv file
# Writing in chunks data/HospitalBedStatement_2017_UpazilaNAME.csv file
# Pausing the process for 60 seconds
# Starting the process for HospitalBedStatement_2017_District files: with geo codes and names respectively
# Constructing file path for HospitalBedStatement_2017_District file
# Getting API query for data/HospitalBedStatement_2017_DistrictCODE.csv file
# Writing in chunks data/HospitalBedStatement_2017_DistrictCODE.csv file
# Pausing the process for 60 seconds
# Restarting the process for data/HospitalBedStatement_2017_DistrictNAME.csv file
# Writing in chunks data/HospitalBedStatement_2017_DistrictNAME.csv file
# Pausing the process for 60 seconds
# Starting the process for HospitalBedStatement_2018_Upazila files: with geo codes and names respectively
# Constructing file path for HospitalBedStatement_2018_Upazila file
# Getting API query for data/HospitalBedStatement_2018_UpazilaCODE.csv file
# Writing in chunks data/HospitalBedStatement_2018_UpazilaCODE.csv file
# Pausing the process for 60 seconds
# Restarting the process for data/HospitalBedStatement_2018_UpazilaNAME.csv file
# Writing in chunks data/HospitalBedStatement_2018_UpazilaNAME.csv file
# Pausing the process for 60 seconds
# Starting the process for HospitalBedStatement_2018_District files: with geo codes and names respectively
# Constructing file path for HospitalBedStatement_2018_District file
# Getting API query for data/HospitalBedStatement_2018_DistrictCODE.csv file
# Writing in chunks data/HospitalBedStatement_2018_DistrictCODE.csv file
# Pausing the process for 60 seconds
# Restarting the process for data/HospitalBedStatement_2018_DistrictNAME.csv file
# Writing in chunks data/HospitalBedStatement_2018_DistrictNAME.csv file
# Pausing the process for 60 seconds
# Starting the process for HospitalIn-PatientDepartment_2009_Upazila files: with geo codes and names respectively
# Constructing file path for HospitalIn-PatientDepartment_2009_Upazila file
# Getting API query for data/HospitalIn-PatientDepartment_2009_UpazilaCODE.csv file
# Writing in chunks data/HospitalIn-PatientDepartment_2009_UpazilaCODE.csv file
# Pausing the process for 60 seconds
# Restarting the process for data/HospitalIn-PatientDepartment_2009_UpazilaNAME.csv file
# Writing in chunks data/HospitalIn-PatientDepartment_2009_UpazilaNAME.csv file
# Pausing the process for 60 seconds
# Starting the process for HospitalIn-PatientDepartment_2009_District files: with geo codes and names respectively
# Constructing file path for HospitalIn-PatientDepartment_2009_District file
# Getting API query for data/HospitalIn-PatientDepartment_2009_DistrictCODE.csv file
# Writing in chunks data/HospitalIn-PatientDepartment_2009_DistrictCODE.csv file
# Pausing the process for 60 seconds
# Restarting the process for data/HospitalIn-PatientDepartment_2009_DistrictNAME.csv file
# Writing in chunks data/HospitalIn-PatientDepartment_2009_DistrictNAME.csv file
# Pausing the process for 60 seconds
# Starting the process for HospitalIn-PatientDepartment_2010_Upazila files: with geo codes and names respectively
# Constructing file path for HospitalIn-PatientDepartment_2010_Upazila file
# Getting API query for data/HospitalIn-PatientDepartment_2010_UpazilaCODE.csv file
# Writing in chunks data/HospitalIn-PatientDepartment_2010_UpazilaCODE.csv file
# Pausing the process for 60 seconds
# Restarting the process for data/HospitalIn-PatientDepartment_2010_UpazilaNAME.csv file
# Writing in chunks data/HospitalIn-PatientDepartment_2010_UpazilaNAME.csv file
# Pausing the process for 60 seconds
# Starting the process for HospitalIn-PatientDepartment_2010_District files: with geo codes and names respectively
# Constructing file path for HospitalIn-PatientDepartment_2010_District file
# Getting API query for data/HospitalIn-PatientDepartment_2010_DistrictCODE.csv file
# Writing in chunks data/HospitalIn-PatientDepartment_2010_DistrictCODE.csv file
# Pausing the process for 60 seconds
# Restarting the process for data/HospitalIn-PatientDepartment_2010_DistrictNAME.csv file
# Writing in chunks data/HospitalIn-PatientDepartment_2010_DistrictNAME.csv file
# Pausing the process for 60 seconds
# Starting the process for HospitalIn-PatientDepartment_2011_Upazila files: with geo codes and names respectively
# Constructing file path for HospitalIn-PatientDepartment_2011_Upazila file
# Getting API query for data/HospitalIn-PatientDepartment_2011_UpazilaCODE.csv file
# Writing in chunks data/HospitalIn-PatientDepartment_2011_UpazilaCODE.csv file
# Pausing the process for 60 seconds
# Restarting the process for data/HospitalIn-PatientDepartment_2011_UpazilaNAME.csv file
# Writing in chunks data/HospitalIn-PatientDepartment_2011_UpazilaNAME.csv file
# Pausing the process for 60 seconds
# Starting the process for HospitalIn-PatientDepartment_2011_District files: with geo codes and names respectively
# Constructing file path for HospitalIn-PatientDepartment_2011_District file
# Getting API query for data/HospitalIn-PatientDepartment_2011_DistrictCODE.csv file
# Writing in chunks data/HospitalIn-PatientDepartment_2011_DistrictCODE.csv file
# Pausing the process for 60 seconds
# Restarting the process for data/HospitalIn-PatientDepartment_2011_DistrictNAME.csv file
# Writing in chunks data/HospitalIn-PatientDepartment_2011_DistrictNAME.csv file
# Pausing the process for 60 seconds
# Starting the process for HospitalIn-PatientDepartment_2012_Upazila files: with geo codes and names respectively
# Constructing file path for HospitalIn-PatientDepartment_2012_Upazila file
# Getting API query for data/HospitalIn-PatientDepartment_2012_UpazilaCODE.csv file
# Writing in chunks data/HospitalIn-PatientDepartment_2012_UpazilaCODE.csv file
# Pausing the process for 60 seconds
# Restarting the process for data/HospitalIn-PatientDepartment_2012_UpazilaNAME.csv file
# Writing in chunks data/HospitalIn-PatientDepartment_2012_UpazilaNAME.csv file
# Pausing the process for 60 seconds
# Starting the process for HospitalIn-PatientDepartment_2012_District files: with geo codes and names respectively
# Constructing file path for HospitalIn-PatientDepartment_2012_District file
# Getting API query for data/HospitalIn-PatientDepartment_2012_DistrictCODE.csv file
# Writing in chunks data/HospitalIn-PatientDepartment_2012_DistrictCODE.csv file
# Pausing the process for 60 seconds
# Restarting the process for data/HospitalIn-PatientDepartment_2012_DistrictNAME.csv file
# Writing in chunks data/HospitalIn-PatientDepartment_2012_DistrictNAME.csv file
# Pausing the process for 60 seconds
# Starting the process for HospitalIn-PatientDepartment_2013_Upazila files: with geo codes and names respectively
# Constructing file path for HospitalIn-PatientDepartment_2013_Upazila file
# Getting API query for data/HospitalIn-PatientDepartment_2013_UpazilaCODE.csv file
# Writing in chunks data/HospitalIn-PatientDepartment_2013_UpazilaCODE.csv file
# Pausing the process for 60 seconds
# Restarting the process for data/HospitalIn-PatientDepartment_2013_UpazilaNAME.csv file
# Writing in chunks data/HospitalIn-PatientDepartment_2013_UpazilaNAME.csv file
# Pausing the process for 60 seconds
# Starting the process for HospitalIn-PatientDepartment_2013_District files: with geo codes and names respectively
# Constructing file path for HospitalIn-PatientDepartment_2013_District file
# Getting API query for data/HospitalIn-PatientDepartment_2013_DistrictCODE.csv file
# Writing in chunks data/HospitalIn-PatientDepartment_2013_DistrictCODE.csv file
# Pausing the process for 60 seconds
# Restarting the process for data/HospitalIn-PatientDepartment_2013_DistrictNAME.csv file
# Writing in chunks data/HospitalIn-PatientDepartment_2013_DistrictNAME.csv file
# Pausing the process for 60 seconds
# Starting the process for HospitalIn-PatientDepartment_2014_Upazila files: with geo codes and names respectively
# Constructing file path for HospitalIn-PatientDepartment_2014_Upazila file
# Getting API query for data/HospitalIn-PatientDepartment_2014_UpazilaCODE.csv file
# Writing in chunks data/HospitalIn-PatientDepartment_2014_UpazilaCODE.csv file
# Pausing the process for 60 seconds
# Restarting the process for data/HospitalIn-PatientDepartment_2014_UpazilaNAME.csv file
# Writing in chunks data/HospitalIn-PatientDepartment_2014_UpazilaNAME.csv file
# Pausing the process for 60 seconds
# Starting the process for HospitalIn-PatientDepartment_2014_District files: with geo codes and names respectively
# Constructing file path for HospitalIn-PatientDepartment_2014_District file
# Getting API query for data/HospitalIn-PatientDepartment_2014_DistrictCODE.csv file
# Writing in chunks data/HospitalIn-PatientDepartment_2014_DistrictCODE.csv file
# Pausing the process for 60 seconds
# Restarting the process for data/HospitalIn-PatientDepartment_2014_DistrictNAME.csv file
# Writing in chunks data/HospitalIn-PatientDepartment_2014_DistrictNAME.csv file
# Pausing the process for 60 seconds
# Starting the process for HospitalIn-PatientDepartment_2015_Upazila files: with geo codes and names respectively
# Constructing file path for HospitalIn-PatientDepartment_2015_Upazila file
# Getting API query for data/HospitalIn-PatientDepartment_2015_UpazilaCODE.csv file
# Writing in chunks data/HospitalIn-PatientDepartment_2015_UpazilaCODE.csv file
# Pausing the process for 60 seconds
# Restarting the process for data/HospitalIn-PatientDepartment_2015_UpazilaNAME.csv file
# Writing in chunks data/HospitalIn-PatientDepartment_2015_UpazilaNAME.csv file
# Pausing the process for 60 seconds
# Starting the process for HospitalIn-PatientDepartment_2015_District files: with geo codes and names respectively
# Constructing file path for HospitalIn-PatientDepartment_2015_District file
# Getting API query for data/HospitalIn-PatientDepartment_2015_DistrictCODE.csv file
# Writing in chunks data/HospitalIn-PatientDepartment_2015_DistrictCODE.csv file
# Pausing the process for 60 seconds
# Restarting the process for data/HospitalIn-PatientDepartment_2015_DistrictNAME.csv file
# Writing in chunks data/HospitalIn-PatientDepartment_2015_DistrictNAME.csv file
# Pausing the process for 60 seconds
# Starting the process for HospitalIn-PatientDepartment_2016_Upazila files: with geo codes and names respectively
# Constructing file path for HospitalIn-PatientDepartment_2016_Upazila file
# Getting API query for data/HospitalIn-PatientDepartment_2016_UpazilaCODE.csv file
# Writing in chunks data/HospitalIn-PatientDepartment_2016_UpazilaCODE.csv file
# Pausing the process for 60 seconds
# Restarting the process for data/HospitalIn-PatientDepartment_2016_UpazilaNAME.csv file
# Writing in chunks data/HospitalIn-PatientDepartment_2016_UpazilaNAME.csv file
# Pausing the process for 60 seconds
# Starting the process for HospitalIn-PatientDepartment_2016_District files: with geo codes and names respectively
# Constructing file path for HospitalIn-PatientDepartment_2016_District file
# Getting API query for data/HospitalIn-PatientDepartment_2016_DistrictCODE.csv file
# Writing in chunks data/HospitalIn-PatientDepartment_2016_DistrictCODE.csv file
# Pausing the process for 60 seconds
# Restarting the process for data/HospitalIn-PatientDepartment_2016_DistrictNAME.csv file
# Writing in chunks data/HospitalIn-PatientDepartment_2016_DistrictNAME.csv file
# Pausing the process for 60 seconds
# Starting the process for HospitalIn-PatientDepartment_2017_Upazila files: with geo codes and names respectively
# Constructing file path for HospitalIn-PatientDepartment_2017_Upazila file
# Getting API query for data/HospitalIn-PatientDepartment_2017_UpazilaCODE.csv file
# Writing in chunks data/HospitalIn-PatientDepartment_2017_UpazilaCODE.csv file
# Pausing the process for 60 seconds
# Restarting the process for data/HospitalIn-PatientDepartment_2017_UpazilaNAME.csv file
# Writing in chunks data/HospitalIn-PatientDepartment_2017_UpazilaNAME.csv file
# Pausing the process for 60 seconds
# Starting the process for HospitalIn-PatientDepartment_2017_District files: with geo codes and names respectively
# Constructing file path for HospitalIn-PatientDepartment_2017_District file
# Getting API query for data/HospitalIn-PatientDepartment_2017_DistrictCODE.csv file
# Writing in chunks data/HospitalIn-PatientDepartment_2017_DistrictCODE.csv file
# Pausing the process for 60 seconds
# Restarting the process for data/HospitalIn-PatientDepartment_2017_DistrictNAME.csv file
# Writing in chunks data/HospitalIn-PatientDepartment_2017_DistrictNAME.csv file
# Pausing the process for 60 seconds
# Starting the process for HospitalIn-PatientDepartment_2018_Upazila files: with geo codes and names respectively
# Constructing file path for HospitalIn-PatientDepartment_2018_Upazila file
# Getting API query for data/HospitalIn-PatientDepartment_2018_UpazilaCODE.csv file
# Writing in chunks data/HospitalIn-PatientDepartment_2018_UpazilaCODE.csv file
# Pausing the process for 60 seconds
# Restarting the process for data/HospitalIn-PatientDepartment_2018_UpazilaNAME.csv file
# Writing in chunks data/HospitalIn-PatientDepartment_2018_UpazilaNAME.csv file
# Pausing the process for 60 seconds
# Starting the process for HospitalIn-PatientDepartment_2018_District files: with geo codes and names respectively
# Constructing file path for HospitalIn-PatientDepartment_2018_District file
# Getting API query for data/HospitalIn-PatientDepartment_2018_DistrictCODE.csv file
# Writing in chunks data/HospitalIn-PatientDepartment_2018_DistrictCODE.csv file
# Pausing the process for 60 seconds
# Restarting the process for data/HospitalIn-PatientDepartment_2018_DistrictNAME.csv file
# Writing in chunks data/HospitalIn-PatientDepartment_2018_DistrictNAME.csv file
# Pausing the process for 60 seconds
# Starting the process for HospitalOutPatientDepartment_2009_Upazila files: with geo codes and names respectively
# Constructing file path for HospitalOutPatientDepartment_2009_Upazila file
# Getting API query for data/HospitalOutPatientDepartment_2009_UpazilaCODE.csv file
# Writing in chunks data/HospitalOutPatientDepartment_2009_UpazilaCODE.csv file
# Pausing the process for 60 seconds
# Restarting the process for data/HospitalOutPatientDepartment_2009_UpazilaNAME.csv file
# Writing in chunks data/HospitalOutPatientDepartment_2009_UpazilaNAME.csv file
# Pausing the process for 60 seconds
# Starting the process for HospitalOutPatientDepartment_2009_District files: with geo codes and names respectively
# Constructing file path for HospitalOutPatientDepartment_2009_District file
# Getting API query for data/HospitalOutPatientDepartment_2009_DistrictCODE.csv file
# Writing in chunks data/HospitalOutPatientDepartment_2009_DistrictCODE.csv file
# Pausing the process for 60 seconds
# Restarting the process for data/HospitalOutPatientDepartment_2009_DistrictNAME.csv file
# Writing in chunks data/HospitalOutPatientDepartment_2009_DistrictNAME.csv file
# Pausing the process for 60 seconds
# Starting the process for HospitalOutPatientDepartment_2010_Upazila files: with geo codes and names respectively
# Constructing file path for HospitalOutPatientDepartment_2010_Upazila file
# Getting API query for data/HospitalOutPatientDepartment_2010_UpazilaCODE.csv file
# Writing in chunks data/HospitalOutPatientDepartment_2010_UpazilaCODE.csv file
# Pausing the process for 60 seconds
# Restarting the process for data/HospitalOutPatientDepartment_2010_UpazilaNAME.csv file
# Writing in chunks data/HospitalOutPatientDepartment_2010_UpazilaNAME.csv file
# Pausing the process for 60 seconds
# Starting the process for HospitalOutPatientDepartment_2010_District files: with geo codes and names respectively
# Constructing file path for HospitalOutPatientDepartment_2010_District file
# Getting API query for data/HospitalOutPatientDepartment_2010_DistrictCODE.csv file
# Writing in chunks data/HospitalOutPatientDepartment_2010_DistrictCODE.csv file
# Pausing the process for 60 seconds
# Restarting the process for data/HospitalOutPatientDepartment_2010_DistrictNAME.csv file
# Writing in chunks data/HospitalOutPatientDepartment_2010_DistrictNAME.csv file
# Pausing the process for 60 seconds
# Starting the process for HospitalOutPatientDepartment_2011_Upazila files: with geo codes and names respectively
# Constructing file path for HospitalOutPatientDepartment_2011_Upazila file
# Getting API query for data/HospitalOutPatientDepartment_2011_UpazilaCODE.csv file
# Writing in chunks data/HospitalOutPatientDepartment_2011_UpazilaCODE.csv file
# Pausing the process for 60 seconds
# Restarting the process for data/HospitalOutPatientDepartment_2011_UpazilaNAME.csv file
# Writing in chunks data/HospitalOutPatientDepartment_2011_UpazilaNAME.csv file
# Pausing the process for 60 seconds
# Starting the process for HospitalOutPatientDepartment_2011_District files: with geo codes and names respectively
# Constructing file path for HospitalOutPatientDepartment_2011_District file
# Getting API query for data/HospitalOutPatientDepartment_2011_DistrictCODE.csv file
# Writing in chunks data/HospitalOutPatientDepartment_2011_DistrictCODE.csv file
# Pausing the process for 60 seconds
# Restarting the process for data/HospitalOutPatientDepartment_2011_DistrictNAME.csv file
# Writing in chunks data/HospitalOutPatientDepartment_2011_DistrictNAME.csv file
# Pausing the process for 60 seconds
# Starting the process for HospitalOutPatientDepartment_2012_Upazila files: with geo codes and names respectively
# Constructing file path for HospitalOutPatientDepartment_2012_Upazila file
# Getting API query for data/HospitalOutPatientDepartment_2012_UpazilaCODE.csv file
# Writing in chunks data/HospitalOutPatientDepartment_2012_UpazilaCODE.csv file
# Pausing the process for 60 seconds
# Restarting the process for data/HospitalOutPatientDepartment_2012_UpazilaNAME.csv file
# Writing in chunks data/HospitalOutPatientDepartment_2012_UpazilaNAME.csv file
# Pausing the process for 60 seconds
# Starting the process for HospitalOutPatientDepartment_2012_District files: with geo codes and names respectively
# Constructing file path for HospitalOutPatientDepartment_2012_District file
# Getting API query for data/HospitalOutPatientDepartment_2012_DistrictCODE.csv file
# Writing in chunks data/HospitalOutPatientDepartment_2012_DistrictCODE.csv file
# Pausing the process for 60 seconds
# Restarting the process for data/HospitalOutPatientDepartment_2012_DistrictNAME.csv file
# Writing in chunks data/HospitalOutPatientDepartment_2012_DistrictNAME.csv file
# Pausing the process for 60 seconds
# Starting the process for HospitalOutPatientDepartment_2013_Upazila files: with geo codes and names respectively
# Constructing file path for HospitalOutPatientDepartment_2013_Upazila file
# Getting API query for data/HospitalOutPatientDepartment_2013_UpazilaCODE.csv file
# Writing in chunks data/HospitalOutPatientDepartment_2013_UpazilaCODE.csv file
# Pausing the process for 60 seconds
# Restarting the process for data/HospitalOutPatientDepartment_2013_UpazilaNAME.csv file
# Writing in chunks data/HospitalOutPatientDepartment_2013_UpazilaNAME.csv file
# Pausing the process for 60 seconds
# Starting the process for HospitalOutPatientDepartment_2013_District files: with geo codes and names respectively
# Constructing file path for HospitalOutPatientDepartment_2013_District file
# Getting API query for data/HospitalOutPatientDepartment_2013_DistrictCODE.csv file
# Writing in chunks data/HospitalOutPatientDepartment_2013_DistrictCODE.csv file
# Pausing the process for 60 seconds
# Restarting the process for data/HospitalOutPatientDepartment_2013_DistrictNAME.csv file
# Writing in chunks data/HospitalOutPatientDepartment_2013_DistrictNAME.csv file
# Pausing the process for 60 seconds
# Starting the process for HospitalOutPatientDepartment_2014_Upazila files: with geo codes and names respectively
# Constructing file path for HospitalOutPatientDepartment_2014_Upazila file
# Getting API query for data/HospitalOutPatientDepartment_2014_UpazilaCODE.csv file
# Writing in chunks data/HospitalOutPatientDepartment_2014_UpazilaCODE.csv file
# Pausing the process for 60 seconds
# Restarting the process for data/HospitalOutPatientDepartment_2014_UpazilaNAME.csv file
# Writing in chunks data/HospitalOutPatientDepartment_2014_UpazilaNAME.csv file
# Pausing the process for 60 seconds
# Starting the process for HospitalOutPatientDepartment_2014_District files: with geo codes and names respectively
# Constructing file path for HospitalOutPatientDepartment_2014_District file
# Getting API query for data/HospitalOutPatientDepartment_2014_DistrictCODE.csv file
# Writing in chunks data/HospitalOutPatientDepartment_2014_DistrictCODE.csv file
# Pausing the process for 60 seconds
# Restarting the process for data/HospitalOutPatientDepartment_2014_DistrictNAME.csv file
# Writing in chunks data/HospitalOutPatientDepartment_2014_DistrictNAME.csv file
# Pausing the process for 60 seconds
# Starting the process for HospitalOutPatientDepartment_2015_Upazila files: with geo codes and names respectively
# Constructing file path for HospitalOutPatientDepartment_2015_Upazila file
# Getting API query for data/HospitalOutPatientDepartment_2015_UpazilaCODE.csv file
# Writing in chunks data/HospitalOutPatientDepartment_2015_UpazilaCODE.csv file
# Pausing the process for 60 seconds
# Restarting the process for data/HospitalOutPatientDepartment_2015_UpazilaNAME.csv file
# Writing in chunks data/HospitalOutPatientDepartment_2015_UpazilaNAME.csv file
# Pausing the process for 60 seconds
# Starting the process for HospitalOutPatientDepartment_2015_District files: with geo codes and names respectively
# Constructing file path for HospitalOutPatientDepartment_2015_District file
# Getting API query for data/HospitalOutPatientDepartment_2015_DistrictCODE.csv file
# Writing in chunks data/HospitalOutPatientDepartment_2015_DistrictCODE.csv file
# Pausing the process for 60 seconds
# Restarting the process for data/HospitalOutPatientDepartment_2015_DistrictNAME.csv file
# Writing in chunks data/HospitalOutPatientDepartment_2015_DistrictNAME.csv file
# Pausing the process for 60 seconds
# Starting the process for HospitalOutPatientDepartment_2016_Upazila files: with geo codes and names respectively
# Constructing file path for HospitalOutPatientDepartment_2016_Upazila file
# Getting API query for data/HospitalOutPatientDepartment_2016_UpazilaCODE.csv file
# Writing in chunks data/HospitalOutPatientDepartment_2016_UpazilaCODE.csv file
# Pausing the process for 60 seconds
# Restarting the process for data/HospitalOutPatientDepartment_2016_UpazilaNAME.csv file
# Writing in chunks data/HospitalOutPatientDepartment_2016_UpazilaNAME.csv file
# Pausing the process for 60 seconds
# Starting the process for HospitalOutPatientDepartment_2016_District files: with geo codes and names respectively
# Constructing file path for HospitalOutPatientDepartment_2016_District file
# Getting API query for data/HospitalOutPatientDepartment_2016_DistrictCODE.csv file
# Writing in chunks data/HospitalOutPatientDepartment_2016_DistrictCODE.csv file
# Pausing the process for 60 seconds
# Restarting the process for data/HospitalOutPatientDepartment_2016_DistrictNAME.csv file
# Writing in chunks data/HospitalOutPatientDepartment_2016_DistrictNAME.csv file
# Pausing the process for 60 seconds
# Starting the process for HospitalOutPatientDepartment_2017_Upazila files: with geo codes and names respectively
# Constructing file path for HospitalOutPatientDepartment_2017_Upazila file
# Getting API query for data/HospitalOutPatientDepartment_2017_UpazilaCODE.csv file
# Writing in chunks data/HospitalOutPatientDepartment_2017_UpazilaCODE.csv file
# Pausing the process for 60 seconds
# Restarting the process for data/HospitalOutPatientDepartment_2017_UpazilaNAME.csv file
# Writing in chunks data/HospitalOutPatientDepartment_2017_UpazilaNAME.csv file
# Pausing the process for 60 seconds
# Starting the process for HospitalOutPatientDepartment_2017_District files: with geo codes and names respectively
# Constructing file path for HospitalOutPatientDepartment_2017_District file
# Getting API query for data/HospitalOutPatientDepartment_2017_DistrictCODE.csv file
# Writing in chunks data/HospitalOutPatientDepartment_2017_DistrictCODE.csv file
# Pausing the process for 60 seconds
# Restarting the process for data/HospitalOutPatientDepartment_2017_DistrictNAME.csv file
# Writing in chunks data/HospitalOutPatientDepartment_2017_DistrictNAME.csv file
# Pausing the process for 60 seconds
# Starting the process for HospitalOutPatientDepartment_2018_Upazila files: with geo codes and names respectively
# Constructing file path for HospitalOutPatientDepartment_2018_Upazila file
# Getting API query for data/HospitalOutPatientDepartment_2018_UpazilaCODE.csv file
# Writing in chunks data/HospitalOutPatientDepartment_2018_UpazilaCODE.csv file
# Pausing the process for 60 seconds
# Restarting the process for data/HospitalOutPatientDepartment_2018_UpazilaNAME.csv file
# Writing in chunks data/HospitalOutPatientDepartment_2018_UpazilaNAME.csv file
# Pausing the process for 60 seconds
# Starting the process for HospitalOutPatientDepartment_2018_District files: with geo codes and names respectively
# Constructing file path for HospitalOutPatientDepartment_2018_District file
# Getting API query for data/HospitalOutPatientDepartment_2018_DistrictCODE.csv file
# Writing in chunks data/HospitalOutPatientDepartment_2018_DistrictCODE.csv file
# Pausing the process for 60 seconds
# Restarting the process for data/HospitalOutPatientDepartment_2018_DistrictNAME.csv file
# Writing in chunks data/HospitalOutPatientDepartment_2018_DistrictNAME.csv file
# Pausing the process for 60 seconds
# Starting the process for EyeHospitalIn-PatientDepartment_2009_Upazila files: with geo codes and names respectively
# Constructing file path for EyeHospitalIn-PatientDepartment_2009_Upazila file
# Getting API query for data/EyeHospitalIn-PatientDepartment_2009_UpazilaCODE.csv file
# Writing in chunks data/EyeHospitalIn-PatientDepartment_2009_UpazilaCODE.csv file
# Pausing the process for 60 seconds
# Restarting the process for data/EyeHospitalIn-PatientDepartment_2009_UpazilaNAME.csv file
# Writing in chunks data/EyeHospitalIn-PatientDepartment_2009_UpazilaNAME.csv file
# Pausing the process for 60 seconds
# Starting the process for EyeHospitalIn-PatientDepartment_2009_District files: with geo codes and names respectively
# Constructing file path for EyeHospitalIn-PatientDepartment_2009_District file
# Getting API query for data/EyeHospitalIn-PatientDepartment_2009_DistrictCODE.csv file
# Writing in chunks data/EyeHospitalIn-PatientDepartment_2009_DistrictCODE.csv file
# Pausing the process for 60 seconds
# Restarting the process for data/EyeHospitalIn-PatientDepartment_2009_DistrictNAME.csv file
# Writing in chunks data/EyeHospitalIn-PatientDepartment_2009_DistrictNAME.csv file
# Pausing the process for 60 seconds
# Starting the process for EyeHospitalIn-PatientDepartment_2010_Upazila files: with geo codes and names respectively
# Constructing file path for EyeHospitalIn-PatientDepartment_2010_Upazila file
# Getting API query for data/EyeHospitalIn-PatientDepartment_2010_UpazilaCODE.csv file
# Writing in chunks data/EyeHospitalIn-PatientDepartment_2010_UpazilaCODE.csv file
# Pausing the process for 60 seconds
# Restarting the process for data/EyeHospitalIn-PatientDepartment_2010_UpazilaNAME.csv file
# Writing in chunks data/EyeHospitalIn-PatientDepartment_2010_UpazilaNAME.csv file
# Pausing the process for 60 seconds
# Starting the process for EyeHospitalIn-PatientDepartment_2010_District files: with geo codes and names respectively
# Constructing file path for EyeHospitalIn-PatientDepartment_2010_District file
# Getting API query for data/EyeHospitalIn-PatientDepartment_2010_DistrictCODE.csv file
# Writing in chunks data/EyeHospitalIn-PatientDepartment_2010_DistrictCODE.csv file
# Pausing the process for 60 seconds
# Restarting the process for data/EyeHospitalIn-PatientDepartment_2010_DistrictNAME.csv file
# Writing in chunks data/EyeHospitalIn-PatientDepartment_2010_DistrictNAME.csv file
# Pausing the process for 60 seconds
# Starting the process for EyeHospitalIn-PatientDepartment_2011_Upazila files: with geo codes and names respectively
# Constructing file path for EyeHospitalIn-PatientDepartment_2011_Upazila file
# Getting API query for data/EyeHospitalIn-PatientDepartment_2011_UpazilaCODE.csv file
# Writing in chunks data/EyeHospitalIn-PatientDepartment_2011_UpazilaCODE.csv file
# Pausing the process for 60 seconds
# Restarting the process for data/EyeHospitalIn-PatientDepartment_2011_UpazilaNAME.csv file
# Writing in chunks data/EyeHospitalIn-PatientDepartment_2011_UpazilaNAME.csv file
# Pausing the process for 60 seconds
# Starting the process for EyeHospitalIn-PatientDepartment_2011_District files: with geo codes and names respectively
# Constructing file path for EyeHospitalIn-PatientDepartment_2011_District file
# Getting API query for data/EyeHospitalIn-PatientDepartment_2011_DistrictCODE.csv file
# Writing in chunks data/EyeHospitalIn-PatientDepartment_2011_DistrictCODE.csv file
# Pausing the process for 60 seconds
# Restarting the process for data/EyeHospitalIn-PatientDepartment_2011_DistrictNAME.csv file
# Writing in chunks data/EyeHospitalIn-PatientDepartment_2011_DistrictNAME.csv file
# Pausing the process for 60 seconds
# Starting the process for EyeHospitalIn-PatientDepartment_2012_Upazila files: with geo codes and names respectively
# Constructing file path for EyeHospitalIn-PatientDepartment_2012_Upazila file
# Getting API query for data/EyeHospitalIn-PatientDepartment_2012_UpazilaCODE.csv file
# Writing in chunks data/EyeHospitalIn-PatientDepartment_2012_UpazilaCODE.csv file
# Pausing the process for 60 seconds
# Restarting the process for data/EyeHospitalIn-PatientDepartment_2012_UpazilaNAME.csv file
# Writing in chunks data/EyeHospitalIn-PatientDepartment_2012_UpazilaNAME.csv file
# Pausing the process for 60 seconds
# Starting the process for EyeHospitalIn-PatientDepartment_2012_District files: with geo codes and names respectively
# Constructing file path for EyeHospitalIn-PatientDepartment_2012_District file
# Getting API query for data/EyeHospitalIn-PatientDepartment_2012_DistrictCODE.csv file
# Writing in chunks data/EyeHospitalIn-PatientDepartment_2012_DistrictCODE.csv file
# Pausing the process for 60 seconds
# Restarting the process for data/EyeHospitalIn-PatientDepartment_2012_DistrictNAME.csv file
# Writing in chunks data/EyeHospitalIn-PatientDepartment_2012_DistrictNAME.csv file
# Pausing the process for 60 seconds
# Starting the process for EyeHospitalIn-PatientDepartment_2013_Upazila files: with geo codes and names respectively
# Constructing file path for EyeHospitalIn-PatientDepartment_2013_Upazila file
# Getting API query for data/EyeHospitalIn-PatientDepartment_2013_UpazilaCODE.csv file
# Writing in chunks data/EyeHospitalIn-PatientDepartment_2013_UpazilaCODE.csv file
# Pausing the process for 60 seconds
# Restarting the process for data/EyeHospitalIn-PatientDepartment_2013_UpazilaNAME.csv file
# Writing in chunks data/EyeHospitalIn-PatientDepartment_2013_UpazilaNAME.csv file
# Pausing the process for 60 seconds
# Starting the process for EyeHospitalIn-PatientDepartment_2013_District files: with geo codes and names respectively
# Constructing file path for EyeHospitalIn-PatientDepartment_2013_District file
# Getting API query for data/EyeHospitalIn-PatientDepartment_2013_DistrictCODE.csv file
# Writing in chunks data/EyeHospitalIn-PatientDepartment_2013_DistrictCODE.csv file
# Pausing the process for 60 seconds
# Restarting the process for data/EyeHospitalIn-PatientDepartment_2013_DistrictNAME.csv file
# Writing in chunks data/EyeHospitalIn-PatientDepartment_2013_DistrictNAME.csv file
# Pausing the process for 60 seconds
# Starting the process for EyeHospitalIn-PatientDepartment_2014_Upazila files: with geo codes and names respectively
# Constructing file path for EyeHospitalIn-PatientDepartment_2014_Upazila file
# Getting API query for data/EyeHospitalIn-PatientDepartment_2014_UpazilaCODE.csv file
# Writing in chunks data/EyeHospitalIn-PatientDepartment_2014_UpazilaCODE.csv file
# Pausing the process for 60 seconds
# Restarting the process for data/EyeHospitalIn-PatientDepartment_2014_UpazilaNAME.csv file
# Writing in chunks data/EyeHospitalIn-PatientDepartment_2014_UpazilaNAME.csv file
# Pausing the process for 60 seconds
# Starting the process for EyeHospitalIn-PatientDepartment_2014_District files: with geo codes and names respectively
# Constructing file path for EyeHospitalIn-PatientDepartment_2014_District file
# Getting API query for data/EyeHospitalIn-PatientDepartment_2014_DistrictCODE.csv file
# Writing in chunks data/EyeHospitalIn-PatientDepartment_2014_DistrictCODE.csv file
# Pausing the process for 60 seconds
# Restarting the process for data/EyeHospitalIn-PatientDepartment_2014_DistrictNAME.csv file
# Writing in chunks data/EyeHospitalIn-PatientDepartment_2014_DistrictNAME.csv file
# Pausing the process for 60 seconds
# Starting the process for EyeHospitalIn-PatientDepartment_2015_Upazila files: with geo codes and names respectively
# Constructing file path for EyeHospitalIn-PatientDepartment_2015_Upazila file
# Getting API query for data/EyeHospitalIn-PatientDepartment_2015_UpazilaCODE.csv file
# Writing in chunks data/EyeHospitalIn-PatientDepartment_2015_UpazilaCODE.csv file
# Pausing the process for 60 seconds
# Restarting the process for data/EyeHospitalIn-PatientDepartment_2015_UpazilaNAME.csv file
# Writing in chunks data/EyeHospitalIn-PatientDepartment_2015_UpazilaNAME.csv file
# Pausing the process for 60 seconds
# Starting the process for EyeHospitalIn-PatientDepartment_2015_District files: with geo codes and names respectively
# Constructing file path for EyeHospitalIn-PatientDepartment_2015_District file
# Getting API query for data/EyeHospitalIn-PatientDepartment_2015_DistrictCODE.csv file
# Writing in chunks data/EyeHospitalIn-PatientDepartment_2015_DistrictCODE.csv file
# Pausing the process for 60 seconds
# Restarting the process for data/EyeHospitalIn-PatientDepartment_2015_DistrictNAME.csv file
# Writing in chunks data/EyeHospitalIn-PatientDepartment_2015_DistrictNAME.csv file
# Pausing the process for 60 seconds
# Starting the process for EyeHospitalIn-PatientDepartment_2016_Upazila files: with geo codes and names respectively
# Constructing file path for EyeHospitalIn-PatientDepartment_2016_Upazila file
# Getting API query for data/EyeHospitalIn-PatientDepartment_2016_UpazilaCODE.csv file
# Writing in chunks data/EyeHospitalIn-PatientDepartment_2016_UpazilaCODE.csv file
# Pausing the process for 60 seconds
# Restarting the process for data/EyeHospitalIn-PatientDepartment_2016_UpazilaNAME.csv file
# Writing in chunks data/EyeHospitalIn-PatientDepartment_2016_UpazilaNAME.csv file
# Pausing the process for 60 seconds
# Starting the process for EyeHospitalIn-PatientDepartment_2016_District files: with geo codes and names respectively
# Constructing file path for EyeHospitalIn-PatientDepartment_2016_District file
# Getting API query for data/EyeHospitalIn-PatientDepartment_2016_DistrictCODE.csv file
# Writing in chunks data/EyeHospitalIn-PatientDepartment_2016_DistrictCODE.csv file
# Pausing the process for 60 seconds
# Restarting the process for data/EyeHospitalIn-PatientDepartment_2016_DistrictNAME.csv file
# Writing in chunks data/EyeHospitalIn-PatientDepartment_2016_DistrictNAME.csv file
# Pausing the process for 60 seconds
# Starting the process for EyeHospitalIn-PatientDepartment_2017_Upazila files: with geo codes and names respectively
# Constructing file path for EyeHospitalIn-PatientDepartment_2017_Upazila file
# Getting API query for data/EyeHospitalIn-PatientDepartment_2017_UpazilaCODE.csv file
# Writing in chunks data/EyeHospitalIn-PatientDepartment_2017_UpazilaCODE.csv file
# Pausing the process for 60 seconds
# Restarting the process for data/EyeHospitalIn-PatientDepartment_2017_UpazilaNAME.csv file
# Writing in chunks data/EyeHospitalIn-PatientDepartment_2017_UpazilaNAME.csv file
# Pausing the process for 60 seconds
# Starting the process for EyeHospitalIn-PatientDepartment_2017_District files: with geo codes and names respectively
# Constructing file path for EyeHospitalIn-PatientDepartment_2017_District file
# Getting API query for data/EyeHospitalIn-PatientDepartment_2017_DistrictCODE.csv file
# Writing in chunks data/EyeHospitalIn-PatientDepartment_2017_DistrictCODE.csv file
# Pausing the process for 60 seconds
# Restarting the process for data/EyeHospitalIn-PatientDepartment_2017_DistrictNAME.csv file
# Writing in chunks data/EyeHospitalIn-PatientDepartment_2017_DistrictNAME.csv file
# Pausing the process for 60 seconds
# Starting the process for EyeHospitalIn-PatientDepartment_2018_Upazila files: with geo codes and names respectively
# Constructing file path for EyeHospitalIn-PatientDepartment_2018_Upazila file
# Getting API query for data/EyeHospitalIn-PatientDepartment_2018_UpazilaCODE.csv file
# Writing in chunks data/EyeHospitalIn-PatientDepartment_2018_UpazilaCODE.csv file
# Pausing the process for 60 seconds
# Restarting the process for data/EyeHospitalIn-PatientDepartment_2018_UpazilaNAME.csv file
# Writing in chunks data/EyeHospitalIn-PatientDepartment_2018_UpazilaNAME.csv file
# Pausing the process for 60 seconds
# Starting the process for EyeHospitalIn-PatientDepartment_2018_District files: with geo codes and names respectively
# Constructing file path for EyeHospitalIn-PatientDepartment_2018_District file
# Getting API query for data/EyeHospitalIn-PatientDepartment_2018_DistrictCODE.csv file
# Writing in chunks data/EyeHospitalIn-PatientDepartment_2018_DistrictCODE.csv file
# Pausing the process for 60 seconds
# Restarting the process for data/EyeHospitalIn-PatientDepartment_2018_DistrictNAME.csv file
# Writing in chunks data/EyeHospitalIn-PatientDepartment_2018_DistrictNAME.csv file
# Pausing the process for 60 seconds
# Starting the process for EyeHospitalOutPatientDepartment_2009_Upazila files: with geo codes and names respectively
# Constructing file path for EyeHospitalOutPatientDepartment_2009_Upazila file
# Getting API query for data/EyeHospitalOutPatientDepartment_2009_UpazilaCODE.csv file
# Writing in chunks data/EyeHospitalOutPatientDepartment_2009_UpazilaCODE.csv file
# Pausing the process for 60 seconds
# Restarting the process for data/EyeHospitalOutPatientDepartment_2009_UpazilaNAME.csv file
# Writing in chunks data/EyeHospitalOutPatientDepartment_2009_UpazilaNAME.csv file
# Pausing the process for 60 seconds
# Starting the process for EyeHospitalOutPatientDepartment_2009_District files: with geo codes and names respectively
# Constructing file path for EyeHospitalOutPatientDepartment_2009_District file
# Getting API query for data/EyeHospitalOutPatientDepartment_2009_DistrictCODE.csv file
# Writing in chunks data/EyeHospitalOutPatientDepartment_2009_DistrictCODE.csv file
# Pausing the process for 60 seconds
# Restarting the process for data/EyeHospitalOutPatientDepartment_2009_DistrictNAME.csv file
# Writing in chunks data/EyeHospitalOutPatientDepartment_2009_DistrictNAME.csv file
# Pausing the process for 60 seconds
# Starting the process for EyeHospitalOutPatientDepartment_2010_Upazila files: with geo codes and names respectively
# Constructing file path for EyeHospitalOutPatientDepartment_2010_Upazila file
# Getting API query for data/EyeHospitalOutPatientDepartment_2010_UpazilaCODE.csv file
# Writing in chunks data/EyeHospitalOutPatientDepartment_2010_UpazilaCODE.csv file
# Pausing the process for 60 seconds
# Restarting the process for data/EyeHospitalOutPatientDepartment_2010_UpazilaNAME.csv file
# Writing in chunks data/EyeHospitalOutPatientDepartment_2010_UpazilaNAME.csv file
# Pausing the process for 60 seconds
# ...
# Pausing the process for 60 seconds
# Restarting the process for data/under5Nutritionservice_2014_UpazilaNAME.csv file
# Writing in chunks data/under5Nutritionservice_2014_UpazilaNAME.csv file
# Pausing the process for 60 seconds
# Starting the process for under5Nutritionservice_2014_District files: with geo codes and names respectively
# Constructing file path for under5Nutritionservice_2014_District file
# Getting API query for data/under5Nutritionservice_2014_DistrictCODE.csv file
# Writing in chunks data/under5Nutritionservice_2014_DistrictCODE.csv file
# Pausing the process for 60 seconds
# Restarting the process for data/under5Nutritionservice_2014_DistrictNAME.csv file
# Writing in chunks data/under5Nutritionservice_2014_DistrictNAME.csv file
# Pausing the process for 60 seconds
# Starting the process for under5Nutritionservice_2015_Upazila files: with geo codes and names respectively
# Constructing file path for under5Nutritionservice_2015_Upazila file
# Getting API query for data/under5Nutritionservice_2015_UpazilaCODE.csv file
# Writing in chunks data/under5Nutritionservice_2015_UpazilaCODE.csv file
# Pausing the process for 60 seconds
# Restarting the process for data/under5Nutritionservice_2015_UpazilaNAME.csv file
# Writing in chunks data/under5Nutritionservice_2015_UpazilaNAME.csv file
# Pausing the process for 60 seconds
# Starting the process for under5Nutritionservice_2015_District files: with geo codes and names respectively
# Constructing file path for under5Nutritionservice_2015_District file
# Getting API query for data/under5Nutritionservice_2015_DistrictCODE.csv file
# Writing in chunks data/under5Nutritionservice_2015_DistrictCODE.csv file
# Pausing the process for 60 seconds
# Restarting the process for data/under5Nutritionservice_2015_DistrictNAME.csv file
# Writing in chunks data/under5Nutritionservice_2015_DistrictNAME.csv file
# Pausing the process for 60 seconds
# Starting the process for under5Nutritionservice_2016_Upazila files: with geo codes and names respectively
# Constructing file path for under5Nutritionservice_2016_Upazila file
# Getting API query for data/under5Nutritionservice_2016_UpazilaCODE.csv file
# Writing in chunks data/under5Nutritionservice_2016_UpazilaCODE.csv file
# Pausing the process for 60 seconds
# Restarting the process for data/under5Nutritionservice_2016_UpazilaNAME.csv file
# Writing in chunks data/under5Nutritionservice_2016_UpazilaNAME.csv file
# Pausing the process for 60 seconds
# Starting the process for under5Nutritionservice_2016_District files: with geo codes and names respectively
# Constructing file path for under5Nutritionservice_2016_District file
# Getting API query for data/under5Nutritionservice_2016_DistrictCODE.csv file
# Writing in chunks data/under5Nutritionservice_2016_DistrictCODE.csv file
# Pausing the process for 60 seconds
# Restarting the process for data/under5Nutritionservice_2016_DistrictNAME.csv file
# Writing in chunks data/under5Nutritionservice_2016_DistrictNAME.csv file
# Pausing the process for 60 seconds
# Starting the process for under5Nutritionservice_2017_Upazila files: with geo codes and names respectively
# Constructing file path for under5Nutritionservice_2017_Upazila file
# Getting API query for data/under5Nutritionservice_2017_UpazilaCODE.csv file
# Writing in chunks data/under5Nutritionservice_2017_UpazilaCODE.csv file
# Pausing the process for 60 seconds
# Restarting the process for data/under5Nutritionservice_2017_UpazilaNAME.csv file
# Writing in chunks data/under5Nutritionservice_2017_UpazilaNAME.csv file
# Pausing the process for 60 seconds
# Starting the process for under5Nutritionservice_2017_District files: with geo codes and names respectively
# Constructing file path for under5Nutritionservice_2017_District file
# Getting API query for data/under5Nutritionservice_2017_DistrictCODE.csv file
# Writing in chunks data/under5Nutritionservice_2017_DistrictCODE.csv file
# Pausing the process for 60 seconds
# Restarting the process for data/under5Nutritionservice_2017_DistrictNAME.csv file
# Writing in chunks data/under5Nutritionservice_2017_DistrictNAME.csv file
# Pausing the process for 60 seconds
# Starting the process for under5Nutritionservice_2018_Upazila files: with geo codes and names respectively
# Constructing file path for under5Nutritionservice_2018_Upazila file
# Getting API query for data/under5Nutritionservice_2018_UpazilaCODE.csv file
# Writing in chunks data/under5Nutritionservice_2018_UpazilaCODE.csv file
# Pausing the process for 60 seconds
# Restarting the process for data/under5Nutritionservice_2018_UpazilaNAME.csv file
# Writing in chunks data/under5Nutritionservice_2018_UpazilaNAME.csv file
# Pausing the process for 60 seconds
# Starting the process for under5Nutritionservice_2018_District files: with geo codes and names respectively
# Constructing file path for under5Nutritionservice_2018_District file
# Getting API query for data/under5Nutritionservice_2018_DistrictCODE.csv file
# Writing in chunks data/under5Nutritionservice_2018_DistrictCODE.csv file
# Pausing the process for 60 seconds
# Restarting the process for data/under5Nutritionservice_2018_DistrictNAME.csv file
# Writing in chunks data/under5Nutritionservice_2018_DistrictNAME.csv file
# Pausing the process for 60 seconds
# Starting the process for NGOs&UrbanonNutrition_2009_Upazila files: with geo codes and names respectively
# Constructing file path for NGOs&UrbanonNutrition_2009_Upazila file
# Getting API query for data/NGOs&UrbanonNutrition_2009_UpazilaCODE.csv file
# Writing in chunks data/NGOs&UrbanonNutrition_2009_UpazilaCODE.csv file
# Pausing the process for 60 seconds
# Restarting the process for data/NGOs&UrbanonNutrition_2009_UpazilaNAME.csv file
# Writing in chunks data/NGOs&UrbanonNutrition_2009_UpazilaNAME.csv file
# Pausing the process for 60 seconds
# Starting the process for NGOs&UrbanonNutrition_2009_District files: with geo codes and names respectively
# Constructing file path for NGOs&UrbanonNutrition_2009_District file
# Getting API query for data/NGOs&UrbanonNutrition_2009_DistrictCODE.csv file
# Writing in chunks data/NGOs&UrbanonNutrition_2009_DistrictCODE.csv file
# Pausing the process for 60 seconds
# Restarting the process for data/NGOs&UrbanonNutrition_2009_DistrictNAME.csv file
# Writing in chunks data/NGOs&UrbanonNutrition_2009_DistrictNAME.csv file
# Pausing the process for 60 seconds
# Starting the process for NGOs&UrbanonNutrition_2010_Upazila files: with geo codes and names respectively
# Constructing file path for NGOs&UrbanonNutrition_2010_Upazila file
# Getting API query for data/NGOs&UrbanonNutrition_2010_UpazilaCODE.csv file
# Writing in chunks data/NGOs&UrbanonNutrition_2010_UpazilaCODE.csv file
# Pausing the process for 60 seconds
# Restarting the process for data/NGOs&UrbanonNutrition_2010_UpazilaNAME.csv file
# Writing in chunks data/NGOs&UrbanonNutrition_2010_UpazilaNAME.csv file
# Pausing the process for 60 seconds
# Starting the process for NGOs&UrbanonNutrition_2010_District files: with geo codes and names respectively
# Constructing file path for NGOs&UrbanonNutrition_2010_District file
# Getting API query for data/NGOs&UrbanonNutrition_2010_DistrictCODE.csv file
# Writing in chunks data/NGOs&UrbanonNutrition_2010_DistrictCODE.csv file
# Pausing the process for 60 seconds
# Restarting the process for data/NGOs&UrbanonNutrition_2010_DistrictNAME.csv file
# Writing in chunks data/NGOs&UrbanonNutrition_2010_DistrictNAME.csv file
# Pausing the process for 60 seconds
# Starting the process for NGOs&UrbanonNutrition_2011_Upazila files: with geo codes and names respectively
# Constructing file path for NGOs&UrbanonNutrition_2011_Upazila file
# Getting API query for data/NGOs&UrbanonNutrition_2011_UpazilaCODE.csv file
# Writing in chunks data/NGOs&UrbanonNutrition_2011_UpazilaCODE.csv file
# Pausing the process for 60 seconds
# Restarting the process for data/NGOs&UrbanonNutrition_2011_UpazilaNAME.csv file
# Writing in chunks data/NGOs&UrbanonNutrition_2011_UpazilaNAME.csv file
# Pausing the process for 60 seconds
# Starting the process for NGOs&UrbanonNutrition_2011_District files: with geo codes and names respectively
# Constructing file path for NGOs&UrbanonNutrition_2011_District file
# Getting API query for data/NGOs&UrbanonNutrition_2011_DistrictCODE.csv file
# Writing in chunks data/NGOs&UrbanonNutrition_2011_DistrictCODE.csv file
# Pausing the process for 60 seconds
# Restarting the process for data/NGOs&UrbanonNutrition_2011_DistrictNAME.csv file
# Writing in chunks data/NGOs&UrbanonNutrition_2011_DistrictNAME.csv file
# Pausing the process for 60 seconds
# Starting the process for NGOs&UrbanonNutrition_2012_Upazila files: with geo codes and names respectively
# Constructing file path for NGOs&UrbanonNutrition_2012_Upazila file
# Getting API query for data/NGOs&UrbanonNutrition_2012_UpazilaCODE.csv file
# Writing in chunks data/NGOs&UrbanonNutrition_2012_UpazilaCODE.csv file
# Pausing the process for 60 seconds
# Restarting the process for data/NGOs&UrbanonNutrition_2012_UpazilaNAME.csv file
# Writing in chunks data/NGOs&UrbanonNutrition_2012_UpazilaNAME.csv file
# Pausing the process for 60 seconds
# Starting the process for NGOs&UrbanonNutrition_2012_District files: with geo codes and names respectively
# Constructing file path for NGOs&UrbanonNutrition_2012_District file
# Getting API query for data/NGOs&UrbanonNutrition_2012_DistrictCODE.csv file
# Writing in chunks data/NGOs&UrbanonNutrition_2012_DistrictCODE.csv file
# Pausing the process for 60 seconds
# Restarting the process for data/NGOs&UrbanonNutrition_2012_DistrictNAME.csv file
# Writing in chunks data/NGOs&UrbanonNutrition_2012_DistrictNAME.csv file
# Pausing the process for 60 seconds
# Starting the process for NGOs&UrbanonNutrition_2013_Upazila files: with geo codes and names respectively
# Constructing file path for NGOs&UrbanonNutrition_2013_Upazila file
# Getting API query for data/NGOs&UrbanonNutrition_2013_UpazilaCODE.csv file
# Writing in chunks data/NGOs&UrbanonNutrition_2013_UpazilaCODE.csv file
# Pausing the process for 60 seconds
# Restarting the process for data/NGOs&UrbanonNutrition_2013_UpazilaNAME.csv file
# Writing in chunks data/NGOs&UrbanonNutrition_2013_UpazilaNAME.csv file
# Pausing the process for 60 seconds
# Starting the process for NGOs&UrbanonNutrition_2013_District files: with geo codes and names respectively
# Constructing file path for NGOs&UrbanonNutrition_2013_District file
# Getting API query for data/NGOs&UrbanonNutrition_2013_DistrictCODE.csv file
# Writing in chunks data/NGOs&UrbanonNutrition_2013_DistrictCODE.csv file
# Pausing the process for 60 seconds
# Restarting the process for data/NGOs&UrbanonNutrition_2013_DistrictNAME.csv file
# Writing in chunks data/NGOs&UrbanonNutrition_2013_DistrictNAME.csv file
# Pausing the process for 60 seconds
# Starting the process for NGOs&UrbanonNutrition_2014_Upazila files: with geo codes and names respectively
# Constructing file path for NGOs&UrbanonNutrition_2014_Upazila file
# Getting API query for data/NGOs&UrbanonNutrition_2014_UpazilaCODE.csv file
# Writing in chunks data/NGOs&UrbanonNutrition_2014_UpazilaCODE.csv file
# Pausing the process for 60 seconds
# Restarting the process for data/NGOs&UrbanonNutrition_2014_UpazilaNAME.csv file
# Writing in chunks data/NGOs&UrbanonNutrition_2014_UpazilaNAME.csv file
# Pausing the process for 60 seconds
# Starting the process for NGOs&UrbanonNutrition_2014_District files: with geo codes and names respectively
# Constructing file path for NGOs&UrbanonNutrition_2014_District file
# Getting API query for data/NGOs&UrbanonNutrition_2014_DistrictCODE.csv file
# Writing in chunks data/NGOs&UrbanonNutrition_2014_DistrictCODE.csv file
# Pausing the process for 60 seconds
# Restarting the process for data/NGOs&UrbanonNutrition_2014_DistrictNAME.csv file
# Writing in chunks data/NGOs&UrbanonNutrition_2014_DistrictNAME.csv file
# Pausing the process for 60 seconds
# Starting the process for NGOs&UrbanonNutrition_2015_Upazila files: with geo codes and names respectively
# Constructing file path for NGOs&UrbanonNutrition_2015_Upazila file
# Getting API query for data/NGOs&UrbanonNutrition_2015_UpazilaCODE.csv file
# Writing in chunks data/NGOs&UrbanonNutrition_2015_UpazilaCODE.csv file
# Pausing the process for 60 seconds
# Restarting the process for data/NGOs&UrbanonNutrition_2015_UpazilaNAME.csv file
# Writing in chunks data/NGOs&UrbanonNutrition_2015_UpazilaNAME.csv file
# Pausing the process for 60 seconds
# Starting the process for NGOs&UrbanonNutrition_2015_District files: with geo codes and names respectively
# Constructing file path for NGOs&UrbanonNutrition_2015_District file
# Getting API query for data/NGOs&UrbanonNutrition_2015_DistrictCODE.csv file
# Writing in chunks data/NGOs&UrbanonNutrition_2015_DistrictCODE.csv file
# Pausing the process for 60 seconds
# Restarting the process for data/NGOs&UrbanonNutrition_2015_DistrictNAME.csv file
# Writing in chunks data/NGOs&UrbanonNutrition_2015_DistrictNAME.csv file
# Pausing the process for 60 seconds
# Starting the process for NGOs&UrbanonNutrition_2016_Upazila files: with geo codes and names respectively
# Constructing file path for NGOs&UrbanonNutrition_2016_Upazila file
# Getting API query for data/NGOs&UrbanonNutrition_2016_UpazilaCODE.csv file
# Writing in chunks data/NGOs&UrbanonNutrition_2016_UpazilaCODE.csv file
# Pausing the process for 60 seconds
# Restarting the process for data/NGOs&UrbanonNutrition_2016_UpazilaNAME.csv file
# Writing in chunks data/NGOs&UrbanonNutrition_2016_UpazilaNAME.csv file
# Pausing the process for 60 seconds
# Starting the process for NGOs&UrbanonNutrition_2016_District files: with geo codes and names respectively
# Constructing file path for NGOs&UrbanonNutrition_2016_District file
# Getting API query for data/NGOs&UrbanonNutrition_2016_DistrictCODE.csv file
# Writing in chunks data/NGOs&UrbanonNutrition_2016_DistrictCODE.csv file
# Pausing the process for 60 seconds
# Restarting the process for data/NGOs&UrbanonNutrition_2016_DistrictNAME.csv file
# Writing in chunks data/NGOs&UrbanonNutrition_2016_DistrictNAME.csv file
# Pausing the process for 60 seconds
# Starting the process for NGOs&UrbanonNutrition_2017_Upazila files: with geo codes and names respectively
# Constructing file path for NGOs&UrbanonNutrition_2017_Upazila file
# Getting API query for data/NGOs&UrbanonNutrition_2017_UpazilaCODE.csv file
# Writing in chunks data/NGOs&UrbanonNutrition_2017_UpazilaCODE.csv file
# Pausing the process for 60 seconds
# Restarting the process for data/NGOs&UrbanonNutrition_2017_UpazilaNAME.csv file
# Writing in chunks data/NGOs&UrbanonNutrition_2017_UpazilaNAME.csv file
# Pausing the process for 60 seconds
# Starting the process for NGOs&UrbanonNutrition_2017_District files: with geo codes and names respectively
# Constructing file path for NGOs&UrbanonNutrition_2017_District file
# Getting API query for data/NGOs&UrbanonNutrition_2017_DistrictCODE.csv file
# Writing in chunks data/NGOs&UrbanonNutrition_2017_DistrictCODE.csv file
# Pausing the process for 60 seconds
# Restarting the process for data/NGOs&UrbanonNutrition_2017_DistrictNAME.csv file
# Writing in chunks data/NGOs&UrbanonNutrition_2017_DistrictNAME.csv file
# Pausing the process for 60 seconds
# Starting the process for NGOs&UrbanonNutrition_2018_Upazila files: with geo codes and names respectively
# Constructing file path for NGOs&UrbanonNutrition_2018_Upazila file
# Getting API query for data/NGOs&UrbanonNutrition_2018_UpazilaCODE.csv file
# Writing in chunks data/NGOs&UrbanonNutrition_2018_UpazilaCODE.csv file
# Pausing the process for 60 seconds
# Restarting the process for data/NGOs&UrbanonNutrition_2018_UpazilaNAME.csv file
# Writing in chunks data/NGOs&UrbanonNutrition_2018_UpazilaNAME.csv file
# Pausing the process for 60 seconds
# Starting the process for NGOs&UrbanonNutrition_2018_District files: with geo codes and names respectively
# Constructing file path for NGOs&UrbanonNutrition_2018_District file
# Getting API query for data/NGOs&UrbanonNutrition_2018_DistrictCODE.csv file
# Writing in chunks data/NGOs&UrbanonNutrition_2018_DistrictCODE.csv file
# Pausing the process for 60 seconds
# Restarting the process for data/NGOs&UrbanonNutrition_2018_DistrictNAME.csv file
# Writing in chunks data/NGOs&UrbanonNutrition_2018_DistrictNAME.csv file
# Pausing the process for 60 seconds
