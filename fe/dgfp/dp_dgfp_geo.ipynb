# %% [markdown]
# ## DGFP: Processing GEO files

# %%
import os
import glob
import logging
import pandas as pd

# %% [markdown]
# ## To do list:
# - **DONE: Extract all names from datasets**
# - **DONE: Define variable names for dataset 1**
# - **DONE: Define variable names for dataset 2**
# - **DONE: Define variable names for dataset 3**
# - **DONE: Define variable names for dataset 4**
# - **DONE: Define variable names for dataset 5**
# - **DONE: Define variable names for dataset 6**
# - **DONE: Define variable names for dataset 7**
# - **DONE: Define variable names for dataset 8**
# - **DONE: Define variable names for dataset 9**
# - **Extract subdistrict codes and names and align**
# - Import BBS codes from BBS data
# - Align DGFP codes with BBS codes from union list
# - Write out data

# %%
def read_data(path, ext):
    files_list = glob.glob(path + '/*.' + ext)
    data = list()
    for file in files_list:
        file_name = os.path.split(file)[1][:-4]
        program = file.split("/")[-2]
        try:
            tmp = pd.read_csv(file, sep='\t', comment=' ')
        except pd.errors.EmptyDataError:
            print(f"{file} has no columns to parse. Moving on")
            continue
        file_name_comp = file_name.split('-')
        tmp['Year'] = file_name_comp[0]
        tmp['Month'] = file_name_comp[1]
        tmp['District'] =file_name_comp[3]
        tmp['Division'] = file_name_comp[4]
        tmp['program'] = program
        data.append(tmp)
    return pd.concat(data, axis=0)

def extract_var_info(files_paths, ext, out):
    names_dict = {'dir':[], 'names':[]}
    dirs = pd.read_csv(files_paths, header=None, names=['dirs'])
    for folder in dirs['dirs']:
        print(folder)
        tmp = read_data(path=folder, ext=ext)
        print(tmp.shape)
        display(tmp.head())
        names_dict['names'] = names_dict['names'] + list(tmp.columns)
        names_dict['dir'] = names_dict['dir'] + [folder]*len(list(tmp.columns))
        output = pd.DataFrame.from_dict(names_dict)
        output.to_csv(OUT, index=False, index_label=False)
    return output

def extract_geo_info(files_paths, ext, vars_to_select, year):
    dirs = pd.read_csv(files_paths, header=None, names=['dirs'])
    out = {}
    for folder in dirs['dirs']:
        tmp = read_data(path=folder, ext=ext)
        if len(tmp[year].unique()) > 2:
            subset = [var for var in list(tmp.columns) if var in vars_to_select]
            print(list(tmp.columns))
            print(subset)
            tmp = tmp[subset]
            print(tmp.shape)
            out[folder] = tmp
    return out

def import_process(in_file, out_file):
    with open(in_file, 'r') as f:
        file = f.readlines()
    # out = [line for line in file if line[0].isdigit()]
    out = []
    for line in file:
        if line[0].isdigit():
            line = line.split(",", 4)
            line[4] = line[4].replace(",", " ")
            line = ",".join(line)
            out.append(line)
    with open(out_file, 'w') as w:
        for line in out:
            w.write(line)
    return out

# %%
PATHS = '../../output/dgfp/selected_list_dir.txt'
OUT = '../../output/dgfp/dataset_vars.csv'

# %%
output = extract_var_info(files_paths=PATHS, ext='csv', out=OUT)
cols = ['thana', 'thana_Name', 'Dist_Name', 'monthid', 'Year', 'Month', 'District', 'Division', 'program']
print(cols)
output = extract_geo_info(files_paths=PATHS, ext='csv', vars_to_select=cols, year = 'Year')
# Out:
# ['thana', 'thana_Name', 'Dist_Name', 'monthid', 'Year', 'Month', 'District', 'Division', 'program']
# ['thana', 'ECouple', 'Pill', 'Condom', 'Injectable', 'IUD', 'Implant', 'PerMale', 'PerFemale', 'Tpermanent', 'GrandTotal', 'CAR', 'Unnamed: 12', 'Year', 'Month', 'District', 'Division', 'program']
# ['thana', 'Year', 'Month', 'District', 'Division', 'program']
# (29317, 6)
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-10-28-0507-05.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-11-28-0102-07.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-11-28-0405-04.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-12-28-0305-03.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-12-28-0114-01.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-11-28-0409-04.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-12-28-0209-02.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-11-28-0509-05.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-10-28-0604-06.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-12-28-0205-02.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-11-28-0505-05.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-10-28-0407-04.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-12-28-0108-07.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-12-28-0411-04.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-11-28-0112-01.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-11-28-0303-03.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-12-28-0403-04.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-10-28-0201-02.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-12-28-0104-07.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-12-28-0414-08.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-10-28-0301-03.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-12-28-0503-05.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-11-28-0203-02.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-12-28-0511-05.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-10-28-0110-01.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-12-28-0106-07.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-10-28-0203-02.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-12-28-0602-06.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-11-28-0301-03.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-12-28-0401-04.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-11-28-0110-01.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-10-28-0112-01.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-12-28-0501-05.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-11-28-0201-02.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-10-28-0303-03.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-10-28-0509-05.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-12-28-0116-01.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-11-28-0407-04.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-10-28-0505-05.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-11-28-0604-06.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-10-28-0405-04.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-10-28-0102-07.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-12-28-0207-02.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-11-28-0507-05.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-10-28-0409-04.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-11-28-0205-02.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-12-28-0505-05.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-10-28-0116-01.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-11-28-0209-02.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-12-28-0509-05.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-12-28-0409-04.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-11-28-0114-01.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-12-28-0102-07.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-10-28-0207-02.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-12-28-0405-04.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-11-28-0305-03.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-11-28-0511-05.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-10-28-0401-04.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-11-28-0503-05.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-10-28-0106-07.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-10-28-0602-06.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-12-28-0203-02.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-12-28-0303-03.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-11-28-0403-04.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-11-28-0104-07.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-10-28-0501-05.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-11-28-0414-08.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-11-28-0108-07.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-11-28-0411-04.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-12-28-0112-01.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-10-28-0414-08.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-11-28-0501-05.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-12-28-0201-02.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-10-28-0104-07.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-10-28-0403-04.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-10-28-0411-04.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-10-28-0108-07.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-12-28-0110-01.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-10-28-0511-05.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-11-28-0602-06.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-11-28-0106-07.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-10-28-0503-05.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-12-28-0301-03.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-11-28-0401-04.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-10-28-0114-01.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-10-28-0305-03.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-11-28-0207-02.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-12-28-0507-05.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-12-28-0407-04.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-10-28-0205-02.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-12-28-0604-06.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-10-28-0209-02.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-11-28-0116-01.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-11-28-0202-02.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-12-28-0502-05.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-11-28-0210-02.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-10-28-0111-01.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-12-28-0510-05.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-11-28-0113-01.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-12-28-0410-04.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-12-28-0415-08.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-12-28-0601-06.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-12-28-0105-07.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-12-28-0402-04.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-11-28-0302-03.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-11-28-0508-05.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-12-28-0208-02.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-10-28-0406-04.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-11-28-0504-05.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-12-28-0204-02.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-10-28-0101-07.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-12-28-0304-03.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-11-28-0404-04.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-11-28-0103-07.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-11-28-0413-08.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-10-28-0506-05.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-11-28-0416-04.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-11-28-0408-04.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-12-28-0115-01.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-11-28-0506-05.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-10-28-0413-08.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-10-28-0103-07.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-12-28-0206-02.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-10-28-0404-04.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-10-28-0408-04.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-10-28-0416-04.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-10-28-0508-05.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-12-28-0109-01.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-11-28-0101-07.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-10-28-0504-05.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-12-28-0306-03.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-11-28-0406-04.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-10-28-0113-01.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-10-28-0302-03.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-12-28-0417-08.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-12-28-0107-07.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-12-28-0603-06.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-10-28-0202-02.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-12-28-0412-04.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-11-28-0111-01.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-10-28-0210-02.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-11-28-0415-08.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-11-28-0105-07.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-11-28-0601-06.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-11-28-0402-04.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-12-28-0302-03.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-12-28-0113-01.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-11-28-0410-04.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-12-28-0210-02.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-11-28-0510-05.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-10-28-0412-04.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-10-28-0107-07.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-12-28-0202-02.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-10-28-0603-06.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-11-28-0502-05.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-10-28-0417-08.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-12-28-0416-04.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-11-28-0115-01.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-12-28-0408-04.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-11-28-0304-03.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-12-28-0404-04.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-12-28-0103-07.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-10-28-0206-02.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-12-28-0413-08.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-10-28-0306-03.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-12-28-0504-05.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-11-28-0204-02.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-10-28-0109-01.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-12-28-0508-05.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-11-28-0208-02.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-10-28-0204-02.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-12-28-0101-07.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-11-28-0306-03.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-12-28-0406-04.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-10-28-0208-02.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-11-28-0109-01.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-10-28-0115-01.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-12-28-0506-05.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-11-28-0206-02.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-10-28-0304-03.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-11-28-0412-04.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-10-28-0510-05.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-12-28-0111-01.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-11-28-0417-08.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-10-28-0502-05.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-11-28-0603-06.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-11-28-0107-07.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-10-28-0402-04.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-10-28-0601-06.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-10-28-0105-07.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-10-28-0415-08.csv has no columns to parse. Moving on
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess/2018-10-28-0410-04.csv has no columns to parse. Moving on
# ['thana_Name', 'MCH37', 'MCH38', 'MCH39', 'MCH40', 'MCH41', 'MCH42', 'MCH43', 'MCH44', 'MCH45', 'MCH46', 'MCH47', 'MCH48', 'MCH49', 'MCH50', 'MCH51', 'MCH52', 'MCH53', 'MCH54', 'MCH55', 'MCH56', 'MCH57', 'MCH58', 'MCH59', 'MCH60', 'MCH61', 'MCH62', 'MCH63', 'MCH64', 'MCH65', 'MCH66', 'MCH67', 'MCH68', 'MCH69', 'MCH70', 'MCH71', 'MCH72', 'MCH73', 'MCH74', 'MCH75', 'MCH76', 'MCH77', 'MCH78', 'MCH79', 'MCH80', 'MCH81', 'MCH82', 'MCH83', 'MCH84', 'MCH85', 'MCH86', 'MCH87', 'MCH88', 'MCH89', 'MCH90', 'MCH91', 'MCH92', 'MCH93', 'MCH94', 'MCH95', 'MCH96', 'MCH97', 'MCH98', 'MCH99', 'MCH100', 'MCH101', 'MCH102', 'MCH103', 'MCH104', 'MCH105', 'MCH106', 'MCH107', 'Year', 'Month', 'District', 'Division', 'program']
# ['thana_Name', 'Year', 'Month', 'District', 'Division', 'program']
# (16104, 6)
# ['thana', 'ECouple', 'Pill', 'Condom', 'Injectable', 'IUD', 'Implant', 'PerMale', 'PerFemale', 'Tpermanent', 'GrandTotal', 'CAR', 'Unnamed: 12', 'Year', 'Month', 'District', 'Division', 'program']
# ['thana', 'Year', 'Month', 'District', 'Division', 'program']
# (63891, 6)

# %%
masters_dict = {}
for key, value in output.items():
    print(key)
    years_dict = {}
    for index, item in enumerate(sorted(value['Year'].unique())):
        print(index,item)
        years_dict[str(item)] = value[value['Year'] == item]
        print(years_dict.keys())
    masters_dict[str(value['program'].unique()[0])] = years_dict

for key, value in masters_dict.items():
    print(key)
    print(value.keys())
# Out:
# ../../data/dgfp/data/importance11_subdistricts/ngothana_process
# 0 2008
# dict_keys(['2008'])
# 1 2009
# dict_keys(['2008', '2009'])
# 2 2010
# dict_keys(['2008', '2009', '2010'])
# 3 2011
# dict_keys(['2008', '2009', '2010', '2011'])
# 4 2012
# dict_keys(['2008', '2009', '2010', '2011', '2012'])
# 5 2013
# dict_keys(['2008', '2009', '2010', '2011', '2012', '2013'])
# 6 2014
# dict_keys(['2008', '2009', '2010', '2011', '2012', '2013', '2014'])
# 7 2015
# dict_keys(['2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015'])
# 8 2016
# dict_keys(['2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016'])
# 9 2017
# dict_keys(['2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017'])
# 10 2018
# dict_keys(['2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018'])
# ../../data/dgfp/data/importance11_subdistricts/mchgo_thanaprocess
# 0 2016
# dict_keys(['2016'])
# 1 2017
# dict_keys(['2016', '2017'])
# 2 2018
# dict_keys(['2016', '2017', '2018'])
# ../../data/dgfp/data/importance11_subdistricts/thana_process
# 0 2008
# dict_keys(['2008'])
# 1 2009
# dict_keys(['2008', '2009'])
# 2 2010
# dict_keys(['2008', '2009', '2010'])
# 3 2011
# dict_keys(['2008', '2009', '2010', '2011'])
# 4 2012
# dict_keys(['2008', '2009', '2010', '2011', '2012'])
# 5 2013
# dict_keys(['2008', '2009', '2010', '2011', '2012', '2013'])
# 6 2014
# dict_keys(['2008', '2009', '2010', '2011', '2012', '2013', '2014'])
# 7 2015
# dict_keys(['2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015'])
# 8 2016
# dict_keys(['2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016'])
# 9 2017
# dict_keys(['2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017'])
# 10 2018
# dict_keys(['2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018'])
# ngothana_process
# dict_keys(['2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018'])
# mchgo_thanaprocess
# dict_keys(['2016', '2017', '2018'])
# thana_process
# dict_keys(['2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018'])

# %%
    logging.basicConfig(filename='check_geos.log',level=logging.INFO)
    logging.info("Checking all geo variables by years available in the following datasets: ")
    logging.info(f"{data_dict.keys()}")

# %%
def check_geos(data_dict, start_year, end_year):
    years = [str(year) for year in range(start_year,end_year+1)]
    out = {}
    for index, year in enumerate(years):
        year_check = {}
        for key, value in data_dict.items():
            if str(year) in list(value.keys()):
                try:
                    year_check[key] = value[year]['thana']
                except KeyError:
                    year_check[key] = value[year]['thana_Name']
            else:
                pass
        out[year] = year_check
    return out

# %%
test = check_geos(data_dict=masters_dict, start_year=2008, end_year=2018)
test.keys()
# Out:
# dict_keys(['2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018'])

# %%
for key, value in test.items():
    print("#"*100)
    print(f"Year: {key}")
    for key1, value1 in value.items():
        print(key1)
        print(len(value1.unique()))
# Out:
# ####################################################################################################
# Year: 2008
# ngothana_process
# 242
# thana_process
# 467
# ####################################################################################################
# Year: 2009
# ngothana_process
# 257
# thana_process
# 468
# ####################################################################################################
# Year: 2010
# ngothana_process
# 258
# thana_process
# 468
# ####################################################################################################
# Year: 2011
# ngothana_process
# 249
# thana_process
# 469
# ####################################################################################################
# Year: 2012
# ngothana_process
# 250
# thana_process
# 471
# ####################################################################################################
# Year: 2013
# ngothana_process
# 242
# thana_process
# 471
# ####################################################################################################
# Year: 2014
# ngothana_process
# 251
# thana_process
# 471
# ####################################################################################################
# Year: 2015
# ngothana_process
# 232
# thana_process
# 471
# ####################################################################################################
# Year: 2016
# ngothana_process
# 270
# mchgo_thanaprocess
# 471
# thana_process
# 471
# ####################################################################################################
# Year: 2017
# ngothana_process
# 270
# mchgo_thanaprocess
# 471
# thana_process
# 471
# ####################################################################################################
# Year: 2018
# ngothana_process
# 269
# mchgo_thanaprocess
# 471
# thana_process
# 471

# %%
print(len(set(test['2008']['thana_process']).union(set(test['2008']['ngothana_process']))))
print(len(set(test['2008']['ngothana_process']).union(set(test['2008']['thana_process']))))
print(len(set(test['2008']['thana_process']).intersection(set(test['2008']['ngothana_process']))))
print(len(set(test['2008']['ngothana_process']).intersection(set(test['2008']['thana_process']))))
# Out:
# 467
# 467

# %%
print(len(set(test['2018']['thana_process']).union(set(test['2008']['ngothana_process']))))
print(len(set(test['2008']['ngothana_process']).union(set(test['2018']['thana_process']))))
print(len(set(test['2018']['thana_process']).intersection(set(test['2008']['ngothana_process']))))
print(len(set(test['2008']['ngothana_process']).intersection(set(test['2018']['thana_process']))))
# Out:
# 471
# 471
# 242
# 242

# %% [markdown]
# ## Importing original BBS list of geogrpahies

# %%
t = import_process(in_file='../../data/geo_files/unionList.csv',out_file='../../data/geo_files/unionList_updated.csv')
unionList = pd.read_csv('../../data/geo_files/unionList_updated.csv', 
                        header=None,
                        names=['Division', 'Zila', 'Upazila', 'Union', 'Name'],
                        dtype = {'Division':'object', 'Zila':'object', 'Upazila':'object', 'Union':'object', 'Name':'object'}
                       )
geo = pd.read_excel('../../data/geo_files/geo_.xlsx', header=1)
display(unionList.head())
display(c.head())
# Out:
#   Division Zila Upazila Union         Name
# 0       10  NaN     NaN   NaN      BARISAL
# 1       10    4     NaN   NaN      BARGUNA
# 2       10    4       9   NaN       AMTALI
# 3       10    4       9    13       AMTALI
# 4       10    4       9    15  ARPANGASHIA
#    Division Code Division name  District Code   District Name  Upazilla code  \
# 0             40        Khulna              1  Bagerhat Zila               8
# 1             40        Khulna              1  Bagerhat Zila               8
# 2             40        Khulna              1  Bagerhat Zila               8
# 3             40        Khulna              1  Bagerhat Zila               8
# 4             40        Khulna              1  Bagerhat Zila               8
#
#                   Upazilla  Union code       Union  Population Total  \
# 0  Bagerhat Sadar Upazila            1  Ward No-01              5339
# 1  Bagerhat Sadar Upazila            2  Ward No-02              5406
# 2  Bagerhat Sadar Upazila            3  Ward No-03              7688
# 3  Bagerhat Sadar Upazila            4  Ward No-04              4530
# 4  Bagerhat Sadar Upazila            5  Ward No-05              4297
#
#    Unnamed: 9
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %%
geo = geo[['Division Code', 'Division name', 'District Code','District Name', 'Upazilla code', 'Upazilla']]
print(geo.shape)
geo = geo.drop_duplicates()
print(geo.shape)
geo.to_excel('../../data/geo_files/geo_.xlsx')
# Out:
# (544, 6)
# (544, 6)

# %%
zila_summary = []
for code in unionList['Division']:
    if str(code) != 'nan':
        t = len(str(code))
        zila_summary.append(t)
collections.Counter(zila_summary)
# Out:
# Counter({2: 5152})

# %%
unionList['Division'].value_counts()
# Out:
# 30    1409
# 20    1066
# 40     651
# 50     640
# 55     604
# 10     401
# 60     381
# Name: Division, dtype: int64

# %%
geo['Upazilla'].unique()
# Out:
# array(['Bagerhat Sadar Upazila ', 'Mongla Upazila ',
#        'Morrelganj Upazila ', 'Bandarban Sadar Upazila ', 'Lama Upazila ',
#        'Amtali Upazila ', 'Barguna Sadar Upazila ', 'Betagi Upazila ',
#        'Patharghata Upazila ', 'Bakerganj Upazila ',
#        'Banari Para Upazila ', 'Gaurnadi Upazila ',
#        'Barisal Sadar Upazila ', 'Mehendiganj Upazila ',
#        'Muladi Upazila ', 'Bhola Sadar Upazila ', 'Burhanuddin Upazila ',
#        'Char Fasson Upazila ', 'Daulat Khan Upazila ',
#        'Lalmohan Upazila ', 'Adamdighi Upazila ', 'Bogra Sadar Upazila ',
#        'Dhunat Upazila ', 'Dhupchanchia Upazila ', 'Gabtali Upazila ',
#        'Kahaloo Upazila ', 'Nandigram Upazila ', 'Sariakandi Upazila ',
#        'Shajahanpur Upazila ', 'Sherpur Upazila ', 'Shibganj Upazila ',
#        'Sonatola Upazila ', 'Akhaura Upazila ',
#        'Brahmanbaria Sadar Upazila ', 'Kasba Upazila ',
#        'Nabinagar Upazila ', 'Chandpur Sadar Upazila ',
#        'Faridganj Upazila ', 'Hajiganj Upazila ', 'Kachua Upazila ',
#        'Matlab Upazila ', 'Matlab Uttar Upazila ', 'Shahrasti Upazila ',
#        'Gomastapur Upazila ', 'Nachole Upazila ',
#        'Chapai Nawabganj Sadar Upazila ', 'Bayejid Bostami Thana ',
#        'Banshkhali Upazila ', 'Bakalia Thana ', 'Chandanaish  Upazila ',
#        'Chandgaon Thana ', 'Chittagong Port Thana ',
#        'Double Mooring Thana ', 'Halishahar Thana ', 'Kotwali Thana ',
#        'Khulshi Thana ', 'Mirsharai Upazila ', 'Pahartali Thana ',
#        'Panchlaish Thana ', 'Patiya Upazila ', 'Patenga Thana ',
#        'Rangunia Upazila ', 'Raozan Upazila ', 'Sandwip Upazila ',
#        'Satkania Upazila ', 'Sitakunda Upazila ', 'Alamdanga Upazila ',
#        'Chuadanga Sadar Upazila ', 'Damurhuda Upazila ',
#        'Jiban Nagar Upazila ', 'Barura Upazila ', 'Chandina Upazila ',
#        'Chauddagram Upazila ', 'Comilla Sadar Dakshin Upazila ',
#        'Daudkandi Upazila ', 'Debidwar Upazila ', 'Homna Upazila ',
#        'Comilla Adarsha Sadar Upazila ', 'Laksam Upazila ',
#        'Nangalkot Upazila ', 'Chakoria Upazila ',
#        "Cox's Bazar Sadar Upazila ", 'Maheshkhali Upazila ',
#        'Teknaf Upazila ', 'Adabor Thana ', 'Badda Thana ',
#        'Bangshal Thana ', 'Biman Bandar Thana ', 'Cantonment Thana ',
#        'Chak Bazar Thana ', 'Darus Salam Thana ', 'Dhamrai Upazila ',
#        'Dhanmondi Thana ', 'Dohar Upazila ', 'Gendaria Thana ',
#        'Gulshan Thana ', 'Hazaribagh Thana ', 'Jatrabari Thana ',
#        'Kafrul Thana ', 'Kadamtali Thana ', 'Kalabagan Thana ',
#        'Khilgaon Thana ', 'Khilkhet Thana ', 'Lalbagh Thana ',
#        'Mirpur Thana ', 'Mohammadpur Thana ', 'Motijheel Thana ',
#        'New Market Thana ', 'Pallabi Thana ', 'Paltan Thana ',
#        'Ramna Thana ', 'Rampura Thana ', 'Sabujbagh Thana ',
#        'Savar Upazila ', 'Shah Ali Thana ', 'Shahbagh Thana ',
#        'Shyampur Thana ', 'Sher-E-Bangla Nagar Thana ', 'Sutrapur Thana ',
#        'Tejgaon Thana ', 'Tejgaon Ind. Area Thana ', 'Uttara Thana ',
#        'Birampur Upazila ', 'Birganj Upazila ', 'Bochaganj Upazila ',
#        'Fulbari Upazila ', 'Ghoraghat Upazila ', 'Hakimpur Upazila ',
#        'Dinajpur Sadar Upazila ', 'Parbatipur Upazila ',
#        'Bhanga Upazila ', 'Boalmari Upazila ', 'Faridpur Sadar Upazila ',
#        'Nagarkanda Upazila ', 'Chhagalnaiya Upazila ',
#        'Daganbhuiyan Upazila ', 'Feni Sadar Upazila ',
#        'Parshuram Upazila ', 'Sonagazi Upazila ',
#        'Gaibandha Sadar Upazila ', 'Gobindaganj Upazila ',
#        'Sundarganj Upazila ', 'Gazipur Sadar Upazila ',
#        'Kaliakair Upazila ', 'Kaliganj Upazila ', 'Sreepur Upazila ',
#        'Gopalganj Sadar Upazila ', 'Kotalipara Upazila ',
#        'Muksudpur Upazila ', 'Tungipara Upazila ', 'Ajmiriganj Upazila ',
#        'Chunarughat Upazila ', 'Habiganj Sadar Upazila ',
#        'Madhabpur Upazila ', 'Nabiganj Upazila ', 'Dewanganj Upazila ',
#        'Islampur Upazila ', 'Jamalpur Sadar Upazila ',
#        'Madarganj Upazila ', 'Melandaha Upazila ', 'Sarishabari Upazila ',
#        'Abhaynagar Upazila ', 'Bagherpara Upazila ',
#        'Chaugachha Upazila ', 'Jhikargachha Upazila ',
#        'Keshabpur Upazila ', 'Jessore Sadar Upazila ',
#        'Manirampur Upazila ', 'Sharsha Upazila ',
#        'Jhalokati Sadar Upazila ', 'Nalchity Upazila ',
#        'Harinakundu Upazila ', 'Jhenaidah Sadar Upazila ',
#        'Kotchandpur Upazila ', 'Maheshpur Upazila ', 'Shailkupa Upazila ',
#        'Akkelpur Upazila ', 'Joypurhat Sadar Upazila ', 'Kalai Upazila ',
#        'Panchbibi Upazila ', 'Khagrachhari Sadar Upazila ',
#        'Matiranga Upazila ', 'Ramgarh Upazila ', 'Dacope Upazila ',
#        'Daulatpur Thana ', 'Khalishpur Thana ', 'Khan Jahan Ali Thana ',
#        'Khulna Sadar Thana ', 'Paikgachha Upazila ', 'Sonadanga Thana ',
#        'Bajitpur Upazila ', 'Bhairab Upazila ', 'Hossainpur Upazila ',
#        'Karimganj Upazila ', 'Katiadi Upazila ',
#        'Kishoreganj Sadar Upazila ', 'Kuliar Char Upazila ',
#        'Pakundia Upazila ', 'Kurigram Sadar Upazila ',
#        'Nageshwari Upazila ', 'Ulipur Upazila ', 'Bheramara Upazila ',
#        'Khoksa Upazila ', 'Kumarkhali Upazila ', 'Kushtia Sadar Upazila ',
#        'Mirpur Upazila ', 'Lakshmipur Sadar Upazila ', 'Roypur Upazila ',
#        'Ramganj Upazila ', 'Ramgati Upazila ',
#        'Lalmonirhat Sadar Upazila ', 'Patgram Upazila ',
#        'Kalkini Upazila ', 'Madaripur Sadar Upazila ',
#        'Shib Char Upazila ', 'Magura Sadar Upazila ',
#        'Manikganj Sadar Upazila ', 'Singair Upazila ',
#        'Barlekha Upazila ', 'Kamalganj Upazila ', 'Kulaura Upazila ',
#        'Maulvibazar Sadar Upazila ', 'Sreemangal Upazila ',
#        'Gangni Upazila ', 'Meherpur Sadar Upazila ',
#        'Munshiganj Sadar Upazila ', 'Bhaluka Upazila ',
#        'Fulbaria Upazila ', 'Gaffargaon Upazila ', 'Gauripur Upazila ',
#        'Ishwarganj Upazila ', 'Mymensingh Sadar Upazila ',
#        'Muktagachha Upazila ', 'Nandail Upazila ', 'Phulpur Upazila ',
#        'Trishal Upazila ', 'Dhamoirhat Upazila ',
#        'Naogaon Sadar Upazila ', 'Patnitala Upazila ', 'Kalia Upazila ',
#        'Lohagara Upazila ', 'Narail Sadar Upazila ', 'Sonargaon Upazila ',
#        'Bandar Upazila ', 'Narayanganj Sadar Upazila ',
#        'Rupganj Upazila ', 'Manohardi Upazila ',
#        'Narsingdi Sadar Upazila ', 'Palash Upazila ', 'Roypura Upazila ',
#        'Shibpur Upazila ', 'Bagatipara Upazila ', 'Baraigram Upazila ',
#        'Gurudaspur Upazila ', 'Lalpur Upazila ', 'Natore Sadar Upazila ',
#        'Singra Upazila ', 'Durgapur Upazila ', 'Kendua Upazila ',
#        'Madan Upazila ', 'Mohanganj Upazila ', 'Netrokona Sadar Upazila ',
#        'Domar Upazila ', 'Jaldhaka Upazila ', 'Nilphamari Sadar Upazila ',
#        'Saidpur Upazila ', 'Begumganj Upazila ', 'Chatkhil Upazila ',
#        'Companiganj Upazila ', 'Hatiya Upazila ', 'Kabirhat Upazila ',
#        'Senbagh Upazila ', 'Sonaimuri Upazila ',
#        'Noakhali Sadar Upazila ', 'Atgharia Upazila ', 'Bera Upazila ',
#        'Bhangura Upazila ', 'Chatmohar Upazila ', 'Faridpur Upazila ',
#        'Ishwardi Upazila ', 'Pabna Sadar Upazila ', 'Santhia Upazila ',
#        'Sujanagar Upazila ', 'Boda Upazila ', 'Panchagarh Sadar Upazila ',
#        'Bauphal Upazila ', 'Galachipa Upazila ', 'Kala Para Upazila ',
#        'Patuakhali Sadar Upazila ', 'Mathbaria Upazila ',
#        'Pirojpur Sadar Upazila ', 'Nesarabad Upazila ',
#        'Goalanda Upazila ', 'Pangsha Upazila ', 'Rajbari Sadar Upazila ',
#        'Bagha Upazila ', 'Baghmara Upazila ', 'Boalia Thana ',
#        'Charghat Upazila ', 'Godagari Upazila ', 'Matihar Thana ',
#        'Mohanpur Upazila ', 'Paba Upazila ', 'Puthia Upazila ',
#        'Rajpara Thana ', 'Shah Makhdum Thana ', 'Tanore Upazila ',
#        'Baghaichhari Upazila ', 'Rangamati Sadar Upazila ',
#        'Badarganj Upazila ', 'Kaunia Upazila ', 'Rangpur Sadar Upazila ',
#        'Kalaroa Upazila ', 'Satkhira Sadar Upazila ',
#        'Bhedarganj Upazila ', 'Damudya Upazila ', 'Naria Upazila ',
#        'Shariatpur Sadar Upazila ', 'Zanjira Upazila ', 'Nakla Upazila ',
#        'Nalitabari Upazila ', 'Sherpur Sadar Upazila ',
#        'Sreebardi Upazila ', 'Belkuchi Upazila ', 'Kazipur Upazila ',
#        'Royganj Upazila ', 'Shahjadpur Upazila ',
#        'Sirajganj Sadar Upazila ', 'Ullah Para Upazila ',
#        'Chhatak Upazila ', 'Derai Upazila ', 'Jagannathpur Upazila ',
#        'Sunamganj Sadar Upazila ', 'Beani Bazar Upazila ',
#        'Golapganj Upazila ', 'Kanaighat Upazila ',
#        'Sylhet Sadar Upazila ', 'Zakiganj Upazila ', 'Bhuapur Upazila ',
#        'Dhanbari Upazila ', 'Ghatail Upazila ', 'Gopalpur Upazila ',
#        'Kalihati Upazila ', 'Madhupur Upazila ', 'Mirzapur Upazila ',
#        'Sakhipur Upazila ', 'Tangail Sadar Upazila ', 'Pirganj Upazila ',
#        'Ranisankail Upazila ', 'Thakurgaon Sadar Upazila ',
#        'Chitalmari Upazila ', 'Fakirhat Upazila ', 'Mollahat Upazila ',
#        'Rampal Upazila ', 'Sarankhola Upazila ', 'Alikadam Upazila ',
#        'Naikhongchhari Upazila ', 'Rowangchhari Upazila ',
#        'Ruma Upazila ', 'Thanchi Upazila ', 'Bamna Upazila ',
#        'Agailjhara Upazila ', 'Babuganj Upazila ', 'Hizla Upazila ',
#        'Wazirpur Upazila ', 'Manpura Upazila ', 'Tazumuddin Upazila ',
#        'Banchharampur Upazila ', 'Bijoynagar Upazila ',
#        'Ashuganj Upazila ', 'Nasirnagar Upazila ', 'Sarail Upazila ',
#        'Haim Char Upazila ', 'Bholahat Upazila ', 'Anowara Upazila ',
#        'Boalkhali Upazila ', 'Fatikchhari Upazila ', 'Hathazari Upazila ',
#        'Brahmanpara Upazila ', 'Burichang Upazila ',
#        'Manoharganj Upazila ', 'Meghna Upazila ', 'Muradnagar Upazila ',
#        'Titas Upazila ', 'Kutubdia Upazila ', 'Pekua Upazila ',
#        'Ramu Upazila ', 'Ukhia Upazila ', 'Dakshinkhan Thana ',
#        'Demra Thana ', 'Kamrangir Char Thana ', 'Keraniganj Upazila ',
#        'Nawabganj Upazila ', 'Turag Thana ', 'Uttar Khan Thana ',
#        'Biral Upazila ', 'Chirirbandar Upazila ', 'Kaharole Upazila ',
#        'Khansama Upazila ', 'Alfadanga Upazila ',
#        'Char Bhadrasan Upazila ', 'Madhukhali Upazila ',
#        'Sadarpur Upazila ', 'Saltha Upazila ', 'Fulgazi Upazila ',
#        'Fulchhari Upazila ', 'Palashbari Upazila ', 'Sadullapur Upazila ',
#        'Saghata Upazila ', 'Kapasia Upazila ', 'Kashiani Upazila ',
#        'Bahubal Upazila ', 'Baniachong Upazila ', 'Lakhai Upazila ',
#        'Bakshiganj Upazila ', 'Kanthalia Upazila ', 'Rajapur Upazila ',
#        'Khetlal Upazila ', 'Dighinala Upazila ', 'Lakshmichhari Upazila ',
#        'Mahalchhari Upazila ', 'Manikchhari Upazila ',
#        'Panchhari Upazila ', 'Batiaghata Upazila ', 'Dumuria Upazila ',
#        'Dighalia Upazila ', 'Koyra Upazila ', 'Phultala Upazila ',
#        'Rupsa Upazila ', 'Terokhada Upazila ', 'Austagram Upazila ',
#        'Itna Upazila ', 'Mithamain Upazila ', 'Nikli Upazila ',
#        'Tarail Upazila ', 'Bhurungamari Upazila ',
#        'Char Rajibpur Upazila ', 'Chilmari Upazila ',
#        'Phulbari Sadar Upazila ', 'Rajarhat Upazila ', 'Raumari Upazila ',
#        'Daulatpur Upazila ', 'Kamalnagar Upazila ', 'Aditmari Upazila ',
#        'Hatibandha Upazila ', 'Kaligang Upazila ', 'Rajoir Upazila ',
#        'Mohammadpur Upazila ', 'Shalikha Upazila ', 'Ghior Upazila ',
#        'Harirampur Upazila ', 'Saturia Upazila ', 'Shibalaya Upazila ',
#        'Juri Upazila ', 'Rajnagar Upazila ', 'Mujib Nagar Upazila ',
#        'Gazaria Upazila ', 'Lohajang Upazila ', 'Serajdikhan Upazila ',
#        'Sreenagar Upazila ', 'Tongibari Upazila ', 'Dhobaura Upazila ',
#        'Haluaghat Upazila ', 'Atrai Upazila ', 'Badalgachhi Upazila ',
#        'Manda Upazila ', 'Mahadebpur Upazila ', 'Niamatpur Upazila ',
#        'Porsha Upazila ', 'Raninagar Upazila ', 'Sapahar Upazila ',
#        'Araihazar Upazila ', 'Belabo Upazila ', 'Atpara Upazila ',
#        'Barhatta Upazila ', 'Khaliajuri Upazila ', 'Kalmakanda Upazila ',
#        'Purbadhala Upazila ', 'Dimla Upazila ', 'Kishoreganj Upazila ',
#        'Subarnachar Upazila ', 'Atwari Upazila ', 'Debiganj Upazila ',
#        'Tentulia Upazila ', 'Dashmina Upazila ', 'Dumki Upazila ',
#        'Mirzaganj Upazila ', 'Bhandaria Upazila ', 'Kawkhali Upazila ',
#        'Nazirpur Upazila ', 'Zianagar Upazila ', 'Baliakandi Upazila ',
#        'Kalukhali Upazila ', 'Barkal Upazila ', 'Belai Chhari Upazila ',
#        'Kaptai  Upazila ', 'Jurai Chhari Upazila ', 'Langadu  Upazila ',
#        'Naniarchar  Upazila ', 'Rajasthali  Upazila ',
#        'Gangachara Upazila ', 'Mithapukur Upazila ', 'Pirgachha Upazila ',
#        'Taraganj Upazila ', 'Assasuni Upazila ', 'Debhata Upazila ',
#        'Shyamnagar Upazila ', 'Tala Upazila ', 'Gosairhat Upazila ',
#        'Jhenaigati Upazila ', 'Chauhali Upazila ', 'Kamarkhanda Upazila ',
#        'Tarash Upazila ', 'Bishwambarpur Upazila ',
#        'Dakshin Sunamganj Upazila ', 'Dharampasha Upazila ',
#        'Dowarabazar Upazila ', 'Jamalganj Upazila ', 'Sulla Upazila ',
#        'Tahirpur Upazila ', 'Balaganj Upazila ', 'Bishwanath Upazila ',
#        'Dakshin Surma Upazila ', 'Fenchuganj Upazila ',
#        'Gowainghat Upazila ', 'Jaintiapur Upazila ', 'Basail Upazila ',
#        'Delduar Upazila ', 'Nagarpur Upazila ', 'Baliadangi Upazila ',
#        'Haripur Upazila '], dtype=object)
