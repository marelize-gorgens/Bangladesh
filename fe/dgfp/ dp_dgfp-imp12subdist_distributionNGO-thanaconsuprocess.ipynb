# %% [markdown]
# # dp dgfp imp12 subdist distributionNGO thanaconsuprocess

# %%
import os
import glob
import collections
import pandas as pd
import numpy as np

# %%
DATA = '../../data/dgfp/data/importance12_subdistricts/distributionNGO_thanaconsuprocess/'

# %%
def read_data(path, ext):
    files_list = glob.glob(path + '/*.' + ext)
    data = list()
    for file in files_list:
        print(file)
        file_name = os.path.split(file)[1][:-4]
        program = file.split("/")[-2]
        tmp = pd.read_csv(file, sep='\t')
        file_name_comp = file_name.split('-')
        tmp['Year'] = file_name_comp[0]
        tmp['Month'] = file_name_comp[1]
        tmp['District'] =file_name_comp[3]
        tmp['Division'] = file_name_comp[4]
        tmp['program'] = program
        data.append(tmp)
    return pd.concat(data, axis=0)

# %%
data = read_data(path=DATA, ext='csv')
# Out:
# ../../data/dgfp/data/importance12_subdistricts/distributionNGO_thanaconsuprocess/2018-12-28-0305-03.csv
# ../../data/dgfp/data/importance12_subdistricts/distributionNGO_thanaconsuprocess/2018-12-28-0114-01.csv
# ../../data/dgfp/data/importance12_subdistricts/distributionNGO_thanaconsuprocess/2018-12-28-0209-02.csv
# ../../data/dgfp/data/importance12_subdistricts/distributionNGO_thanaconsuprocess/2018-12-28-0205-02.csv
# ../../data/dgfp/data/importance12_subdistricts/distributionNGO_thanaconsuprocess/2018-12-28-0108-07.csv
# ../../data/dgfp/data/importance12_subdistricts/distributionNGO_thanaconsuprocess/2018-12-28-0411-04.csv
# ../../data/dgfp/data/importance12_subdistricts/distributionNGO_thanaconsuprocess/2018-12-28-0403-04.csv
# ../../data/dgfp/data/importance12_subdistricts/distributionNGO_thanaconsuprocess/2018-12-28-0104-07.csv
# ../../data/dgfp/data/importance12_subdistricts/distributionNGO_thanaconsuprocess/2018-12-28-0414-08.csv
# ../../data/dgfp/data/importance12_subdistricts/distributionNGO_thanaconsuprocess/2018-12-28-0503-05.csv
# ../../data/dgfp/data/importance12_subdistricts/distributionNGO_thanaconsuprocess/2018-12-28-0511-05.csv
# ../../data/dgfp/data/importance12_subdistricts/distributionNGO_thanaconsuprocess/2018-12-28-0106-07.csv
# ../../data/dgfp/data/importance12_subdistricts/distributionNGO_thanaconsuprocess/2018-12-28-0602-06.csv
# ../../data/dgfp/data/importance12_subdistricts/distributionNGO_thanaconsuprocess/2018-12-28-0401-04.csv
# ../../data/dgfp/data/importance12_subdistricts/distributionNGO_thanaconsuprocess/2018-12-28-0501-05.csv
# ../../data/dgfp/data/importance12_subdistricts/distributionNGO_thanaconsuprocess/2018-12-28-0116-01.csv
# ../../data/dgfp/data/importance12_subdistricts/distributionNGO_thanaconsuprocess/2018-12-28-0207-02.csv
# ../../data/dgfp/data/importance12_subdistricts/distributionNGO_thanaconsuprocess/2018-12-28-0505-05.csv
# ../../data/dgfp/data/importance12_subdistricts/distributionNGO_thanaconsuprocess/2018-12-28-0509-05.csv
# ../../data/dgfp/data/importance12_subdistricts/distributionNGO_thanaconsuprocess/2018-12-28-0409-04.csv
# ../../data/dgfp/data/importance12_subdistricts/distributionNGO_thanaconsuprocess/2018-12-28-0102-07.csv
# ../../data/dgfp/data/importance12_subdistricts/distributionNGO_thanaconsuprocess/2018-12-28-0405-04.csv
# ../../data/dgfp/data/importance12_subdistricts/distributionNGO_thanaconsuprocess/2018-12-28-0203-02.csv
# ../../data/dgfp/data/importance12_subdistricts/distributionNGO_thanaconsuprocess/2018-12-28-0303-03.csv
# ../../data/dgfp/data/importance12_subdistricts/distributionNGO_thanaconsuprocess/2018-12-28-0112-01.csv
# ../../data/dgfp/data/importance12_subdistricts/distributionNGO_thanaconsuprocess/2018-12-28-0201-02.csv
# ../../data/dgfp/data/importance12_subdistricts/distributionNGO_thanaconsuprocess/2018-12-28-0110-01.csv
# ../../data/dgfp/data/importance12_subdistricts/distributionNGO_thanaconsuprocess/2018-12-28-0301-03.csv
# ../../data/dgfp/data/importance12_subdistricts/distributionNGO_thanaconsuprocess/2018-12-28-0507-05.csv
# ../../data/dgfp/data/importance12_subdistricts/distributionNGO_thanaconsuprocess/2018-12-28-0407-04.csv
# ../../data/dgfp/data/importance12_subdistricts/distributionNGO_thanaconsuprocess/2018-12-28-0604-06.csv
# ../../data/dgfp/data/importance12_subdistricts/distributionNGO_thanaconsuprocess/2018-12-28-0502-05.csv
# ../../data/dgfp/data/importance12_subdistricts/distributionNGO_thanaconsuprocess/2018-12-28-0510-05.csv
# ../../data/dgfp/data/importance12_subdistricts/distributionNGO_thanaconsuprocess/2018-12-28-0410-04.csv
# ../../data/dgfp/data/importance12_subdistricts/distributionNGO_thanaconsuprocess/2018-12-28-0415-08.csv
# ../../data/dgfp/data/importance12_subdistricts/distributionNGO_thanaconsuprocess/2018-12-28-0601-06.csv
# ../../data/dgfp/data/importance12_subdistricts/distributionNGO_thanaconsuprocess/2018-12-28-0105-07.csv
# ../../data/dgfp/data/importance12_subdistricts/distributionNGO_thanaconsuprocess/2018-12-28-0402-04.csv
# ../../data/dgfp/data/importance12_subdistricts/distributionNGO_thanaconsuprocess/2018-12-28-0208-02.csv
# ../../data/dgfp/data/importance12_subdistricts/distributionNGO_thanaconsuprocess/2018-12-28-0204-02.csv
# ../../data/dgfp/data/importance12_subdistricts/distributionNGO_thanaconsuprocess/2018-12-28-0304-03.csv
# ../../data/dgfp/data/importance12_subdistricts/distributionNGO_thanaconsuprocess/2018-12-28-0115-01.csv
# ../../data/dgfp/data/importance12_subdistricts/distributionNGO_thanaconsuprocess/2018-12-28-0206-02.csv
# ../../data/dgfp/data/importance12_subdistricts/distributionNGO_thanaconsuprocess/2018-12-28-0109-01.csv
# ../../data/dgfp/data/importance12_subdistricts/distributionNGO_thanaconsuprocess/2018-12-28-0306-03.csv
# ../../data/dgfp/data/importance12_subdistricts/distributionNGO_thanaconsuprocess/2018-12-28-0417-08.csv
# ../../data/dgfp/data/importance12_subdistricts/distributionNGO_thanaconsuprocess/2018-12-28-0107-07.csv
# ../../data/dgfp/data/importance12_subdistricts/distributionNGO_thanaconsuprocess/2018-12-28-0603-06.csv
# ../../data/dgfp/data/importance12_subdistricts/distributionNGO_thanaconsuprocess/2018-12-28-0412-04.csv
# ../../data/dgfp/data/importance12_subdistricts/distributionNGO_thanaconsuprocess/2018-12-28-0302-03.csv
# ../../data/dgfp/data/importance12_subdistricts/distributionNGO_thanaconsuprocess/2018-12-28-0113-01.csv
# ../../data/dgfp/data/importance12_subdistricts/distributionNGO_thanaconsuprocess/2018-12-28-0210-02.csv
# ../../data/dgfp/data/importance12_subdistricts/distributionNGO_thanaconsuprocess/2018-12-28-0202-02.csv
# ../../data/dgfp/data/importance12_subdistricts/distributionNGO_thanaconsuprocess/2018-12-28-0416-04.csv
# ../../data/dgfp/data/importance12_subdistricts/distributionNGO_thanaconsuprocess/2018-12-28-0408-04.csv
# ../../data/dgfp/data/importance12_subdistricts/distributionNGO_thanaconsuprocess/2018-12-28-0404-04.csv
# ../../data/dgfp/data/importance12_subdistricts/distributionNGO_thanaconsuprocess/2018-12-28-0103-07.csv
# ../../data/dgfp/data/importance12_subdistricts/distributionNGO_thanaconsuprocess/2018-12-28-0413-08.csv
# ../../data/dgfp/data/importance12_subdistricts/distributionNGO_thanaconsuprocess/2018-12-28-0504-05.csv
# ../../data/dgfp/data/importance12_subdistricts/distributionNGO_thanaconsuprocess/2018-12-28-0508-05.csv
# ../../data/dgfp/data/importance12_subdistricts/distributionNGO_thanaconsuprocess/2018-12-28-0101-07.csv
# ../../data/dgfp/data/importance12_subdistricts/distributionNGO_thanaconsuprocess/2018-12-28-0406-04.csv
# ../../data/dgfp/data/importance12_subdistricts/distributionNGO_thanaconsuprocess/2018-12-28-0506-05.csv
# ../../data/dgfp/data/importance12_subdistricts/distributionNGO_thanaconsuprocess/2018-12-28-0111-01.csv

# %%
data.head()
# Out:
#     thana_Name  Shukhi  Apon   Condom  Inj_Vial  Inj_Siringe  IUD_Normal  \
# 0  Bhola Sadar   64348    10   480034     44426        16199        1599
# 1   Daulatkhan  616509   483  1367133    185424       106876         652
# 2   Tajumuddin  319609   559   807033    171031        90743         693
# 3     Lalmohan  739027  2240  1466517    329384       204038         918
# 4  Charfashion  530526     0  2260833    244589       209620         972
#
#    IUD_Partum  IUD_Remove  Implanon                ...                  \
# 0          18         108       579                ...
# 1           0           2       229                ...
# 2           0          12        19                ...
# 3           0          41       499                ...
# 4           0           2        13                ...
#
#    IFA_number  Sanitary_Pad    NSV  Tubectomy_Normal  Tubectomy_Partum  Year  \
# 0           0            23  10411                49                25  2018
# 1           0             0     82                 1                 0  2018
# 2           0             0     20                 1                 0  2018
# 3       96050             0     51                29                 0  2018
# 4           0             0      0                 0                 0  2018
#
#    Month  District  Division                            program
# 0     12      0305        03  distributionNGO_thanaconsuprocess
# 1     12      0305        03  distributionNGO_thanaconsuprocess
# 2     12      0305        03  distributionNGO_thanaconsuprocess
# 3     12      0305        03  distributionNGO_thanaconsuprocess
# 4     12      0305        03  distributionNGO_thanaconsuprocess
#
# [5 rows x 27 columns]

# %%
data.to_csv('../../output/dgfp/data/dp_dgfp-imp12subdist_distributionNGO-thanaconsuprocess.csv', index_label=False, index=False)
