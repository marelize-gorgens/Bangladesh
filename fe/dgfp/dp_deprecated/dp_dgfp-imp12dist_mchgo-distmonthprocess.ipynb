# %% [markdown]
# # dp dgfp imp12dist mchgo distmonthprocess

# %%
import os
import glob
import collections
import pandas as pd
import numpy as np

# %%
DATA = '../../data/dgfp/data/importance12_districts/mchgo_distmonthprocess/'

# %%
def read_data(path, ext):
    files_list = glob.glob(path + '/*.' + ext)
    data = list()
    for file in files_list:
        print(file)
        file_name = os.path.split(file)[1][:-4]
        program = file.split("/")[-2]
        tmp = pd.read_csv(file, sep='\t')
        file_name_comp = file_name.split('-')
        tmp['Year'] = file_name_comp[0]
        tmp['Month'] = file_name_comp[1]
        tmp['District'] =file_name_comp[3]
        tmp['Division'] = file_name_comp[4]
        tmp['program'] = program
        data.append(tmp)
    return pd.concat(data, axis=0)

# %%
data = read_data(path=DATA, ext='csv')
# Out:
# ../../data/dgfp/data/importance12_districts/mchgo_distmonthprocess/2018-12-28-0305-03.csv
# ../../data/dgfp/data/importance12_districts/mchgo_distmonthprocess/2018-12-28-0114-01.csv
# ../../data/dgfp/data/importance12_districts/mchgo_distmonthprocess/2018-12-28-0209-02.csv
# ../../data/dgfp/data/importance12_districts/mchgo_distmonthprocess/2018-12-28-0205-02.csv
# ../../data/dgfp/data/importance12_districts/mchgo_distmonthprocess/2018-12-28-0108-07.csv
# ../../data/dgfp/data/importance12_districts/mchgo_distmonthprocess/2018-12-28-0411-04.csv
# ../../data/dgfp/data/importance12_districts/mchgo_distmonthprocess/2018-12-28-0403-04.csv
# ../../data/dgfp/data/importance12_districts/mchgo_distmonthprocess/2018-12-28-0104-07.csv
# ../../data/dgfp/data/importance12_districts/mchgo_distmonthprocess/2018-12-28-0414-08.csv
# ../../data/dgfp/data/importance12_districts/mchgo_distmonthprocess/2018-12-28-0503-05.csv
# ../../data/dgfp/data/importance12_districts/mchgo_distmonthprocess/2018-12-28-0511-05.csv
# ../../data/dgfp/data/importance12_districts/mchgo_distmonthprocess/2018-12-28-0106-07.csv
# ../../data/dgfp/data/importance12_districts/mchgo_distmonthprocess/2018-12-28-0602-06.csv
# ../../data/dgfp/data/importance12_districts/mchgo_distmonthprocess/2018-12-28-0401-04.csv
# ../../data/dgfp/data/importance12_districts/mchgo_distmonthprocess/2018-12-28-0501-05.csv
# ../../data/dgfp/data/importance12_districts/mchgo_distmonthprocess/2018-12-28-0116-01.csv
# ../../data/dgfp/data/importance12_districts/mchgo_distmonthprocess/2018-12-28-0207-02.csv
# ../../data/dgfp/data/importance12_districts/mchgo_distmonthprocess/2018-12-28-0505-05.csv
# ../../data/dgfp/data/importance12_districts/mchgo_distmonthprocess/2018-12-28-0509-05.csv
# ../../data/dgfp/data/importance12_districts/mchgo_distmonthprocess/2018-12-28-0409-04.csv
# ../../data/dgfp/data/importance12_districts/mchgo_distmonthprocess/2018-12-28-0102-07.csv
# ../../data/dgfp/data/importance12_districts/mchgo_distmonthprocess/2018-12-28-0405-04.csv
# ../../data/dgfp/data/importance12_districts/mchgo_distmonthprocess/2018-12-28-0203-02.csv
# ../../data/dgfp/data/importance12_districts/mchgo_distmonthprocess/2018-12-28-0303-03.csv
# ../../data/dgfp/data/importance12_districts/mchgo_distmonthprocess/2018-12-28-0112-01.csv
# ../../data/dgfp/data/importance12_districts/mchgo_distmonthprocess/2018-12-28-0201-02.csv
# ../../data/dgfp/data/importance12_districts/mchgo_distmonthprocess/2018-12-28-0110-01.csv
# ../../data/dgfp/data/importance12_districts/mchgo_distmonthprocess/2018-12-28-0301-03.csv
# ../../data/dgfp/data/importance12_districts/mchgo_distmonthprocess/2018-12-28-0507-05.csv
# ../../data/dgfp/data/importance12_districts/mchgo_distmonthprocess/2018-12-28-0407-04.csv
# ../../data/dgfp/data/importance12_districts/mchgo_distmonthprocess/2018-12-28-0604-06.csv
# ../../data/dgfp/data/importance12_districts/mchgo_distmonthprocess/2018-12-28-0502-05.csv
# ../../data/dgfp/data/importance12_districts/mchgo_distmonthprocess/2018-12-28-0510-05.csv
# ../../data/dgfp/data/importance12_districts/mchgo_distmonthprocess/2018-12-28-0410-04.csv
# ../../data/dgfp/data/importance12_districts/mchgo_distmonthprocess/2018-12-28-0415-08.csv
# ../../data/dgfp/data/importance12_districts/mchgo_distmonthprocess/2018-12-28-0601-06.csv
# ../../data/dgfp/data/importance12_districts/mchgo_distmonthprocess/2018-12-28-0105-07.csv
# ../../data/dgfp/data/importance12_districts/mchgo_distmonthprocess/2018-12-28-0402-04.csv
# ../../data/dgfp/data/importance12_districts/mchgo_distmonthprocess/2018-12-28-0208-02.csv
# ../../data/dgfp/data/importance12_districts/mchgo_distmonthprocess/2018-12-28-0204-02.csv
# ../../data/dgfp/data/importance12_districts/mchgo_distmonthprocess/2018-12-28-0304-03.csv
# ../../data/dgfp/data/importance12_districts/mchgo_distmonthprocess/2018-12-28-0115-01.csv
# ../../data/dgfp/data/importance12_districts/mchgo_distmonthprocess/2018-12-28-0206-02.csv
# ../../data/dgfp/data/importance12_districts/mchgo_distmonthprocess/2018-12-28-0109-01.csv
# ../../data/dgfp/data/importance12_districts/mchgo_distmonthprocess/2018-12-28-0306-03.csv
# ../../data/dgfp/data/importance12_districts/mchgo_distmonthprocess/2018-12-28-0417-08.csv
# ../../data/dgfp/data/importance12_districts/mchgo_distmonthprocess/2018-12-28-0107-07.csv
# ../../data/dgfp/data/importance12_districts/mchgo_distmonthprocess/2018-12-28-0603-06.csv
# ../../data/dgfp/data/importance12_districts/mchgo_distmonthprocess/2018-12-28-0412-04.csv
# ../../data/dgfp/data/importance12_districts/mchgo_distmonthprocess/2018-12-28-0302-03.csv
# ../../data/dgfp/data/importance12_districts/mchgo_distmonthprocess/2018-12-28-0113-01.csv
# ../../data/dgfp/data/importance12_districts/mchgo_distmonthprocess/2018-12-28-0210-02.csv
# ../../data/dgfp/data/importance12_districts/mchgo_distmonthprocess/2018-12-28-0202-02.csv
# ../../data/dgfp/data/importance12_districts/mchgo_distmonthprocess/2018-12-28-0416-04.csv
# ../../data/dgfp/data/importance12_districts/mchgo_distmonthprocess/2018-12-28-0408-04.csv
# ../../data/dgfp/data/importance12_districts/mchgo_distmonthprocess/2018-12-28-0404-04.csv
# ../../data/dgfp/data/importance12_districts/mchgo_distmonthprocess/2018-12-28-0103-07.csv
# ../../data/dgfp/data/importance12_districts/mchgo_distmonthprocess/2018-12-28-0413-08.csv
# ../../data/dgfp/data/importance12_districts/mchgo_distmonthprocess/2018-12-28-0504-05.csv
# ../../data/dgfp/data/importance12_districts/mchgo_distmonthprocess/2018-12-28-0508-05.csv
# ../../data/dgfp/data/importance12_districts/mchgo_distmonthprocess/2018-12-28-0101-07.csv
# ../../data/dgfp/data/importance12_districts/mchgo_distmonthprocess/2018-12-28-0406-04.csv
# ../../data/dgfp/data/importance12_districts/mchgo_distmonthprocess/2018-12-28-0506-05.csv
# ../../data/dgfp/data/importance12_districts/mchgo_distmonthprocess/2018-12-28-0111-01.csv

# %%
data.head()
# Out:
#       monthid  MCH37  MCH38  MCH39  MCH40  MCH41  MCH42  MCH43  MCH44  MCH45  \
# 0  2016-01-28   2768   6689   9457   6479  15936   1544    929    932    369
# 1  2016-02-28   3037   6413   9450   8232  17682   1375    971    851    548
# 2  2016-03-28   1329   7615   8944   8294  17238   1281    996    770    617
# 3  2016-04-28   1512   7289   8801   8066  16867   1812   1005    731    572
# 4  2016-05-28   1913   6462   8375   7621  15996   1331   1054    928    663
#
#             ...            MCH103  MCH104  MCH105  MCH106  MCH107  Year  \
# 0           ...               714       0      91      54     134  2018
# 1           ...              1828       0      80      78     152  2018
# 2           ...              1383       1      97      84     262  2018
# 3           ...              2490       0      95      79     208  2018
# 4           ...              1300       0      61      73     243  2018
#
#    Month  District  Division                 program
# 0     12      0305        03  mchgo_distmonthprocess
# 1     12      0305        03  mchgo_distmonthprocess
# 2     12      0305        03  mchgo_distmonthprocess
# 3     12      0305        03  mchgo_distmonthprocess
# 4     12      0305        03  mchgo_distmonthprocess
#
# [5 rows x 77 columns]

# %%
dp dgfp imp12dist mchgo distmonthprocess
