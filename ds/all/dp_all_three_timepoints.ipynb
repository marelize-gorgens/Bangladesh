# %% [markdown]
# # NOTEBOOK

# %% [markdown]
# ## Data sources:
#
# - **DHIS2 health indicators:**
#     - 2011, 2014 and 2017
# - **DGFP health indicators:**
#     - 2011, 2014 and 2017
# - **DHS raw variables:**
#     - 2011, 2014, 2017
# - **SVRS raw variables:**
#     - 2012, 2014, 2017
# - **CES indicators:**
#     - 2011, 2014, 2016
#
# ## Time points:
# ![Timpoints](timepoints_version2.png)

# %%
import os
import re
import numpy as np
import pandas as pd
from collections import Counter
from fuzzywuzzy import fuzz

# %%
def intersect_dfs(list_dfs):
    subset_var = []
    for key, value in list_dfs.items():
        if len(subset_var) == 0:
            subset_var = list(value.columns)
        else:
            subset_var = list(set(subset_var).intersection(set(list(value.columns))))
    for key, value in list_dfs.items():
        value = value[subset_var]
        list_dfs[key] = value
    del subset_var
    return list_dfs

def read_ces(files_list, common=True):
    data_dict = {}
    for file in files_list:
        data_dict[file] = pd.read_csv(file, encoding='cp850')
        data_dict[file].rename(columns={'Survey.Units"':'geo'}, inplace=True)
        subset = [not bool(re.search(r"Division|Launch District|CC|KCC|RCC|DCC|SCC|CCC|BCC|Urban|Rural|CC Slum| Slum|National", geo)) for geo in data_dict[file]['Survey.Units']]
        print(Counter([not bool(re.search(r"Division|Launch District|CC|KCC|RCC|DCC|SCC|CCC|BCC|Urban|Rural|CC Slum| Slum|National", geo)) for geo in data_dict[file]['Survey.Units']]))
        data_dict[file] = data_dict[file].loc[subset,:]
        print(data_dict[file].shape)
    return data_dict

def match_districts(ref_df, ref_match, input_df, input_match):
    out = pd.DataFrame()
    for key, code in enumerate(input_df[input_match]):
        code_match = {}
        code_match['FuzzRatio'] = [fuzz.ratio(ref_code, code)  for ref_code in ref_df[ref_match]]
        code_match['Geo'] = code
        code_match['DistrictGeo'] = [value[0] for value in ref_df.values]
        code_match['DistrictName'] = [value[1]  for value in ref_df.values]
        code_match = pd.DataFrame.from_dict(code_match)
        out = out.append(code_match.sort_values('FuzzRatio', ascending=False).iloc[0,:])
    for var in list(out.columns):
        if out[var].dtype.kind == 'f':
            out[var] = out[var].astype(int)
            out[var] = out[var].astype(str)
            code_length = max([len(char) for char in out[var]])
            out[var] = out[var].str.pad(width=code_length, side='left', fillchar='0') 
    return out

def read_dgfp(files_list):
    data_dict = {}
    for file in files_list:
        data_dict[file] = pd.read_csv(file)
    return data_dict

def distrGO_rates(input_df, pattern, denominator_male, denominator_female):
    df = input_df.copy(deep=True)
    vars_rates = [var for var in df.columns if pattern in var]
    for var in vars_rates:
        if "_male" in var:
            df[var] = np.round(df[var]/(denominator_male/1000),4)
        else: 
            df[var] = np.round(df[var]/(denominator_female/1000), 4)
    return df, vars_rates

# %% [markdown]
# ## GEOS

# %% [markdown]
# ## CES Data

# %%
CES2011 = '/Users/edinhamzic/Symphony/wb_bangladesh/Bangladesh/output/unicef/gdata/gdata_unicef_ces_2011.csv'
CES2014 = '/Users/edinhamzic/Symphony/wb_bangladesh/Bangladesh/output/unicef/gdata/gdata_unicef_ces_2014.csv'
CES2016 = '/Users/edinhamzic/Symphony/wb_bangladesh/Bangladesh/output/unicef/gdata/gdata_unicef_ces_2016.csv'
ces_list = [CES2011, CES2014, CES2016]
ces = read_ces(files_list=ces_list, common=True)
ces.keys()
# Out:
# Counter({True: 64, False: 20})
# (64, 44)
# Counter({True: 64, False: 23})
# (64, 50)
# Counter({True: 64, False: 24})
# (64, 52)
# dict_keys(['/Users/edinhamzic/Symphony/wb_bangladesh/Bangladesh/output/unicef/gdata/gdata_unicef_ces_2011.csv', '/Users/edinhamzic/Symphony/wb_bangladesh/Bangladesh/output/unicef/gdata/gdata_unicef_ces_2014.csv', '/Users/edinhamzic/Symphony/wb_bangladesh/Bangladesh/output/unicef/gdata/gdata_unicef_ces_2016.csv'])

# %%
ces = intersect_dfs(list_dfs=ces)
ces_2011 = ces['/Users/edinhamzic/Symphony/wb_bangladesh/Bangladesh/output/unicef/gdata/gdata_unicef_ces_2011.csv']
ces_2014 = ces['/Users/edinhamzic/Symphony/wb_bangladesh/Bangladesh/output/unicef/gdata/gdata_unicef_ces_2014.csv']
ces_2016 = ces['/Users/edinhamzic/Symphony/wb_bangladesh/Bangladesh/output/unicef/gdata/gdata_unicef_ces_2016.csv']

# %%
ces_2011['DistrictCode'] = ces_2011['DistrictCode'].astype(str).str.pad(width=2, side='left', fillchar='0')
ces_2011['DivisionCode'] = ces_2011['DivisionCode'].astype(str).str.pad(width=2, side='left', fillchar='0')
ces_2011['DistrictGeo'] = ces_2011['DivisionCode'].str.cat(ces_2011['DistrictCode'], sep="")
ces_2011 = ces_2011.drop(['DivisionName', 'DivisionCode', 'Geo', 'DistrictCode', 'Year', 'FuzzRatio', 'Survey.Units'], axis=1)
ces_2011.head()
# Out:
#    Fully_Children23M  PENTA1_Children23M  PENTA3_Children12M  \
# 0               75.0                99.0                83.3
# 1               79.7                98.1                85.6
# 2               76.2                94.3                83.8
# 3               79.9               100.0                87.3
# 4               77.4                98.6                86.9
#
#    PENTA3_Children23M  TT2_Mother0-11MChildren  TT5_Mother0-11MChildren  \
# 0                84.1                     95.7                     53.8
# 1                85.6                     86.2                     31.9
# 2                84.4                     85.2                     38.6
# 3                87.9                     98.6                     27.6
# 4                86.9                     94.8                     31.0
#
#    PENTA1_Children12M  PENTA2_Children12M  Fully_Children12M  BCG_Children23M  \
# 0                98.3                97.5               72.6             99.0
# 1                98.1                96.0               78.3             98.1
# 2                94.3                90.2               73.1             94.3
# 3               100.0                98.6               74.4            100.0
# 4                98.6                98.1               73.4             98.6
#
#    ...  VitACoverage_Children12-59M  OPV1_Children12M   DistrictName  \
# 0  ...                         88.1              98.3  Brahmanbaria
# 1  ...                         96.7              98.1      Bagerhat
# 2  ...                         83.3              93.8     Bandarban
# 3  ...                         96.7              99.5       Barguna
# 4  ...                         79.0              98.6       Barisal
#
#    Measles_Children12M  PENTA2_Children23M  OPV3_Children23M  \
# 0                 81.3                98.3              93.5
# 1                 86.7                96.0              93.3
# 2                 79.2                90.2              89.4
# 3                 82.6                98.6              95.4
# 4                 82.6                98.1              94.5
#
#    OPV1_Children23M  OPV2_Children12M BCG_Children12M  DistrictGeo
# 0              99.0              97.5            98.3         2012
# 1              98.1              96.0            98.1         4001
# 2              93.8              90.8            94.3         2003
# 3              99.5              98.6           100.0         1004
# 4              98.6              98.1            98.6         1006
#
# [5 rows x 26 columns]

# %%
ces_2014['DistrictCode'] = ces_2014['DistrictCode'].astype(str).str.pad(width=2, side='left', fillchar='0')
ces_2014['DivisionCode'] = ces_2014['DivisionCode'].astype(str).str.pad(width=2, side='left', fillchar='0')
ces_2014['DistrictGeo'] = ces_2014['DivisionCode'].str.cat(ces_2014['DistrictCode'], sep="")
ces_2014 = ces_2014.drop(['DivisionName', 'DivisionCode', 'Geo', 'DistrictCode', 'Year', 'FuzzRatio', 'Survey.Units'], axis=1)
ces_2014.head()
# Out:
#    Fully_Children23M  PENTA1_Children23M  PENTA3_Children12M  \
# 0               87.7                95.9                91.4
# 1               84.8                90.3                90.7
# 2               88.6                93.9                94.1
# 3               91.7                96.1                98.1
# 6               83.1                95.1                94.5
#
#    PENTA3_Children23M  TT2_Mother0-11MChildren  TT5_Mother0-11MChildren  \
# 0                91.4                     96.2                     56.7
# 1                91.2                     85.7                     42.9
# 2                94.1                     97.6                     41.9
# 3                98.1                     99.5                     58.6
# 6                94.5                     96.7                     38.6
#
#    PENTA1_Children12M  PENTA2_Children12M  Fully_Children12M  BCG_Children23M  \
# 0                95.9                96.4               82.4            100.0
# 1                90.3                89.5               79.6             98.6
# 2                93.9                93.5               86.6            100.0
# 3                96.1                98.1               88.8             99.5
# 6                95.1                95.3               78.7            100.0
#
#    ...  VitACoverage_Children12-59M  OPV1_Children12M  DistrictName  \
# 0  ...                         94.8              97.4     Bagerhat
# 1  ...                         82.9              91.4    Bandarban
# 2  ...                         97.1              96.4      Barguna
# 3  ...                         96.2              99.5      Barisal
# 6  ...                         77.1              98.4        Bhola
#
#    Measles_Children12M  PENTA2_Children23M  OPV3_Children23M  \
# 0                 88.3                96.4              95.0
# 1                 81.3                89.5              90.7
# 2                 91.8                93.5              95.4
# 3                 94.1                98.1              98.6
# 6                 83.1                95.3              93.4
#
#    OPV1_Children23M  OPV2_Children12M BCG_Children12M  DistrictGeo
# 0              97.4              96.9           100.0         4001
# 1              91.4              90.6            98.6         2003
# 2              96.4              95.4           100.0         1004
# 3              99.5              99.5            99.5         1006
# 6              98.4              97.5           100.0         1009
#
# [5 rows x 26 columns]

# %%
ces_2016['DistrictCode'] = ces_2016['DistrictCode'].astype(str).str.pad(width=2, side='left', fillchar='0')
ces_2016['DivisionCode'] = ces_2016['DivisionCode'].astype(str).str.pad(width=2, side='left', fillchar='0')
ces_2016['DistrictGeo'] = ces_2016['DivisionCode'].str.cat(ces_2016['DistrictCode'], sep="")
ces_2016 = ces_2016.drop(['DivisionName', 'DivisionCode', 'Geo', 'DistrictCode', 'Year', 'FuzzRatio', 'Survey.Units'], axis=1)
ces_2016.head()
# Out:
#    Fully_Children23M  PENTA1_Children23M  PENTA3_Children12M  \
# 0               88.3                97.4                90.8
# 1               83.9                96.3                87.8
# 2               91.1                98.8                93.0
# 3               94.6                99.1                95.5
# 6               91.9                99.8                94.5
#
#    PENTA3_Children23M  TT2_Mother0-11MChildren  TT5_Mother0-11MChildren  \
# 0                91.0                     97.8                     36.5
# 1                87.8                     92.2                     65.3
# 2                93.6                     97.4                     36.3
# 3                96.0                    100.0                     60.0
# 6                94.5                    100.0                     56.1
#
#    PENTA1_Children12M  PENTA2_Children12M  Fully_Children12M  BCG_Children23M  \
# 0                97.4                96.8               86.8             98.2
# 1                96.3                94.8               80.9             99.0
# 2                98.8                97.9               87.6             99.7
# 3                99.1                99.3               91.0             99.7
# 6                99.8                99.8               91.3             99.8
#
#    ...  VitACoverage_Children12-59M  OPV1_Children12M  DistrictName  \
# 0  ...                         82.0              97.4     Bagerhat
# 1  ...                         84.1              96.3    Bandarban
# 2  ...                         96.8              98.8      Barguna
# 3  ...                        100.0              99.1      Barisal
# 6  ...                         98.4              99.8        Bhola
#
#    Measles_Children12M  PENTA2_Children23M  OPV3_Children23M  \
# 0                 90.3                97.1              91.0
# 1                 86.3                94.8              87.8
# 2                 91.0                98.3              93.6
# 3                 93.1                99.3              96.0
# 6                 95.4                99.8              94.5
#
#    OPV1_Children23M  OPV2_Children12M BCG_Children12M  DistrictGeo
# 0              97.4              96.8            98.2         4001
# 1              96.3              94.8            99.0         2003
# 2              98.8              97.9            99.7         1004
# 3              99.1              99.3            99.7         1006
# 6              99.8              99.8            99.8         1009
#
# [5 rows x 26 columns]

# %%
check_list = []
for var1, var2, var3 in zip(sorted(ces_2011['DistrictName']), sorted(ces_2014['DistrictName']), sorted(ces_2016['DistrictName'])):
    check_list.append(var1==var2)
    check_list.append(var1==var3)
    check_list.append(var2==var3)
    print(var1==var2)
    print(var1==var3)
    print(var2==var3)
print("#"*100)
print(all(check_list))
# Out:
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# ####################################################################################################
# True

# %%
geo = ces_2011[['DistrictGeo', 'DistrictName']]
geo.head()
# Out:
#   DistrictGeo   DistrictName
# 0        2012  Brahmanbaria
# 1        4001      Bagerhat
# 2        2003     Bandarban
# 3        1004       Barguna
# 4        1006       Barisal

# %% [markdown]
# ## SVRS Data

# %%
SVRS2011 = '/Users/edinhamzic/Symphony/wb_bangladesh/Bangladesh/output/bbs/data/data_svrs_zila_2012_clean.csv'
SVRS2014 = '/Users/edinhamzic/Symphony/wb_bangladesh/Bangladesh/output/bbs/data/data_svrs_zila_2014_clean.csv'
SVRS2017 = '/Users/edinhamzic/Symphony/wb_bangladesh/Bangladesh/output/bbs/data/data_svrs_zila_2017_clean.csv'

# %%
svrs_2011 = pd.read_csv(SVRS2011)
svrs_2011['district'] = svrs_2011['district'].str.replace(' Zila', '')
display(svrs_2011.head())
print(svrs_2011.columns)
# Out:
#     district  prop_live_births  prop_registered_births  prop_deaths_rural  \
# 0   Bagerhat             98.62                       7                 78
# 1  Bandarban             98.61                      12                 56
# 2    Barguna             99.30                       7                 75
# 3    Barisal             98.96                      14                 68
# 4      Bhola             99.02                      51                 73
#
#    sex_ratio  dependency_ratio  prop_pop_rural  prop_pop_women  \
# 0     103.13             51.40           73.67           49.23
# 1     107.07             63.84           45.42           48.29
# 2     100.62             56.56           64.75           49.85
# 3     105.58             54.58           63.40           48.64
# 4     110.73             61.07           71.88           47.45
#
#    prop_pop_rural_women  prop_women_15.45y_overwomen  \
# 0                 36.03                        50.65
# 1                 22.10                        49.68
# 2                 32.28                        49.91
# 3                 30.64                        48.66
# 4                 34.15                        49.20
#
#    prop_married_women_15.45y  prop_married_..15y  rate_live_births  \
# 0                      73.58               66.24             10.85
# 1                      73.23               70.54             19.26
# 2                      82.21               74.90             20.55
# 3                      69.59               65.86             19.36
# 4                      73.60               68.84             18.19
#
#    rate_fertility  rate_death  rate_child_death  rate_under5y_mortality  \
# 0           43.49        3.66              1.14                   27.97
# 1           80.30        3.48              0.98                   56.34
# 2           82.58        5.77              5.03                   38.87
# 3           81.80        5.97              0.76                   52.77
# 4           77.89        5.13              1.52                   66.23
#
#    rate_infant_mortality  rate_maternal_mortality  year
# 0                  20.98                  1398.60  2012
# 1                  51.64                   469.48  2012
# 2                  21.20                     0.00  2012
# 3                  50.13                     0.00  2012
# 4                  59.60                   993.38  2012
# Index(['district', 'prop_live_births', 'prop_registered_births',
#        'prop_deaths_rural', 'sex_ratio', 'dependency_ratio', 'prop_pop_rural',
#        'prop_pop_women', 'prop_pop_rural_women', 'prop_women_15.45y_overwomen',
#        'prop_married_women_15.45y', 'prop_married_..15y', 'rate_live_births',
#        'rate_fertility', 'rate_death', 'rate_child_death',
#        'rate_under5y_mortality', 'rate_infant_mortality',
#        'rate_maternal_mortality', 'year'],
#       dtype='object')

# %% [markdown]
# ```
# svrs_2014 = pd.read_csv(SVRS2014)
# display(svrs_2014.head())
# print(svrs_2014.columns)
# ```

# %%
svrs_2016 = pd.read_csv(SVRS2016)
display(svrs_2016.head())
svrs_2011, svrs_2016 = intersect_dfs(input_df1=svrs_2011, input_df2=svrs_2016)
print(svrs_2016.columns)

# %%
geo_svrs_2011 = match_districts(ref_df=geo, ref_match='DistrictName', input_df=svrs_2011, input_match='district')
geo_svrs_2016 = match_districts(ref_df=geo, ref_match='DistrictName', input_df=svrs_2016, input_match='district')

# %%
print(svrs_2011.shape)
print(svrs_2016.shape)
svrs_2011 = svrs_2011.merge(geo_svrs_2011, how='left', left_on='district', right_on='Geo')
svrs_2016 = svrs_2016.merge(geo_svrs_2016, how='left', left_on='district', right_on='Geo')
svrs_2011 = svrs_2011.drop(['FuzzRatio','Geo', 'district', 'year'], axis=1)
svrs_2016 = svrs_2016.drop(['FuzzRatio','Geo', 'district', 'year'], axis=1)
print(svrs_2011.shape)
print(svrs_2016.shape)
# Out:
# (64, 20)
# (64, 20)
# (64, 20)
# (64, 20)

# %%
print(svrs_2011['rate_maternal_mortality'].mean())
print(svrs_2016['rate_maternal_mortality'].mean())
# Out:
# 228.3010937500001
# 2.65078125

# %% [markdown]
# ## DHIS2 Data

# %%
DHIS2011 = '/Users/edinhamzic/Symphony/wb_bangladesh/Bangladesh/output/dhis2/health_indicators/District_2011_NAME.csv'
DHIS2014 = '/Users/edinhamzic/Symphony/wb_bangladesh/Bangladesh/output/dhis2/health_indicators/District_2014_NAME.csv'
DHIS2017 = '/Users/edinhamzic/Symphony/wb_bangladesh/Bangladesh/output/dhis2/health_indicators/District_2017_NAME.csv'

# %%
dhis_2011 = pd.read_csv(DHIS2011)
dhis_2011['Geo'] = dhis_2011['True'].str.replace(" District", "")
display(dhis_2011.head())
# Out:
#                  True  \
# 0   Bagerhat District
# 1  Bandarban District
# 2    Barguna District
# 3   Barishal District
# 4      Bhola District
#
#    07Vaccine&LogisticsstockofUpazilaMunCC: Differences between Pentavalent doses and vial uses  \
# 0                                              358.0
# 1                                             -667.0
# 2                                                0.0
# 3                                              492.0
# 4                                               10.0
#
#    07Vaccine&LogisticsstockofUpazilaMunCC: Penta vial Opening + Receive  \
# 0                                           128774.0
# 1                                            62055.0
# 2                                           109797.0
# 3                                           297323.0
# 4                                           198050.0
#
#    07Vaccine&LogisticsstockofUpazilaMunCC: Upazila EPI AEFI Form need with buffer  \
# 0                                              643.0
# 1                                              115.0
# 2                                             3856.0
# 3                                             1827.0
# 4                                             3499.0
#
#    07Vaccine&LogisticsstockofUpazilaMunCC: Upazila EPI AEFI Investigation form need with buffer  \
# 0                                              395.0
# 1                                              112.0
# 2                                               33.0
# 3                                              552.0
# 4                                               95.0
#
#    07Vaccine&LogisticsstockofUpazilaMunCC: Upazila EPI AEFI form E36 - E39 need with buffer  \
# 0                                              398.0
# 1                                              110.0
# 2                                               36.0
# 3                                              551.0
# 4                                               92.0
#
#    07Vaccine&LogisticsstockofUpazilaMunCC: Upazila EPI AEFI line listing form need with buffer  \
# 0                                              509.0
# 1                                              120.0
# 2                                               38.0
# 3                                              552.0
# 4                                               94.0
#
#    07Vaccine&LogisticsstockofUpazilaMunCC: Upazila EPI BCG diluent need with buffer  \
# 0                                            26253.0
# 1                                             8212.5
# 2                                            15523.5
# 3                                            40608.0
# 4                                            29293.5
#
#    07Vaccine&LogisticsstockofUpazilaMunCC: Upazila EPI BCG need with buffer  \
# 0                                            26373.0
# 1                                             8362.5
# 2                                            15523.5
# 3                                            40608.0
# 4                                            29430.0
#
#    07Vaccine&LogisticsstockofUpazilaMunCC: Upazila EPI CC supply book need with buffer  \
# 0                                               93.0
# 1                                                4.0
# 2                                               14.0
# 3                                               27.0
# 4                                               41.0
#
#    ...  02ChildHealth: IMCI Wasting (%)  \
# 0  ...                             1.80
# 1  ...                             0.16
# 2  ...                             1.40
# 3  ...                             1.00
# 4  ...                             8.30
#
#    02ChildHealth: Neonatal Case fatality rate (EmOC)  \
# 0                                             0.2009
# 1                                             0.1165
# 2                                             1.1355
# 3                                             0.3973
# 4                                             0.0774
#
#    02ChildHealth: Percentage of diarrhea reported at facility  \
# 0                                              11.35
# 1                                               8.70
# 2                                               7.10
# 3                                              11.74
# 4                                              13.54
#
#    02ChildHealth: Percentage of pneumonia reported at facility  \
# 0                                               3.70
# 1                                               8.39
# 2                                               4.07
# 3                                               5.68
# 4                                               3.74
#
#    05Logistics: Percentage of functional ambulance  \
# 0                                            68.85
# 1                                            65.24
# 2                                            71.36
# 3                                            81.82
# 4                                            76.34
#
#    05Logistics: Percentage of functional x-ray  \
# 0                                       37.025
# 1                                       61.538
# 2                                       46.073
# 3                                       51.923
# 4                                       67.742
#
#    AntenatalCare(ANC): 1st Visit ANC  AntenatalCare(ANC): 2nd Visit ANC  \
# 0                                NaN                                NaN
# 1                                NaN                                NaN
# 2                                NaN                                NaN
# 3                                NaN                                NaN
# 4                                NaN                                NaN
#
#    AntenatalCare(ANC): 3rd & more ANC        Geo
# 0                                 NaN   Bagerhat
# 1                                 NaN  Bandarban
# 2                                 NaN    Barguna
# 3                                 NaN   Barishal
# 4                                 NaN      Bhola
#
# [5 rows x 350 columns]

# %%
dhis_2014 = pd.read_csv(DHIS2014)
dhis_2014['Geo'] = dhis_2014['True'].str.replace(" District", "")
display(dhis_2014.head())
# Out:
#                  True  \
# 0   Bagerhat District
# 1  Bandarban District
# 2    Barguna District
# 3   Barishal District
# 4      Bhola District
#
#    07Vaccine&LogisticsstockofUpazilaMunCC: Differences between Pentavalent doses and vial uses  \
# 0                                           -17303.0
# 1                                            12213.0
# 2                                           -15554.0
# 3                                            29932.0
# 4                                           -18086.0
#
#    07Vaccine&LogisticsstockofUpazilaMunCC: Penta vial Opening + Receive  \
# 0                                           249362.0
# 1                                            75120.0
# 2                                           217151.0
# 3                                           378314.0
# 4                                           433679.0
#
#    07Vaccine&LogisticsstockofUpazilaMunCC: Upazila EPI AEFI Form need with buffer  \
# 0                                              643.0
# 1                                              115.0
# 2                                             3856.0
# 3                                             1827.0
# 4                                             3499.0
#
#    07Vaccine&LogisticsstockofUpazilaMunCC: Upazila EPI AEFI Investigation form need with buffer  \
# 0                                              395.0
# 1                                              112.0
# 2                                               33.0
# 3                                              552.0
# 4                                               95.0
#
#    07Vaccine&LogisticsstockofUpazilaMunCC: Upazila EPI AEFI form E36 - E39 need with buffer  \
# 0                                              398.0
# 1                                              110.0
# 2                                               36.0
# 3                                              551.0
# 4                                               92.0
#
#    07Vaccine&LogisticsstockofUpazilaMunCC: Upazila EPI AEFI line listing form need with buffer  \
# 0                                              509.0
# 1                                              120.0
# 2                                               38.0
# 3                                              552.0
# 4                                               94.0
#
#    07Vaccine&LogisticsstockofUpazilaMunCC: Upazila EPI BCG diluent need with buffer  \
# 0                                            26253.0
# 1                                             8212.5
# 2                                            15523.5
# 3                                            40608.0
# 4                                            29293.5
#
#    07Vaccine&LogisticsstockofUpazilaMunCC: Upazila EPI BCG need with buffer  \
# 0                                            26373.0
# 1                                             8362.5
# 2                                            15523.5
# 3                                            40608.0
# 4                                            29430.0
#
#    07Vaccine&LogisticsstockofUpazilaMunCC: Upazila EPI CC supply book need with buffer  \
# 0                                               93.0
# 1                                                4.0
# 2                                               14.0
# 3                                               27.0
# 4                                               41.0
#
#    ...  02ChildHealth: IMCI Wasting (%)  \
# 0  ...                             1.20
# 1  ...                             0.11
# 2  ...                             0.85
# 3  ...                             0.58
# 4  ...                             6.20
#
#    02ChildHealth: Neonatal Case fatality rate (EmOC)  \
# 0                                             0.1486
# 1                                             0.0491
# 2                                             1.0348
# 3                                             0.0657
# 4                                             0.2078
#
#    02ChildHealth: Percentage of diarrhea reported at facility  \
# 0                                              10.72
# 1                                               8.59
# 2                                               6.63
# 3                                              11.60
# 4                                              14.24
#
#    02ChildHealth: Percentage of pneumonia reported at facility  \
# 0                                               3.74
# 1                                               8.07
# 2                                               5.13
# 3                                               5.92
# 4                                               4.99
#
#    05Logistics: Percentage of functional ambulance  \
# 0                                            66.90
# 1                                            65.17
# 2                                            68.21
# 3                                            81.23
# 4                                            72.43
#
#    05Logistics: Percentage of functional x-ray  \
# 0                                       38.402
# 1                                       58.861
# 2                                       34.722
# 3                                       54.373
# 4                                       56.122
#
#    AntenatalCare(ANC): 1st Visit ANC  AntenatalCare(ANC): 2nd Visit ANC  \
# 0                                NaN                                NaN
# 1                                NaN                                NaN
# 2                                NaN                                NaN
# 3                                NaN                                NaN
# 4                                NaN                                NaN
#
#    AntenatalCare(ANC): 3rd & more ANC        Geo
# 0                                 NaN   Bagerhat
# 1                                 NaN  Bandarban
# 2                                 NaN    Barguna
# 3                                 NaN   Barishal
# 4                                 NaN      Bhola
#
# [5 rows x 350 columns]

# %%
dhis_2017 = pd.read_csv(DHIS2017)
dhis_2017['Geo'] = dhis_2017['True'].str.replace(" District", "")
display(dhis_2017.head())
# Out:
#                  True  04Newborn: % of Nurse training on ETAT at SCANU  \
# 0   Bagerhat District                                              NaN
# 1  Bandarban District                                              NaN
# 2    Barguna District                                              NaN
# 3   Barishal District                                              NaN
# 4      Bhola District                                            368.4
#
#    04Newborn: % of female baby admitted in SCANU reported individually  \
# 0                                               41.5
# 1                                               48.3
# 2                                                0.0
# 3                                              100.0
# 4                                               37.0
#
#    04Newborn: % of female baby admitted in SCANU reported monthly  \
# 0                                               39.1
# 1                                               46.1
# 2                                                NaN
# 3                                                NaN
# 4                                               35.8
#
#    04Newborn: % of functional Radiant warmer  \
# 0                                       40.4
# 1                                        0.0
# 2                                        NaN
# 3                                        NaN
# 4                                       38.5
#
#    04Newborn: % of male baby admitted in SCANU reported individually  \
# 0                                               58.5
# 1                                               51.7
# 2                                              100.0
# 3                                                0.0
# 4                                               63.0
#
#    04Newborn: % of male baby admitted in SCANU reported monthly  \
# 0                                               60.9
# 1                                               53.9
# 2                                                NaN
# 3                                                NaN
# 4                                               64.2
#
#    04Newborn: % of non functional Photo therapy unit  \
# 0                                               38.8
# 1                                                0.0
# 2                                                NaN
# 3                                                NaN
# 4                                               19.8
#
#    04Newborn: % of non-functioning Table Resuscitator with Radiant warmer  \
# 0                                               24.1
# 1                                                0.0
# 2                                                NaN
# 3                                                NaN
# 4                                                1.0
#
#    04Newborn: % of nurse allocated in SCANU among all nurses in the facility  \
# 0                                                0.0
# 1                                                0.0
# 2                                                NaN
# 3                                                NaN
# 4                                               12.6
#
#    ...  03Immunization: Total Pentavalent Given  \
# 0  ...                                 172226.0
# 1  ...                                  67484.0
# 2  ...                                 123124.0
# 3  ...                                 364881.0
# 4  ...                                 306078.0
#
#    03Immunization: Total TT Given to 15 - 49 Y  \
# 0                                     140738.0
# 1                                      73615.0
# 2                                     137826.0
# 3                                     332370.0
# 4                                     337464.0
#
#    03Immunization: Total TT Given to Pregnant Women  \
# 0                                           29415.0
# 1                                            9341.0
# 2                                           38831.0
# 3                                          100269.0
# 4                                           88113.0
#
#    03Immunization: Total fIPV Given  03Immunization: fIPV1 Crude Coverage %  \
# 0                           64545.0                                    57.7
# 1                           17521.0                                    42.6
# 2                           35770.0                                    45.9
# 3                          120074.0                                    55.6
# 4                          100339.0                                    55.5
#
#    03Immunization: fIPV2 Crude Coverage %  AntenatalCare(ANC): 1st Visit ANC  \
# 0                                    53.6                                NaN
# 1                                    32.2                                NaN
# 2                                    38.8                                NaN
# 3                                    42.6                                NaN
# 4                                    38.4                                NaN
#
#    AntenatalCare(ANC): 2nd Visit ANC  AntenatalCare(ANC): 3rd & more ANC  \
# 0                                NaN                                 NaN
# 1                                NaN                                 NaN
# 2                                NaN                                 NaN
# 3                                NaN                                 NaN
# 4                                NaN                                 NaN
#
#          Geo
# 0   Bagerhat
# 1  Bandarban
# 2    Barguna
# 3   Barishal
# 4      Bhola
#
# [5 rows x 350 columns]

# %%
dhis2 = intersect_dfs(list_dfs={'DHIS2_2011': dhis_2011, 'DHIS2_2014':dhis_2014, 'DHIS2_2017':dhis_2017})
for key, value in dhis2.items():
    print(key)
    print(value.shape)
# Out:
# DHIS2_2011
# (64, 350)
# DHIS2_2014
# (64, 350)
# DHIS2_2017
# (64, 350)

# %%
dhis_2011, dhis_2014, dhis_2017 = dhis2['DHIS2_2011'], dhis2['DHIS2_2014'], dhis2['DHIS2_2017']

# %%
geo_dhis_2011 = match_districts(ref_df=geo, ref_match='DistrictName', input_df=dhis_2011, input_match='Geo')
geo_dhis_2014 = match_districts(ref_df=geo, ref_match='DistrictName', input_df=dhis_2014, input_match='Geo')
geo_dhis_2017 = match_districts(ref_df=geo, ref_match='DistrictName', input_df=dhis_2017, input_match='Geo')

# %%
print(dhis_2011.shape)
print(dhis_2014.shape)
print(dhis_2017.shape)
dhis_2011 = dhis_2011.merge(geo_dhis_2011, how='left', left_on='Geo', right_on='Geo')
dhis_2014 = dhis_2014.merge(geo_dhis_2014, how='left', left_on='Geo', right_on='Geo')
dhis_2016 = dhis_2017.merge(geo_dhis_2017, how='left', left_on='Geo', right_on='Geo')
dhis_2011 = dhis_2011.drop(['FuzzRatio','Geo',], axis=1)
dhis_2014 = dhis_2014.drop(['FuzzRatio','Geo',], axis=1)
dhis_2017 = dhis_2017.drop(['FuzzRatio','Geo',], axis=1)
print(dhis_2011.shape)
print(dhis_2014.shape)
print(dhis_2017.shape)
# Out:
# (64, 350)
# (64, 350)
# (64, 351)
# (64, 351)

# %% [markdown]
# ## DGFP Data

# %%
DGFP2011a = '/Users/edinhamzic/Symphony/wb_bangladesh/Bangladesh/output/dgfp/data/data_dgfp_imp11subdistr_ngothanaprocess_2011.csv'
DGFP2011b = '/Users/edinhamzic/Symphony/wb_bangladesh/Bangladesh/output/dgfp/data/data_dgfp_imp11subdistr_thanaprocess_2011.csv'
DGFP2011c = '/Users/edinhamzic/Symphony/wb_bangladesh/Bangladesh/output/dgfp/data/data_dgfp_imp12distr_district_monthprocess_2011.csv'
DGFP2011d = '/Users/edinhamzic/Symphony/wb_bangladesh/Bangladesh/output/dgfp/data/data_dgfp_imp12distr_ngodistrict_monthprocess_2011.csv'
DGFP2011e = '/Users/edinhamzic/Symphony/wb_bangladesh/Bangladesh/output/dgfp/data/data_dgfp_imp12distr_distributionGO_distmonthProcess_2011.csv'
DGFP2011 = [DGFP2011a, DGFP2011b, DGFP2011c, DGFP2011d, DGFP2011e]


DGFP2014a = '/Users/edinhamzic/Symphony/wb_bangladesh/Bangladesh/output/dgfp/data/data_dgfp_imp11subdistr_ngothanaprocess_2014.csv'
DGFP2014b = '/Users/edinhamzic/Symphony/wb_bangladesh/Bangladesh/output/dgfp/data/data_dgfp_imp11subdistr_thanaprocess_2014.csv'
DGFP2014c = '/Users/edinhamzic/Symphony/wb_bangladesh/Bangladesh/output/dgfp/data/data_dgfp_imp12distr_district_monthprocess_2014.csv'
DGFP2014d = '/Users/edinhamzic/Symphony/wb_bangladesh/Bangladesh/output/dgfp/data/data_dgfp_imp12distr_ngodistrict_monthprocess_2014.csv'
DGFP2014e = '/Users/edinhamzic/Symphony/wb_bangladesh/Bangladesh/output/dgfp/data/data_dgfp_imp12distr_distributionGO_distmonthProcess_2014.csv'
DGFP2014 = [DGFP2014a, DGFP2014b, DGFP2014c, DGFP2014d, DGFP2014e]


DGFP2017a = '/Users/edinhamzic/Symphony/wb_bangladesh/Bangladesh/output/dgfp/data/data_dgfp_imp11subdistr_ngothanaprocess_2017.csv'
DGFP2017b = '/Users/edinhamzic/Symphony/wb_bangladesh/Bangladesh/output/dgfp/data/data_dgfp_imp11subdistr_thanaprocess_2017.csv'
DGFP2017c = '/Users/edinhamzic/Symphony/wb_bangladesh/Bangladesh/output/dgfp/data/data_dgfp_imp12distr_district_monthprocess_2017.csv'
DGFP2017d = '/Users/edinhamzic/Symphony/wb_bangladesh/Bangladesh/output/dgfp/data/data_dgfp_imp12distr_ngodistrict_monthprocess_2017.csv'
DGFP2017e = '/Users/edinhamzic/Symphony/wb_bangladesh/Bangladesh/output/dgfp/data/data_dgfp_imp12distr_distributionGO_distmonthProcess_2017.csv'
DGFP2017 = [DGFP2017a, DGFP2017b, DGFP2017c, DGFP2017d, DGFP2017e]

# %%
dgfp2011 = read_dgfp(files_list=DGFP2011)
dgfp2014 = read_dgfp(files_list=DGFP2014)
dgfp2017 = read_dgfp(files_list=DGFP2017)

# %%
dgfp2011[DGFP2011e]['distr_GOdistr_GOfemalepn'].sum()
# Out:
# 0

# %%
dgfp2011df = pd.concat([dgfp2011[DGFP2011a], 
                        dgfp2011[DGFP2011b].drop('geo', axis=1), 
                        dgfp2011[DGFP2011c].drop('geo', axis=1),
                        dgfp2011[DGFP2011d].drop('geo', axis=1),
                        dgfp2011[DGFP2011e].drop('geo', axis=1)], axis=1)
print(dgfp2011df.shape)
print(dgfp2011df.columns)
# Out:
# (64, 59)
# Index(['imp11subdistr_ngothanaprocessNGO_Percent_Pill',
#        'imp11subdistr_ngothanaprocessNGO_Percent_Condom',
#        'imp11subdistr_ngothanaprocessNGO_Percent_Injectable',
#        'imp11subdistr_ngothanaprocessNGO_Percent_IUD',
#        'imp11subdistr_ngothanaprocessNGO_Percent_Implant',
#        'imp11subdistr_ngothanaprocessNGO_Percent_PerMale',
#        'imp11subdistr_ngothanaprocessNGO_Percent_PerFemale',
#        'imp11subdistr_ngothanaprocessNGO_CAR', 'geo',
#        'imp11subdistr_thanaprocessPercent_Pill',
#        'imp11subdistr_thanaprocessPercent_Condom',
#        'imp11subdistr_thanaprocessPercent_Injectable',
#        'imp11subdistr_thanaprocessPercent_IUD',
#        'imp11subdistr_thanaprocessPercent_Implant',
#        'imp11subdistr_thanaprocessPercent_PerMale',
#        'imp11subdistr_thanaprocessPercent_PerFemale',
#        'imp11subdistr_thanaprocessCAR',
#        'imp12distr_monthprocessImp12DistrMonthThana_Percent_Pill',
#        'imp12distr_monthprocessImp12DistrMonthThana_Percent_Condom',
#        'imp12distr_monthprocessImp12DistrMonthThana_Percent_Injectable',
#        'imp12distr_monthprocessImp12DistrMonthThana_Percent_IUD',
#        'imp12distr_monthprocessImp12DistrMonthThana_Percent_Implant',
#        'imp12distr_monthprocessImp12DistrMonthThana_Percent_PerMale',
#        'imp12distr_monthprocessImp12DistrMonthThana_Percent_PerFemale',
#        'imp12distr_monthprocessImp12DistrMonthThana_CAR',
#        'Imp12DistrNGOMonthThana_Percent_Pill',
#        'Imp12DistrNGOMonthThana_Percent_Condom',
#        'Imp12DistrNGOMonthThana_Percent_Injectable',
#        'Imp12DistrNGOMonthThana_Percent_IUD',
#        'Imp12DistrNGOMonthThana_Percent_Implant',
#        'Imp12DistrNGOMonthThana_Percent_PerMale',
#        'Imp12DistrNGOMonthThana_Percent_PerFemale',
#        'Imp12DistrNGOMonthThana_CAR', 'distr_GOdistr_GOShukhi',
#        'distr_GOdistr_GOApon', 'distr_GOdistr_GOPill_total',
#        'distr_GOdistr_GOCondom', 'distr_GOdistr_GOInj_vial',
#        'distr_GOdistr_GOInj_siringe', 'distr_GOdistr_GOIUD_normal',
#        'distr_GOdistr_GOIUD_partum', 'distr_GOdistr_GOIUD_total',
#        'distr_GOdistr_GOIUD_remove', 'distr_GOdistr_GOImp_normal',
#        'distr_GOdistr_GOImp_Jadel', 'distr_GOdistr_GOImp_total',
#        'distr_GOdistr_GOimplant_remove', 'distr_GOdistr_GOecp',
#        'distr_GOdistr_GOmisoprostol', 'distr_GOdistr_GOmrm_pack',
#        'distr_GOdistr_GOinj_mgs4', 'distr_GOdistr_GOmnp_saset',
#        'distr_GOdistr_GOifa_number', 'distr_GOdistr_GOsanitary_pad',
#        'distr_GOdistr_GOper_male', 'distr_GOdistr_GOfemalenormal',
#        'distr_GOdistr_GOfemalepn', 'distr_GOdistr_GOfemale_total',
#        'distr_GOdistr_GOPermanent_method'],
#       dtype='object')

# %%
dgfp2014df = pd.concat([dgfp2014[DGFP2014a], 
                        dgfp2014[DGFP2014b].drop('geo', axis=1), 
                        dgfp2014[DGFP2014c].drop('geo', axis=1),
                        dgfp2014[DGFP2014d].drop('geo', axis=1),
                        dgfp2014[DGFP2014e].drop('geo', axis=1)], axis=1)
print(dgfp2014df.shape)
print(dgfp2014df.columns)
# Out:
# (64, 59)
# Index(['imp11subdistr_ngothanaprocessNGO_Percent_Pill',
#        'imp11subdistr_ngothanaprocessNGO_Percent_Condom',
#        'imp11subdistr_ngothanaprocessNGO_Percent_Injectable',
#        'imp11subdistr_ngothanaprocessNGO_Percent_IUD',
#        'imp11subdistr_ngothanaprocessNGO_Percent_Implant',
#        'imp11subdistr_ngothanaprocessNGO_Percent_PerMale',
#        'imp11subdistr_ngothanaprocessNGO_Percent_PerFemale',
#        'imp11subdistr_ngothanaprocessNGO_CAR', 'geo',
#        'imp11subdistr_thanaprocessPercent_Pill',
#        'imp11subdistr_thanaprocessPercent_Condom',
#        'imp11subdistr_thanaprocessPercent_Injectable',
#        'imp11subdistr_thanaprocessPercent_IUD',
#        'imp11subdistr_thanaprocessPercent_Implant',
#        'imp11subdistr_thanaprocessPercent_PerMale',
#        'imp11subdistr_thanaprocessPercent_PerFemale',
#        'imp11subdistr_thanaprocessCAR',
#        'imp12distr_monthprocessImp12DistrMonthThana_Percent_Pill',
#        'imp12distr_monthprocessImp12DistrMonthThana_Percent_Condom',
#        'imp12distr_monthprocessImp12DistrMonthThana_Percent_Injectable',
#        'imp12distr_monthprocessImp12DistrMonthThana_Percent_IUD',
#        'imp12distr_monthprocessImp12DistrMonthThana_Percent_Implant',
#        'imp12distr_monthprocessImp12DistrMonthThana_Percent_PerMale',
#        'imp12distr_monthprocessImp12DistrMonthThana_Percent_PerFemale',
#        'imp12distr_monthprocessImp12DistrMonthThana_CAR',
#        'Imp12DistrNGOMonthThana_Percent_Pill',
#        'Imp12DistrNGOMonthThana_Percent_Condom',
#        'Imp12DistrNGOMonthThana_Percent_Injectable',
#        'Imp12DistrNGOMonthThana_Percent_IUD',
#        'Imp12DistrNGOMonthThana_Percent_Implant',
#        'Imp12DistrNGOMonthThana_Percent_PerMale',
#        'Imp12DistrNGOMonthThana_Percent_PerFemale',
#        'Imp12DistrNGOMonthThana_CAR', 'distr_GOdistr_GOShukhi',
#        'distr_GOdistr_GOApon', 'distr_GOdistr_GOPill_total',
#        'distr_GOdistr_GOCondom', 'distr_GOdistr_GOInj_vial',
#        'distr_GOdistr_GOInj_siringe', 'distr_GOdistr_GOIUD_normal',
#        'distr_GOdistr_GOIUD_partum', 'distr_GOdistr_GOIUD_total',
#        'distr_GOdistr_GOIUD_remove', 'distr_GOdistr_GOImp_normal',
#        'distr_GOdistr_GOImp_Jadel', 'distr_GOdistr_GOImp_total',
#        'distr_GOdistr_GOimplant_remove', 'distr_GOdistr_GOecp',
#        'distr_GOdistr_GOmisoprostol', 'distr_GOdistr_GOmrm_pack',
#        'distr_GOdistr_GOinj_mgs4', 'distr_GOdistr_GOmnp_saset',
#        'distr_GOdistr_GOifa_number', 'distr_GOdistr_GOsanitary_pad',
#        'distr_GOdistr_GOper_male', 'distr_GOdistr_GOfemalenormal',
#        'distr_GOdistr_GOfemalepn', 'distr_GOdistr_GOfemale_total',
#        'distr_GOdistr_GOPermanent_method'],
#       dtype='object')

# %%
dgfp2017df = pd.concat([dgfp2017[DGFP2017a], 
                        dgfp2017[DGFP2017b].drop('geo', axis=1), 
                        dgfp2017[DGFP2017c].drop('geo', axis=1), 
                        dgfp2017[DGFP2017d].drop('geo', axis=1),
                        dgfp2017[DGFP2017e].drop('geo', axis=1)], axis=1)
print(dgfp2017df.shape)
print(dgfp2017df.columns)
# Out:
# (64, 59)
# Index(['imp11subdistr_ngothanaprocessNGO_Percent_Pill',
#        'imp11subdistr_ngothanaprocessNGO_Percent_Condom',
#        'imp11subdistr_ngothanaprocessNGO_Percent_Injectable',
#        'imp11subdistr_ngothanaprocessNGO_Percent_IUD',
#        'imp11subdistr_ngothanaprocessNGO_Percent_Implant',
#        'imp11subdistr_ngothanaprocessNGO_Percent_PerMale',
#        'imp11subdistr_ngothanaprocessNGO_Percent_PerFemale',
#        'imp11subdistr_ngothanaprocessNGO_CAR', 'geo',
#        'imp11subdistr_thanaprocessPercent_Pill',
#        'imp11subdistr_thanaprocessPercent_Condom',
#        'imp11subdistr_thanaprocessPercent_Injectable',
#        'imp11subdistr_thanaprocessPercent_IUD',
#        'imp11subdistr_thanaprocessPercent_Implant',
#        'imp11subdistr_thanaprocessPercent_PerMale',
#        'imp11subdistr_thanaprocessPercent_PerFemale',
#        'imp11subdistr_thanaprocessCAR',
#        'imp12distr_monthprocessImp12DistrMonthThana_Percent_Pill',
#        'imp12distr_monthprocessImp12DistrMonthThana_Percent_Condom',
#        'imp12distr_monthprocessImp12DistrMonthThana_Percent_Injectable',
#        'imp12distr_monthprocessImp12DistrMonthThana_Percent_IUD',
#        'imp12distr_monthprocessImp12DistrMonthThana_Percent_Implant',
#        'imp12distr_monthprocessImp12DistrMonthThana_Percent_PerMale',
#        'imp12distr_monthprocessImp12DistrMonthThana_Percent_PerFemale',
#        'imp12distr_monthprocessImp12DistrMonthThana_CAR',
#        'Imp12DistrNGOMonthThana_Percent_Pill',
#        'Imp12DistrNGOMonthThana_Percent_Condom',
#        'Imp12DistrNGOMonthThana_Percent_Injectable',
#        'Imp12DistrNGOMonthThana_Percent_IUD',
#        'Imp12DistrNGOMonthThana_Percent_Implant',
#        'Imp12DistrNGOMonthThana_Percent_PerMale',
#        'Imp12DistrNGOMonthThana_Percent_PerFemale',
#        'Imp12DistrNGOMonthThana_CAR', 'distr_GOdistr_GOShukhi',
#        'distr_GOdistr_GOApon', 'distr_GOdistr_GOPill_total',
#        'distr_GOdistr_GOCondom', 'distr_GOdistr_GOInj_vial',
#        'distr_GOdistr_GOInj_siringe', 'distr_GOdistr_GOIUD_normal',
#        'distr_GOdistr_GOIUD_partum', 'distr_GOdistr_GOIUD_total',
#        'distr_GOdistr_GOIUD_remove', 'distr_GOdistr_GOImp_normal',
#        'distr_GOdistr_GOImp_Jadel', 'distr_GOdistr_GOImp_total',
#        'distr_GOdistr_GOimplant_remove', 'distr_GOdistr_GOecp',
#        'distr_GOdistr_GOmisoprostol', 'distr_GOdistr_GOmrm_pack',
#        'distr_GOdistr_GOinj_mgs4', 'distr_GOdistr_GOmnp_saset',
#        'distr_GOdistr_GOifa_number', 'distr_GOdistr_GOsanitary_pad',
#        'distr_GOdistr_GOper_male', 'distr_GOdistr_GOfemalenormal',
#        'distr_GOdistr_GOfemalepn', 'distr_GOdistr_GOfemale_total',
#        'distr_GOdistr_GOPermanent_method'],
#       dtype='object')

# %%
dgfp_data = intersect_dfs({'DGFP2011': dgfp2011df, 'DGFP2014': dgfp2014df, 'DGFP2017': dgfp2017df})
dgfp2011df = dgfp_data['DGFP2011']
dgfp2014df = dgfp_data['DGFP2014']
dgfp2017df = dgfp_data['DGFP2017']

# %%
dgfp2011df["geo"] = dgfp2011df["geo"].astype(str)
print(dgfp2011df.shape)
dgfp2011df = dgfp2011df.merge(geo, how='left', left_on="geo", right_on="DistrictGeo")
print(dgfp2011df.shape)
dgfp2011df = dgfp2011df.drop('geo', axis=1)
# Out:
# (64, 59)
# (64, 61)

# %%
dgfp2014df["geo"] = dgfp2014df["geo"].astype(str)
print(dgfp2014df.shape)
dgfp2014df = dgfp2014df.merge(geo, how='left', left_on="geo", right_on="DistrictGeo")
print(dgfp2014df.shape)
dgfp2014df = dgfp2014df.drop('geo', axis=1)
# Out:
# (64, 59)
# (64, 61)

# %%
dgfp2017df["geo"] = dgfp2017df["geo"].astype(str)
print(dgfp2017df.shape)
dgfp2017df = dgfp2017df.merge(geo, how='left', left_on="geo", right_on="DistrictGeo")
print(dgfp2017df.shape)
dgfp2017df = dgfp2017df.drop('geo', axis=1)
# Out:
# (64, 59)
# (64, 61)

# %% [markdown]
# ## Demographics

# %%
woman15_45_2011 = '/Users/edinhamzic/Symphony/wb_bangladesh/Bangladesh/output/bbs/data/data_svrs_zila_2012.csv'
woman15_45_2016 = '/Users/edinhamzic/Symphony/wb_bangladesh/Bangladesh/output/bbs/data/data_svrs_zila_2015.csv'
TOTAL_POP2011 = 144043697
TOTAL_POP2016 = 162951560
data_svrs2011 = pd.read_csv(woman15_45_2011)
data_svrs2011['district'] = data_svrs2011['district'].str.replace(' Zila', '')
data_svrs2016 = pd.read_csv(woman15_45_2016)
data_svrs2011['total_bang_svrs'] = data_svrs2011['total_pop'].sum()
data_svrs2016['total_bang_svrs'] = data_svrs2016['total_pop'].sum()
data_svrs2011['total_bang'] = TOTAL_POP2011
data_svrs2016['total_bang'] = TOTAL_POP2016

data_svrs2011['total_pop_percent'] = data_svrs2011['total_pop']/data_svrs2011['total_pop'].sum()
data_svrs2016['total_pop_percent'] = data_svrs2016['total_pop']/data_svrs2016['total_pop'].sum()
data_svrs2011['total_pop_abs'] = data_svrs2011['total_pop_percent']*TOTAL_POP2011
data_svrs2016['total_pop_abs'] = data_svrs2016['total_pop_percent']*TOTAL_POP2016
data_svrs2011['woman15_45_abs'] = np.round(data_svrs2011['total_pop_abs'] * data_svrs2011['women_15.45y']/data_svrs2011['total_pop'])
data_svrs2016['woman15_45_abs'] = np.round(data_svrs2016['total_pop_abs'] * data_svrs2016['women_15.45y']/data_svrs2016['total_pop'])
display(data_svrs2011[['total_bang_svrs', 'total_pop', 'total_pop_percent', 'women_15.45y',
                      'total_pop_abs', 'woman15_45_abs', 'total_bang']].head())
display(data_svrs2016[['total_bang_svrs', 'total_pop', 'total_pop_percent', 'women_15.45y',
                      'total_pop_abs', 'woman15_45_abs', 'total_bang']].head())
# Out:
#    total_bang_svrs  total_pop  total_pop_percent  women_15.45y  total_pop_abs  \
# 0          1116845      13370           0.011971          3334   1.724379e+06
# 1          1116845      11213           0.010040          2690   1.446183e+06
# 2          1116845      13871           0.012420          3451   1.788995e+06
# 3          1116845      19779           0.017710          4682   2.550972e+06
# 4          1116845      16772           0.015017          3916   2.163148e+06
#
#    woman15_45_abs  total_bang
# 0        429999.0   144043697
# 1        346939.0   144043697
# 2        445088.0   144043697
# 3        603855.0   144043697
# 4        505061.0   144043697
#    total_bang_svrs  total_pop  total_pop_percent  women_15.45y  total_pop_abs  \
# 0           939530       9274           0.009871          2330   1.608477e+06
# 1           939530       3629           0.003863           895   6.294117e+05
# 2           939530       7773           0.008273          1981   1.348145e+06
# 3           939530      45404           0.048326         11903   7.874844e+06
# 4           939530      15999           0.017029          3833   2.774858e+06
#
#    woman15_45_abs  total_bang
# 0        404114.0   162951560
# 1        155228.0   162951560
# 2        343584.0   162951560
# 3       2064450.0   162951560
# 4        664793.0   162951560

# %%
geo_svrs_2011s = match_districts(ref_df=geo, ref_match='DistrictName', input_df=data_svrs2011, input_match='district')
geo_svrs_2016s = match_districts(ref_df=geo, ref_match='DistrictName', input_df=data_svrs2016, input_match='district')
print(data_svrs2011.shape)
print(data_svrs2016.shape)
data_svrs2011 = data_svrs2011.merge(geo_svrs_2011s, how='left', left_on='district', right_on='Geo')
data_svrs2016 = data_svrs2016.merge(geo_svrs_2016s, how='left', left_on='district', right_on='Geo')
data_svrs2011 = data_svrs2011.drop(['FuzzRatio','Geo', 'district', 'year'], axis=1)
data_svrs2016 = data_svrs2016.drop(['FuzzRatio','Geo', 'district', 'year'], axis=1)
print(data_svrs2011.shape)
print(data_svrs2016.shape)
# Out:
# (64, 47)
# (64, 48)
# (64, 47)
# (64, 48)

# %% [markdown]
# ## Recalculating indicators

# %%
print(sorted(data_svrs2011['DistrictName']) == sorted(dgfp2011df['DistrictName']))
print(sorted(data_svrs2016['DistrictName']) == sorted(dgfp2016df['DistrictName']))
# Out:
# True
# True

# %%
dgfp2011df = dgfp2011df.sort_values("DistrictName")
data_svrs2011 = data_svrs2011.sort_values("DistrictName")
dgfp2011df, variables = distrGO_rates(input_df=dgfp2011df, pattern="distr_GO", 
              denominator_female=data_svrs2011['woman15_45_abs'], 
              denominator_male=data_svrs2011['total_bang'])
display(dgfp2011df[variables].head())
# Out:
#     distr_GOdistr_GOShukhi  distr_GOdistr_GOCondom  \
# 2                3657.7126               4532.7463
# 63                655.7759                886.7231
# 11               1302.0635                771.2989
# 61               2935.3205               2969.4840
# 51               2403.5347               3192.5034
#
#     distr_GOdistr_GOPermanent_method  distr_GOdistr_GOecp  \
# 2                             7.6412               2.7163
# 63                            1.9211               1.2523
# 11                            5.8866               0.8026
# 61                            9.1668               2.1889
# 51                            5.3922               2.6037
#
#     distr_GOdistr_GOPill_total  distr_GOdistr_GOIUD_remove  \
# 2                    3657.7126                         0.0
# 63                    655.7759                         0.0
# 11                   1302.0635                         0.0
# 61                   2935.3205                         0.0
# 51                   2403.5347                         0.0
#
#     distr_GOdistr_GOmnp_saset  distr_GOdistr_GOImp_total  \
# 2                         0.0                     8.4006
# 63                        0.0                     1.7435
# 11                        0.0                     9.5650
# 61                        0.0                     7.5193
# 51                        0.0                     7.4587
#
#     distr_GOdistr_GOIUD_partum  distr_GOdistr_GOApon  ...  \
# 2                          0.0                   0.0  ...
# 63                         0.0                   0.0  ...
# 11                         0.0                   0.0  ...
# 61                         0.0                   0.0  ...
# 51                         0.0                   0.0  ...
#
#     distr_GOdistr_GOper_male  distr_GOdistr_GOfemalepn  \
# 2                     0.0141                       0.0
# 63                    0.0041                       0.0
# 11                    0.0172                       0.0
# 61                    0.0194                       0.0
# 51                    0.0130                       0.0
#
#     distr_GOdistr_GOfemalenormal  distr_GOdistr_GOInj_siringe  \
# 2                         3.0646                          0.0
# 63                        0.5443                          0.0
# 11                        0.4057                          0.0
# 61                        3.6730                          0.0
# 51                        0.7171                          0.0
#
#     distr_GOdistr_GOImp_normal  distr_GOdistr_GOfemale_total  \
# 2                       8.4006                        3.0646
# 63                      1.7435                        0.5443
# 11                      9.5650                        0.4057
# 61                      7.5193                        3.6730
# 51                      7.4587                        0.7171
#
#     distr_GOdistr_GOmrm_pack  distr_GOdistr_GOImp_Jadel  \
# 2                        0.0                        0.0
# 63                       0.0                        0.0
# 11                       0.0                        0.0
# 61                       0.0                        0.0
# 51                       0.0                        0.0
#
#     distr_GOdistr_GOIUD_normal  distr_GOdistr_GOsanitary_pad
# 2                       8.3871                           0.0
# 63                      2.6429                           0.0
# 11                      4.3501                           0.0
# 61                     12.7257                           0.0
# 51                      6.8440                           0.0
#
# [5 rows x 26 columns]

# %%
dgfp2016df = dgfp2016df.sort_values(by ="DistrictName")
data_svrs2016 = data_svrs2016.sort_values("DistrictName")
dgfp2016df, variables = distrGO_rates(input_df=dgfp2016df, pattern="distr_GO", 
              denominator_female=data_svrs2016['woman15_45_abs'], 
              denominator_male=data_svrs2016['total_bang'])
display(dgfp2016df[variables].head())
# Out:
#     distr_GOdistr_GOShukhi  distr_GOdistr_GOCondom  \
# 2                4134.4882               6076.5373
# 63                653.2773                872.6982
# 11               1175.8020                745.9456
# 61                602.7928                709.7482
# 51               2015.3560               3057.8958
#
#     distr_GOdistr_GOPermanent_method  distr_GOdistr_GOecp  \
# 2                             4.4763                  0.0
# 63                            1.5088                  0.0
# 11                            2.7186                  0.0
# 61                            1.1744                  0.0
# 51                            3.5129                  0.0
#
#     distr_GOdistr_GOPill_total  distr_GOdistr_GOIUD_remove  \
# 2                    4209.6460                      1.5513
# 63                    671.4688                      0.3837
# 11                   1196.4034                      0.3347
# 61                    611.6951                      0.4192
# 51                   2050.1934                      0.2410
#
#     distr_GOdistr_GOmnp_saset  distr_GOdistr_GOImp_total  \
# 2                      0.0000                    10.1809
# 63                     0.0000                     2.8958
# 11                     0.0000                     8.5741
# 61                     0.0000                     2.8073
# 51                  1264.5546                    13.3310
#
#     distr_GOdistr_GOIUD_partum  distr_GOdistr_GOApon  ...  \
# 2                       0.0728               75.1577  ...
# 63                      0.0518               18.1915  ...
# 11                      0.0000               20.6014  ...
# 61                      0.0299                8.9024  ...
# 51                      0.9263               34.8374  ...
#
#     distr_GOdistr_GOper_male  distr_GOdistr_GOfemalepn  \
# 2                     0.0045                    0.6258
# 63                    0.0030                    0.0311
# 11                    0.0057                    0.5082
# 61                    0.0080                    0.2462
# 51                    0.0088                    0.3184
#
#     distr_GOdistr_GOfemalenormal  distr_GOdistr_GOInj_siringe  \
# 2                         1.7114                     421.9230
# 63                        0.1996                     108.9366
# 11                        0.3266                     228.1260
# 61                        0.3437                     116.0210
# 51                        0.0398                     977.2401
#
#     distr_GOdistr_GOImp_normal  distr_GOdistr_GOfemale_total  \
# 2                       9.6017                        2.3371
# 63                      2.8595                        0.2255
# 11                      8.1495                        0.8348
# 61                      2.6675                        0.5894
# 51                     13.0502                        0.3316
#
#     distr_GOdistr_GOmrm_pack  distr_GOdistr_GOImp_Jadel  \
# 2                     0.1048                     0.5792
# 63                    0.0985                     0.0363
# 11                    0.1102                     0.4245
# 61                    0.0103                     0.1399
# 51                   95.9963                     0.2808
#
#     distr_GOdistr_GOIUD_normal  distr_GOdistr_GOsanitary_pad
# 2                       9.3980                        1.2632
# 63                      3.1421                        0.0674
# 11                      4.0778                        0.4123
# 61                      1.5042                        0.0697
# 51                      8.1887                        0.8268
#
# [5 rows x 26 columns]

# %%
dgfp2011df.head()
# Out:
#     imp12distr_monthprocessImp12DistrMonthThana_Percent_PerMale  \
# 2                                                5.53
# 63                                               4.76
# 11                                               7.91
# 61                                               2.46
# 51                                               2.71
#
#     imp12distr_monthprocessImp12DistrMonthThana_Percent_Injectable  \
# 2                                               19.05
# 63                                              24.25
# 11                                              28.08
# 61                                              21.85
# 51                                              42.80
#
#     distr_GOdistr_GOShukhi  distr_GOdistr_GOCondom  \
# 2                3657.7126               4532.7463
# 63                655.7759                886.7231
# 11               1302.0635                771.2989
# 61               2935.3205               2969.4840
# 51               2403.5347               3192.5034
#
#     distr_GOdistr_GOPermanent_method  distr_GOdistr_GOecp  \
# 2                             7.6412               2.7163
# 63                            1.9211               1.2523
# 11                            5.8866               0.8026
# 61                            9.1668               2.1889
# 51                            5.3922               2.6037
#
#     distr_GOdistr_GOPill_total  imp11subdistr_thanaprocessPercent_IUD  \
# 2                    3657.7126                                   5.41
# 63                    655.7759                                   7.68
# 11                   1302.0635                                   3.64
# 61                   2935.3205                                   4.35
# 51                   2403.5347                                   2.52
#
#     imp11subdistr_ngothanaprocessNGO_Percent_PerMale  \
# 2                                               3.81
# 63                                               NaN
# 11                                              3.19
# 61                                              0.55
# 51                                              1.48
#
#     imp11subdistr_thanaprocessPercent_PerFemale  ...  \
# 2                                          7.76  ...
# 63                                         6.65  ...
# 11                                         6.72  ...
# 61                                         8.47  ...
# 51                                         4.01  ...
#
#     imp12distr_monthprocessImp12DistrMonthThana_Percent_PerFemale  \
# 2                                                7.76
# 63                                               6.65
# 11                                               6.72
# 61                                               8.47
# 51                                               4.01
#
#     distr_GOdistr_GOImp_Jadel  \
# 2                         0.0
# 63                        0.0
# 11                        0.0
# 61                        0.0
# 51                        0.0
#
#     imp11subdistr_ngothanaprocessNGO_Percent_Implant  \
# 2                                               2.73
# 63                                               NaN
# 11                                              6.61
# 61                                              4.01
# 51                                              1.45
#
#     imp11subdistr_thanaprocessPercent_PerMale  distr_GOdistr_GOIUD_normal  \
# 2                                        5.53                      8.3871
# 63                                       4.76                      2.6429
# 11                                       7.91                      4.3501
# 61                                       2.46                     12.7257
# 51                                       2.71                      6.8440
#
#     Imp12DistrNGOMonthThana_CAR  \
# 2                         80.02
# 63                          NaN
# 11                        69.28
# 61                        68.72
# 51                        73.41
#
#     imp12distr_monthprocessImp12DistrMonthThana_CAR  \
# 2                                             80.83
# 63                                            77.01
# 11                                            75.47
# 61                                            72.62
# 51                                            72.18
#
#     distr_GOdistr_GOsanitary_pad  DistrictGeo  DistrictName
# 2                            0.0         4001     Bagerhat
# 63                           0.0         2003    Bandarban
# 11                           0.0         1004      Barguna
# 61                           0.0         1006      Barisal
# 51                           0.0         1009        Bhola
#
# [5 rows x 60 columns]

# %%
dgfp2016df.head()
# Out:
#     imp12distr_monthprocessImp12DistrMonthThana_Percent_PerMale  \
# 2                                                5.33
# 63                                               9.05
# 11                                               9.46
# 61                                               2.98
# 51                                               3.21
#
#     imp12distr_monthprocessImp12DistrMonthThana_Percent_Injectable  \
# 2                                               18.25
# 63                                              22.16
# 11                                              28.00
# 61                                              21.32
# 51                                              40.52
#
#     distr_GOdistr_GOShukhi  distr_GOdistr_GOCondom  \
# 2                4134.4882               6076.5373
# 63                653.2773                872.6982
# 11               1175.8020                745.9456
# 61                602.7928                709.7482
# 51               2015.3560               3057.8958
#
#     distr_GOdistr_GOPermanent_method  distr_GOdistr_GOecp  \
# 2                             4.4763                  0.0
# 63                            1.5088                  0.0
# 11                            2.7186                  0.0
# 61                            1.1744                  0.0
# 51                            3.5129                  0.0
#
#     distr_GOdistr_GOPill_total  imp11subdistr_thanaprocessPercent_IUD  \
# 2                    4209.6460                                   4.34
# 63                    671.4688                                   8.22
# 11                   1196.4034                                   3.21
# 61                    611.6951                                   4.07
# 51                   2050.1934                                   3.15
#
#     imp11subdistr_ngothanaprocessNGO_Percent_PerMale  \
# 2                                               4.69
# 63                                               NaN
# 11                                              3.20
# 61                                              0.97
# 51                                              2.31
#
#     imp11subdistr_thanaprocessPercent_PerFemale  ...  \
# 2                                          8.12  ...
# 63                                         6.30  ...
# 11                                         5.74  ...
# 61                                         8.42  ...
# 51                                         3.23  ...
#
#     imp12distr_monthprocessImp12DistrMonthThana_Percent_PerFemale  \
# 2                                                8.12
# 63                                               6.30
# 11                                               5.74
# 61                                               8.42
# 51                                               3.23
#
#     distr_GOdistr_GOImp_Jadel  \
# 2                      0.5792
# 63                     0.0363
# 11                     0.4245
# 61                     0.1399
# 51                     0.2808
#
#     imp11subdistr_ngothanaprocessNGO_Percent_Implant  \
# 2                                               4.35
# 63                                               NaN
# 11                                              5.77
# 61                                              6.84
# 51                                              4.96
#
#     imp11subdistr_thanaprocessPercent_PerMale  distr_GOdistr_GOIUD_normal  \
# 2                                        5.33                      9.3980
# 63                                       9.05                      3.1421
# 11                                       9.46                      4.0778
# 61                                       2.98                      1.5042
# 51                                       3.21                      8.1887
#
#     Imp12DistrNGOMonthThana_CAR  \
# 2                         83.61
# 63                          NaN
# 11                        84.62
# 61                        76.43
# 51                        80.44
#
#     imp12distr_monthprocessImp12DistrMonthThana_CAR  \
# 2                                             81.39
# 63                                            77.95
# 11                                            76.12
# 61                                            75.77
# 51                                            79.61
#
#     distr_GOdistr_GOsanitary_pad  DistrictGeo  DistrictName
# 2                         1.2632         4001     Bagerhat
# 63                        0.0674         2003    Bandarban
# 11                        0.4123         1004      Barguna
# 61                        0.0697         1006      Barisal
# 51                        0.8268         1009        Bhola
#
# [5 rows x 60 columns]

# %% [markdown]
# ## DHS Data

# %%
DHS2011 = '/Users/edinhamzic/Symphony/wb_bangladesh/Bangladesh/output/dhs/data/data_dhs_2011_clean.csv' 
DHS2014 = '/Users/edinhamzic/Symphony/wb_bangladesh/Bangladesh/output/dhs/data/data_dhs_2014_clean.csv'

# %%
dhs_2011 = pd.read_csv(DHS2011)
display(dhs_2011.head())
dhs_2014 = pd.read_csv(DHS2014)
display(dhs_2014.head())
# Out:
#     district  prop_current_contraceptive  prop_unmet_need_family_planing  \
# 0   Bagerhat                       65.52                            7.89
# 1  Bandarban                       45.45                           27.27
# 2    Barguna                       72.36                           11.14
# 3    Barisal                       64.33                           13.31
# 4      Bhola                       68.40                           10.81
#
#    prop_antenatal_coverage  prop_antenatal_care4.  \
# 0                    29.91                  26.56
# 1                    30.00                   0.00
# 2                    37.91                  20.97
# 3                    35.21                  26.53
# 4                    25.64                  29.51
#
#    prop_institutional_delivery  prop_attendant_delivery  prop_caesarean  \
# 0                        30.66                    35.58           15.74
# 1                         0.00                     0.00            0.00
# 2                        10.56                    16.30            5.21
# 3                        21.53                    26.92           13.06
# 4                         9.64                    11.89            3.75
#
#    sex_ratio  dependency_ratio  ...  prop_hypertensive  prop_pop_rural  \
# 0      93.31             74.37  ...               8.92           11.48
# 1      84.44            107.50  ...               0.00            0.00
# 2     105.44             70.73  ...              19.23            6.48
# 3      89.02             75.53  ...              19.85            8.22
# 4      94.76             80.16  ...              18.37            7.40
#
#    prop_pop_women  prop_pop_rural_women  prop_women_15.45y_overwomen  \
# 0           44.85                  5.67                        46.74
# 1          127.03                  0.00                        35.56
# 2           25.33                  2.98                        49.26
# 3           24.48                  4.37                        48.17
# 4           26.74                  3.86                        45.49
#
#    prop_married_women_15.45y  prop_married_..15y  prop_female_head  \
# 0                      80.33               73.46             11.29
# 1                      75.00               69.05             11.29
# 2                      88.00               77.71              2.97
# 3                      78.47               71.65              5.10
# 4                      80.19               74.76              5.65
#
#    prop_registered_under5  year
# 0                   32.84  2011
# 1                   31.25  2011
# 2                   41.40  2011
# 3                   38.53  2011
# 4                   21.19  2011
#
# [5 rows x 22 columns]
#     district  prop_current_contraceptive  prop_unmet_need_family_planing  \
# 0   Bagerhat                       67.82                           11.00
# 1  Bandarban                       63.64                           13.64
# 2    Barguna                       73.30                            8.22
# 3    Barisal                       64.26                           10.08
# 4      Bhola                       67.28                           10.01
#
#    prop_antenatal_coverage  prop_antenatal_care4.  \
# 0                    48.69                  25.13
# 1                   100.00                  75.00
# 2                    37.97                  47.46
# 3                    64.01                  32.39
# 4                    29.44                  15.62
#
#    prop_institutional_delivery  prop_attendant_delivery  prop_caesarean  \
# 0                        26.49                    36.95           22.38
# 1                        75.00                    75.00           50.00
# 2                        27.54                    34.43           22.90
# 3                        46.33                    56.91           31.22
# 4                        11.27                    18.42            4.01
#
#    sex_ratio  dependency_ratio  prop_pop_rural  prop_pop_women  \
# 0      94.78             56.82           14.38           39.86
# 1      84.93             45.16            0.00           77.52
# 2      87.82             68.24            9.48           28.64
# 3      94.74             59.68           28.48           30.97
# 4     101.71             69.35            9.99           26.58
#
#    prop_pop_rural_women  prop_women_15.45y_overwomen  \
# 0                  7.53                        48.65
# 1                  0.00                        54.79
# 2                  5.13                        44.84
# 3                 13.91                        51.10
# 4                  5.06                        47.39
#
#    prop_married_women_15.45y  prop_married_..15y  prop_female_head  \
# 0                      74.84               72.88              4.17
# 1                      57.50               63.46             25.49
# 2                      86.50               77.54              8.06
# 3                      77.42               69.16              6.99
# 4                      82.49               75.20              3.53
#
#    prop_registered_under5  year
# 0                   37.56  2014
# 1                   40.00  2014
# 2                   25.10  2014
# 3                   23.40  2014
# 4                   17.64  2014

# %%
print(geo.shape)
print(dhs_2011.shape)
geo_dhs_2011 = match_districts(ref_df=geo, ref_match='DistrictName', input_df=dhs_2011, input_match='district')
print(geo_dhs_2011.shape)
print("#"*100)
print(geo.shape)
print(dhs_2014.shape)
geo_dhs_2014 = match_districts(ref_df=geo, ref_match='DistrictName', input_df=dhs_2014, input_match='district')
print(geo_dhs_2014.shape)
# Out:
# (64, 2)
# (64, 22)
# (64, 4)
# ####################################################################################################
# (64, 2)
# (64, 19)
# (64, 4)

# %%
print(dhs_2011.shape)
print(dhs_2014.shape)
dhs_2011 = dhs_2011.merge(geo_dhs_2011, how='left', left_on='district', right_on='Geo')
dhs_2014 = dhs_2014.merge(geo_dhs_2014, how='left', left_on='district', right_on='Geo')
dhs_2011 = dhs_2011.drop(['FuzzRatio','Geo', 'district', 'year'], axis=1)
dhs_2014 = dhs_2014.drop(['FuzzRatio','Geo', 'district', 'year'], axis=1)
print(dhs_2011.shape)
print(dhs_2014.shape)
# Out:
# (64, 22)
# (64, 19)
# (64, 22)
# (64, 19)

# %% [markdown]
# ### Renaming DHS data sets from 2014 to 2016

# %%
dhs_2011, dhs_2016 = intersect_dfs(input_df1= dhs_2011, input_df2= dhs_2014)

# %%
dhs_2011.equals(dhs_2016)
# Out:
# False

# %% [markdown]
# ## Combine data

# %%
for ces, svrs, dhis, dgfp, dhs in zip(sorted(ces_2011['DistrictName']), sorted(svrs_2011['DistrictName']), 
                                 sorted(dhis_2011['DistrictName']), sorted(dgfp2011df['DistrictName']),
                                 sorted(dhs_2011['DistrictName'])):
    print("\n -------------------")
    print(ces, svrs, dhis, dgfp, dhs)
    print(f"CES vs SVRS: {ces == svrs}")
    print(f"CES vs DHIS: {ces == dhis}")
    print(f"CES vs DGFP: {ces == dgfp}")
    print(f"CES vs DHS: {ces == dhs}")
    print(f"SVRS vs DHIS: {svrs == dhis}")
    print(f"SVRS vs DGFP: {svrs == dgfp}")
    print(f"SVRS vs DHS: {svrs == dhs}")
    print(f"DHIS vs DGFP: {dhis == dgfp}")
    print(f"DHIS vs DHS: {dhis == dhs}")
    print(f"DHS vs DGFP: {dhs == dgfp}")
# Out:
#  -------------------
# Bagerhat  Bagerhat  Bagerhat  Bagerhat  Bagerhat
# CES vs SVRS: True
# CES vs DHIS: True
# CES vs DGFP: True
# CES vs DHS: True
# SVRS vs DHIS: True
# SVRS vs DGFP: True
# SVRS vs DHS: True
# DHIS vs DGFP: True
# DHIS vs DHS: True
# DHS vs DGFP: True
#
#  -------------------
# Bandarban  Bandarban  Bandarban  Bandarban  Bandarban
# CES vs SVRS: True
# CES vs DHIS: True
# CES vs DGFP: True
# CES vs DHS: True
# SVRS vs DHIS: True
# SVRS vs DGFP: True
# SVRS vs DHS: True
# DHIS vs DGFP: True
# DHIS vs DHS: True
# DHS vs DGFP: True
#
#  -------------------
# Barguna  Barguna  Barguna  Barguna  Barguna
# CES vs SVRS: True
# CES vs DHIS: True
# CES vs DGFP: True
# CES vs DHS: True
# SVRS vs DHIS: True
# SVRS vs DGFP: True
# SVRS vs DHS: True
# DHIS vs DGFP: True
# DHIS vs DHS: True
# DHS vs DGFP: True
#
#  -------------------
# Barisal  Barisal  Barisal  Barisal  Barisal
# CES vs SVRS: True
# CES vs DHIS: True
# CES vs DGFP: True
# CES vs DHS: True
# SVRS vs DHIS: True
# SVRS vs DGFP: True
# SVRS vs DHS: True
# DHIS vs DGFP: True
# DHIS vs DHS: True
# DHS vs DGFP: True
#
#  -------------------
# Bhola  Bhola  Bhola  Bhola  Bhola
# CES vs SVRS: True
# CES vs DHIS: True
# CES vs DGFP: True
# CES vs DHS: True
# SVRS vs DHIS: True
# SVRS vs DGFP: True
# SVRS vs DHS: True
# DHIS vs DGFP: True
# DHIS vs DHS: True
# DHS vs DGFP: True
#
#  -------------------
# Bogra  Bogra  Bogra  Bogra  Bogra
# CES vs SVRS: True
# CES vs DHIS: True
# CES vs DGFP: True
# CES vs DHS: True
# SVRS vs DHIS: True
# SVRS vs DGFP: True
# SVRS vs DHS: True
# DHIS vs DGFP: True
# DHIS vs DHS: True
# DHS vs DGFP: True
#
#  -------------------
# Brahmanbaria  Brahmanbaria  Brahmanbaria  Brahmanbaria  Brahmanbaria
# CES vs SVRS: True
# CES vs DHIS: True
# CES vs DGFP: True
# CES vs DHS: True
# SVRS vs DHIS: True
# SVRS vs DGFP: True
# SVRS vs DHS: True
# DHIS vs DGFP: True
# DHIS vs DHS: True
# DHS vs DGFP: True
#
#  -------------------
# Chandpur  Chandpur  Chandpur  Chandpur  Chandpur
# CES vs SVRS: True
# CES vs DHIS: True
# CES vs DGFP: True
# CES vs DHS: True
# SVRS vs DHIS: True
# SVRS vs DGFP: True
# SVRS vs DHS: True
# DHIS vs DGFP: True
# DHIS vs DHS: True
# DHS vs DGFP: True
#
#  -------------------
# Chapai Nawabganj  Chapai Nawabganj  Chapai Nawabganj  Chapai Nawabganj  Chapai Nawabganj
# CES vs SVRS: True
# CES vs DHIS: True
# CES vs DGFP: True
# CES vs DHS: True
# SVRS vs DHIS: True
# SVRS vs DGFP: True
# SVRS vs DHS: True
# DHIS vs DGFP: True
# DHIS vs DHS: True
# DHS vs DGFP: True
#
#  -------------------
# Chittagong  Chittagong  Chittagong  Chittagong  Chittagong
# CES vs SVRS: True
# CES vs DHIS: True
# CES vs DGFP: True
# CES vs DHS: True
# SVRS vs DHIS: True
# SVRS vs DGFP: True
# SVRS vs DHS: True
# DHIS vs DGFP: True
# DHIS vs DHS: True
# DHS vs DGFP: True
#
#  -------------------
# Chuadanga  Chuadanga  Chuadanga  Chuadanga  Chuadanga
# CES vs SVRS: True
# CES vs DHIS: True
# CES vs DGFP: True
# CES vs DHS: True
# SVRS vs DHIS: True
# SVRS vs DGFP: True
# SVRS vs DHS: True
# DHIS vs DGFP: True
# DHIS vs DHS: True
# DHS vs DGFP: True
#
#  -------------------
# Comilla  Comilla  Comilla  Comilla  Comilla
# CES vs SVRS: True
# CES vs DHIS: True
# CES vs DGFP: True
# CES vs DHS: True
# SVRS vs DHIS: True
# SVRS vs DGFP: True
# SVRS vs DHS: True
# DHIS vs DGFP: True
# DHIS vs DHS: True
# DHS vs DGFP: True
#
#  -------------------
# Cox's Bazar  Cox's Bazar  Cox's Bazar  Cox's Bazar  Cox's Bazar
# CES vs SVRS: True
# CES vs DHIS: True
# CES vs DGFP: True
# CES vs DHS: True
# SVRS vs DHIS: True
# SVRS vs DGFP: True
# SVRS vs DHS: True
# DHIS vs DGFP: True
# DHIS vs DHS: True
# DHS vs DGFP: True
#
#  -------------------
# Dhaka  Dhaka  Dhaka  Dhaka  Dhaka
# CES vs SVRS: True
# CES vs DHIS: True
# CES vs DGFP: True
# CES vs DHS: True
# SVRS vs DHIS: True
# SVRS vs DGFP: True
# SVRS vs DHS: True
# DHIS vs DGFP: True
# DHIS vs DHS: True
# DHS vs DGFP: True
#
#  -------------------
# Dinajpur  Dinajpur  Dinajpur  Dinajpur  Dinajpur
# CES vs SVRS: True
# CES vs DHIS: True
# CES vs DGFP: True
# CES vs DHS: True
# SVRS vs DHIS: True
# SVRS vs DGFP: True
# SVRS vs DHS: True
# DHIS vs DGFP: True
# DHIS vs DHS: True
# DHS vs DGFP: True
#
#  -------------------
# Faridpur  Faridpur  Faridpur  Faridpur  Faridpur
# CES vs SVRS: True
# CES vs DHIS: True
# CES vs DGFP: True
# CES vs DHS: True
# SVRS vs DHIS: True
# SVRS vs DGFP: True
# SVRS vs DHS: True
# DHIS vs DGFP: True
# DHIS vs DHS: True
# DHS vs DGFP: True
#
#  -------------------
# Feni  Feni  Feni  Feni  Feni
# CES vs SVRS: True
# CES vs DHIS: True
# CES vs DGFP: True
# CES vs DHS: True
# SVRS vs DHIS: True
# SVRS vs DGFP: True
# SVRS vs DHS: True
# DHIS vs DGFP: True
# DHIS vs DHS: True
# DHS vs DGFP: True
#
#  -------------------
# Gaibandha  Gaibandha  Gaibandha  Gaibandha  Gaibandha
# CES vs SVRS: True
# CES vs DHIS: True
# CES vs DGFP: True
# CES vs DHS: True
# SVRS vs DHIS: True
# SVRS vs DGFP: True
# SVRS vs DHS: True
# DHIS vs DGFP: True
# DHIS vs DHS: True
# DHS vs DGFP: True
#
#  -------------------
# Gazipur  Gazipur  Gazipur  Gazipur  Gazipur
# CES vs SVRS: True
# CES vs DHIS: True
# CES vs DGFP: True
# CES vs DHS: True
# SVRS vs DHIS: True
# SVRS vs DGFP: True
# SVRS vs DHS: True
# DHIS vs DGFP: True
# DHIS vs DHS: True
# DHS vs DGFP: True
#
#  -------------------
# Gopalganj  Gopalganj  Gopalganj  Gopalganj  Gopalganj
# CES vs SVRS: True
# CES vs DHIS: True
# CES vs DGFP: True
# CES vs DHS: True
# SVRS vs DHIS: True
# SVRS vs DGFP: True
# SVRS vs DHS: True
# DHIS vs DGFP: True
# DHIS vs DHS: True
# DHS vs DGFP: True
#
#  -------------------
# Habiganj  Habiganj  Habiganj  Habiganj  Habiganj
# CES vs SVRS: True
# CES vs DHIS: True
# CES vs DGFP: True
# CES vs DHS: True
# SVRS vs DHIS: True
# SVRS vs DGFP: True
# SVRS vs DHS: True
# DHIS vs DGFP: True
# DHIS vs DHS: True
# DHS vs DGFP: True
#
#  -------------------
# Jamalpur  Jamalpur  Jamalpur  Jamalpur  Jamalpur
# CES vs SVRS: True
# CES vs DHIS: True
# CES vs DGFP: True
# CES vs DHS: True
# SVRS vs DHIS: True
# SVRS vs DGFP: True
# SVRS vs DHS: True
# DHIS vs DGFP: True
# DHIS vs DHS: True
# DHS vs DGFP: True
#
#  -------------------
# Jessore  Jessore  Jessore  Jessore  Jessore
# CES vs SVRS: True
# CES vs DHIS: True
# CES vs DGFP: True
# CES vs DHS: True
# SVRS vs DHIS: True
# SVRS vs DGFP: True
# SVRS vs DHS: True
# DHIS vs DGFP: True
# DHIS vs DHS: True
# DHS vs DGFP: True
#
#  -------------------
# Jhalokati  Jhalokati  Jhalokati  Jhalokati  Jhalokati
# CES vs SVRS: True
# CES vs DHIS: True
# CES vs DGFP: True
# CES vs DHS: True
# SVRS vs DHIS: True
# SVRS vs DGFP: True
# SVRS vs DHS: True
# DHIS vs DGFP: True
# DHIS vs DHS: True
# DHS vs DGFP: True
#
#  -------------------
# Jhenaidah  Jhenaidah  Jhenaidah  Jhenaidah  Jhenaidah
# CES vs SVRS: True
# CES vs DHIS: True
# CES vs DGFP: True
# CES vs DHS: True
# SVRS vs DHIS: True
# SVRS vs DGFP: True
# SVRS vs DHS: True
# DHIS vs DGFP: True
# DHIS vs DHS: True
# DHS vs DGFP: True
#
#  -------------------
# Joypurhat  Joypurhat  Joypurhat  Joypurhat  Joypurhat
# CES vs SVRS: True
# CES vs DHIS: True
# CES vs DGFP: True
# CES vs DHS: True
# SVRS vs DHIS: True
# SVRS vs DGFP: True
# SVRS vs DHS: True
# DHIS vs DGFP: True
# DHIS vs DHS: True
# DHS vs DGFP: True
#
#  -------------------
# Khagrachhari  Khagrachhari  Khagrachhari  Khagrachhari  Khagrachhari
# CES vs SVRS: True
# CES vs DHIS: True
# CES vs DGFP: True
# CES vs DHS: True
# SVRS vs DHIS: True
# SVRS vs DGFP: True
# SVRS vs DHS: True
# DHIS vs DGFP: True
# DHIS vs DHS: True
# DHS vs DGFP: True
#
#  -------------------
# Khulna  Khulna  Khulna  Khulna  Khulna
# CES vs SVRS: True
# CES vs DHIS: True
# CES vs DGFP: True
# CES vs DHS: True
# SVRS vs DHIS: True
# SVRS vs DGFP: True
# SVRS vs DHS: True
# DHIS vs DGFP: True
# DHIS vs DHS: True
# DHS vs DGFP: True
#
#  -------------------
# Kishoreganj  Kishoreganj  Kishoreganj  Kishoreganj  Kishoreganj
# CES vs SVRS: True
# CES vs DHIS: True
# CES vs DGFP: True
# CES vs DHS: True
# SVRS vs DHIS: True
# SVRS vs DGFP: True
# SVRS vs DHS: True
# DHIS vs DGFP: True
# DHIS vs DHS: True
# DHS vs DGFP: True
#
#  -------------------
# Kurigram  Kurigram  Kurigram  Kurigram  Kurigram
# CES vs SVRS: True
# CES vs DHIS: True
# CES vs DGFP: True
# CES vs DHS: True
# SVRS vs DHIS: True
# SVRS vs DGFP: True
# SVRS vs DHS: True
# DHIS vs DGFP: True
# DHIS vs DHS: True
# DHS vs DGFP: True
#
#  -------------------
# Kushtia  Kushtia  Kushtia  Kushtia  Kushtia
# CES vs SVRS: True
# CES vs DHIS: True
# CES vs DGFP: True
# CES vs DHS: True
# SVRS vs DHIS: True
# SVRS vs DGFP: True
# SVRS vs DHS: True
# DHIS vs DGFP: True
# DHIS vs DHS: True
# DHS vs DGFP: True
#
#  -------------------
# Lakshmipur  Lakshmipur  Lakshmipur  Lakshmipur  Lakshmipur
# CES vs SVRS: True
# CES vs DHIS: True
# CES vs DGFP: True
# CES vs DHS: True
# SVRS vs DHIS: True
# SVRS vs DGFP: True
# SVRS vs DHS: True
# DHIS vs DGFP: True
# DHIS vs DHS: True
# DHS vs DGFP: True
#
#  -------------------
# Lalmonirhat  Lalmonirhat  Lalmonirhat  Lalmonirhat  Lalmonirhat
# CES vs SVRS: True
# CES vs DHIS: True
# CES vs DGFP: True
# CES vs DHS: True
# SVRS vs DHIS: True
# SVRS vs DGFP: True
# SVRS vs DHS: True
# DHIS vs DGFP: True
# DHIS vs DHS: True
# DHS vs DGFP: True
#
#  -------------------
# Madaripur  Madaripur  Madaripur  Madaripur  Madaripur
# CES vs SVRS: True
# CES vs DHIS: True
# CES vs DGFP: True
# CES vs DHS: True
# SVRS vs DHIS: True
# SVRS vs DGFP: True
# SVRS vs DHS: True
# DHIS vs DGFP: True
# DHIS vs DHS: True
# DHS vs DGFP: True
#
#  -------------------
# Magura  Magura  Magura  Magura  Magura
# CES vs SVRS: True
# CES vs DHIS: True
# CES vs DGFP: True
# CES vs DHS: True
# SVRS vs DHIS: True
# SVRS vs DGFP: True
# SVRS vs DHS: True
# DHIS vs DGFP: True
# DHIS vs DHS: True
# DHS vs DGFP: True
#
#  -------------------
# Manikganj  Manikganj  Manikganj  Manikganj  Manikganj
# CES vs SVRS: True
# CES vs DHIS: True
# CES vs DGFP: True
# CES vs DHS: True
# SVRS vs DHIS: True
# SVRS vs DGFP: True
# SVRS vs DHS: True
# DHIS vs DGFP: True
# DHIS vs DHS: True
# DHS vs DGFP: True
#
#  -------------------
# Maulvibazar  Maulvibazar  Maulvibazar  Maulvibazar  Maulvibazar
# CES vs SVRS: True
# CES vs DHIS: True
# CES vs DGFP: True
# CES vs DHS: True
# SVRS vs DHIS: True
# SVRS vs DGFP: True
# SVRS vs DHS: True
# DHIS vs DGFP: True
# DHIS vs DHS: True
# DHS vs DGFP: True
#
#  -------------------
# Meherpur  Meherpur  Meherpur  Meherpur  Meherpur
# CES vs SVRS: True
# CES vs DHIS: True
# CES vs DGFP: True
# CES vs DHS: True
# SVRS vs DHIS: True
# SVRS vs DGFP: True
# SVRS vs DHS: True
# DHIS vs DGFP: True
# DHIS vs DHS: True
# DHS vs DGFP: True
#
#  -------------------
# Munshiganj  Munshiganj  Munshiganj  Munshiganj  Munshiganj
# CES vs SVRS: True
# CES vs DHIS: True
# CES vs DGFP: True
# CES vs DHS: True
# SVRS vs DHIS: True
# SVRS vs DGFP: True
# SVRS vs DHS: True
# DHIS vs DGFP: True
# DHIS vs DHS: True
# DHS vs DGFP: True
#
#  -------------------
# Mymensingh  Mymensingh  Mymensingh  Mymensingh  Mymensingh
# CES vs SVRS: True
# CES vs DHIS: True
# CES vs DGFP: True
# CES vs DHS: True
# SVRS vs DHIS: True
# SVRS vs DGFP: True
# SVRS vs DHS: True
# DHIS vs DGFP: True
# DHIS vs DHS: True
# DHS vs DGFP: True
#
#  -------------------
# Naogaon  Naogaon  Naogaon  Naogaon  Naogaon
# CES vs SVRS: True
# CES vs DHIS: True
# CES vs DGFP: True
# CES vs DHS: True
# SVRS vs DHIS: True
# SVRS vs DGFP: True
# SVRS vs DHS: True
# DHIS vs DGFP: True
# DHIS vs DHS: True
# DHS vs DGFP: True
#
#  -------------------
# Narail  Narail  Narail  Narail  Narail
# CES vs SVRS: True
# CES vs DHIS: True
# CES vs DGFP: True
# CES vs DHS: True
# SVRS vs DHIS: True
# SVRS vs DGFP: True
# SVRS vs DHS: True
# DHIS vs DGFP: True
# DHIS vs DHS: True
# DHS vs DGFP: True
#
#  -------------------
# Narayanganj  Narayanganj  Narayanganj  Narayanganj  Narayanganj
# CES vs SVRS: True
# CES vs DHIS: True
# CES vs DGFP: True
# CES vs DHS: True
# SVRS vs DHIS: True
# SVRS vs DGFP: True
# SVRS vs DHS: True
# DHIS vs DGFP: True
# DHIS vs DHS: True
# DHS vs DGFP: True
#
#  -------------------
# Narsingdi  Narsingdi  Narsingdi  Narsingdi  Narsingdi
# CES vs SVRS: True
# CES vs DHIS: True
# CES vs DGFP: True
# CES vs DHS: True
# SVRS vs DHIS: True
# SVRS vs DGFP: True
# SVRS vs DHS: True
# DHIS vs DGFP: True
# DHIS vs DHS: True
# DHS vs DGFP: True
#
#  -------------------
# Natore  Natore  Natore  Natore  Natore
# CES vs SVRS: True
# CES vs DHIS: True
# CES vs DGFP: True
# CES vs DHS: True
# SVRS vs DHIS: True
# SVRS vs DGFP: True
# SVRS vs DHS: True
# DHIS vs DGFP: True
# DHIS vs DHS: True
# DHS vs DGFP: True
#
#  -------------------
# Netrakona  Netrakona  Netrakona  Netrakona  Netrakona
# CES vs SVRS: True
# CES vs DHIS: True
# CES vs DGFP: True
# CES vs DHS: True
# SVRS vs DHIS: True
# SVRS vs DGFP: True
# SVRS vs DHS: True
# DHIS vs DGFP: True
# DHIS vs DHS: True
# DHS vs DGFP: True
#
#  -------------------
# Nilphamari  Nilphamari  Nilphamari  Nilphamari  Nilphamari
# CES vs SVRS: True
# CES vs DHIS: True
# CES vs DGFP: True
# CES vs DHS: True
# SVRS vs DHIS: True
# SVRS vs DGFP: True
# SVRS vs DHS: True
# DHIS vs DGFP: True
# DHIS vs DHS: True
# DHS vs DGFP: True
#
#  -------------------
# Noakhali  Noakhali  Noakhali  Noakhali  Noakhali
# CES vs SVRS: True
# CES vs DHIS: True
# CES vs DGFP: True
# CES vs DHS: True
# SVRS vs DHIS: True
# SVRS vs DGFP: True
# SVRS vs DHS: True
# DHIS vs DGFP: True
# DHIS vs DHS: True
# DHS vs DGFP: True
#
#  -------------------
# Pabna  Pabna  Pabna  Pabna  Pabna
# CES vs SVRS: True
# CES vs DHIS: True
# CES vs DGFP: True
# CES vs DHS: True
# SVRS vs DHIS: True
# SVRS vs DGFP: True
# SVRS vs DHS: True
# DHIS vs DGFP: True
# DHIS vs DHS: True
# DHS vs DGFP: True
#
#  -------------------
# Panchagarh  Panchagarh  Panchagarh  Panchagarh  Panchagarh
# CES vs SVRS: True
# CES vs DHIS: True
# CES vs DGFP: True
# CES vs DHS: True
# SVRS vs DHIS: True
# SVRS vs DGFP: True
# SVRS vs DHS: True
# DHIS vs DGFP: True
# DHIS vs DHS: True
# DHS vs DGFP: True
#
#  -------------------
# Patuakhali  Patuakhali  Patuakhali  Patuakhali  Patuakhali
# CES vs SVRS: True
# CES vs DHIS: True
# CES vs DGFP: True
# CES vs DHS: True
# SVRS vs DHIS: True
# SVRS vs DGFP: True
# SVRS vs DHS: True
# DHIS vs DGFP: True
# DHIS vs DHS: True
# DHS vs DGFP: True
#
#  -------------------
# Pirojpur  Pirojpur  Pirojpur  Pirojpur  Pirojpur
# CES vs SVRS: True
# CES vs DHIS: True
# CES vs DGFP: True
# CES vs DHS: True
# SVRS vs DHIS: True
# SVRS vs DGFP: True
# SVRS vs DHS: True
# DHIS vs DGFP: True
# DHIS vs DHS: True
# DHS vs DGFP: True
#
#  -------------------
# Rajbari  Rajbari  Rajbari  Rajbari  Rajbari
# CES vs SVRS: True
# CES vs DHIS: True
# CES vs DGFP: True
# CES vs DHS: True
# SVRS vs DHIS: True
# SVRS vs DGFP: True
# SVRS vs DHS: True
# DHIS vs DGFP: True
# DHIS vs DHS: True
# DHS vs DGFP: True
#
#  -------------------
# Rajshahi  Rajshahi  Rajshahi  Rajshahi  Rajshahi
# CES vs SVRS: True
# CES vs DHIS: True
# CES vs DGFP: True
# CES vs DHS: True
# SVRS vs DHIS: True
# SVRS vs DGFP: True
# SVRS vs DHS: True
# DHIS vs DGFP: True
# DHIS vs DHS: True
# DHS vs DGFP: True
#
#  -------------------
# Rangamati  Rangamati  Rangamati  Rangamati  Rangamati
# CES vs SVRS: True
# CES vs DHIS: True
# CES vs DGFP: True
# CES vs DHS: True
# SVRS vs DHIS: True
# SVRS vs DGFP: True
# SVRS vs DHS: True
# DHIS vs DGFP: True
# DHIS vs DHS: True
# DHS vs DGFP: True
#
#  -------------------
# Rangpur  Rangpur  Rangpur  Rangpur  Rangpur
# CES vs SVRS: True
# CES vs DHIS: True
# CES vs DGFP: True
# CES vs DHS: True
# SVRS vs DHIS: True
# SVRS vs DGFP: True
# SVRS vs DHS: True
# DHIS vs DGFP: True
# DHIS vs DHS: True
# DHS vs DGFP: True
#
#  -------------------
# Satkhira  Satkhira  Satkhira  Satkhira  Satkhira
# CES vs SVRS: True
# CES vs DHIS: True
# CES vs DGFP: True
# CES vs DHS: True
# SVRS vs DHIS: True
# SVRS vs DGFP: True
# SVRS vs DHS: True
# DHIS vs DGFP: True
# DHIS vs DHS: True
# DHS vs DGFP: True
#
#  -------------------
# Shariatpur  Shariatpur  Shariatpur  Shariatpur  Shariatpur
# CES vs SVRS: True
# CES vs DHIS: True
# CES vs DGFP: True
# CES vs DHS: True
# SVRS vs DHIS: True
# SVRS vs DGFP: True
# SVRS vs DHS: True
# DHIS vs DGFP: True
# DHIS vs DHS: True
# DHS vs DGFP: True
#
#  -------------------
# Sherpur  Sherpur  Sherpur  Sherpur  Sherpur
# CES vs SVRS: True
# CES vs DHIS: True
# CES vs DGFP: True
# CES vs DHS: True
# SVRS vs DHIS: True
# SVRS vs DGFP: True
# SVRS vs DHS: True
# DHIS vs DGFP: True
# DHIS vs DHS: True
# DHS vs DGFP: True
#
#  -------------------
# Sirajganj  Sirajganj  Sirajganj  Sirajganj  Sirajganj
# CES vs SVRS: True
# CES vs DHIS: True
# CES vs DGFP: True
# CES vs DHS: True
# SVRS vs DHIS: True
# SVRS vs DGFP: True
# SVRS vs DHS: True
# DHIS vs DGFP: True
# DHIS vs DHS: True
# DHS vs DGFP: True
#
#  -------------------
# Sunamganj  Sunamganj  Sunamganj  Sunamganj  Sunamganj
# CES vs SVRS: True
# CES vs DHIS: True
# CES vs DGFP: True
# CES vs DHS: True
# SVRS vs DHIS: True
# SVRS vs DGFP: True
# SVRS vs DHS: True
# DHIS vs DGFP: True
# DHIS vs DHS: True
# DHS vs DGFP: True
#
#  -------------------
# Sylhet  Sylhet  Sylhet  Sylhet  Sylhet
# CES vs SVRS: True
# CES vs DHIS: True
# CES vs DGFP: True
# CES vs DHS: True
# SVRS vs DHIS: True
# SVRS vs DGFP: True
# SVRS vs DHS: True
# DHIS vs DGFP: True
# DHIS vs DHS: True
# DHS vs DGFP: True
#
#  -------------------
# Tangail  Tangail  Tangail  Tangail  Tangail
# CES vs SVRS: True
# CES vs DHIS: True
# CES vs DGFP: True
# CES vs DHS: True
# SVRS vs DHIS: True
# SVRS vs DGFP: True
# SVRS vs DHS: True
# DHIS vs DGFP: True
# DHIS vs DHS: True
# DHS vs DGFP: True
#
#  -------------------
# Thakurgaon  Thakurgaon  Thakurgaon  Thakurgaon  Thakurgaon
# CES vs SVRS: True
# CES vs DHIS: True
# CES vs DGFP: True
# CES vs DHS: True
# SVRS vs DHIS: True
# SVRS vs DGFP: True
# SVRS vs DHS: True
# DHIS vs DGFP: True
# DHIS vs DHS: True
# DHS vs DGFP: True

# %%
for ces, svrs, dhis, dgfp, dhs in zip(sorted(ces_2016['DistrictName']), sorted(svrs_2016['DistrictName']), 
                                 sorted(dhis_2016['DistrictName']), sorted(dgfp2016df['DistrictName']),
                                 sorted(dhs_2016['DistrictName'])):
    print("\n -------------------")
    print(ces, svrs, dhis, dgfp, dhs)
    print(f"CES vs SVRS: {ces == svrs}")
    print(f"CES vs DHIS: {ces == dhis}")
    print(f"CES vs DGFP: {ces == dgfp}")
    print(f"CES vs DHS: {ces == dhs}")
    print(f"SVRS vs DHIS: {svrs == dhis}")
    print(f"SVRS vs DGFP: {svrs == dgfp}")
    print(f"SVRS vs DHS: {svrs == dhs}")
    print(f"DHIS vs DGFP: {dhis == dgfp}")
    print(f"DHIS vs DHS: {dhis == dhs}")
    print(f"DHS vs DGFP: {dhs == dgfp}")
# Out:
#  -------------------
# Bagerhat  Bagerhat  Bagerhat  Bagerhat  Bagerhat
# CES vs SVRS: True
# CES vs DHIS: True
# CES vs DGFP: True
# CES vs DHS: True
# SVRS vs DHIS: True
# SVRS vs DGFP: True
# SVRS vs DHS: True
# DHIS vs DGFP: True
# DHIS vs DHS: True
# DHS vs DGFP: True
#
#  -------------------
# Bandarban  Bandarban  Bandarban  Bandarban  Bandarban
# CES vs SVRS: True
# CES vs DHIS: True
# CES vs DGFP: True
# CES vs DHS: True
# SVRS vs DHIS: True
# SVRS vs DGFP: True
# SVRS vs DHS: True
# DHIS vs DGFP: True
# DHIS vs DHS: True
# DHS vs DGFP: True
#
#  -------------------
# Barguna  Barguna  Barguna  Barguna  Barguna
# CES vs SVRS: True
# CES vs DHIS: True
# CES vs DGFP: True
# CES vs DHS: True
# SVRS vs DHIS: True
# SVRS vs DGFP: True
# SVRS vs DHS: True
# DHIS vs DGFP: True
# DHIS vs DHS: True
# DHS vs DGFP: True
#
#  -------------------
# Barisal  Barisal  Barisal  Barisal  Barisal
# CES vs SVRS: True
# CES vs DHIS: True
# CES vs DGFP: True
# CES vs DHS: True
# SVRS vs DHIS: True
# SVRS vs DGFP: True
# SVRS vs DHS: True
# DHIS vs DGFP: True
# DHIS vs DHS: True
# DHS vs DGFP: True
#
#  -------------------
# Bhola  Bhola  Bhola  Bhola  Bhola
# CES vs SVRS: True
# CES vs DHIS: True
# CES vs DGFP: True
# CES vs DHS: True
# SVRS vs DHIS: True
# SVRS vs DGFP: True
# SVRS vs DHS: True
# DHIS vs DGFP: True
# DHIS vs DHS: True
# DHS vs DGFP: True
#
#  -------------------
# Bogra  Bogra  Bogra  Bogra  Bogra
# CES vs SVRS: True
# CES vs DHIS: True
# CES vs DGFP: True
# CES vs DHS: True
# SVRS vs DHIS: True
# SVRS vs DGFP: True
# SVRS vs DHS: True
# DHIS vs DGFP: True
# DHIS vs DHS: True
# DHS vs DGFP: True
#
#  -------------------
# Brahmanbaria  Brahmanbaria  Brahmanbaria  Brahmanbaria  Brahmanbaria
# CES vs SVRS: True
# CES vs DHIS: True
# CES vs DGFP: True
# CES vs DHS: True
# SVRS vs DHIS: True
# SVRS vs DGFP: True
# SVRS vs DHS: True
# DHIS vs DGFP: True
# DHIS vs DHS: True
# DHS vs DGFP: True
#
#  -------------------
# Chandpur  Chandpur  Chandpur  Chandpur  Chandpur
# CES vs SVRS: True
# CES vs DHIS: True
# CES vs DGFP: True
# CES vs DHS: True
# SVRS vs DHIS: True
# SVRS vs DGFP: True
# SVRS vs DHS: True
# DHIS vs DGFP: True
# DHIS vs DHS: True
# DHS vs DGFP: True
#
#  -------------------
# Chapai Nawabganj  Chapai Nawabganj  Chapai Nawabganj  Chapai Nawabganj  Chapai Nawabganj
# CES vs SVRS: True
# CES vs DHIS: True
# CES vs DGFP: True
# CES vs DHS: True
# SVRS vs DHIS: True
# SVRS vs DGFP: True
# SVRS vs DHS: True
# DHIS vs DGFP: True
# DHIS vs DHS: True
# DHS vs DGFP: True
#
#  -------------------
# Chittagong  Chittagong  Chittagong  Chittagong  Chittagong
# CES vs SVRS: True
# CES vs DHIS: True
# CES vs DGFP: True
# CES vs DHS: True
# SVRS vs DHIS: True
# SVRS vs DGFP: True
# SVRS vs DHS: True
# DHIS vs DGFP: True
# DHIS vs DHS: True
# DHS vs DGFP: True
#
#  -------------------
# Chuadanga  Chuadanga  Chuadanga  Chuadanga  Chuadanga
# CES vs SVRS: True
# CES vs DHIS: True
# CES vs DGFP: True
# CES vs DHS: True
# SVRS vs DHIS: True
# SVRS vs DGFP: True
# SVRS vs DHS: True
# DHIS vs DGFP: True
# DHIS vs DHS: True
# DHS vs DGFP: True
#
#  -------------------
# Comilla  Comilla  Comilla  Comilla  Comilla
# CES vs SVRS: True
# CES vs DHIS: True
# CES vs DGFP: True
# CES vs DHS: True
# SVRS vs DHIS: True
# SVRS vs DGFP: True
# SVRS vs DHS: True
# DHIS vs DGFP: True
# DHIS vs DHS: True
# DHS vs DGFP: True
#
#  -------------------
# Cox's Bazar  Cox's Bazar  Cox's Bazar  Cox's Bazar  Cox's Bazar
# CES vs SVRS: True
# CES vs DHIS: True
# CES vs DGFP: True
# CES vs DHS: True
# SVRS vs DHIS: True
# SVRS vs DGFP: True
# SVRS vs DHS: True
# DHIS vs DGFP: True
# DHIS vs DHS: True
# DHS vs DGFP: True
#
#  -------------------
# Dhaka  Dhaka  Dhaka  Dhaka  Dhaka
# CES vs SVRS: True
# CES vs DHIS: True
# CES vs DGFP: True
# CES vs DHS: True
# SVRS vs DHIS: True
# SVRS vs DGFP: True
# SVRS vs DHS: True
# DHIS vs DGFP: True
# DHIS vs DHS: True
# DHS vs DGFP: True
#
#  -------------------
# Dinajpur  Dinajpur  Dinajpur  Dinajpur  Dinajpur
# CES vs SVRS: True
# CES vs DHIS: True
# CES vs DGFP: True
# CES vs DHS: True
# SVRS vs DHIS: True
# SVRS vs DGFP: True
# SVRS vs DHS: True
# DHIS vs DGFP: True
# DHIS vs DHS: True
# DHS vs DGFP: True
#
#  -------------------
# Faridpur  Faridpur  Faridpur  Faridpur  Faridpur
# CES vs SVRS: True
# CES vs DHIS: True
# CES vs DGFP: True
# CES vs DHS: True
# SVRS vs DHIS: True
# SVRS vs DGFP: True
# SVRS vs DHS: True
# DHIS vs DGFP: True
# DHIS vs DHS: True
# DHS vs DGFP: True
#
#  -------------------
# Feni  Feni  Feni  Feni  Feni
# CES vs SVRS: True
# CES vs DHIS: True
# CES vs DGFP: True
# CES vs DHS: True
# SVRS vs DHIS: True
# SVRS vs DGFP: True
# SVRS vs DHS: True
# DHIS vs DGFP: True
# DHIS vs DHS: True
# DHS vs DGFP: True
#
#  -------------------
# Gaibandha  Gaibandha  Gaibandha  Gaibandha  Gaibandha
# CES vs SVRS: True
# CES vs DHIS: True
# CES vs DGFP: True
# CES vs DHS: True
# SVRS vs DHIS: True
# SVRS vs DGFP: True
# SVRS vs DHS: True
# DHIS vs DGFP: True
# DHIS vs DHS: True
# DHS vs DGFP: True
#
#  -------------------
# Gazipur  Gazipur  Gazipur  Gazipur  Gazipur
# CES vs SVRS: True
# CES vs DHIS: True
# CES vs DGFP: True
# CES vs DHS: True
# SVRS vs DHIS: True
# SVRS vs DGFP: True
# SVRS vs DHS: True
# DHIS vs DGFP: True
# DHIS vs DHS: True
# DHS vs DGFP: True
#
#  -------------------
# Gopalganj  Gopalganj  Gopalganj  Gopalganj  Gopalganj
# CES vs SVRS: True
# CES vs DHIS: True
# CES vs DGFP: True
# CES vs DHS: True
# SVRS vs DHIS: True
# SVRS vs DGFP: True
# SVRS vs DHS: True
# DHIS vs DGFP: True
# DHIS vs DHS: True
# DHS vs DGFP: True
#
#  -------------------
# Habiganj  Habiganj  Habiganj  Habiganj  Habiganj
# CES vs SVRS: True
# CES vs DHIS: True
# CES vs DGFP: True
# CES vs DHS: True
# SVRS vs DHIS: True
# SVRS vs DGFP: True
# SVRS vs DHS: True
# DHIS vs DGFP: True
# DHIS vs DHS: True
# DHS vs DGFP: True
#
#  -------------------
# Jamalpur  Jamalpur  Jamalpur  Jamalpur  Jamalpur
# CES vs SVRS: True
# CES vs DHIS: True
# CES vs DGFP: True
# CES vs DHS: True
# SVRS vs DHIS: True
# SVRS vs DGFP: True
# SVRS vs DHS: True
# DHIS vs DGFP: True
# DHIS vs DHS: True
# DHS vs DGFP: True
#
#  -------------------
# Jessore  Jessore  Jessore  Jessore  Jessore
# CES vs SVRS: True
# CES vs DHIS: True
# CES vs DGFP: True
# CES vs DHS: True
# SVRS vs DHIS: True
# SVRS vs DGFP: True
# SVRS vs DHS: True
# DHIS vs DGFP: True
# DHIS vs DHS: True
# DHS vs DGFP: True
#
#  -------------------
# Jhalokati  Jhalokati  Jhalokati  Jhalokati  Jhalokati
# CES vs SVRS: True
# CES vs DHIS: True
# CES vs DGFP: True
# CES vs DHS: True
# SVRS vs DHIS: True
# SVRS vs DGFP: True
# SVRS vs DHS: True
# DHIS vs DGFP: True
# DHIS vs DHS: True
# DHS vs DGFP: True
#
#  -------------------
# Jhenaidah  Jhenaidah  Jhenaidah  Jhenaidah  Jhenaidah
# CES vs SVRS: True
# CES vs DHIS: True
# CES vs DGFP: True
# CES vs DHS: True
# SVRS vs DHIS: True
# SVRS vs DGFP: True
# SVRS vs DHS: True
# DHIS vs DGFP: True
# DHIS vs DHS: True
# DHS vs DGFP: True
#
#  -------------------
# Joypurhat  Joypurhat  Joypurhat  Joypurhat  Joypurhat
# CES vs SVRS: True
# CES vs DHIS: True
# CES vs DGFP: True
# CES vs DHS: True
# SVRS vs DHIS: True
# SVRS vs DGFP: True
# SVRS vs DHS: True
# DHIS vs DGFP: True
# DHIS vs DHS: True
# DHS vs DGFP: True
#
#  -------------------
# Khagrachhari  Khagrachhari  Khagrachhari  Khagrachhari  Khagrachhari
# CES vs SVRS: True
# CES vs DHIS: True
# CES vs DGFP: True
# CES vs DHS: True
# SVRS vs DHIS: True
# SVRS vs DGFP: True
# SVRS vs DHS: True
# DHIS vs DGFP: True
# DHIS vs DHS: True
# DHS vs DGFP: True
#
#  -------------------
# Khulna  Khulna  Khulna  Khulna  Khulna
# CES vs SVRS: True
# CES vs DHIS: True
# CES vs DGFP: True
# CES vs DHS: True
# SVRS vs DHIS: True
# SVRS vs DGFP: True
# SVRS vs DHS: True
# DHIS vs DGFP: True
# DHIS vs DHS: True
# DHS vs DGFP: True
#
#  -------------------
# Kishoreganj  Kishoreganj  Kishoreganj  Kishoreganj  Kishoreganj
# CES vs SVRS: True
# CES vs DHIS: True
# CES vs DGFP: True
# CES vs DHS: True
# SVRS vs DHIS: True
# SVRS vs DGFP: True
# SVRS vs DHS: True
# DHIS vs DGFP: True
# DHIS vs DHS: True
# DHS vs DGFP: True
#
#  -------------------
# Kurigram  Kurigram  Kurigram  Kurigram  Kurigram
# CES vs SVRS: True
# CES vs DHIS: True
# CES vs DGFP: True
# CES vs DHS: True
# SVRS vs DHIS: True
# SVRS vs DGFP: True
# SVRS vs DHS: True
# DHIS vs DGFP: True
# DHIS vs DHS: True
# DHS vs DGFP: True
#
#  -------------------
# Kushtia  Kushtia  Kushtia  Kushtia  Kushtia
# CES vs SVRS: True
# CES vs DHIS: True
# CES vs DGFP: True
# CES vs DHS: True
# SVRS vs DHIS: True
# SVRS vs DGFP: True
# SVRS vs DHS: True
# DHIS vs DGFP: True
# DHIS vs DHS: True
# DHS vs DGFP: True
#
#  -------------------
# Lakshmipur  Lakshmipur  Lakshmipur  Lakshmipur  Lakshmipur
# CES vs SVRS: True
# CES vs DHIS: True
# CES vs DGFP: True
# CES vs DHS: True
# SVRS vs DHIS: True
# SVRS vs DGFP: True
# SVRS vs DHS: True
# DHIS vs DGFP: True
# DHIS vs DHS: True
# DHS vs DGFP: True
#
#  -------------------
# Lalmonirhat  Lalmonirhat  Lalmonirhat  Lalmonirhat  Lalmonirhat
# CES vs SVRS: True
# CES vs DHIS: True
# CES vs DGFP: True
# CES vs DHS: True
# SVRS vs DHIS: True
# SVRS vs DGFP: True
# SVRS vs DHS: True
# DHIS vs DGFP: True
# DHIS vs DHS: True
# DHS vs DGFP: True
#
#  -------------------
# Madaripur  Madaripur  Madaripur  Madaripur  Madaripur
# CES vs SVRS: True
# CES vs DHIS: True
# CES vs DGFP: True
# CES vs DHS: True
# SVRS vs DHIS: True
# SVRS vs DGFP: True
# SVRS vs DHS: True
# DHIS vs DGFP: True
# DHIS vs DHS: True
# DHS vs DGFP: True
#
#  -------------------
# Magura  Magura  Magura  Magura  Magura
# CES vs SVRS: True
# CES vs DHIS: True
# CES vs DGFP: True
# CES vs DHS: True
# SVRS vs DHIS: True
# SVRS vs DGFP: True
# SVRS vs DHS: True
# DHIS vs DGFP: True
# DHIS vs DHS: True
# DHS vs DGFP: True
#
#  -------------------
# Manikganj  Manikganj  Manikganj  Manikganj  Manikganj
# CES vs SVRS: True
# CES vs DHIS: True
# CES vs DGFP: True
# CES vs DHS: True
# SVRS vs DHIS: True
# SVRS vs DGFP: True
# SVRS vs DHS: True
# DHIS vs DGFP: True
# DHIS vs DHS: True
# DHS vs DGFP: True
#
#  -------------------
# Maulvibazar  Maulvibazar  Maulvibazar  Maulvibazar  Maulvibazar
# CES vs SVRS: True
# CES vs DHIS: True
# CES vs DGFP: True
# CES vs DHS: True
# SVRS vs DHIS: True
# SVRS vs DGFP: True
# SVRS vs DHS: True
# DHIS vs DGFP: True
# DHIS vs DHS: True
# DHS vs DGFP: True
#
#  -------------------
# Meherpur  Meherpur  Meherpur  Meherpur  Meherpur
# CES vs SVRS: True
# CES vs DHIS: True
# CES vs DGFP: True
# CES vs DHS: True
# SVRS vs DHIS: True
# SVRS vs DGFP: True
# SVRS vs DHS: True
# DHIS vs DGFP: True
# DHIS vs DHS: True
# DHS vs DGFP: True
#
#  -------------------
# Munshiganj  Munshiganj  Munshiganj  Munshiganj  Munshiganj
# CES vs SVRS: True
# CES vs DHIS: True
# CES vs DGFP: True
# CES vs DHS: True
# SVRS vs DHIS: True
# SVRS vs DGFP: True
# SVRS vs DHS: True
# DHIS vs DGFP: True
# DHIS vs DHS: True
# DHS vs DGFP: True
#
#  -------------------
# Mymensingh  Mymensingh  Mymensingh  Mymensingh  Mymensingh
# CES vs SVRS: True
# CES vs DHIS: True
# CES vs DGFP: True
# CES vs DHS: True
# SVRS vs DHIS: True
# SVRS vs DGFP: True
# SVRS vs DHS: True
# DHIS vs DGFP: True
# DHIS vs DHS: True
# DHS vs DGFP: True
#
#  -------------------
# Naogaon  Naogaon  Naogaon  Naogaon  Naogaon
# CES vs SVRS: True
# CES vs DHIS: True
# CES vs DGFP: True
# CES vs DHS: True
# SVRS vs DHIS: True
# SVRS vs DGFP: True
# SVRS vs DHS: True
# DHIS vs DGFP: True
# DHIS vs DHS: True
# DHS vs DGFP: True
#
#  -------------------
# Narail  Narail  Narail  Narail  Narail
# CES vs SVRS: True
# CES vs DHIS: True
# CES vs DGFP: True
# CES vs DHS: True
# SVRS vs DHIS: True
# SVRS vs DGFP: True
# SVRS vs DHS: True
# DHIS vs DGFP: True
# DHIS vs DHS: True
# DHS vs DGFP: True
#
#  -------------------
# Narayanganj  Narayanganj  Narayanganj  Narayanganj  Narayanganj
# CES vs SVRS: True
# CES vs DHIS: True
# CES vs DGFP: True
# CES vs DHS: True
# SVRS vs DHIS: True
# SVRS vs DGFP: True
# SVRS vs DHS: True
# DHIS vs DGFP: True
# DHIS vs DHS: True
# DHS vs DGFP: True
#
#  -------------------
# Narsingdi  Narsingdi  Narsingdi  Narsingdi  Narsingdi
# CES vs SVRS: True
# CES vs DHIS: True
# CES vs DGFP: True
# CES vs DHS: True
# SVRS vs DHIS: True
# SVRS vs DGFP: True
# SVRS vs DHS: True
# DHIS vs DGFP: True
# DHIS vs DHS: True
# DHS vs DGFP: True
#  -------------------
# Natore  Natore  Natore  Natore  Natore
# CES vs SVRS: True
# CES vs DHIS: True
# CES vs DGFP: True
# CES vs DHS: True
# SVRS vs DHIS: True
# SVRS vs DGFP: True
# SVRS vs DHS: True
# DHIS vs DGFP: True
# DHIS vs DHS: True
# DHS vs DGFP: True
#
#  -------------------
# Netrakona  Netrakona  Netrakona  Netrakona  Netrakona
# CES vs SVRS: True
# CES vs DHIS: True
# CES vs DGFP: True
# CES vs DHS: True
# SVRS vs DHIS: True
# SVRS vs DGFP: True
# SVRS vs DHS: True
# DHIS vs DGFP: True
# DHIS vs DHS: True
# DHS vs DGFP: True
#
#  -------------------
# Nilphamari  Nilphamari  Nilphamari  Nilphamari  Nilphamari
# CES vs SVRS: True
# CES vs DHIS: True
# CES vs DGFP: True
# CES vs DHS: True
# SVRS vs DHIS: True
# SVRS vs DGFP: True
# SVRS vs DHS: True
# DHIS vs DGFP: True
# DHIS vs DHS: True
# DHS vs DGFP: True
#
#  -------------------
# Noakhali  Noakhali  Noakhali  Noakhali  Noakhali
# CES vs SVRS: True
# CES vs DHIS: True
# CES vs DGFP: True
# CES vs DHS: True
# SVRS vs DHIS: True
# SVRS vs DGFP: True
# SVRS vs DHS: True
# DHIS vs DGFP: True
# DHIS vs DHS: True
# DHS vs DGFP: True
#
#  -------------------
# Pabna  Pabna  Pabna  Pabna  Pabna
# CES vs SVRS: True
# CES vs DHIS: True
# CES vs DGFP: True
# CES vs DHS: True
# SVRS vs DHIS: True
# SVRS vs DGFP: True
# SVRS vs DHS: True
# DHIS vs DGFP: True
# DHIS vs DHS: True
# DHS vs DGFP: True
#
#  -------------------
# Panchagarh  Panchagarh  Panchagarh  Panchagarh  Panchagarh
# CES vs SVRS: True
# CES vs DHIS: True
# CES vs DGFP: True
# CES vs DHS: True
# SVRS vs DHIS: True
# SVRS vs DGFP: True
# SVRS vs DHS: True
# DHIS vs DGFP: True
# DHIS vs DHS: True
# DHS vs DGFP: True
#
#  -------------------
# Patuakhali  Patuakhali  Patuakhali  Patuakhali  Patuakhali
# CES vs SVRS: True
# CES vs DHIS: True
# CES vs DGFP: True
# CES vs DHS: True
# SVRS vs DHIS: True
# SVRS vs DGFP: True
# SVRS vs DHS: True
# DHIS vs DGFP: True
# DHIS vs DHS: True
# DHS vs DGFP: True
#
#  -------------------
# Pirojpur  Pirojpur  Pirojpur  Pirojpur  Pirojpur
# CES vs SVRS: True
# CES vs DHIS: True
# CES vs DGFP: True
# CES vs DHS: True
# SVRS vs DHIS: True
# SVRS vs DGFP: True
# SVRS vs DHS: True
# DHIS vs DGFP: True
# DHIS vs DHS: True
# DHS vs DGFP: True
#
#  -------------------
# Rajbari  Rajbari  Rajbari  Rajbari  Rajbari
# CES vs SVRS: True
# CES vs DHIS: True
# CES vs DGFP: True
# CES vs DHS: True
# SVRS vs DHIS: True
# SVRS vs DGFP: True
# SVRS vs DHS: True
# DHIS vs DGFP: True
# DHIS vs DHS: True
# DHS vs DGFP: True
#
#  -------------------
# Rajshahi  Rajshahi  Rajshahi  Rajshahi  Rajshahi
# CES vs SVRS: True
# CES vs DHIS: True
# CES vs DGFP: True
# CES vs DHS: True
# SVRS vs DHIS: True
# SVRS vs DGFP: True
# SVRS vs DHS: True
# DHIS vs DGFP: True
# DHIS vs DHS: True
# DHS vs DGFP: True
#
#  -------------------
# Rangamati  Rangamati  Rangamati  Rangamati  Rangamati
# CES vs SVRS: True
# CES vs DHIS: True
# CES vs DGFP: True
# CES vs DHS: True
# SVRS vs DHIS: True
# SVRS vs DGFP: True
# SVRS vs DHS: True
# DHIS vs DGFP: True
# DHIS vs DHS: True
# DHS vs DGFP: True
#
#  -------------------
# Rangpur  Rangpur  Rangpur  Rangpur  Rangpur
# CES vs SVRS: True
# CES vs DHIS: True
# CES vs DGFP: True
# CES vs DHS: True
# SVRS vs DHIS: True
# SVRS vs DGFP: True
# SVRS vs DHS: True
# DHIS vs DGFP: True
# DHIS vs DHS: True
# DHS vs DGFP: True
#
#  -------------------
# Satkhira  Satkhira  Satkhira  Satkhira  Satkhira
# CES vs SVRS: True
# CES vs DHIS: True
# CES vs DGFP: True
# CES vs DHS: True
# SVRS vs DHIS: True
# SVRS vs DGFP: True
# SVRS vs DHS: True
# DHIS vs DGFP: True
# DHIS vs DHS: True
# DHS vs DGFP: True
#
#  -------------------
# Shariatpur  Shariatpur  Shariatpur  Shariatpur  Shariatpur
# CES vs SVRS: True
# CES vs DHIS: True
# CES vs DGFP: True
# CES vs DHS: True
# SVRS vs DHIS: True
# SVRS vs DGFP: True
# SVRS vs DHS: True
# DHIS vs DGFP: True
# DHIS vs DHS: True
# DHS vs DGFP: True
#
#  -------------------
# Sherpur  Sherpur  Sherpur  Sherpur  Sherpur
# CES vs SVRS: True
# CES vs DHIS: True
# CES vs DGFP: True
# CES vs DHS: True
# SVRS vs DHIS: True
# SVRS vs DGFP: True
# SVRS vs DHS: True
# DHIS vs DGFP: True
# DHIS vs DHS: True
# DHS vs DGFP: True
#
#  -------------------
# Sirajganj  Sirajganj  Sirajganj  Sirajganj  Sirajganj
# CES vs SVRS: True
# CES vs DHIS: True
# CES vs DGFP: True
# CES vs DHS: True
# SVRS vs DHIS: True
# SVRS vs DGFP: True
# SVRS vs DHS: True
# DHIS vs DGFP: True
# DHIS vs DHS: True
# DHS vs DGFP: True
#
#  -------------------
# Sunamganj  Sunamganj  Sunamganj  Sunamganj  Sunamganj
# CES vs SVRS: True
# CES vs DHIS: True
# CES vs DGFP: True
# CES vs DHS: True
# SVRS vs DHIS: True
# SVRS vs DGFP: True
# SVRS vs DHS: True
# DHIS vs DGFP: True
# DHIS vs DHS: True
# DHS vs DGFP: True
#
#  -------------------
# Sylhet  Sylhet  Sylhet  Sylhet  Sylhet
# CES vs SVRS: True
# CES vs DHIS: True
# CES vs DGFP: True
# CES vs DHS: True
# SVRS vs DHIS: True
# SVRS vs DGFP: True
# SVRS vs DHS: True
# DHIS vs DGFP: True
# DHIS vs DHS: True
# DHS vs DGFP: True
#
#  -------------------
# Tangail  Tangail  Tangail  Tangail  Tangail
# CES vs SVRS: True
# CES vs DHIS: True
# CES vs DGFP: True
# CES vs DHS: True
# SVRS vs DHIS: True
# SVRS vs DGFP: True
# SVRS vs DHS: True
# DHIS vs DGFP: True
# DHIS vs DHS: True
# DHS vs DGFP: True
#
#  -------------------
# Thakurgaon  Thakurgaon  Thakurgaon  Thakurgaon  Thakurgaon
# CES vs SVRS: True
# CES vs DHIS: True
# CES vs DGFP: True
# CES vs DHS: True
# SVRS vs DHIS: True
# SVRS vs DGFP: True
# SVRS vs DHS: True
# DHIS vs DGFP: True
# DHIS vs DHS: True
# DHS vs DGFP: True

# %% [markdown]
# ## Combining data

# %%
for a,b,c,d in zip(dgfp2011[DGFP2011a]['geo'], dgfp2011[DGFP2011b]['geo'], 
                   dgfp2011[DGFP2011c]['geo'], dgfp2011[DGFP2011d]['geo']):
    print(a,b,c,d)
    print(a == b)
    print(a == c)
    print(a == d)
    print(b == c)
    print(b == d)
    print(c == d)
    print("\n -----------")
# Out:
# 5577 5577 5577 5577
# True
# True
# True
# True
# True
# True
#
#  -----------
# 4044 4044 4044 4044
# True
# True
# True
# True
# True
# True
#
#  -----------
# 4001 4001 4001 4001
# True
# True
# True
# True
# True
# True
#
#  -----------
# 3061 3061 3061 3061
# True
# True
# True
# True
# True
# True
#
#  -----------
# 1079 1079 1079 1079
# True
# True
# True
# True
# True
# True
#
#  -----------
# 5527 5527 5527 5527
# True
# True
# True
# True
# True
# True
#
#  -----------
# 3026 3026 3026 3026
# True
# True
# True
# True
# True
# True
#
#  -----------
# 2022 2022 2022 2022
# True
# True
# True
# True
# True
# True
#
#  -----------
# 3029 3029 3029 3029
# True
# True
# True
# True
# True
# True
#
#  -----------
# 5010 5010 5010 5010
# True
# True
# True
# True
# True
# True
#
#  -----------
# 4087 4087 4087 4087
# True
# True
# True
# True
# True
# True
#
#  -----------
# 1004 1004 1004 1004
# True
# True
# True
# True
# True
# True
#
#  -----------
# 4018 4018 4018 4018
# True
# True
# True
# True
# True
# True
#
#  -----------
# 2046 2046 2046 2046
# True
# True
# True
# True
# True
# True
#
#  -----------
# 6036 6036 6036 6036
# True
# True
# True
# True
# True
# True
#
#  -----------
# 1042 1042 1042 1042
# True
# True
# True
# True
# True
# True
#
#  -----------
# 4065 4065 4065 4065
# True
# True
# True
# True
# True
# True
#
#  -----------
# 1078 1078 1078 1078
# True
# True
# True
# True
# True
# True
#
#  -----------
# 5549 5549 5549 5549
# True
# True
# True
# True
# True
# True
#
#  -----------
# 3048 3048 3048 3048
# True
# True
# True
# True
# True
# True
#
#  -----------
# 5088 5088 5088 5088
# True
# True
# True
# True
# True
# True
#
#  -----------
# 3035 3035 3035 3035
# True
# True
# True
# True
# True
# True
#
#  -----------
# 3068 3068 3068 3068
# True
# True
# True
# True
# True
# True
#
#  -----------
# 3039 3039 3039 3039
# True
# True
# True
# True
# True
# True
#
#  -----------
# 2013 2013 2013 2013
# True
# True
# True
# True
# True
# True
#
#  -----------
# 3093 3093 3093 3093
# True
# True
# True
# True
# True
# True
#
#  -----------
# 5069 5069 5069 5069
# True
# True
# True
# True
# True
# True
#
#  -----------
# 5076 5076 5076 5076
# True
# True
# True
# True
# True
# True
#
#  -----------
# 4047 4047 4047 4047
# True
# True
# True
# True
# True
# True
#
#  -----------
# 2084 2084 2084 2084
# True
# True
# True
# True
# True
# True
#
#  -----------
# 2030 2030 2030 2030
# True
# True
# True
# True
# True
# True
#
#  -----------
# 6091 6091 6091 6091
# True
# True
# True
# True
# True
# True
#
#  -----------
# 2051 2051 2051 2051
# True
# True
# True
# True
# True
# True
#
#  -----------
# 5064 5064 5064 5064
# True
# True
# True
# True
# True
# True
#
#  -----------
# 5585 5585 5585 5585
# True
# True
# True
# True
# True
# True
#
#  -----------
# 5081 5081 5081 5081
# True
# True
# True
# True
# True
# True
#
#  -----------
# 3059 3059 3059 3059
# True
# True
# True
# True
# True
# True
#
#  -----------
# 3054 3054 3054 3054
# True
# True
# True
# True
# True
# True
#
#  -----------
# 2019 2019 2019 2019
# True
# True
# True
# True
# True
# True
#
#  -----------
# 5532 5532 5532 5532
# True
# True
# True
# True
# True
# True
#
#  -----------
# 3067 3067 3067 3067
# True
# True
# True
# True
# True
# True
#
#  -----------
# 4057 4057 4057 4057
# True
# True
# True
# True
# True
# True
#
#  -----------
# 6058 6058 6058 6058
# True
# True
# True
# True
# True
# True
#
#  -----------
# 4055 4055 4055 4055
# True
# True
# True
# True
# True
# True
#
#  -----------
# 4041 4041 4041 4041
# True
# True
# True
# True
# True
# True
#
#  -----------
# 3072 3072 3072 3072
# True
# True
# True
# True
# True
# True
#
#  -----------
# 3082 3082 3082 3082
# True
# True
# True
# True
# True
# True
#
#  -----------
# 2075 2075 2075 2075
# True
# True
# True
# True
# True
# True
#
#  -----------
# 5038 5038 5038 5038
# True
# True
# True
# True
# True
# True
#
#  -----------
# 3033 3033 3033 3033
# True
# True
# True
# True
# True
# True
#
#  -----------
# 5594 5594 5594 5594
# True
# True
# True
# True
# True
# True
#
#  -----------
# 1009 1009 1009 1009
# True
# True
# True
# True
# True
# True
#
#  -----------
# 6090 6090 6090 6090
# True
# True
# True
# True
# True
# True
#
#  -----------
# 2015 2015 2015 2015
# True
# True
# True
# True
# True
# True
#
#  -----------
# 5070 5070 5070 5070
# True
# True
# True
# True
# True
# True
#
#  -----------
# 3056 3056 3056 3056
# True
# True
# True
# True
# True
# True
#
#  -----------
# 5552 5552 5552 5552
# True
# True
# True
# True
# True
# True
#
#  -----------
# 3086 3086 3086 3086
# True
# True
# True
# True
# True
# True
#
#  -----------
# 3089 3089 3089 3089
# True
# True
# True
# True
# True
# True
#
#  -----------
# 2012 2012 2012 2012
# True
# True
# True
# True
# True
# True
#
#  -----------
# 4050 4050 4050 4050
# True
# True
# True
# True
# True
# True
#
#  -----------
# 1006 1006 1006 1006
# True
# True
# True
# True
# True
# True
#
#  -----------
# 5573 5573 5573 5573
# True
# True
# True
# True
# True
# True
#
#  -----------
# 2003 2003 2003 2003
# True
# True
# True
# True
# True
# True
#
#  -----------

# %% [markdown]
# ### Preparing 2011

# %%
drop_vars = ['DistrictName', 'DistrictGeo']
ces_2011 = ces_2011.sort_values(by='DistrictName').reset_index(drop=True)
svrs_2011 = svrs_2011.sort_values(by='DistrictName').reset_index(drop=True)
dhis_2011 = dhis_2011.sort_values(by='DistrictName').reset_index(drop=True)
dgfp2011df = dgfp2011df.sort_values(by='DistrictName').reset_index(drop=True)
dhs_2011 = dhs_2011.sort_values(by='DistrictName').reset_index(drop=True)

d2011 = [ces_2011, svrs_2011.drop(drop_vars,axis=1), dhis_2011.drop(drop_vars,axis=1),
         dgfp2011df.drop(drop_vars,axis=1), dhs_2011.drop(drop_vars, axis=1)]
df2011 = pd.concat(d2011, axis=1)
df2011.shape
# Out:
# (64, 468)

# %% [markdown]
# ### Preparing 2016

# %%
ces_2016 = ces_2016.sort_values(by='DistrictName').reset_index(drop=True)
svrs_2016 = svrs_2016.sort_values(by='DistrictName').reset_index(drop=True)
dhis_2016 = dhis_2016.sort_values(by='DistrictName').reset_index(drop=True)
dgfp2016df = dgfp2016df.sort_values(by='DistrictName').reset_index(drop=True)
d2016 = [ces_2016, svrs_2016.drop(drop_vars,axis=1),
         dhis_2016.drop(drop_vars,axis=1), dgfp2016df.drop(drop_vars,axis=1),
         dhs_2016.drop(drop_vars, axis=1)]
df2016 = pd.concat(d2016, axis=1)
df2016.shape
# Out:
# (64, 468)

# %% [markdown]
# ## Determining outcome variables

# %%
print(df2011['rate_maternal_mortality'].mean())
print(df2016['rate_maternal_mortality'].mean())
# Out:
# 228.3010937500001
# 2.65078125

# %%
print(df2011['rate_under5y_mortality'].mean())
print(df2016['rate_under5y_mortality'].mean())
# Out:
# 42.829375
# 39.446562500000006

# %%
print(df2011['prop_antenatal_coverage'].mean())
print(df2016['prop_antenatal_coverage'].mean())
# Out:
# 37.97062499999999
# 56.92234374999999

# %%
print(df2011['prop_unmet_need_family_planing'].mean())
print(df2016['prop_unmet_need_family_planing'].mean())
# Out:
# 13.562187500000004
# 11.942968750000002

# %% [markdown]
# ```
# print(df2011['ORS_RHF_ORT'].mean())
# print(df2016['ORS_RHF_ORT'].mean())
# ```

# %%
df2011.shape
468-3
# Out:
# 465

# %%
list(df2011.columns)
# Out:
# ['OPV2_Children12M',
#  'Fully_Children12M',
#  'Measles_Children23M',
#  'TT3_Mother0-11MChildren',
#  'VitACoverage_Children12-59M',
#  'Fully_Children23M',
#  'OPV3_Children12M',
#  'OPV1_Children23M',
#  'OPV3_Children23M',
#  'OPV1_Children12M',
#  'PENTA1_Children12M',
#  'PENTA1_Children23M',
#  'BCG_Children12M',
#  'OPV2_Children23M',
#  'PENTA3_Children12M',
#  'TT4_Mother0-11MChildren',
#  'PENTA2_Children12M',
#  'DistrictName',
#  'TT5_Mother0-11MChildren',
#  'Measles_Children12M',
#  'PENTA3_Children23M',
#  'BCG_Children23M',
#  'PENTA2_Children23M',
#  'TT2_Mother0-11MChildren',
#  'TT1_Mother0-11MChildren',
#  'DistrictGeo',
#  'prop_women_15.45y_overwomen',
#  'rate_death',
#  'prop_pop_rural_women',
#  'rate_fertility',
#  'rate_live_births',
#  'rate_maternal_mortality',
#  'prop_registered_births',
#  'rate_under5y_mortality',
#  'dependency_ratio',
#  'prop_married_..15y',
#  'sex_ratio',
#  'prop_pop_rural',
#  'prop_live_births',
#  'prop_married_women_15.45y',
#  'prop_deaths_rural',
#  'rate_infant_mortality',
#  'prop_pop_women',
#  'rate_child_death',
#  '07Vaccine&LogisticsstockofUpazilaMunCC: Upazila EPI Syringe(2/3ml) need with buffer',
#  '06Vaccine&LogisticsstockofDistrict: District EPI Syringe (5 ml) stock requested',
#  '03Immunization: Pentavalent vial wastage rate',
#  '03Immunization: EPI Session drop out rate',
#  '06Vaccine&LogisticsstockofDistrict: District EPI total MR supplied on 2nd delivery',
#  '07Vaccine&LogisticsstockofUpazilaMunCC: upazilla_epi_BCG closing balance',
#  '06Vaccine&LogisticsstockofDistrict: District EPI total MR Diluent supplied on 2nd delivery',
#  '06Vaccine&LogisticsstockofDistrict: District EPI IPV stock requested',
#  '03Immunization: IPV vial wastage rate',
#  '03Immunization: MR 2 Crude Coverage %',
#  '07Vaccine&LogisticsstockofUpazilaMunCC: upazilla_epi_Women Report Book closing balance',
#  '07Vaccine&LogisticsstockofUpazilaMunCC: Upazilla EPI AEFI Investigation form stock requested',
#  '07Vaccine&LogisticsstockofUpazilaMunCC: upazilla_epi_Child register closing balance',
#  '07Vaccine&LogisticsstockofUpazilaMunCC: upazilla_epi_Syringe (5 ml) closing balance',
#  '02ChildHealth: % of breast feeding initiated within 1 hour by CSBA',
#  '06Vaccine&LogisticsstockofDistrict: District EPI Syringe (0.1 ml) stock requested',
#  '06Vaccine&LogisticsstockofDistrict: Safety box total supplied',
#  '06Vaccine&LogisticsstockofDistrict: dist_epi_Child Card closing balance',
#  '03Immunization: Penta 3 Crude Coverage %',
#  '03Immunization: Penta 1 Crude Coverage %',
#  '06Vaccine&LogisticsstockofDistrict: District EPI Child register need with buffer',
#  '06Vaccine&LogisticsstockofDistrict: Syringe (5 ml) total supplied',
#  '06Vaccine&LogisticsstockofDistrict: District EPI Tally Book(child) need with buffer',
#  '07Vaccine&LogisticsstockofUpazilaMunCC: Upazilla EPI Women register stock requested',
#  '07Vaccine&LogisticsstockofUpazilaMunCC: Upazila EPI Child Card need with buffer',
#  '07Vaccine&LogisticsstockofUpazilaMunCC: Upazila EPI batch card need with buffer',
#  '07Vaccine&LogisticsstockofUpazilaMunCC: Upazilla EPI OPV stock requested',
#  '07Vaccine&LogisticsstockofUpazilaMunCC: Upazila EPI zip lock bag need with buffer',
#  '06Vaccine&LogisticsstockofDistrict: District EPI IPV need with buffer',
#  '04Newborn: % of Nurse training on ETAT at SCANU',
#  '06Vaccine&LogisticsstockofDistrict: District EPI OPV dropper stock requested',
#  '06Vaccine&LogisticsstockofDistrict: District EPI Child Card need with buffer',
#  '03Immunization: fIPV2 Crude Coverage %',
#  '03Immunization: fIPV1 Crude Coverage %',
#  '06Vaccine&LogisticsstockofDistrict: District EPI OPV need with buffer',
#  '07Vaccine&LogisticsstockofUpazilaMunCC: Upazila EPI Syringe (5 ml) need with buffer',
#  '06Vaccine&LogisticsstockofDistrict: District EPI total Pentavalent supplied on 2nd delivery',
#  '06Vaccine&LogisticsstockofDistrict: District EPI total PCV supplied on 1st delivery',
#  '03Immunization: Total Pentavalent Given',
#  '07Vaccine&LogisticsstockofUpazilaMunCC: Upazila EPI Women Report Book need with buffer',
#  '06Vaccine&LogisticsstockofDistrict: dist_epi_BCG closing balance',
#  '03Immunization: BCG vial wastage rate',
#  '01MaternalHealth: Institutional Normal Delivery Rate (Only EmOC Facilities)',
#  '07Vaccine&LogisticsstockofUpazilaMunCC: upazilla_epi_Syringe (0.05 ml) closing balance',
#  '02ChildHealth: Percentage of diarrhea reported at facility',
#  '07Vaccine&LogisticsstockofUpazilaMunCC: Upazila EPI Syringe (0.5 ml) need with buffer',
#  '05Logistics: Percentage of functional x-ray',
#  '06Vaccine&LogisticsstockofDistrict: District Women Report Book requested',
#  '06Vaccine&LogisticsstockofDistrict: dist_epi_Supervision Form closing balance',
#  '04Newborn: Case fatality rate at SCANU',
#  '03Immunization: PCV 1 Crude Coverage %',
#  '06Vaccine&LogisticsstockofDistrict: District EPI TT stock requested',
#  '07Vaccine&LogisticsstockofUpazilaMunCC: upazilla_epi_temperature chart closing balance',
#  '07Vaccine&LogisticsstockofUpazilaMunCC: Upazilla EPI Tally Book(Women) stock requested',
#  '07Vaccine&LogisticsstockofUpazilaMunCC: upazilla_epi_Pentavalent closing balance',
#  '07Vaccine&LogisticsstockofUpazilaMunCC: upazilla_epi_AEFI Investigation form closing balance',
#  '07Vaccine&LogisticsstockofUpazilaMunCC: Upazila EPI Pentavalent need with buffer',
#  '06Vaccine&LogisticsstockofDistrict: District EPI total BCG supplied on 1st delivery',
#  '07Vaccine&LogisticsstockofUpazilaMunCC: Upazilla EPI MR stock requested',
#  '07Vaccine&LogisticsstockofUpazilaMunCC: Upazila EPI Syringe (0.05 ml) need with buffer',
#  '07Vaccine&LogisticsstockofUpazilaMunCC: Upazila EPI temperature chart need with buffer',
#  '07Vaccine&LogisticsstockofUpazilaMunCC: upazilla_epi_Syringe (0.1 ml) closing balance',
#  '06Vaccine&LogisticsstockofDistrict: District EPI Syringe (5 ml) need with buffer',
#  '06Vaccine&LogisticsstockofDistrict: District EPI Pentavalent need with buffer',
#  '07Vaccine&LogisticsstockofUpazilaMunCC: Upazilla EPI MR diluent stock requested',
#  '03Immunization: OPV vial wastage rate',
#  '01MaternalHealth: Percentage of cases with puerperal sepsis among admitted patient in EmONC',
#  '06Vaccine&LogisticsstockofDistrict: dist_epi_stock register for logistic closing balance',
#  '07Vaccine&LogisticsstockofUpazilaMunCC: Upazilla EPI Syringe(2/3ml) stock requested',
#  '06Vaccine&LogisticsstockofDistrict: District EPI total OPV supplied on 2nd delivery',
#  '01MaternalHealth: Total No. of pregnant mothers with obstetric complication',
#  '06Vaccine&LogisticsstockofDistrict: District EPI Syringe (0.05 ml) stock requested',
#  '06Vaccine&LogisticsstockofDistrict: dist_epi_OPV closing balance',
#  '06Vaccine&LogisticsstockofDistrict: District EPI temperature chart need with buffer',
#  '07Vaccine&LogisticsstockofUpazilaMunCC: Upazila EPI CC supply book need with buffer',
#  '06Vaccine&LogisticsstockofDistrict: District EPI daily vaccine distribution register need with buffer',
#  '07Vaccine&LogisticsstockofUpazilaMunCC: Upazilla EPI Safety Box stock requested',
#  '06Vaccine&LogisticsstockofDistrict: District EPI TT Card need with buffer',
#  '07Vaccine&LogisticsstockofUpazilaMunCC: Upazila EPI Child register need with buffer',
#  '07Vaccine&LogisticsstockofUpazilaMunCC: upazilla_epi_Safety Box closing balance',
#  '03Immunization: Total TT Given to 15 - 49 Y',
#  '04Newborn: % of male baby admitted in SCANU reported individually',
#  '04Newborn: % of non functional Photo therapy unit',
#  '07Vaccine&LogisticsstockofUpazilaMunCC: Upazila EPI AEFI form E36 - E39 need with buffer',
#  '07Vaccine&LogisticsstockofUpazilaMunCC: Upazila EPI FW product distribution register need with buffer',
#  '07Vaccine&LogisticsstockofUpazilaMunCC: Upazila EPI Child Report Book need with buffer',
#  '07Vaccine&LogisticsstockofUpazilaMunCC: Upazila EPI AEFI line listing form need with buffer',
#  '07Vaccine&LogisticsstockofUpazilaMunCC: upazilla_epi_Child Report Book closing balance',
#  '03Immunization: BCG to MR 1 Drop out Rate',
#  '06Vaccine&LogisticsstockofDistrict: dist_epi_supply book closing balance',
#  '07Vaccine&LogisticsstockofUpazilaMunCC: Upazilla EPI IPV stock requested',
#  '06Vaccine&LogisticsstockofDistrict: dist_epi_MR closing balance',
#  '07Vaccine&LogisticsstockofUpazilaMunCC: Upazila EPI stock register for vaccine/diluent need with buffer',
#  '07Vaccine&LogisticsstockofUpazilaMunCC: upazilla_epi_stock register for vaccine/diluent closing balance',
#  '06Vaccine&LogisticsstockofDistrict: District EPI MR stock requested',
#  '06Vaccine&LogisticsstockofDistrict: District EPI batch card need with buffer',
#  '06Vaccine&LogisticsstockofDistrict: dist_epi_AEFI line listing form closing balance',
#  '06Vaccine&LogisticsstockofDistrict: District EPI BCG stock requested',
#  '07Vaccine&LogisticsstockofUpazilaMunCC: Upazilla EPI supply book stock requested',
#  '06Vaccine&LogisticsstockofDistrict: District EPI BCG need with buffer',
#  'AntenatalCare(ANC): 1st Visit ANC',
#  '07Vaccine&LogisticsstockofUpazilaMunCC: upazilla_epi_OPV dropper closing balance',
#  '03Immunization: OPV 0 Crude Coverage %',
#  'AntenatalCare(ANC): 2nd Visit ANC',
#  '01MaternalHealth: Percentage of postpartum hemorrhage among admitted patient in EmONC',
#  '04Newborn: % of nurse training on KMC at SCANU',
#  '06Vaccine&LogisticsstockofDistrict: District TT Card requested',
#  '04Newborn: Nurse Bed ratio at SCANU (Recommended 0.8)',
#  '06Vaccine&LogisticsstockofDistrict: dist_epi_BCG Diluent closing balance',
#  '04Newborn: % of male baby admitted in SCANU reported monthly',
#  '04Newborn: Percentage of newborns delivered by SBA at community that received CHX (7.1%) to the cord after birth',
#  '06Vaccine&LogisticsstockofDistrict: District Tally Book(child) requested',
#  '06Vaccine&LogisticsstockofDistrict: District Supervision Form requested',
#  '07Vaccine&LogisticsstockofUpazilaMunCC: Upazilla EPI Tally Book(child) stock requested',
#  '07Vaccine&LogisticsstockofUpazilaMunCC: Upazila EPI AEFI Form need with buffer',
#  '06Vaccine&LogisticsstockofDistrict: District EPI Syringe (0.5 ml) need with buffer',
#  '03Immunization: OPV 3 Crude Coverage %',
#  '06Vaccine&LogisticsstockofDistrict: dist_epi_Pentavalent closing balance',
#  '06Vaccine&LogisticsstockofDistrict: District EPI stock register for vaccine/diluent need with buffer',
#  '01MaternalHealth: Total still birth at EmOC facility',
#  '06Vaccine&LogisticsstockofDistrict: dist_epi_Tally Book (child) closing balance',
#  '07Vaccine&LogisticsstockofUpazilaMunCC: upazilla_epi_supply book closing balance',
#  '06Vaccine&LogisticsstockofDistrict: dist_epi_temperature chart closing balance',
#  '04Newborn: Percentage of newborns initiated breastfeeding within one hour after birth',
#  '07Vaccine&LogisticsstockofUpazilaMunCC: upazilla_epi_zip lock bag closing balance',
#  '06Vaccine&LogisticsstockofDistrict: District EPI total IPV supplied on 2nd delivery',
#  '06Vaccine&LogisticsstockofDistrict: District EPI total IPV supplied on 1st delivery',
#  '01MaternalHealth: Institutional C-section rate',
#  '07Vaccine&LogisticsstockofUpazilaMunCC: Upazilla EPI daily vaccine distribution register stock requested',
#  '07Vaccine&LogisticsstockofUpazilaMunCC: Upazilla EPI Syringe (0.5 ml) stock requested',
#  '07Vaccine&LogisticsstockofUpazilaMunCC: Upazila EPI Tally Book(child) need with buffer',
#  '07Vaccine&LogisticsstockofUpazilaMunCC: upazilla_epi_MR Diluent closing balance',
#  '04Newborn: % of nurse allocated in SCANU among all nurses in the facility',
#  '06Vaccine&LogisticsstockofDistrict: dist_epi_stock register for vaccine/diluent closing balance',
#  '06Vaccine&LogisticsstockofDistrict: dist_epi_Syringe (3 ml) closing balance',
#  '03Immunization: Penta 2 Crude Coverage %',
#  '07Vaccine&LogisticsstockofUpazilaMunCC: Upazila EPI OPV need with buffer',
#  '06Vaccine&LogisticsstockofDistrict: dist_epi_Safety Box closing balance',
#  '03Immunization: BCG left out Rate',
#  '07Vaccine&LogisticsstockofUpazilaMunCC: Upazila EPI Supervision Form need with buffer',
#  'True',
#  '06Vaccine&LogisticsstockofDistrict: District EPI Syringe(2/3ml) stock requested',
#  '06Vaccine&LogisticsstockofDistrict: District EPI OPV dropper need with buffer',
#  '06Vaccine&LogisticsstockofDistrict: District EPI total BCG Diluent supplied on 3rd delivery',
#  '07Vaccine&LogisticsstockofUpazilaMunCC: upazilla_epi_AEFI Form closing balance',
#  '04Newborn: % of non-functioning Table Resuscitator with Radiant warmer',
#  '06Vaccine&LogisticsstockofDistrict: District EPI AEFI Form need with buffer',
#  '06Vaccine&LogisticsstockofDistrict: dist_epi_Syringe (5 ml) closing balance',
#  '07Vaccine&LogisticsstockofUpazilaMunCC: upazilla_epi_BCG Diluent closing balance',
#  '07Vaccine&LogisticsstockofUpazilaMunCC: Upazilla EPI Moni flag stock requested',
#  '03Immunization: MR 1 to MR 2 drop out Rate',
#  '06Vaccine&LogisticsstockofDistrict: dist_epi_fw product distribution closing balance',
#  '06Vaccine&LogisticsstockofDistrict: dist_epi_MR Diluent closing balance',
#  '07Vaccine&LogisticsstockofUpazilaMunCC: Upazila EPI TT need with buffer',
#  '07Vaccine&LogisticsstockofUpazilaMunCC: Upazilla EPI BCG stock requested',
#  '06Vaccine&LogisticsstockofDistrict: District EPI total BCG Diluent supplied on 1st delivery',
#  '07Vaccine&LogisticsstockofUpazilaMunCC: upazilla_epi_Tally Book (Women) closing balance',
#  '07Vaccine&LogisticsstockofUpazilaMunCC: upazilla_epi_MR closing balance',
#  '06Vaccine&LogisticsstockofDistrict: District EPI PCV stock requested',
#  '03Immunization: PCV vial wastage rate',
#  '04Newborn: % of referral cases admitted at SCANU',
#  '07Vaccine&LogisticsstockofUpazilaMunCC: upazilla_epi_Syringe (3 ml) closing balance',
#  '06Vaccine&LogisticsstockofDistrict: District EPI Child Report Book need with buffer',
#  '07Vaccine&LogisticsstockofUpazilaMunCC: upazilla_epi_Child Card closing balance',
#  '07Vaccine&LogisticsstockofUpazilaMunCC: Upazila EPI AEFI Investigation form need with buffer',
#  '06Vaccine&LogisticsstockofDistrict: District EPI Tally Book(Women) need with buffer',
#  '07Vaccine&LogisticsstockofUpazilaMunCC: Upazilla EPI Syringe (5 ml) stock requested',
#  '06Vaccine&LogisticsstockofDistrict: District Tally Book(Women) requested',
#  '07Vaccine&LogisticsstockofUpazilaMunCC: Upazila EPI PCV need with buffer',
#  '07Vaccine&LogisticsstockofUpazilaMunCC: Upazilla EPI zip lock bag stock requested',
#  '06Vaccine&LogisticsstockofDistrict: dist_epi_Women register closing balance',
#  '04Newborn: % of female baby admitted in SCANU reported individually',
#  '06Vaccine&LogisticsstockofDistrict: District stock register for logistic requested',
#  '06Vaccine&LogisticsstockofDistrict: dist_epi_IPV closing balance',
#  '03Immunization: MR vial wastage rate',
#  '06Vaccine&LogisticsstockofDistrict: District EPI total MR Diluent supplied on 1st delivery',
#  '07Vaccine&LogisticsstockofUpazilaMunCC: Upazilla EPI Syringe (0.1 ml) stock requested',
#  '03Immunization: Total TT Given to Pregnant Women',
#  '06Vaccine&LogisticsstockofDistrict: dist_epi_Child register closing balance',
#  '06Vaccine&LogisticsstockofDistrict: dist_epi_Moni Flag closing balance',
#  '07Vaccine&LogisticsstockofUpazilaMunCC: upazilla_epi_Supervision Form closing balance',
#  '06Vaccine&LogisticsstockofDistrict: District EPI Supervision Form need with buffer',
#  '04Newborn: Consultant Bed ratio at SCANU (Recommended 0.1)',
#  '07Vaccine&LogisticsstockofUpazilaMunCC: Upazila EPI Syringe (0.1 ml) need with buffer',
#  '07Vaccine&LogisticsstockofUpazilaMunCC: Upazilla EPI stock register for logistic stock requested',
#  '06Vaccine&LogisticsstockofDistrict: District Women register requested',
#  '06Vaccine&LogisticsstockofDistrict: dist_epi_Fridge Tag Temperature chart closing balance',
#  '02ChildHealth: Percentage of pneumonia reported at facility',
#  '06Vaccine&LogisticsstockofDistrict: District EPI total BCG Diluent supplied on 2nd delivery',
#  '07Vaccine&LogisticsstockofUpazilaMunCC: Upazilla EPI Child register stock requested',
#  '03Immunization: OPV 1 Crude Coverage %',
#  '06Vaccine&LogisticsstockofDistrict: dist_epi_Syringe (0.5 ml) closing balance',
#  '06Vaccine&LogisticsstockofDistrict: dist_epi_batch card closing balance',
#  '06Vaccine&LogisticsstockofDistrict: District EPI Moni Flag requested',
#  '04Newborn: Doctor Bed ratio at SCANU (Recommended 0.4)',
#  '06Vaccine&LogisticsstockofDistrict: District EPI total MR supplied on 1st delivery',
#  '06Vaccine&LogisticsstockofDistrict: District daily vaccine distribution register requested',
#  '07Vaccine&LogisticsstockofUpazilaMunCC: Upazilla EPI batch card stock requested',
#  '03Immunization: PCV 3 Crude Coverage %',
#  '01MaternalHealth: Proportion of cases with postpartum hemorrhage among admitted patient in EmONC',
#  '06Vaccine&LogisticsstockofDistrict: District EPI Syringe (0.5 ml) stock requested',
#  '06Vaccine&LogisticsstockofDistrict: District EPI supply book need with buffer',
#  '04Newborn: % of functional Radiant warmer',
#  '06Vaccine&LogisticsstockofDistrict: dist_epi_Women Report Book closing balance',
#  '07Vaccine&LogisticsstockofUpazilaMunCC: Upazila EPI supply book need with buffer',
#  '07Vaccine&LogisticsstockofUpazilaMunCC: Upazilla EPI AEFI form E36 - E39 stock requested',
#  '06Vaccine&LogisticsstockofDistrict: District EPI Syringe (0.1 ml) need with buffer',
#  '07Vaccine&LogisticsstockofUpazilaMunCC: Upazila EPI BCG diluent need with buffer',
#  '06Vaccine&LogisticsstockofDistrict: dist_epi_AEFI Investigation form closing balance',
#  '06Vaccine&LogisticsstockofDistrict: District EPI Safety box requested',
#  '03Immunization: OPV 2 Crude Coverage %',
#  '06Vaccine&LogisticsstockofDistrict: District EPI TT need with buffer',
#  '06Vaccine&LogisticsstockofDistrict: District EPI total OPV supplied on 1st delivery',
#  '07Vaccine&LogisticsstockofUpazilaMunCC: upazilla_epi_TT Card closing balance',
#  '06Vaccine&LogisticsstockofDistrict: District EPI total TT supplied on 1st delivery',
#  '06Vaccine&LogisticsstockofDistrict: District EPI total PCV supplied on 3rd delivery',
#  '03Immunization: Penta 1 to MR 1 drop out Rate',
#  '06Vaccine&LogisticsstockofDistrict: District EPI total MR supplied on 3rd delivery',
#  '07Vaccine&LogisticsstockofUpazilaMunCC: Upazilla EPI stock register for vaccine/diluent stock requested',
#  '01MaternalHealth: Proportion of cases with puerperal sepsis among admitted patient in EmONC',
#  '03Immunization: Total fIPV Given',
#  '04Newborn: Percentage of newborn who received postnatal care within two days of birth at facility',
#  '01MaternalHealth: Total birth in EmONC facilities',
#  '07Vaccine&LogisticsstockofUpazilaMunCC: Upazilla EPI TT Card stock requested',
#  '07Vaccine&LogisticsstockofUpazilaMunCC: Upazila EPI BCG need with buffer',
#  '07Vaccine&LogisticsstockofUpazilaMunCC: Upazila EPI Tally Book(Women) need with buffer',
#  '07Vaccine&LogisticsstockofUpazilaMunCC: Upazilla EPI PCV stock requested',
#  '03Immunization: MR 1 Crude Coverage %',
#  '07Vaccine&LogisticsstockofUpazilaMunCC: upazilla_epi_Women register closing balance',
#  '06Vaccine&LogisticsstockofDistrict: Syringe (3 ml) total supplied',
#  '06Vaccine&LogisticsstockofDistrict: District EPI Syringe (0.05 ml) need with buffer',
#  '06Vaccine&LogisticsstockofDistrict: District EPI total TT supplied on 2nd delivery',
#  '06Vaccine&LogisticsstockofDistrict: dist_epi_AEFI Form closing balance',
#  '07Vaccine&LogisticsstockofUpazilaMunCC: Upazila EPI stock register for logistic need with buffer',
#  '07Vaccine&LogisticsstockofUpazilaMunCC: upazilla_epi_fw product distribution closing balance',
#  '06Vaccine&LogisticsstockofDistrict: dist_epi_cc EPI supply book closing balance',
#  '03Immunization: Penta 1 to MR 2 drop out Rate',
#  '05Logistics: Percentage of functional ambulance',
#  '07Vaccine&LogisticsstockofUpazilaMunCC: Upazila EPI MR need with buffer',
#  '07Vaccine&LogisticsstockofUpazilaMunCC: Upazila EPI Safety Box need with buffer',
#  '07Vaccine&LogisticsstockofUpazilaMunCC: Upazilla EPI AEFI Form stock requested',
#  '06Vaccine&LogisticsstockofDistrict: dist_epi_daily vaccine distribution closing balance',
#  '07Vaccine&LogisticsstockofUpazilaMunCC: Upazila EPI Women register need with buffer',
#  '06Vaccine&LogisticsstockofDistrict: District EPI OPV stock requested',
#  '07Vaccine&LogisticsstockofUpazilaMunCC: Upazilla EPI Syringe (0.05 ml) stock requested',
#  '06Vaccine&LogisticsstockofDistrict: District EPI Moni flag need with buffer',
#  '06Vaccine&LogisticsstockofDistrict: District EPI Syringe(2/3ml) need with buffer',
#  '02ChildHealth: IMCI Total Child',
#  '06Vaccine&LogisticsstockofDistrict: District stock register for vaccine/diluent requested',
#  '07Vaccine&LogisticsstockofUpazilaMunCC: upazilla_epi_IPV closing balance',
#  '06Vaccine&LogisticsstockofDistrict: District EPI FW product distribution register need with buffer',
#  '06Vaccine&LogisticsstockofDistrict: District supply book requested',
#  '03Immunization: Total MR Given',
#  '07Vaccine&LogisticsstockofUpazilaMunCC: Upazilla EPI Child Card stock requested',
#  '06Vaccine&LogisticsstockofDistrict: District EPI batch card requested',
#  '06Vaccine&LogisticsstockofDistrict: dist_epi_PCV closing balance',
#  '06Vaccine&LogisticsstockofDistrict: District EPI CC supply book need with buffer',
#  '03Immunization: Penta 1 to Penta 3 drop out Rate',
#  '06Vaccine&LogisticsstockofDistrict: District EPI MR diluent need with buffer',
#  '07Vaccine&LogisticsstockofUpazilaMunCC: Upazilla EPI Supervision Form stock requested',
#  '07Vaccine&LogisticsstockofUpazilaMunCC: Upazilla EPI TT stock requested',
#  '07Vaccine&LogisticsstockofUpazilaMunCC: Upazilla EPI pentavalent stock requested',
#  '07Vaccine&LogisticsstockofUpazilaMunCC: Upazila EPI OPV dropper need with buffer',
#  '03Immunization: BCG to Penta 3 drop out Rate',
#  '07Vaccine&LogisticsstockofUpazilaMunCC: Upazila EPI MR vial total supplied',
#  '03Immunization: BCG Crude Coverage %',
#  '07Vaccine&LogisticsstockofUpazilaMunCC: Upazilla EPI AEFI line listing form stock requested',
#  '07Vaccine&LogisticsstockofUpazilaMunCC: Upazila EPI TT Card need with buffer',
#  '07Vaccine&LogisticsstockofUpazilaMunCC: upazilla_epi_AEFI form E36 - E39 closing balance',
#  '07Vaccine&LogisticsstockofUpazilaMunCC: Upazila EPI MR diluent need with buffer',
#  '06Vaccine&LogisticsstockofDistrict: District EPI total PCV supplied on 2nd delivery',
#  '07Vaccine&LogisticsstockofUpazilaMunCC: Upazilla EPI BCG diluent stock requested',
#  '07Vaccine&LogisticsstockofUpazilaMunCC: Upazilla EPI Child Report Book stock requested',
#  '07Vaccine&LogisticsstockofUpazilaMunCC: upazilla_epi_PCV closing balance',
#  '06Vaccine&LogisticsstockofDistrict: District EPI stock register for logistic need with buffer',
#  '07Vaccine&LogisticsstockofUpazilaMunCC: upazilla_epi_TT closing balance',
#  '06Vaccine&LogisticsstockofDistrict: dist_epi_zip lock bag closing balance',
#  '06Vaccine&LogisticsstockofDistrict: District EPI total IPV supplied on 3rd delivery',
#  '06Vaccine&LogisticsstockofDistrict: District EPI Safety Box need with buffer',
#  '06Vaccine&LogisticsstockofDistrict: dist_epi_AEFI form E36 - E39 closing balance',
#  '06Vaccine&LogisticsstockofDistrict: District EPI Women register need with buffer',
#  '06Vaccine&LogisticsstockofDistrict: District EPI Women Report Book need with buffer',
#  '07Vaccine&LogisticsstockofUpazilaMunCC: Upazilla EPI OPV dropper stock requested',
#  '06Vaccine&LogisticsstockofDistrict: dist_epi_Vaccine holder closing balance',
#  '06Vaccine&LogisticsstockofDistrict: dist_epi_TT closing balance',
#  '02ChildHealth: % of neonatal death reported individually',
#  '02ChildHealth: IMCI Underweight (%)',
#  '02ChildHealth: Neonatal Case fatality rate (EmOC)',
#  '06Vaccine&LogisticsstockofDistrict: District EPI AEFI Investigation need with buffer',
#  '07Vaccine&LogisticsstockofUpazilaMunCC: upazilla_epi_Syringe (0.5 ml) closing balance',
#  '06Vaccine&LogisticsstockofDistrict: dist_epi_Syringe (0.1 ml) closing balance',
#  '07Vaccine&LogisticsstockofUpazilaMunCC: Upazilla EPI FW product distribution register stock requested',
#  '07Vaccine&LogisticsstockofUpazilaMunCC: Upazilla EPI CC supply book stock requested',
#  '07Vaccine&LogisticsstockofUpazilaMunCC: upazilla_epi_Tally Book (child) closing balance',
#  '06Vaccine&LogisticsstockofDistrict: District EPI total Pentavalent supplied on 1st delivery',
#  '06Vaccine&LogisticsstockofDistrict: dist_epi_TT Card closing balance',
#  '07Vaccine&LogisticsstockofUpazilaMunCC: Upazila EPI daily vaccine distribution register need with buffer',
#  '06Vaccine&LogisticsstockofDistrict: District EPI MR diluent stock requested',
#  '07Vaccine&LogisticsstockofUpazilaMunCC: upazilla_epi_stock register for logistic closing balance',
#  '06Vaccine&LogisticsstockofDistrict: District EPI pentavalent stock requested',
#  '06Vaccine&LogisticsstockofDistrict: District EPI total TT supplied on 3rd delivery',
#  '04Newborn: % of female baby admitted in SCANU reported monthly',
#  '06Vaccine&LogisticsstockofDistrict: District FW product distribution register requested',
#  '06Vaccine&LogisticsstockofDistrict: dist_epi_Tally Book (Women) closing balance',
#  '07Vaccine&LogisticsstockofUpazilaMunCC: Differences between Pentavalent doses and vial uses',
#  '06Vaccine&LogisticsstockofDistrict: District EPI total BCG supplied on 3rd delivery',
#  '07Vaccine&LogisticsstockofUpazilaMunCC: upazilla_epi_OPV closing balance',
#  '06Vaccine&LogisticsstockofDistrict: District EPI total OPV supplied on 3rd delivery',
#  '06Vaccine&LogisticsstockofDistrict: Syringe (0.05 ml) total supplied',
#  '06Vaccine&LogisticsstockofDistrict: dist_epi_Syringe (0.05 ml) closing balance',
#  '07Vaccine&LogisticsstockofUpazilaMunCC: Penta vial Opening + Receive',
#  '07Vaccine&LogisticsstockofUpazilaMunCC: upazilla_epi_batch card closing balance',
#  '06Vaccine&LogisticsstockofDistrict: District EPI total BCG supplied on 2nd delivery',
#  '02ChildHealth: IMCI Wasting (%)',
#  '07Vaccine&LogisticsstockofUpazilaMunCC: Upazila EPI Moni flag need with buffer',
#  '04Newborn: % of nurse trained on IMCI working at SCANU',
#  '04Newborn: Percentage of newborns delivered by SBA at facility that received CHX (7.1%) to the cord after birth',
#  '07Vaccine&LogisticsstockofUpazilaMunCC: Upazilla EPI Women Report Book stock requested',
#  '06Vaccine&LogisticsstockofDistrict: District EPI PCV need with buffer',
#  '07Vaccine&LogisticsstockofUpazilaMunCC: upazilla_epi_AEFI line listing form closing balance',
#  '03Immunization: Total PCV Given',
#  '06Vaccine&LogisticsstockofDistrict: District EPI total Pentavalent supplied on 3rd delivery',
#  '02ChildHealth: IMCI Stunting (%)',
#  '03Immunization: Total OPV Given',
#  '04Newborn: Medical Officer Bed ratio at SCANU (Recommended 0.3)',
#  '07Vaccine&LogisticsstockofUpazilaMunCC: Upazila EPI IPV need with buffer',
#  '07Vaccine&LogisticsstockofUpazilaMunCC: upazilla_epi_Moni Flag closing balance',
#  '06Vaccine&LogisticsstockofDistrict: dist_epi_Child Report Book closing balance',
#  '06Vaccine&LogisticsstockofDistrict: District EPI MR need with buffer',
#  '06Vaccine&LogisticsstockofDistrict: District EPI total MR Diluent supplied on 3rd delivery',
#  '01MaternalHealth: % of maternal death reported individually with causes of death',
#  '03Immunization: PCV 2 Crude Coverage %',
#  '06Vaccine&LogisticsstockofDistrict: District EPI zip lock bag need with buffer',
#  '06Vaccine&LogisticsstockofDistrict: District temperature chart requested',
#  '03Immunization: Pentavalent vial use and doses ratio',
#  '06Vaccine&LogisticsstockofDistrict: District EPI BCG diluent need with buffer',
#  '06Vaccine&LogisticsstockofDistrict: District EPI BCG diluent stock requested',
#  '01MaternalHealth: Total deliveries in EmONC facilities',
#  '06Vaccine&LogisticsstockofDistrict: Syringe (0.1 ml) total supplied',
#  '06Vaccine&LogisticsstockofDistrict: Syringe (0.5 ml) total supplied',
#  '07Vaccine&LogisticsstockofUpazilaMunCC: upazilla_epi_cc EPI supply book closing balance',
#  '01MaternalHealth: Maternal Case fatality rate (EmOC)',
#  '06Vaccine&LogisticsstockofDistrict: District EPI AEFI line listing form need with buffer',
#  '07Vaccine&LogisticsstockofUpazilaMunCC: Upazilla EPI temperature chart stock requested',
#  'AntenatalCare(ANC): 3rd & more ANC',
#  '07Vaccine&LogisticsstockofUpazilaMunCC: upazilla_epi_daily vaccine distribution closing balance',
#  '06Vaccine&LogisticsstockofDistrict: dist_epi_OPV dropper closing balance',
#  '03Immunization: TT vial wastage rate',
#  '01MaternalHealth: Total Complicated Mother',
#  'imp12distr_monthprocessImp12DistrMonthThana_Percent_PerMale',
#  'imp12distr_monthprocessImp12DistrMonthThana_Percent_Injectable',
#  'distr_GOdistr_GOShukhi',
#  'distr_GOdistr_GOCondom',
#  'distr_GOdistr_GOPermanent_method',
#  'distr_GOdistr_GOecp',
#  'distr_GOdistr_GOPill_total',
#  'imp11subdistr_thanaprocessPercent_IUD',
#  'imp11subdistr_ngothanaprocessNGO_Percent_PerMale',
#  'imp11subdistr_thanaprocessPercent_PerFemale',
#  'imp11subdistr_thanaprocessCAR',
#  'distr_GOdistr_GOIUD_remove',
#  'distr_GOdistr_GOmnp_saset',
#  'imp12distr_monthprocessImp12DistrMonthThana_Percent_Implant',
#  'distr_GOdistr_GOImp_total',
#  'distr_GOdistr_GOIUD_partum',
#  'distr_GOdistr_GOApon',
#  'distr_GOdistr_GOimplant_remove',
#  'imp11subdistr_ngothanaprocessNGO_Percent_IUD',
#  'imp11subdistr_thanaprocessPercent_Injectable',
#  'Imp12DistrNGOMonthThana_Percent_PerMale',
#  'Imp12DistrNGOMonthThana_Percent_Condom',
#  'imp11subdistr_thanaprocessPercent_Condom',
#  'imp12distr_monthprocessImp12DistrMonthThana_Percent_IUD',
#  'distr_GOdistr_GOifa_number',
#  'Imp12DistrNGOMonthThana_Percent_IUD',
#  'imp11subdistr_ngothanaprocessNGO_Percent_Injectable',
#  'imp11subdistr_ngothanaprocessNGO_Percent_Condom',
#  'distr_GOdistr_GOInj_vial',
#  'imp12distr_monthprocessImp12DistrMonthThana_Percent_Pill',
#  'distr_GOdistr_GOmisoprostol',
#  'distr_GOdistr_GOinj_mgs4',
#  'distr_GOdistr_GOIUD_total',
#  'imp11subdistr_ngothanaprocessNGO_Percent_Pill',
#  'distr_GOdistr_GOper_male',
#  'imp12distr_monthprocessImp12DistrMonthThana_Percent_Condom',
#  'Imp12DistrNGOMonthThana_Percent_Implant',
#  'distr_GOdistr_GOfemalepn',
#  'distr_GOdistr_GOfemalenormal',
#  'imp11subdistr_thanaprocessPercent_Pill',
#  'imp11subdistr_ngothanaprocessNGO_CAR',
#  'distr_GOdistr_GOInj_siringe',
#  'distr_GOdistr_GOImp_normal',
#  'imp11subdistr_thanaprocessPercent_Implant',
#  'Imp12DistrNGOMonthThana_Percent_PerFemale',
#  'distr_GOdistr_GOfemale_total',
#  'imp11subdistr_ngothanaprocessNGO_Percent_PerFemale',
#  'Imp12DistrNGOMonthThana_Percent_Pill',
#  'Imp12DistrNGOMonthThana_Percent_Injectable',
#  'distr_GOdistr_GOmrm_pack',
#  'imp12distr_monthprocessImp12DistrMonthThana_Percent_PerFemale',
#  'distr_GOdistr_GOImp_Jadel',
#  'imp11subdistr_ngothanaprocessNGO_Percent_Implant',
#  'imp11subdistr_thanaprocessPercent_PerMale',
#  'distr_GOdistr_GOIUD_normal',
#  'Imp12DistrNGOMonthThana_CAR',
#  'imp12distr_monthprocessImp12DistrMonthThana_CAR',
#  'distr_GOdistr_GOsanitary_pad',
#  'prop_women_15.45y_overwomen',
#  'prop_pop_rural_women',
#  'prop_current_contraceptive',
#  'prop_caesarean',
#  'prop_registered_under5',
#  'prop_institutional_delivery',
#  'dependency_ratio',
#  'prop_married_..15y',
#  'sex_ratio',
#  'prop_pop_rural',
#  'prop_antenatal_coverage',
#  'prop_unmet_need_family_planing',
#  'prop_married_women_15.45y',
#  'prop_antenatal_care4.',
#  'prop_female_head',
#  'prop_pop_women',
#  'prop_attendant_delivery']

# %%
df2011.to_csv('/Users/edinhamzic/Symphony/wb_bangladesh/Bangladesh/output/all/all2011.csv', index=False, index_label=False)
df2016.to_csv('/Users/edinhamzic/Symphony/wb_bangladesh/Bangladesh/output/all/all2016.csv', index=False, index_label=False)

# %%
df2011['year'] = 2011
df2016['year'] = 2016
tmp = pd.concat([df2011, df2016], axis=0)
tmp.to_csv('/Users/edinhamzic/Symphony/wb_bangladesh/Bangladesh/output/all/all.csv')
print(tmp.shape)
# Out:
# (128, 469)
