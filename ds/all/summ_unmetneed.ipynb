# %% [markdown]
# # Tables: Unmet needs

# %%
import pandas as pd

# %%
DATA = '/Users/edinhamzic/Symphony/wb_bangladesh/Bangladesh/output/all/'
clusters_intersect_all = 'clusters_unmet_needs_vars_intersect_all.csv'
clusters_intersect_2016 = 'clusters_unmet_needs_vars_intersect_2016.csv'
clusters_intersect_2011 = 'clusters_unmet_needs_vars_intersect_2011.csv'
clusters_union_all = 'clusters_unmet_needs_vars_union_all.csv'
clusters_union_2016 = 'clusters_unmet_needs_vars_union_2016.csv'
clusters_union_2011 = 'clusters_unmet_needs_vars_union_2011.csv'
corr_2016 = 'corr_unmet_needs_2016.csv'
cca_2016 = 'cca_unmet_needs_2016.csv'
corr_2011 = 'corr_unmet_needs_2011.csv'
cca_2011 = 'cca_unmet_needs_2011.csv'
corr_cca = [corr_2011, cca_2011, corr_2016, cca_2016]

# %%
def read_corr_cca(dir_path, files_list):
    data_dict = {}
    for file in files_list:
        data_dict[file] = pd.read_csv(dir_path+file)
    return data_dict

# %% [markdown]
# ## Summary tables

# %%
clusters_intersect = pd.read_csv(DATA+clusters_intersect_all)
clusters_union = pd.read_csv(DATA+clusters_union_all)

# %%
clusters_intersect_summ = clusters_intersect.groupby(['cluster', 'year']).median().transpose()
clusters_union_summ = clusters_union.groupby(['cluster', 'year']).median().transpose()

# %%
display(clusters_intersect_summ.head())
clusters_intersect_summ.to_csv(DATA+'/unmetneeds_summaries/unmetneeds_intersect.csv')
# Out:
# cluster                                                  0               1  \
# year                                                  2011    2016    2011
# Crude coverage OPV 1, %                             97.800  98.450  98.300
# Distributed condoms out of total (month, thana), %   6.420   6.925   9.600
# DHS: Proportion of women (15-45 years)              46.085  48.180  47.705
# Distributed condoms out of total (thana), %          6.420   6.920   9.600
# Crude coverage measles children 23 months, %        84.850  91.250  88.100
#
# cluster                                                         2         \
# year                                                 2016    2011   2016
# Crude coverage OPV 1, %                             98.85  99.600  99.00
# Distributed condoms out of total (month, thana), %  11.02   5.685   6.80
# DHS: Proportion of women (15-45 years)              48.36  50.880  51.46
# Distributed condoms out of total (thana), %         11.02   5.685   6.80
# Crude coverage measles children 23 months, %        93.15  90.700  93.30
#
# cluster                                                  3
# year                                                  2011   2016
# Crude coverage OPV 1, %                             98.600  99.60
# Distributed condoms out of total (month, thana), %  10.370  10.72
# DHS: Proportion of women (15-45 years)              53.815  51.74
# Distributed condoms out of total (thana), %         10.370  10.72
# Crude coverage measles children 23 months, %        89.650  92.50

# %%
pd.set_option('display.max_rows', 500)
display(clusters_union_summ)
clusters_union_summ.to_csv(DATA+'/unmetneeds_summaries/unmetneeds_union.csv')
# Out:
# cluster                                                      0              \
# year                                                      2011        2016
# Crude coverage BCG children 23 months, %             99.500000  100.000000
# Crude coverage penta 3 children 23 months, %         88.550000   92.100000
# Crude coverage OPV 1, %                              96.750000   98.200000
# Distributed pills out of total (month, thana) N...   46.815000   42.830000
# Cases with puerperal sepsis among admitted pati...    0.220000    0.320000
# Crude coverage PCV 3, %                              96.150000   95.900000
# Distributed condoms out of total (thana), %          10.245000   10.660000
# Crude coverage measles children 23 months, %         87.400000   94.000000
# Diarrhea reported at facility, %                     12.260000   12.950000
# DHS: Proportion of married women (15-45 years)       77.150000   79.640000
# DHS: Proportion of rural population                   5.375000   13.970000
# Non-functional photo therapty unit, %                17.209091   15.423529
# IPV vial wastage rate                                 8.000000   18.300000
# Rate of distributed IUDs (normal)                     2.970700    7.261700
# Distributed condoms out of total (month, thana)...   14.700000   15.050000
# Medical officer bed ratio at SCANU (recommended...    0.056250    0.054545
# Fully vaccinated children 23 months, %               80.900000   89.800000
# Crude coverage penta 2 children 23 months, %         98.450000   97.800000
# Functional ambulance, %                              60.890000   61.180000
# Crude coverage penta 3 children 12 months, %         87.850000   91.400000
# Performed permanent methods out of total (month...    1.940000    1.750000
# Crude coverage BCG children 12 months, %             99.500000  100.000000
# Crude coverage penta 1 children 12 months, %         99.150000   98.000000
# Rate of distributed misoprostol (dose)                0.000000   16.936800
# Nurse trained on IMCI working at SCANU, %            43.444444   59.648276
# Crude coverage penta 2, %                            97.050000   97.900000
# TT vial wastage rate                                 18.350000   23.800000
# Crude coverage measles children 12 months, %         84.300000   87.700000
# Performed permanent methods out of total NGO (m...    1.325000    2.040000
# Nurse training on KMC at SCANU, %                    66.354167   63.611538
# Distributed implants out of total, %                  1.770000    3.540000
# Proportion of rural deaths                           77.000000   84.000000
# Crude coverage OPV 0, %                               4.050000    3.600000
# DHS: Proportion of use of current contraceptive...   46.460000   49.220000
# Contraceptive acceptance rate (month, thana), %      74.250000   75.050000
# Nurse training on ETAT at SCANU, %                  147.895833  179.273077
# Crude coverage OPV 2 children 23 months, %           98.450000   97.800000
# Non-functioning table resuscitator with radiant...   33.577419   30.150000
# Proportion of women (15-45 years)                    48.285000   49.960000
# Contraceptive acceptance rate (CAR) NGO (month,...   76.402583   78.270000
# Distributed IUDs out of total (month, thana), %       5.500000    4.950000
# DHS: Proportion of females as head of household      14.805000   12.480000
# Proportion of live births                            98.905000   96.530000
# Distributed pills out of total (thana) NGO, %        46.815000   42.830000
# Proportion of cases with puerperal sepsis among...    0.002200    0.003200
# IMCI wasting, %                                       0.885000    0.730000
# Crude coverage OPV 2, %                              96.950000   97.700000
# Crude coverage OPV1 children 12 months, %            98.950000   98.000000
# Crude coverage OPV 2 children 12 months, %           97.750000   97.800000
# DHS: Proportion of registered                        37.075000   18.400000
# Pentavalent 1 crude coverage, %                      97.100000   98.200000
# Crude coverage TT5 among mothers with 0-11 chil...   49.750000   57.700000
# Crude coverage OPV 3 children 12 months, %           94.000000   91.400000
# Pneumonia reported at facility, %                     6.050000    7.420000
# Crude coverage TT1 among mothers with 0-11 mont...   97.850000   98.100000
# Crude coverage PCV 1, %                              97.150000   97.800000
# Newborn who received postnatal care within two ...   24.750000   32.500000
# DHS: Proportion of antenatal coverage                37.095000   57.450000
# BCG to penta 3 dropout rate                           1.045000    1.500000
# Proportion of married women (15-45 years)            72.735000   75.760000
# BCG vial wastage rate                                84.700000   83.200000
# Crude coverage of PCV 2, %                           97.150000   97.200000
# Crude coverage fIPV1, %                              91.300000   39.800000
# Crude coverage OPV 1 children 23 months, %           99.250000   98.100000
# Distributed pills out of total (thana), %            50.485000   46.430000
# Distributed condoms out of total (month, thana), %   10.245000   10.660000
# Distributed implants out of total (thana), %          1.770000    3.540000
# BCG left-out rate                                     2.100000    1.300000
# DHS: Proportion of women (15-45 years)               46.885000   49.830000
# Dependency ratio                                     61.630000   63.770000
# Contraceptive acceptance rate (thana), %             74.250000   75.050000
# DHS: Proporation of married women (15 years)         69.820000   70.700000
# Distributed condoms out of total (thana) NGO, %      14.700000   15.050000
# Birth rate                                           18.350000   20.120000
# Contraceptive acceptance rate (thana) NGO, %         76.402583   78.270000
# Fully vaccinated children 12 months, %               76.600000   84.100000
# DHS: Sex ratio (males / females)                     84.110000   90.950000
# Crude coverage penta 1 children 23 months, %         99.500000   98.100000
# Distributed IUDs out of total (thana), %              5.500000    4.950000
# Crude coverage BCG, %                                97.900000   98.700000
# Functional radiant warmer, %                         19.989286   23.179310
# Death rate                                            4.895000    5.260000
# Rate of distributed implant EEW (total)               2.970700    8.405000
# DHS: Proportion of women population                  62.610000   54.640000
# Rate of distributed injectable vials                156.577550  341.005400
# Distributed pills out of total, %                    50.485000   46.430000
# Crude coverage OPV 3, %                              96.400000   97.700000
# Crude coverage OPV 3 children 23 months, %           94.850000   92.100000
# DHS: Proportion of C-sections                        10.450000   13.970000
# Crude coverage penta 3, %                            96.400000   97.200000
# DHS: Proportion of institutional deliveries          17.665000   22.120000
# Proportion of cases with postpartum hemorrhage ...    0.009450    0.009500
# MR vial wastage rate                                 46.900000   46.700000
# Postpartum hemorrhage among admitted patient in...    0.945000    0.950000
# DHS: Dependency ratio                                75.305000   76.870000
# Proportion of women population                       49.560000   50.800000
# Crude coverage penta 2 children 12 months, %         97.750000   97.800000
# DHS: Proportion of attendant deliveries              20.775000   29.220000
# Distributed IUDs out of total (thana) NGO, %          4.715000    5.520000
# Vitamin A coverage children 12-59 months, %          95.000000   90.000000
# DHS: Proportion of antental coverage 4+              18.080000   25.220000
# Performed permanent methods out of total (month...    1.325000    2.040000
# Distributed IUDs out of total (month thana) NGO, %    4.715000    5.520000
# Case fatality rate at SCANU                           8.332353    8.473529
# IMCI stunting, %                                      0.860000    1.200000
# Performed permanent methods out of total (month...   10.275000   11.420000
# Rate of distributed MRMs (pack)                       0.000000    0.070900
# Crude coverage MR 1, %                               97.300000   97.500000
# Fertility rate                                       79.620000   80.160000
# Sex ratio                                           101.785000   96.870000
# Crude coverage TT2 among mothers with 0-11 chil...   96.650000   95.800000
# Performed permanent methods out of total (thana...    1.940000    1.750000
# Performed permanent methods out of total (thana...   10.275000   11.420000
# Maternal case fatality rate (EmOC)                    0.076800    0.161500
# Proportion of married women (15 years)               66.300000   70.500000
# DHS: Unmet need for family planning                  20.925000   16.240000
#
# cluster                                                      1              \
# year                                                      2011        2016
# Crude coverage BCG children 23 months, %             99.500000   99.800000
# Crude coverage penta 3 children 23 months, %         91.800000   92.100000
# Crude coverage OPV 1, %                              99.450000   99.800000
# Distributed pills out of total (month, thana) N...   49.060000   43.830000
# Cases with puerperal sepsis among admitted pati...    0.100000    0.080000
# Crude coverage PCV 3, %                              98.050000   97.200000
# Distributed condoms out of total (thana), %           5.965000    7.630000
# Crude coverage measles children 23 months, %         90.700000   93.700000
# Diarrhea reported at facility, %                     10.700000   11.330000
# DHS: Proportion of married women (15-45 years)       83.890000   82.400000
# DHS: Proportion of rural population                  12.285000   15.580000
# Non-functional photo therapty unit, %                17.209091   15.423529
# IPV vial wastage rate                                13.350000   14.000000
# Rate of distributed IUDs (normal)                     7.683150    8.149500
# Distributed condoms out of total (month, thana)...   10.955000   10.420000
# Medical officer bed ratio at SCANU (recommended...    0.056250    0.054545
# Fully vaccinated children 23 months, %               85.600000   88.400000
# Crude coverage penta 2 children 23 months, %         98.600000   98.200000
# Functional ambulance, %                              71.210000   70.980000
# Crude coverage penta 3 children 12 months, %         91.100000   91.900000
# Performed permanent methods out of total (month...    4.120000    4.460000
# Crude coverage BCG children 12 months, %             99.500000   99.800000
# Crude coverage penta 1 children 12 months, %         99.500000   98.800000
# Rate of distributed misoprostol (dose)                0.000000   22.120200
# Nurse trained on IMCI working at SCANU, %            43.444444   59.648276
# Crude coverage penta 2, %                            98.800000   99.200000
# TT vial wastage rate                                 18.700000   26.000000
# Crude coverage measles children 12 months, %         88.900000   89.700000
# Performed permanent methods out of total NGO (m...    3.110000    3.200000
# Nurse training on KMC at SCANU, %                    66.354167   63.611538
# Distributed implants out of total, %                  2.485000    5.050000
# Proportion of rural deaths                           72.000000   72.000000
# Crude coverage OPV 0, %                               8.450000   10.700000
# DHS: Proportion of use of current contraceptive...   68.540000   65.320000
# Contraceptive acceptance rate (month, thana), %      79.545000   78.740000
# Nurse training on ETAT at SCANU, %                  147.895833  179.273077
# Crude coverage OPV 2 children 23 months, %           98.600000   98.200000
# Non-functioning table resuscitator with radiant...   33.577419   30.150000
# Proportion of women (15-45 years)                    51.250000   51.320000
# Contraceptive acceptance rate (CAR) NGO (month,...   80.225000   80.950000
# Distributed IUDs out of total (month, thana), %       2.675000    2.830000
# DHS: Proportion of females as head of household       4.170000    6.990000
# Proportion of live births                            99.025000   97.130000
# Distributed pills out of total (thana) NGO, %        49.060000   43.830000
# Proportion of cases with puerperal sepsis among...    0.001000    0.000800
# IMCI wasting, %                                       0.720000    0.690000
# Crude coverage OPV 2, %                              98.750000   98.900000
# Crude coverage OPV1 children 12 months, %            99.500000   98.800000
# Crude coverage OPV 2 children 12 months, %           98.600000   98.200000
# DHS: Proportion of registered                        27.915000   17.590000
# Pentavalent 1 crude coverage, %                      99.200000  100.400000
# Crude coverage TT5 among mothers with 0-11 chil...   40.500000   52.400000
# Crude coverage OPV 3 children 12 months, %           96.300000   91.900000
# Pneumonia reported at facility, %                     4.980000    5.830000
# Crude coverage TT1 among mothers with 0-11 mont...   98.600000   99.200000
# Crude coverage PCV 1, %                              98.950000   99.800000
# Newborn who received postnatal care within two ...   20.300000   21.300000
# DHS: Proportion of antenatal coverage                41.040000   56.460000
# BCG to penta 3 dropout rate                           2.150000    1.700000
# Proportion of married women (15-45 years)            78.415000   80.250000
# BCG vial wastage rate                                86.050000   85.800000
# Crude coverage of PCV 2, %                           98.350000   98.800000
# Crude coverage fIPV1, %                              91.900000   45.400000
# Crude coverage OPV 1 children 23 months, %           99.500000   98.800000
# Distributed pills out of total (thana), %            53.360000   49.260000
# Distributed condoms out of total (month, thana), %    5.965000    7.630000
# Distributed implants out of total (thana), %          2.485000    5.050000
# BCG left-out rate                                     0.505000   -0.460000
# DHS: Proportion of women (15-45 years)               51.110000   51.100000
# Dependency ratio                                     51.640000   51.750000
# Contraceptive acceptance rate (thana), %             79.555000   78.740000
# DHS: Proporation of married women (15 years)         76.770000   75.190000
# Distributed condoms out of total (thana) NGO, %      10.955000   10.420000
# Birth rate                                           19.355000   18.180000
# Contraceptive acceptance rate (thana) NGO, %         80.225000   80.950000
# Fully vaccinated children 12 months, %               83.450000   85.600000
# DHS: Sex ratio (males / females)                     97.635000   94.060000
# Crude coverage penta 1 children 23 months, %         99.500000   98.800000
# Distributed IUDs out of total (thana), %              2.675000    2.830000
# Crude coverage BCG, %                                99.500000  100.500000
# Functional radiant warmer, %                         19.989286   23.179310
# Death rate                                            5.785000    5.200000
# Rate of distributed implant EEW (total)               7.683150    8.574100
# DHS: Proportion of women population                  44.665000   41.480000
# Rate of distributed injectable vials                372.767900  290.322400
# Distributed pills out of total, %                    53.345000   49.260000
# Crude coverage OPV 3, %                              98.500000   98.400000
# Crude coverage OPV 3 children 23 months, %           96.650000   92.100000
# DHS: Proportion of C-sections                        17.265000   27.350000
# Crude coverage penta 3, %                            98.200000   99.100000
# DHS: Proportion of institutional deliveries          29.290000   40.730000
# Proportion of cases with postpartum hemorrhage ...    0.007650    0.006200
# MR vial wastage rate                                 54.650000   56.800000
# Postpartum hemorrhage among admitted patient in...    0.765000    0.620000
# DHS: Dependency ratio                                59.860000   59.380000
# Proportion of women population                       49.385000   49.730000
# Crude coverage penta 2 children 12 months, %         98.600000   98.200000
# DHS: Proportion of attendant deliveries              32.860000   44.630000
# Distributed IUDs out of total (thana) NGO, %          3.055000    4.330000
# Vitamin A coverage children 12-59 months, %          95.450000   94.000000
# DHS: Proportion of antental coverage 4+              26.420000   32.390000
# Performed permanent methods out of total (month...    3.110000    3.200000
# Distributed IUDs out of total (month thana) NGO, %    3.055000    4.330000
# Case fatality rate at SCANU                           8.332353    8.473529
# IMCI stunting, %                                      1.400000    1.100000
# Performed permanent methods out of total (month...   10.545000    8.540000
# Rate of distributed MRMs (pack)                       0.000000    0.053800
# Crude coverage MR 1, %                               98.200000   99.900000
# Fertility rate                                       75.915000   69.730000
# Sex ratio                                           102.480000  101.090000
# Crude coverage TT2 among mothers with 0-11 chil...   96.900000   98.300000
# Performed permanent methods out of total (thana...    4.120000    4.460000
# Performed permanent methods out of total (thana...   10.545000    8.540000
# Maternal case fatality rate (EmOC)                    0.070300    0.023500
# Proportion of married women (15 years)               71.605000   74.020000
# DHS: Unmet need for family planning                   9.485000   10.010000
#
# cluster                                                      2              \
# year                                                      2011        2016
# Crude coverage BCG children 23 months, %             96.450000   98.500000
# Crude coverage penta 3 children 23 months, %         86.400000   87.300000
# Crude coverage OPV 1, %                              97.850000   99.250000
# Distributed pills out of total (month, thana) N...   48.990500   44.877016
# Cases with puerperal sepsis among admitted pati...    0.125000    0.135000
# Crude coverage PCV 3, %                              97.250000   95.850000
# Distributed condoms out of total (thana), %           8.775000   11.295000
# Crude coverage measles children 23 months, %         81.800000   89.950000
# Diarrhea reported at facility, %                     13.815000    8.930000
# DHS: Proportion of married women (15-45 years)       76.870000   72.085000
# DHS: Proportion of rural population                   6.685000    9.690000
# Non-functional photo therapty unit, %                 0.500000   15.423529
# IPV vial wastage rate                                13.200000   31.000000
# Rate of distributed IUDs (normal)                     4.228400    4.787300
# Distributed condoms out of total (month, thana)...   13.621167   14.099839
# Medical officer bed ratio at SCANU (recommended...    0.028125    0.054545
# Fully vaccinated children 23 months, %               78.100000   84.100000
# Crude coverage penta 2 children 23 months, %         93.400000   93.500000
# Functional ambulance, %                              68.900000   69.950000
# Crude coverage penta 3 children 12 months, %         85.550000   87.200000
# Performed permanent methods out of total (month...    4.235000    4.395000
# Crude coverage BCG children 12 months, %             95.700000   98.500000
# Crude coverage penta 1 children 12 months, %         95.700000   94.950000
# Rate of distributed misoprostol (dose)                0.000000    9.156150
# Nurse trained on IMCI working at SCANU, %           120.600000   59.648276
# Crude coverage penta 2, %                            95.850000   98.150000
# TT vial wastage rate                                 20.250000   28.250000
# Crude coverage measles children 12 months, %         77.950000   84.550000
# Performed permanent methods out of total NGO (m...    2.088167    2.438548
# Nurse training on KMC at SCANU, %                    66.354167   63.611538
# Distributed implants out of total, %                  2.980000    5.165000
# Proportion of rural deaths                           68.000000   73.500000
# Crude coverage OPV 0, %                               3.950000    5.950000
# DHS: Proportion of use of current contraceptive...   50.605000   60.920000
# Contraceptive acceptance rate (month, thana), %      75.780000   79.080000
# Nurse training on ETAT at SCANU, %                  147.895833  179.273077
# Crude coverage OPV 2 children 23 months, %           93.550000   93.500000
# Non-functioning table resuscitator with radiant...   17.700000   30.150000
# Proportion of women (15-45 years)                    48.090000   50.055000
# Contraceptive acceptance rate (CAR) NGO (month,...   76.735167   81.990000
# Distributed IUDs out of total (month, thana), %       4.765000    4.350000
# DHS: Proportion of females as head of household      10.435000   10.380000
# Proportion of live births                            98.575000   98.030000
# Distributed pills out of total (thana) NGO, %        48.990500   44.877016
# Proportion of cases with puerperal sepsis among...    0.001250    0.001350
# IMCI wasting, %                                       0.325000    0.310000
# Crude coverage OPV 2, %                              96.500000   98.400000
# Crude coverage OPV1 children 12 months, %            95.700000   94.950000
# Crude coverage OPV 2 children 12 months, %           92.950000   93.050000
# DHS: Proportion of registered                        31.520000   23.270000
# Pentavalent 1 crude coverage, %                      97.900000   99.250000
# Crude coverage TT5 among mothers with 0-11 chil...   42.400000   51.150000
# Crude coverage OPV 3 children 12 months, %           89.100000   87.200000
# Pneumonia reported at facility, %                     8.025000    7.690000
# Crude coverage TT1 among mothers with 0-11 mont...   94.550000   95.700000
# Crude coverage PCV 1, %                              98.800000   99.550000
# Newborn who received postnatal care within two ...   37.000000   20.550000
# DHS: Proportion of antenatal coverage                31.100000   56.505000
# BCG to penta 3 dropout rate                           2.550000    2.350000
# Proportion of married women (15-45 years)            70.590000   73.625000
# BCG vial wastage rate                                86.000000   85.700000
# Crude coverage of PCV 2, %                           97.750000   98.200000
# Crude coverage fIPV1, %                              95.300000   48.500000
# Crude coverage OPV 1 children 23 months, %           96.450000   95.050000
# Distributed pills out of total (thana), %            50.405000   48.600000
# Distributed condoms out of total (month, thana), %    8.775000   11.290000
# Distributed implants out of total (thana), %          2.980000    5.160000
# BCG left-out rate                                     0.830000   -0.265000
# DHS: Proportion of women (15-45 years)               43.605000   49.140000
# Dependency ratio                                     63.580000   58.115000
# Contraceptive acceptance rate (thana), %             75.780000   79.080000
# DHS: Proporation of married women (15 years)         69.770000   68.985000
# Distributed condoms out of total (thana) NGO, %      13.621167   14.099839
# Birth rate                                           18.645000   18.765000
# Contraceptive acceptance rate (thana) NGO, %         76.735167   81.990000
# Fully vaccinated children 12 months, %               74.150000   80.000000
# DHS: Sex ratio (males / females)                     90.815000   94.375000
# Crude coverage penta 1 children 23 months, %         96.450000   95.050000
# Distributed IUDs out of total (thana), %              4.765000    4.350000
# Crude coverage BCG, %                                99.150000  100.250000
# Functional radiant warmer, %                         13.244643   23.179310
# Death rate                                            4.245000    5.160000
# Rate of distributed implant EEW (total)               4.228400    4.856800
# DHS: Proportion of women population                  66.165000   69.165000
# Rate of distributed injectable vials                318.516450  150.574900
# Distributed pills out of total, %                    50.405000   48.600000
# Crude coverage OPV 3, %                              95.800000   97.050000
# Crude coverage OPV 3 children 23 months, %           90.000000   87.300000
# DHS: Proportion of C-sections                         7.735000   15.635000
# Crude coverage penta 3, %                            95.500000   98.250000
# DHS: Proportion of institutional deliveries           9.990000   22.865000
# Proportion of cases with postpartum hemorrhage ...    0.009400    0.005500
# MR vial wastage rate                                 51.300000   65.050000
# Postpartum hemorrhage among admitted patient in...    0.940000    0.550000
# DHS: Dependency ratio                                89.820000   69.010000
# Proportion of women population                       49.360000   49.990000
# Crude coverage penta 2 children 12 months, %         92.950000   93.050000
# DHS: Proportion of attendant deliveries              15.515000   26.070000
# Distributed IUDs out of total (thana) NGO, %          3.354417    4.589355
# Vitamin A coverage children 12-59 months, %          91.650000   90.350000
# DHS: Proportion of antental coverage 4+              14.190000   18.280000
# Performed permanent methods out of total (month...    2.088167    2.438548
# Distributed IUDs out of total (month thana) NGO, %    3.354417    4.589355
# Case fatality rate at SCANU                           8.100000    8.473529
# IMCI stunting, %                                      1.005000    0.520000
# Performed permanent methods out of total (month...    8.920000    8.845000
# Rate of distributed MRMs (pack)                       0.000000    0.021550
# Crude coverage MR 1, %                               94.550000   97.050000
# Fertility rate                                       78.490000   75.520000
# Sex ratio                                           102.610000  100.045000
# Crude coverage TT2 among mothers with 0-11 chil...   91.700000   93.650000
# Performed permanent methods out of total (thana...    4.235000    4.390000
# Performed permanent methods out of total (thana...    8.920000    8.840000
# Maternal case fatality rate (EmOC)                    0.234950    0.019950
# Proportion of married women (15 years)               64.905000   71.690000
# DHS: Unmet need for family planning                  19.530000   12.345000
#
# cluster                                                      3
# year                                                      2011        2016
# Crude coverage BCG children 23 months, %             99.500000   99.550000
# Crude coverage penta 3 children 23 months, %         89.050000   90.700000
# Crude coverage OPV 1, %                              99.700000   98.200000
# Distributed pills out of total (month, thana) N...   48.640000   45.760000
# Cases with puerperal sepsis among admitted pati...    0.245000    0.140000
# Crude coverage PCV 3, %                              98.200000   95.700000
# Distributed condoms out of total (thana), %           8.775000    8.100000
# Crude coverage measles children 23 months, %         88.250000   92.050000
# Diarrhea reported at facility, %                     11.800000   12.055000
# DHS: Proportion of married women (15-45 years)       79.360000   81.005000
# DHS: Proportion of rural population                  22.430000   15.160000
# Non-functional photo therapty unit, %                17.209091   15.423529
# IPV vial wastage rate                                12.000000   17.850000
# Rate of distributed IUDs (normal)                     7.489000   12.400650
# Distributed condoms out of total (month, thana)...   13.035000   13.130000
# Medical officer bed ratio at SCANU (recommended...    0.056250    0.054545
# Fully vaccinated children 23 months, %               81.400000   86.600000
# Crude coverage penta 2 children 23 months, %         97.400000   97.200000
# Functional ambulance, %                              68.495000   64.075000
# Crude coverage penta 3 children 12 months, %         89.050000   90.300000
# Performed permanent methods out of total (month...    2.090000    3.430000
# Crude coverage BCG children 12 months, %             99.500000   99.550000
# Crude coverage penta 1 children 12 months, %         99.250000   97.500000
# Rate of distributed misoprostol (dose)                0.000000   39.559400
# Nurse trained on IMCI working at SCANU, %            43.444444   59.648276
# Crude coverage penta 2, %                            97.600000   98.350000
# TT vial wastage rate                                 15.500000   23.850000
# Crude coverage measles children 12 months, %         83.850000   87.350000
# Performed permanent methods out of total NGO (m...    1.300000    1.795000
# Nurse training on KMC at SCANU, %                    66.354167   63.611538
# Distributed implants out of total, %                  2.500000    4.570000
# Proportion of rural deaths                           68.500000   80.500000
# Crude coverage OPV 0, %                               8.100000    5.950000
# DHS: Proportion of use of current contraceptive...   61.500000   66.440000
# Contraceptive acceptance rate (month, thana), %      76.140000   77.860000
# Nurse training on ETAT at SCANU, %                  147.895833  179.273077
# Crude coverage OPV 2 children 23 months, %           97.850000   97.200000
# Non-functioning table resuscitator with radiant...   33.577419   30.150000
# Proportion of women (15-45 years)                    49.455000   49.205000
# Contraceptive acceptance rate (CAR) NGO (month,...   74.490000   79.610000
# Distributed IUDs out of total (month, thana), %       3.940000    3.375000
# DHS: Proportion of females as head of household      10.275000   13.090000
# Proportion of live births                            98.515000   96.720000
# Distributed pills out of total (thana) NGO, %        48.640000   45.760000
# Proportion of cases with puerperal sepsis among...    0.002450    0.001400
# IMCI wasting, %                                       0.540000    0.750000
# Crude coverage OPV 2, %                              98.950000   98.100000
# Crude coverage OPV1 children 12 months, %            99.000000   97.500000
# Crude coverage OPV 2 children 12 months, %           97.850000   96.600000
# DHS: Proportion of registered                        29.135000   19.400000
# Pentavalent 1 crude coverage, %                      98.300000   98.900000
# Crude coverage TT5 among mothers with 0-11 chil...   40.750000   51.200000
# Crude coverage OPV 3 children 12 months, %           94.000000   90.300000
# Pneumonia reported at facility, %                     6.890000    7.300000
# Crude coverage TT1 among mothers with 0-11 mont...   97.850000   98.050000
# Crude coverage PCV 1, %                              99.350000   98.400000
# Newborn who received postnatal care within two ...   29.600000   31.300000
# DHS: Proportion of antenatal coverage                33.150000   56.415000
# BCG to penta 3 dropout rate                           2.400000    1.700000
# Proportion of married women (15-45 years)            73.935000   79.640000
# BCG vial wastage rate                                83.650000   84.700000
# Crude coverage of PCV 2, %                           98.900000   98.150000
# Crude coverage fIPV1, %                              96.350000   44.850000
# Crude coverage OPV 1 children 23 months, %           99.000000   97.800000
# Distributed pills out of total (thana), %            52.895000   49.700000
# Distributed condoms out of total (month, thana), %    8.770000    8.100000
# Distributed implants out of total (thana), %          2.500000    4.570000
# BCG left-out rate                                     0.065000    0.435000
# DHS: Proportion of women (15-45 years)               47.735000   50.740000
# Dependency ratio                                     56.330000   58.120000
# Contraceptive acceptance rate (thana), %             76.105000   77.860000
# DHS: Proporation of married women (15 years)         73.420000   75.380000
# Distributed condoms out of total (thana) NGO, %      13.035000   13.130000
# Birth rate                                           19.365000   20.050000
# Contraceptive acceptance rate (thana) NGO, %         74.490000   79.610000
# Fully vaccinated children 12 months, %               78.000000   82.250000
# DHS: Sex ratio (males / females)                     95.180000   93.585000
# Crude coverage penta 1 children 23 months, %         99.250000   97.800000
# Distributed IUDs out of total (thana), %              3.940000    3.375000
# Crude coverage BCG, %                                99.950000   99.600000
# Functional radiant warmer, %                         19.989286   23.179310
# Death rate                                            5.505000    5.655000
# Rate of distributed implant EEW (total)               7.489000   12.568100
# DHS: Proportion of women population                  78.645000   56.840000
# Rate of distributed injectable vials                521.786550  454.822950
# Distributed pills out of total, %                    52.895000   49.700000
# Crude coverage OPV 3, %                              98.700000   97.100000
# Crude coverage OPV 3 children 23 months, %           94.250000   90.700000
# DHS: Proportion of C-sections                         9.710000   21.065000
# Crude coverage penta 3, %                            97.450000   98.150000
# DHS: Proportion of institutional deliveries          18.355000   34.105000
# Proportion of cases with postpartum hemorrhage ...    0.012400    0.011350
# MR vial wastage rate                                 45.050000   50.450000
# Postpartum hemorrhage among admitted patient in...    1.240000    1.135000
# DHS: Dependency ratio                                72.415000   63.935000
# Proportion of women population                       48.795000   49.575000
# Crude coverage penta 2 children 12 months, %         97.400000   96.600000
# DHS: Proportion of attendant deliveries              23.405000   38.700000
# Distributed IUDs out of total (thana) NGO, %          3.630000    4.205000
# Vitamin A coverage children 12-59 months, %          90.250000   89.500000
# DHS: Proportion of antental coverage 4+              16.140000   24.500000
# Performed permanent methods out of total (month...    1.300000    1.795000
# Distributed IUDs out of total (month thana) NGO, %    3.630000    4.205000
# Case fatality rate at SCANU                           8.332353    8.473529
# IMCI stunting, %                                      0.560000    0.780000
# Performed permanent methods out of total (month...    7.945000    9.415000
# Rate of distributed MRMs (pack)                       0.000000    0.094150
# Crude coverage MR 1, %                               98.800000   98.200000
# Fertility rate                                       81.895000   85.190000
# Sex ratio                                           104.930000  101.720000
# Crude coverage TT2 among mothers with 0-11 chil...   96.200000   96.900000
# Performed permanent methods out of total (thana...    2.090000    3.430000
# Performed permanent methods out of total (thana...    7.945000    9.410000
# Maternal case fatality rate (EmOC)                    0.073250    0.022850
# Proportion of married women (15 years)               68.895000   73.160000
# DHS: Unmet need for family planning                  13.285000   11.055000

# %% [markdown]
# ## Outcome variable

# %%
ALL2011 = '/Users/edinhamzic/Symphony/wb_bangladesh/Bangladesh/output/all/all2011.csv'
ALL2016 = '/Users/edinhamzic/Symphony/wb_bangladesh/Bangladesh/output/all/all2016.csv'
all2011 = pd.read_csv(ALL2011)
clusters_intersect2011 = pd.read_csv(DATA+clusters_intersect_2011)
all2016 = pd.read_csv(ALL2016)
clusters_intersect2016 = pd.read_csv(DATA+clusters_intersect_2016)
all2011 = all2011.merge(clusters_intersect2011[['DistrictName', 'cluster', ]], how='left', on='DistrictName')
all2016 = all2016.merge(clusters_intersect2016[['DistrictName', 'cluster', ]], how='left', on='DistrictName')
display(all2011[['prop_unmet_need_family_planing', 'cluster']].groupby('cluster').median().transpose())
display(all2016[['prop_unmet_need_family_planing', 'cluster']].groupby('cluster').median().transpose())
# Out:
# cluster                             0       1      2      3
# prop_unmet_need_family_planing  13.65  20.035  9.485  10.06
# cluster                              0      1     2      3
# prop_unmet_need_family_planing  12.975  15.41  8.67  10.12

# %%
ALL2011 = '/Users/edinhamzic/Symphony/wb_bangladesh/Bangladesh/output/all/all2011.csv'
ALL2016 = '/Users/edinhamzic/Symphony/wb_bangladesh/Bangladesh/output/all/all2016.csv'
all2011 = pd.read_csv(ALL2011)
clusters_union2011 = pd.read_csv(DATA+clusters_union_2011)
all2016 = pd.read_csv(ALL2016)
clusters_union2016 = pd.read_csv(DATA+clusters_union_2016)
all2011 = all2011.merge(clusters_union2011[['DistrictName', 'cluster', ]], how='left', on='DistrictName')
all2016 = all2016.merge(clusters_union2011[['DistrictName', 'cluster', ]], how='left', on='DistrictName')
display(all2011[['prop_unmet_need_family_planing', 'cluster']].groupby('cluster').median().transpose())
display(all2016[['prop_unmet_need_family_planing', 'cluster']].groupby('cluster').median().transpose())
# Out:
# cluster                              0      1      2       3
# prop_unmet_need_family_planing  20.925  9.485  19.53  13.285
# cluster                             0       1       2     3
# prop_unmet_need_family_planing  12.12  11.025  15.935  9.54

# %%
print(all2011['cluster'].value_counts())
print(all2016['cluster'].value_counts())
# Out:
# 1    28
# 3    20
# 0    10
# 2     6
# Name: cluster, dtype: int64
# 1    28
# 3    20
# 0    10
# 2     6
# Name: cluster, dtype: int64

# %% [markdown]
# ## Correlations

# %%
corr_cca = read_corr_cca(dir_path=DATA,files_list=corr_cca)
for key, value in corr_cca.items():
    print(key)
    display(value.head())
    display(value.shape)
# Out:
# corr_unmet_needs_2011.csv
#                                                index  \
# 0  DHS: Proportion of use of current contraceptiv...
# 1                                   Dependency ratio
# 2           Distributed IUDs out of total (thana), %
# 3    Distributed IUDs out of total (month, thana), %
# 4                   DHS: Sex ratio (males / females)
#
#    DHS: Unmet need for family planning  abs_prop_unmet_need_family_planing  \
# 0                            -0.831776                            0.831776
# 1                             0.633349                            0.633349
# 2                             0.617231                            0.617231
# 3                             0.617231                            0.617231
# 4                            -0.548085                            0.548085
#
#         p_value
# 0  1.708276e-17
# 1  1.949960e-08
# 2  5.572988e-08
# 3  5.572988e-08
# 4  2.760155e-06
# (80, 4)
# cca_unmet_needs_2011.csv
#                        Indicators  CCA_coeff  CCA_coeff_abs
# 0                      Death rate  -0.161607       0.161607
# 1  Proportion of women population   0.122904       0.122904
# 2                Dependency ratio   0.176366       0.176366
# 3                       Sex ratio  -0.118884       0.118884
# 4       Proportion of live births   0.105973       0.105973
# (25, 3)
# corr_unmet_needs_2016.csv
#                                                index  \
# 0  DHS: Proportion of use of current contraceptiv...
# 1                              DHS: Dependency ratio
# 2    DHS: Proportion of females as head of household
# 3  Performed permanent methods out of total (than...
# 4  Performed permanent methods out of total (mont...
#
#    DHS: Unmet need for family planning  abs_prop_unmet_need_family_planing  \
# 0                            -0.839687                            0.839687
# 1                             0.652078                            0.652078
# 2                             0.426293                            0.426293
# 3                             0.378648                            0.378648
# 4                             0.378611                            0.378611
#
#         p_value
# 0  4.346822e-18
# 1  5.319055e-09
# 2  4.442170e-04
# 3  2.033911e-03
# 4  2.036142e-03
# (27, 4)
# cca_unmet_needs_2016.csv
#                                      Indicators  CCA_coeff  CCA_coeff_abs
# 0  Crude coverage measles children 23 months, %   0.127010       0.127010
# 1   Vitamin A coverage children 12-59 months, %   0.117877       0.117877
# 2             Proportion of women (15-45 years)  -0.155142       0.155142
# 3                                Fertility rate   0.139743       0.139743
# 4                    Proportion of rural deaths  -0.112983       0.112983
# (26, 3)
