# %% [markdown]
# ## Clustering Maternal Mortality

# %% [markdown]
# ## TO DO LIST:
#
# - Evaluate the optimal number of clusters using HDBSCAN and K-means
# - Run clustering on 2011 and predict clusters for 2016
# - Take average values for clusters for maternal mortality for 2011 and 2016
# - Take average values for all variables in corresponding clustering option for 2011 and 2016
# - Take difference for maternal mortality and all other indicators
# - Create spreadsheet and share with Marelize

# %%
import os
import re
import glob
import conda
import hdbscan
import operator
import itertools
import numpy as np
import pandas as pd
import seaborn as sns
from config import Config
from collections import Counter
from matplotlib import pyplot as plt
conda_file_dir = conda.__file__
conda_dir = conda_file_dir.split('lib')[0]
proj_lib = os.path.join(os.path.join(conda_dir, 'share'), 'proj')
os.environ["PROJ_LIB"] = proj_lib
from mpl_toolkits.basemap import Basemap
from matplotlib.patches import Polygon
from matplotlib.lines import Line2D
from matplotlib.collections import PatchCollection
from sklearn.cluster import KMeans

# %%
def evaluate_hdbscan(input_df, min_samples, min_cluster_size, 
                     output, cluster_selection_method, 
                     fmin_samples, fmin_cluster_size,
                     prune=False, plot=True):
    samples = list(itertools.product(min_samples, min_cluster_size))
    counter = 0
    models = pd.DataFrame(columns=['min_samples',
                                   'min_cluster_size',
                                   'num_clusters_including_unclustered',
                                   'percent_of_unclustered_geos',
                                   'percent_of_maxclass',],index=range(len(samples)))
    #geo = input_df['index']
    #input_df = input_df.drop('index', axis=1)
    df = input_df.copy(deep=True)
    for iteration in samples:
        model = hdbscan.HDBSCAN(min_samples=int(iteration[0]), 
                                min_cluster_size=int(iteration[1]), 
                                metric='euclidean', 
                                algorithm='best',
                                cluster_selection_method=cluster_selection_method, prediction_data=False).fit(df)
        models.loc[counter,'min_cluster_size'] = iteration[1]
        models.loc[counter, 'min_samples'] = iteration[0]
        models.loc[counter, 'num_clusters_including_unclustered'] = len(Counter(model.labels_))
        tmp_dict = dict(Counter(model.labels_))
        total = sum([v for k,v in tmp_dict.items()])
        tmp_dict = {k:round(v/total*100,2) for k,v in tmp_dict.items()}
        try:
            models.loc[counter, 'percent_of_unclustered_geos'] = tmp_dict.pop(-1)
        except KeyError as error:
            models.loc[counter, 'percent_of_unclustered_geos'] = 0 
        if len(tmp_dict) > 1:
            models.loc[counter, 'percent_of_maxclass'] = tmp_dict[max(tmp_dict.items(), key=operator.itemgetter(1))[0]]
        else:
            models.loc[counter, 'percent_of_maxclass'] = 100
        counter += 1
    if prune:
        out_model = hdbscan.HDBSCAN(min_samples=int(fmin_samples), 
                                min_cluster_size=int(fmin_cluster_size), 
                                metric='euclidean', 
                                algorithm='best',
                                cluster_selection_method=cluster_selection_method, prediction_data=False).fit(df)

    else:
        out_model = None

    if plot:
        plt.rcParams['figure.figsize'] = [20,10]
        plt.plot(models['num_clusters_including_unclustered'], label='Number of clusters including unclustered')
        plt.plot(models['percent_of_unclustered_geos'], label='Percent of unclustered geographies')
        plt.plot(models['percent_of_maxclass'], label='Size of larges cluster (%)')
        plt.xlabel("Iterations", fontsize=20)
        plt.ylabel("Value", fontsize=20)
        plt.savefig(os.path.split(output)[1] + "/finetune_parameteres.jpeg")
        plt.legend()
        plt.show()
    del(input_df, df)
    return models, out_model

# %%
DATA2011 = '/Users/edinhamzic/Symphony/wb_bangladesh/Bangladesh/output/all/maternal_mortality_2011.csv'
DATA2016 = '/Users/edinhamzic/Symphony/wb_bangladesh/Bangladesh/output/all/maternal_mortality_2016.csv'
SDATA2011 = '/Users/edinhamzic/Symphony/wb_bangladesh/Bangladesh/output/all/s_maternal_mortality_2011.csv'
SDATA2016 = '/Users/edinhamzic/Symphony/wb_bangladesh/Bangladesh/output/all/s_maternal_mortality_2016.csv'
OUT = '/Users/edinhamzic/Symphony/wb_bangladesh/Bangladesh/output/all/'

# %% [markdown]
# ## Import Data

# %% [markdown]
# - Under 5 year mortality rate = (Number of deaths under 5 year / Number of live births) * 1000
# - Infant mortality rate = (Number of deaths under 1 year / Number of live births) * 1000
# - Maternal mortality rate = Number of maternal deaths / Number of live births) * 1000

# %%
data2011 = pd.read_csv(DATA2011)
s_data2011 = pd.read_csv(SDATA2011)
data2016 = pd.read_csv(DATA2016)
s_data2016 = pd.read_csv(SDATA2016)

# %% [markdown]
# ## Evaluate clustering method: HDBSCAN - leaf - 2011

# %%
tmp, out = evaluate_hdbscan(input_df=s_data2011.drop('rate_maternal_mortality', axis=1), 
                       min_samples=Config.tune_min_sample, 
                       min_cluster_size=Config.tune_min_cluster,
                       output=OUT, cluster_selection_method ='leaf',
                       fmin_samples=3, fmin_cluster_size=12,
                       prune=True, plot=False)

# %%
tmp = tmp[tmp['num_clusters_including_unclustered'] <10]
tmp.sort_values('percent_of_unclustered_geos', ascending=True).head(10)
# Out:
#    min_samples min_cluster_size num_clusters_including_unclustered  \
# 69           2               23                                  3
# 72           2               26                                  3
# 71           2               25                                  3
# 70           2               24                                  3
# 68           2               22                                  3
# 67           2               21                                  3
# 66           2               20                                  3
# 65           2               19                                  3
# 64           2               18                                  3
# 25           1               27                                  3
#
#    percent_of_unclustered_geos percent_of_maxclass
# 69                       15.62               42.19
# 72                       15.62               42.19
# 71                       15.62               42.19
# 70                       15.62               42.19
# 68                       15.62               42.19
# 67                       15.62               42.19
# 66                       15.62               42.19
# 65                       15.62               42.19
# 64                       15.62               42.19
# 25                       15.62               42.19

# %% [markdown]
# ## Evaluate clustering method: HDBSCAN - eom - 2011

# %%
tmp, out = evaluate_hdbscan(input_df=s_data2011.drop('rate_maternal_mortality', axis=1), 
                       min_samples=Config.tune_min_sample, 
                       min_cluster_size=Config.tune_min_cluster,
                       output=OUT, cluster_selection_method ='eom',
                       fmin_samples=3, fmin_cluster_size=12,
                       prune=True, plot=False)

# %%
tmp = tmp[tmp['num_clusters_including_unclustered'] <10]
tmp.sort_values('percent_of_unclustered_geos', ascending=True).head(10)
# Out:
#    min_samples min_cluster_size num_clusters_including_unclustered  \
# 69           2               23                                  3
# 59           2               13                                  3
# 73           2               27                                  3
# 72           2               26                                  3
# 71           2               25                                  3
# 70           2               24                                  3
# 68           2               22                                  3
# 67           2               21                                  3
# 66           2               20                                  3
# 65           2               19                                  3
#
#    percent_of_unclustered_geos percent_of_maxclass
# 69                       15.62               42.19
# 59                       15.62               42.19
# 73                       15.62               42.19
# 72                       15.62               42.19
# 71                       15.62               42.19
# 70                       15.62               42.19
# 68                       15.62               42.19
# 67                       15.62               42.19
# 66                       15.62               42.19
# 65                       15.62               42.19

# %% [markdown]
# ## Evaluate clustering method: HDBSCAN - leaf - 2016

# %%
tmp, out = evaluate_hdbscan(input_df=s_data2016.drop('rate_maternal_mortality', axis=1), 
                       min_samples=Config.tune_min_sample, 
                       min_cluster_size=Config.tune_min_cluster,
                       output=OUT, cluster_selection_method ='leaf',
                       fmin_samples=3, fmin_cluster_size=12,
                       prune=True, plot=False)

# %%
tmp = tmp[tmp['num_clusters_including_unclustered'] <10]
tmp.sort_values('percent_of_unclustered_geos', ascending=True).head(10)
# Out:
#     min_samples min_cluster_size num_clusters_including_unclustered  \
# 56            2               10                                  3
# 58            2               12                                  3
# 57            2               11                                  3
# 8             1               10                                  3
# 9             1               11                                  3
# 10            1               12                                  3
# 105           3               11                                  3
# 104           3               10                                  3
# 103           3                9                                  3
# 102           3                8                                  3
#
#     percent_of_unclustered_geos percent_of_maxclass
# 56                        31.25                  50
# 58                        31.25                  50
# 57                        31.25                  50
# 8                         31.25                  50
# 9                         31.25                  50
# 10                        31.25                  50
# 105                       46.88               34.38
# 104                       46.88               34.38
# 103                       46.88               34.38
# 102                       46.88               34.38

# %% [markdown]
# ## Evaluate clustering method: HDBSCAN - eom - 2016

# %%
tmp, out = evaluate_hdbscan(input_df=s_data2016.drop('rate_maternal_mortality', axis=1), 
                       min_samples=Config.tune_min_sample, 
                       min_cluster_size=Config.tune_min_cluster,
                       output=OUT, cluster_selection_method ='eom',
                       fmin_samples=3, fmin_cluster_size=12,
                       prune=True, plot=False)

# %%
tmp = tmp[tmp['num_clusters_including_unclustered'] <10]
tmp.sort_values('percent_of_unclustered_geos', ascending=True).head(10)
# Out:
#    min_samples min_cluster_size num_clusters_including_unclustered  \
# 54           2                8                                  3
# 53           2                7                                  3
# 55           2                9                                  3
# 57           2               11                                  3
# 58           2               12                                  3
# 10           1               12                                  3
# 9            1               11                                  3
# 56           2               10                                  3
# 7            1                9                                  3
# 6            1                8                                  3
#
#    percent_of_unclustered_geos percent_of_maxclass
# 54                       31.25                  50
# 53                       31.25                  50
# 55                       31.25                  50
# 57                       31.25                  50
# 58                       31.25                  50
# 10                       31.25                  50
# 9                        31.25                  50
# 56                       31.25                  50
# 7                        31.25                  50
# 6                        31.25                  50

# %% [markdown]
# # Clustering with K-means

# %%
kmeans_model = KMeans(n_clusters=3, random_state=0).fit(s_data2011.drop('rate_maternal_mortality', axis=1))
predicted2016 = kmeans_model.predict(s_data2016.drop('rate_maternal_mortality', axis=1))
data2011['cluster'] = kmeans_model.labels_
data2016['cluster'] = predicted2016

# %%
print(Counter(data2011['cluster']))
# Out:
# Counter({1: 22, 0: 21, 2: 21})

# %%
print(Counter(data2011['cluster']))
# Out:
# Counter({1: 22, 0: 21, 2: 21})

# %%
mean_cluster_values2011 = data2011.groupby('cluster').mean().transpose()
mean_cluster_values2011.head()
# Out:
# cluster                                                     0          1  \
# imp12distr_monthprocessImp12DistrMonthThana_Per...   9.406667   9.143182
# VitACoverage_Children12-59M                         91.119048  91.577273
# PENTA2_Children23M                                  97.280952  97.431818
# Fully_Children23M                                   81.842857  83.118182
# imp12distr_monthprocessImp12DistrMonthThana_Per...   2.427619   2.735909
#
# cluster                                                     2
# imp12distr_monthprocessImp12DistrMonthThana_Per...  10.672381
# VitACoverage_Children12-59M                         93.723810
# PENTA2_Children23M                                  98.033333
# Fully_Children23M                                   84.219048
# imp12distr_monthprocessImp12DistrMonthThana_Per...   2.440476

# %%
mean_cluster_values2016 = data2016.groupby('cluster').mean().transpose()
mean_cluster_values2016.head()
# Out:
# cluster                                                     0          1  \
# imp12distr_monthprocessImp12DistrMonthThana_Per...   9.308571   9.024545
# VitACoverage_Children12-59M                         90.014286  89.831818
# PENTA2_Children23M                                  97.347619  96.709091
# Fully_Children23M                                   88.200000  86.190909
# imp12distr_monthprocessImp12DistrMonthThana_Per...   4.657619   4.910455
#
# cluster                                                     2
# imp12distr_monthprocessImp12DistrMonthThana_Per...  10.839048
# VitACoverage_Children12-59M                         92.133333
# PENTA2_Children23M                                  97.928571
# Fully_Children23M                                   87.666667
# imp12distr_monthprocessImp12DistrMonthThana_Per...   4.939524

# %%
percentdiff_cluster_values = ((mean_cluster_values2016 - mean_cluster_values2011) / mean_cluster_values2011) * 100
percentdiff_cluster_values = percentdiff_cluster_values.round(2)

# %%
percentdiff_cluster_values.head()
# Out:
# cluster                                                 0      1       2
# imp12distr_monthprocessImp12DistrMonthThana_Per...  -1.04  -1.30    1.56
# VitACoverage_Children12-59M                         -1.21  -1.91   -1.70
# PENTA2_Children23M                                   0.07  -0.74   -0.11
# Fully_Children23M                                    7.77   3.70    4.09
# imp12distr_monthprocessImp12DistrMonthThana_Per...  91.86  79.48  102.40

# %%
percentdiff_cluster_values.sort_values(by=0 ,ascending=False)
# Out:
# cluster                                                   0         1        2
# 03Immunization: Penta 1 to MR 2 drop out Rate        379.48    679.71   494.46
# imp12distr_monthprocessImp12DistrMonthThana_Per...    91.86     79.48   102.40
# imp11subdistr_thanaprocessPercent_Implant             91.67     79.41   102.50
# imp11subdistr_ngothanaprocessNGO_Percent_Implant      80.73    108.14    91.18
# Imp12DistrNGOMonthThana_Percent_Implant               80.73    108.14    91.18
# 03Immunization: IPV vial wastage rate                 56.86     37.21    47.55
# imp11subdistr_ngothanaprocessNGO_Percent_PerMale      48.55     26.20    15.60
# Imp12DistrNGOMonthThana_Percent_PerMale               48.55     26.20    15.60
# 03Immunization: EPI Session drop out rate             33.19    -53.80   522.30
# 04Newborn: Nurse Bed ratio at SCANU (Recommende...    32.67      1.24    83.11
# imp11subdistr_thanaprocessPercent_PerMale             25.93     12.42    19.33
# imp12distr_monthprocessImp12DistrMonthThana_Per...    25.89     12.40    19.37
# 03Immunization: TT vial wastage rate                  24.75     37.59    53.09
# 03Immunization: BCG left out Rate                     19.66   -114.16  -107.19
# 01MaternalHealth: Institutional C-section rate        17.46     14.95    17.80
# 02ChildHealth: % of neonatal death reported ind...    16.11    -37.64   119.38
# TT4_Mother0-11MChildren                               14.67     19.09    10.57
# 04Newborn: % of nurse allocated in SCANU among ...    10.56      3.97    13.60
# Fully_Children23M                                      7.77      3.70     4.09
# TT3_Mother0-11MChildren                                7.47      8.76     5.16
# Imp12DistrNGOMonthThana_CAR                            6.17      6.75     1.61
# imp11subdistr_ngothanaprocessNGO_CAR                   6.17      6.75     1.61
# 04Newborn: Percentage of newborn who received p...     6.17     -3.46   -11.30
# rate_live_births                                       5.45     -0.09    -5.85
# rate_fertility                                         3.32     -1.51    -7.30
# 05Logistics: Percentage of functional x-ray            3.07      2.54    -4.23
# prop_pop_women                                         1.62      0.97     0.75
# 03Immunization: MR vial wastage rate                   1.46     10.97    11.25
# 04Newborn: Doctor Bed ratio at SCANU (Recommend...     1.40      8.69     8.06
# imp11subdistr_ngothanaprocessNGO_Percent_PerFemale     0.78     22.53    -8.90
# ...                                                     ...       ...      ...
# 03Immunization: BCG Crude Coverage %                  -0.21      0.42     0.46
# dependency_ratio                                      -0.54      2.47    -0.11
# OPV1_Children23M                                      -0.89     -1.51    -0.85
# imp12distr_monthprocessImp12DistrMonthThana_Per...    -1.04     -1.30     1.56
# PENTA1_Children12M                                    -1.04     -1.49    -0.81
# imp11subdistr_thanaprocessPercent_PerFemale           -1.04     -1.32     1.56
# PENTA1_Children23M                                    -1.05     -1.53    -0.85
# VitACoverage_Children12-59M                           -1.21     -1.91    -1.70
# 03Immunization: BCG vial wastage rate                 -1.53     -0.26     0.37
# 05Logistics: Percentage of functional ambulance       -1.65     -2.31     1.82
# 04Newborn: Case fatality rate at SCANU                -1.89      2.68     5.62
# sex_ratio                                             -3.17     -1.86    -1.46
# 04Newborn: % of referral cases admitted at SCANU      -4.15     -6.36    -8.43
# imp11subdistr_thanaprocessPercent_Pill                -5.25     -6.77    -7.16
# imp12distr_monthprocessImp12DistrMonthThana_Per...    -5.26     -6.77    -7.16
# 03Immunization: OPV 0 Crude Coverage %                -7.93      3.37     1.49
# 01MaternalHealth: Institutional Normal Delivery...    -9.36     -9.22   -11.73
# 04Newborn: Medical Officer Bed ratio at SCANU (...   -10.43      7.02    -5.79
# 03Immunization: MR 2 Crude Coverage %                -12.70    -16.81   -18.45
# 04Newborn: % of non-functioning Table Resuscita...   -13.36     -5.19   -12.07
# 02ChildHealth: IMCI Stunting (%)                     -16.99     -7.63   -11.86
# 02ChildHealth: IMCI Wasting (%)                      -18.89    -16.69   -27.42
# 04Newborn: Percentage of newborns delivered by ...   -20.85    -16.88   -14.03
# distr_GOfemale_total                                 -25.07     -3.90   -32.15
# 03Immunization: BCG to Penta 3 drop out Rate         -38.74    -25.33   -29.13
# rate_maternal_mortality                              -44.33    -38.43    -7.11
# distr_GOfemalenormal                                 -53.31    -52.39   -69.53
# 03Immunization: PCV vial wastage rate              -1187.00  -1289.47 -1106.80
# 03Immunization: Pentavalent vial wastage rate      -2140.32 -13700.00  1212.01
# 03Immunization: Pentavalent vial use and doses ... -4823.78   2270.86   896.04
#
# [65 rows x 3 columns]

# %%
percentdiff_cluster_values.to_csv(OUT+"clustersummary_maternal.csv")
