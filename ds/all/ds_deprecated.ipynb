# %% [markdown]
# ### Deprecated Code
# ```
# plt.rcParams['figure.figsize'] = [10,10]
# pca = PCA()
# pca2011 = pca.fit(data1)
# pca2011.shape
# pc = pd.DataFrame(pca2011, columns=["PC" + str(i) for i in range(1,19)])
# pc['DistrictName'] = d2011.index
# pca = PCA()
# pca2011 = pca.fit_transform(data1)
# pca2011.shape
# pc = pd.DataFrame(pca2011, columns=["PC" + str(i) for i in range(1,19)])
# pc['DistrictName'] = d2011.index
# pca2011t = pca.fit(data1)
# y = list(pc['PC1'])
# z = list(pc['PC2'])
# n = list(pc['DistrictName'])
#
# fig, ax = plt.subplots()
# ax.scatter(z, y)
#
# for i, txt in enumerate(n):
#     ax.annotate(txt, (z[i], y[i]))
#
# y = list(pc['PC2'])
# z = list(pc['PC3'])
# n = list(pc['DistrictName'])
#
# fig, ax = plt.subplots()
# ax.scatter(z, y)
#
# for i, txt in enumerate(n):
#     ax.annotate(txt, (z[i], y[i]))
#
# y = list(pc['PC1'])
# z = list(pc['PC3'])
# n = list(pc['DistrictName'])
#
# fig, ax = plt.subplots()
# ax.scatter(z, y)
#
# for i, txt in enumerate(n):
#     ax.annotate(txt, (z[i], y[i]))
#
# loadings = pd.DataFrame(pca2011t.components_.transpose(), columns=["PC" + str(i) for i in range(1,19)])
# loadings['Vars'] = list(data.columns)
# print(loadings.shape)
# loadings = loadings.merge(vars_labels, how='left', left_on='Vars', right_on='vars')
# print(loadings.shape)
# loadings = loadings.drop('vars', axis=1)
# loadings['Data Sources'] = loadings['data source'].astype(str).astype('category')
# dict_levels = {'1': 'CES UNICEF', '2': 'SVRS', '3': 'DHIS2', '4': 'DGFP'}
# loadings['Data Sources'] = loadings['Data Sources'].cat.rename_categories(dict_levels)
#
# palet = sns.color_palette("hls", 4)
# sns.scatterplot(x='PC1', y='PC2', hue='Data Sources', data=loadings, palette=palet)
#
# palet = sns.color_palette("hls", 4)
# sns.scatterplot(x='PC1', y='PC3', hue='Data Sources', data=loadings, palette=palet)
#
# palet = sns.color_palette("hls", 4)
# sns.scatterplot(x='PC2', y='PC3', hue='Data Sources', data=loadings, palette=palet)
#
# palet = sns.color_palette("hls", 4)
# sns.scatterplot(x='PC1', y='PC4', hue='Data Sources', data=loadings, palette=palet)
#
# def myplot(score,coeff,labels=None):
#     xs = score[:,0]
#     ys = score[:,1]
#     n = coeff.shape[0]
#     scalex = 1.0/(xs.max() - xs.min())
#     scaley = 1.0/(ys.max() - ys.min())
#     plt.scatter(xs * scalex,ys * scaley, c = y)
#     for i in range(n):
#         plt.arrow(0, 0, coeff[i,0], coeff[i,1],color = 'r',alpha = 0.5)
#         if labels is None:
#             plt.text(coeff[i,0]* 1.15, coeff[i,1] * 1.15, "Var"+str(i+1), color = 'g', ha = 'center', va = 'center')
#         else:
#             plt.text(coeff[i,0]* 1.15, coeff[i,1] * 1.15, labels[i], color = 'g', ha = 'center', va = 'center')
# plt.xlim(-1,1)
# plt.ylim(-1,1)
# plt.xlabel("PC{}".format(1))
# plt.ylabel("PC{}".format(2))
# plt.grid()
#
# #Call the function. Use only the 2 PCs.
# myplot(pca2011[:,0:2],np.transpose(pca.components_[0:2, :]))
# plt.show()
# ```
