# %% [markdown]
# ## Clustering Fully Immunized

# %% [markdown]
# ## TO DO LIST:
#
# - Evaluate the optimal number of clusters using HDBSCAN and K-means
# - Run clustering on 2011 and predict clusters for 2016
# - Take average values for clusters for maternal mortality for 2011 and 2016
# - Take average values for all variables in corresponding clustering option for 2011 and 2016
# - Take difference for maternal mortality and all other indicators
# - Create spreadsheet and share with Marelize

# %%
import os
import re
import glob
import conda
import hdbscan
import operator
import itertools
import numpy as np
import pandas as pd
import seaborn as sns
from config import Config
from collections import Counter
from matplotlib import pyplot as plt
conda_file_dir = conda.__file__
conda_dir = conda_file_dir.split('lib')[0]
proj_lib = os.path.join(os.path.join(conda_dir, 'share'), 'proj')
os.environ["PROJ_LIB"] = proj_lib
from mpl_toolkits.basemap import Basemap
from matplotlib.patches import Polygon
from matplotlib.lines import Line2D
from matplotlib.collections import PatchCollection
from sklearn.cluster import KMeans

# %%
def evaluate_hdbscan(input_df, min_samples, min_cluster_size, 
                     output, cluster_selection_method, 
                     fmin_samples, fmin_cluster_size,
                     prune=False, plot=True):
    samples = list(itertools.product(min_samples, min_cluster_size))
    counter = 0
    models = pd.DataFrame(columns=['min_samples',
                                   'min_cluster_size',
                                   'num_clusters_including_unclustered',
                                   'percent_of_unclustered_geos',
                                   'percent_of_maxclass',],index=range(len(samples)))
    #geo = input_df['index']
    #input_df = input_df.drop('index', axis=1)
    df = input_df.copy(deep=True)
    for iteration in samples:
        model = hdbscan.HDBSCAN(min_samples=int(iteration[0]), 
                                min_cluster_size=int(iteration[1]), 
                                metric='euclidean', 
                                algorithm='best',
                                cluster_selection_method=cluster_selection_method, prediction_data=False).fit(df)
        models.loc[counter,'min_cluster_size'] = iteration[1]
        models.loc[counter, 'min_samples'] = iteration[0]
        models.loc[counter, 'num_clusters_including_unclustered'] = len(Counter(model.labels_))
        tmp_dict = dict(Counter(model.labels_))
        total = sum([v for k,v in tmp_dict.items()])
        tmp_dict = {k:round(v/total*100,2) for k,v in tmp_dict.items()}
        try:
            models.loc[counter, 'percent_of_unclustered_geos'] = tmp_dict.pop(-1)
        except KeyError as error:
            models.loc[counter, 'percent_of_unclustered_geos'] = 0 
        if len(tmp_dict) > 1:
            models.loc[counter, 'percent_of_maxclass'] = tmp_dict[max(tmp_dict.items(), key=operator.itemgetter(1))[0]]
        else:
            models.loc[counter, 'percent_of_maxclass'] = 100
        counter += 1
    if prune:
        out_model = hdbscan.HDBSCAN(min_samples=int(fmin_samples), 
                                min_cluster_size=int(fmin_cluster_size), 
                                metric='euclidean', 
                                algorithm='best',
                                cluster_selection_method=cluster_selection_method, prediction_data=False).fit(df)

    else:
        out_model = None

    if plot:
        plt.rcParams['figure.figsize'] = [20,10]
        plt.plot(models['num_clusters_including_unclustered'], label='Number of clusters including unclustered')
        plt.plot(models['percent_of_unclustered_geos'], label='Percent of unclustered geographies')
        plt.plot(models['percent_of_maxclass'], label='Size of larges cluster (%)')
        plt.xlabel("Iterations", fontsize=20)
        plt.ylabel("Value", fontsize=20)
        plt.savefig(os.path.split(output)[1] + "/finetune_parameteres.jpeg")
        plt.legend()
        plt.show()
    del(input_df, df)
    return models, out_model

# %%
DATA2011 = '/Users/edinhamzic/Symphony/wb_bangladesh/Bangladesh/output/all/full_immunized_2011.csv'
DATA2016 = '/Users/edinhamzic/Symphony/wb_bangladesh/Bangladesh/output/all/full_immunized_2016.csv'
SDATA2011 = '/Users/edinhamzic/Symphony/wb_bangladesh/Bangladesh/output/all/s_full_immunized_2011.csv'
SDATA2016 = '/Users/edinhamzic/Symphony/wb_bangladesh/Bangladesh/output/all/s_full_immunized_2016.csv'
OUT = '/Users/edinhamzic/Symphony/wb_bangladesh/Bangladesh/output/all/'

# %% [markdown]
# ## Import Data

# %% [markdown]
# - Under 5 year mortality rate = (Number of deaths under 5 year / Number of live births) * 1000
# - Infant mortality rate = (Number of deaths under 1 year / Number of live births) * 1000
# - Maternal mortality rate = Number of maternal deaths / Number of live births) * 1000

# %%
data2011 = pd.read_csv(DATA2011)
s_data2011 = pd.read_csv(SDATA2011)
data2016 = pd.read_csv(DATA2016)
s_data2016 = pd.read_csv(SDATA2016)

# %% [markdown]
# ## Evaluate clustering method: HDBSCAN - leaf - 2011

# %%
tmp, out = evaluate_hdbscan(input_df=s_data2011.drop('Fully_Children12M', axis=1), 
                       min_samples=Config.tune_min_sample, 
                       min_cluster_size=Config.tune_min_cluster,
                       output=OUT, cluster_selection_method ='leaf',
                       fmin_samples=3, fmin_cluster_size=12,
                       prune=True, plot=False)

# %%
tmp = tmp[tmp['num_clusters_including_unclustered'] <10]
tmp.sort_values('percent_of_unclustered_geos', ascending=True).head(10)
# Out:
#    min_samples min_cluster_size num_clusters_including_unclustered  \
# 17           1               19                                  3
# 18           1               20                                  3
# 16           1               18                                  3
# 15           1               17                                  3
# 14           1               16                                  3
# 13           1               15                                  3
# 12           1               14                                  3
# 10           1               12                                  3
# 11           1               13                                  3
# 8            1               10                                  3
#
#    percent_of_unclustered_geos percent_of_maxclass
# 17                       32.81               35.94
# 18                       32.81               35.94
# 16                       32.81               35.94
# 15                       32.81               35.94
# 14                       32.81               35.94
# 13                       32.81               35.94
# 12                       32.81               35.94
# 10                       32.81               35.94
# 11                       32.81               35.94
# 8                        32.81               35.94

# %% [markdown]
# ## Evaluate clustering method: HDBSCAN - eom - 2011

# %%
tmp, out = evaluate_hdbscan(input_df=s_data2011.drop('Fully_Children12M', axis=1), 
                       min_samples=Config.tune_min_sample, 
                       min_cluster_size=Config.tune_min_cluster,
                       output=OUT, cluster_selection_method ='eom',
                       fmin_samples=3, fmin_cluster_size=12,
                       prune=True, plot=False)

# %%
tmp = tmp[tmp['num_clusters_including_unclustered'] <10]
tmp.sort_values('percent_of_unclustered_geos', ascending=True).head(10)
# Out:
#    min_samples min_cluster_size num_clusters_including_unclustered  \
# 0            1                2                                  4
# 18           1               20                                  3
# 17           1               19                                  3
# 16           1               18                                  3
# 14           1               16                                  3
# 13           1               15                                  3
# 12           1               14                                  3
# 11           1               13                                  3
# 10           1               12                                  3
# 15           1               17                                  3
#
#    percent_of_unclustered_geos percent_of_maxclass
# 0                         7.81               85.94
# 18                       32.81               35.94
# 17                       32.81               35.94
# 16                       32.81               35.94
# 14                       32.81               35.94
# 13                       32.81               35.94
# 12                       32.81               35.94
# 11                       32.81               35.94
# 10                       32.81               35.94
# 15                       32.81               35.94

# %% [markdown]
# ## Evaluate clustering method: HDBSCAN - leaf - 2016

# %%
tmp, out = evaluate_hdbscan(input_df=s_data2016.drop('Fully_Children12M', axis=1), 
                       min_samples=Config.tune_min_sample, 
                       min_cluster_size=Config.tune_min_cluster,
                       output=OUT, cluster_selection_method ='leaf',
                       fmin_samples=3, fmin_cluster_size=12,
                       prune=True, plot=False)

# %%
tmp = tmp[tmp['num_clusters_including_unclustered'] <10]
tmp.sort_values('percent_of_unclustered_geos', ascending=True).head(10)
# Out:
#    min_samples min_cluster_size num_clusters_including_unclustered  \
# 18           1               20                                  3
# 24           1               26                                  3
# 23           1               25                                  3
# 22           1               24                                  3
# 21           1               23                                  3
# 20           1               22                                  3
# 19           1               21                                  3
# 17           1               19                                  3
# 16           1               18                                  3
# 15           1               17                                  3
#
#    percent_of_unclustered_geos percent_of_maxclass
# 18                       18.75               40.62
# 24                       18.75               40.62
# 23                       18.75               40.62
# 22                       18.75               40.62
# 21                       18.75               40.62
# 20                       18.75               40.62
# 19                       18.75               40.62
# 17                       18.75               40.62
# 16                       18.75               40.62
# 15                       18.75               40.62

# %% [markdown]
# ## Evaluate clustering method: HDBSCAN - eom - 2016

# %%
tmp, out = evaluate_hdbscan(input_df=s_data2016.drop('Fully_Children12M', axis=1), 
                       min_samples=Config.tune_min_sample, 
                       min_cluster_size=Config.tune_min_cluster,
                       output=OUT, cluster_selection_method ='eom',
                       fmin_samples=3, fmin_cluster_size=12,
                       prune=True, plot=False)

# %%
tmp = tmp[tmp['num_clusters_including_unclustered'] <10]
tmp.sort_values('percent_of_unclustered_geos', ascending=True).head(10)
# Out:
#    min_samples min_cluster_size num_clusters_including_unclustered  \
# 20           1               22                                  3
# 23           1               25                                  3
# 19           1               21                                  3
# 18           1               20                                  3
# 17           1               19                                  3
# 16           1               18                                  3
# 15           1               17                                  3
# 14           1               16                                  3
# 13           1               15                                  3
# 12           1               14                                  3
#
#    percent_of_unclustered_geos percent_of_maxclass
# 20                       18.75               40.62
# 23                       18.75               40.62
# 19                       18.75               40.62
# 18                       18.75               40.62
# 17                       18.75               40.62
# 16                       18.75               40.62
# 15                       18.75               40.62
# 14                       18.75               40.62
# 13                       18.75               40.62
# 12                       18.75               40.62

# %% [markdown]
# # Clustering with K-means

# %%
kmeans_model = KMeans(n_clusters=4, random_state=0).fit(s_data2011.drop('Fully_Children12M', axis=1))
predicted2016 = kmeans_model.predict(s_data2016.drop('Fully_Children12M', axis=1))
data2011['cluster'] = kmeans_model.labels_
data2016['cluster'] = predicted2016

# %%
print(Counter(data2011['cluster']))
# Out:
# Counter({1: 17, 0: 17, 2: 16, 3: 14})

# %%
print(Counter(data2016['cluster']))
# Out:
# Counter({1: 17, 0: 17, 2: 16, 3: 14})

# %%
mean_cluster_values2011 = data2011.groupby('cluster').mean().transpose()
mean_cluster_values2011.head()
# Out:
# cluster                                                      0           1  \
# 07Vaccine&LogisticsstockofUpazilaMunCC: Differe...  489.588235  172.058824
# 04Newborn: % of nurse trained on IMCI working a...   56.459477   34.919608
# PENTA2_Children23M                                   97.323529   98.117647
# Fully_Children23M                                    82.629412   84.200000
# PENTA1_Children12M                                   98.788235   99.064706
#
# cluster                                                      2           3
# 07Vaccine&LogisticsstockofUpazilaMunCC: Differe...  126.500000 -769.357143
# 04Newborn: % of nurse trained on IMCI working a...   33.250694   49.642063
# PENTA2_Children23M                                   97.768750   97.021429
# Fully_Children23M                                    84.106250   81.007143
# PENTA1_Children12M                                   99.056250   98.764286

# %%
mean_cluster_values2016 = data2016.groupby('cluster').mean().transpose()
mean_cluster_values2016.head()
# Out:
# cluster                                                        0  \
# 07Vaccine&LogisticsstockofUpazilaMunCC: Differe...  10568.117647
# 04Newborn: % of nurse trained on IMCI working a...     85.164097
# PENTA2_Children23M                                     97.411765
# Fully_Children23M                                      87.205882
# PENTA1_Children12M                                     97.911765
#
# cluster                                                        1  \
# 07Vaccine&LogisticsstockofUpazilaMunCC: Differe...  10232.000000
# 04Newborn: % of nurse trained on IMCI working a...     46.945842
# PENTA2_Children23M                                     97.600000
# Fully_Children23M                                      87.082353
# PENTA1_Children12M                                     97.864706
#
# cluster                                                        2             3
# 07Vaccine&LogisticsstockofUpazilaMunCC: Differe...  10271.562500  56394.214286
# 04Newborn: % of nurse trained on IMCI working a...     48.071121     57.320197
# PENTA2_Children23M                                     96.687500     97.585714
# Fully_Children23M                                      86.568750     88.671429
# PENTA1_Children12M                                     97.225000     98.321429

# %%
percentdiff_cluster_values = ((mean_cluster_values2016 - mean_cluster_values2011) / mean_cluster_values2011) * 100
percentdiff_cluster_values = percentdiff_cluster_values.round(2)

# %%
percentdiff_cluster_values.head()
# Out:
# cluster                                                   0        1        2  \
# 07Vaccine&LogisticsstockofUpazilaMunCC: Differe...  2058.57  5846.80  8019.81
# 04Newborn: % of nurse trained on IMCI working a...    50.84    34.44    44.57
# PENTA2_Children23M                                     0.09    -0.53    -1.11
# Fully_Children23M                                      5.54     3.42     2.93
# PENTA1_Children12M                                    -0.89    -1.21    -1.85
#
# cluster                                                   3
# 07Vaccine&LogisticsstockofUpazilaMunCC: Differe... -7430.04
# 04Newborn: % of nurse trained on IMCI working a...    15.47
# PENTA2_Children23M                                     0.58
# Fully_Children23M                                      9.46
# PENTA1_Children12M                                    -0.45

# %%
percentdiff_cluster_values.sort_values(by=0 ,ascending=False)
# Out:
# cluster                                                   0        1        2  \
# 07Vaccine&LogisticsstockofUpazilaMunCC: Differe...  2058.57  5846.80  8019.81
# imp11subdistr_ngothanaprocessNGO_Percent_Implant      83.78   106.67   100.18
# Imp12DistrNGOMonthThana_Percent_Implant               83.78   106.67   100.18
# 04Newborn: % of nurse trained on IMCI working a...    50.84    34.44    44.57
# TT5_Mother0-11MChildren                               16.14    13.04    32.59
# TT4_Mother0-11MChildren                               12.19    10.03    17.99
# Measles_Children23M                                    6.22     2.45     3.73
# Fully_Children23M                                      5.54     3.42     2.93
# TT3_Mother0-11MChildren                                5.52     4.18     8.89
# prop_married_women_15.45y                              4.82     3.97     3.50
# Measles_Children12M                                    4.78    -0.51     1.62
# Fully_Children12M                                      3.98     0.53     0.92
# dependency_ratio                                       3.12    -1.27     1.11
# imp12distr_monthprocessImp12DistrMonthThana_Per...     2.67    -0.33     1.92
# imp11subdistr_thanaprocessPercent_Injectable           2.66    -0.35     1.93
# rate_under5y_mortality                                 2.56    -3.92   -19.69
# rate_infant_mortality                                  2.37    -1.45   -15.08
# imp11subdistr_ngothanaprocessNGO_Percent_Inject...     1.99    -7.69     8.36
# Imp12DistrNGOMonthThana_Percent_Injectable             1.99    -7.69     8.36
# Imp12DistrNGOMonthThana_CAR                            1.50     3.17     8.96
# imp11subdistr_ngothanaprocessNGO_CAR                   1.50     3.17     8.96
# PENTA3_Children12M                                     1.48     0.15    -0.86
# PENTA3_Children23M                                     1.26     0.04    -0.80
# BCG_Children12M                                        0.79     0.59     0.11
# TT2_Mother0-11MChildren                                0.76     0.11     0.75
# BCG_Children23M                                        0.62     0.55     0.04
# prop_women_15.45y_overwomen                            0.49     1.76     1.04
# 04Newborn: % of functional Radiant warmer              0.45     7.55    40.98
# TT1_Mother0-11MChildren                                0.33     0.25     0.29
# PENTA2_Children12M                                     0.23    -0.61    -1.21
# 03Immunization: BCG vial wastage rate                  0.15    -0.55     0.07
# PENTA2_Children23M                                     0.09    -0.53    -1.11
# OPV2_Children12M                                       0.01    -0.79    -1.28
# OPV2_Children23M                                      -0.13    -0.70    -1.18
# PENTA1_Children12M                                    -0.89    -1.21    -1.85
# OPV1_Children12M                                      -0.89    -1.13    -1.82
# OPV1_Children23M                                      -0.97    -1.13    -1.79
# PENTA1_Children23M                                    -0.97    -1.21    -1.82
# rate_fertility                                        -0.97    -9.60    -2.38
# Imp12DistrNGOMonthThana_Percent_Pill                  -1.13   -10.16   -14.83
# imp11subdistr_ngothanaprocessNGO_Percent_Pill         -1.13   -10.16   -14.83
# rate_death                                            -2.24    -5.87    -7.02
# OPV3_Children12M                                      -2.79    -5.31    -5.35
# OPV3_Children23M                                      -3.32    -5.68    -5.40
# 04Newborn: % of non functional Photo therapy unit     -9.78   -21.25    -6.06
# Imp12DistrNGOMonthThana_Percent_PerFemale            -16.10    11.90    25.37
# imp11subdistr_ngothanaprocessNGO_Percent_PerFemale   -16.10    11.90    25.37
# 04Newborn: % of non-functioning Table Resuscita...   -18.21   -13.11     3.18
# 03Immunization: MR 2 Crude Coverage %                -19.40   -15.04   -17.26
# 02ChildHealth: IMCI Underweight (%)                  -19.83     0.44    -2.90
# 02ChildHealth: IMCI Stunting (%)                     -20.42   -11.80    -4.27
# 02ChildHealth: IMCI Wasting (%)                      -27.97   -17.50   -17.37
# 01MaternalHealth: Proportion of cases with puer...   -34.83     8.78   -34.76
# 01MaternalHealth: Percentage of cases with puer...   -34.83     8.78   -34.76
# distr_GOfemalenormal                                 -61.76   -68.64   -49.85
# prop_registered_births                               -73.65   -51.94   -36.10
#
# cluster                                                   3
# 07Vaccine&LogisticsstockofUpazilaMunCC: Differe... -7430.04
# imp11subdistr_ngothanaprocessNGO_Percent_Implant      80.07
# Imp12DistrNGOMonthThana_Percent_Implant               80.07
# 04Newborn: % of nurse trained on IMCI working a...    15.47
# TT5_Mother0-11MChildren                               34.08
# TT4_Mother0-11MChildren                               20.41
# Measles_Children23M                                    6.71
# Fully_Children23M                                      9.46
# TT3_Mother0-11MChildren                               10.92
# prop_married_women_15.45y                              3.20
# Measles_Children12M                                    6.15
# Fully_Children12M                                      9.34
# dependency_ratio                                      -0.62
# imp12distr_monthprocessImp12DistrMonthThana_Per...    -3.26
# imp11subdistr_thanaprocessPercent_Injectable          -3.26
# rate_under5y_mortality                               -11.98
# rate_infant_mortality                                -14.34
# imp11subdistr_ngothanaprocessNGO_Percent_Inject...     2.32
# Imp12DistrNGOMonthThana_Percent_Injectable             2.32
# Imp12DistrNGOMonthThana_CAR                            6.39
# imp11subdistr_ngothanaprocessNGO_CAR                   6.39
# PENTA3_Children12M                                     3.74
# PENTA3_Children23M                                     3.60
# BCG_Children12M                                        0.61
# TT2_Mother0-11MChildren                                2.61
# BCG_Children23M                                        0.56
# prop_women_15.45y_overwomen                            0.93
# 04Newborn: % of functional Radiant warmer             11.62
# TT1_Mother0-11MChildren                                1.74
# PENTA2_Children12M                                     0.60
# 03Immunization: BCG vial wastage rate                 -1.71
# PENTA2_Children23M                                     0.58
# OPV2_Children12M                                       0.36
# OPV2_Children23M                                       0.35
# PENTA1_Children12M                                    -0.45
# OPV1_Children12M                                      -0.30
# OPV1_Children23M                                      -0.36
# PENTA1_Children23M                                    -0.51
# rate_fertility                                         7.88
# Imp12DistrNGOMonthThana_Percent_Pill                  -8.15
# imp11subdistr_ngothanaprocessNGO_Percent_Pill         -8.15
# rate_death                                            15.41
# OPV3_Children12M                                      -3.23
# OPV3_Children23M                                      -3.41
# 04Newborn: % of non functional Photo therapy unit     -6.18
# Imp12DistrNGOMonthThana_Percent_PerFemale              6.02
# imp11subdistr_ngothanaprocessNGO_Percent_PerFemale     6.02
# 04Newborn: % of non-functioning Table Resuscita...   -12.98
# 03Immunization: MR 2 Crude Coverage %                -11.58
# 02ChildHealth: IMCI Underweight (%)                    4.83
# 02ChildHealth: IMCI Stunting (%)                     -15.26
# 02ChildHealth: IMCI Wasting (%)                      -19.72
# 01MaternalHealth: Proportion of cases with puer...    -0.55
# 01MaternalHealth: Percentage of cases with puer...    -0.55
# distr_GOfemalenormal                                 -49.67
# prop_registered_births                               -68.64

# %%
percentdiff_cluster_values.to_csv(OUT+"clustersummary_fullimmunized.csv")
